# %%
import numpy as np
import matplotlib.pyplot as plt


#model = "kepler_2d"
#model = "harmonic_2d_aniso"
#model = "harmonic_2d_iso"
#model = "threebody_2d"
#model = "KdV_1d"
model = "quantum"

exps = np.load('./saved_checkpoints/{}/seed_experiments/dH_explained.npy'.format(model))
z_dim = exps.shape[0]

plt.plot(np.arange(1,z_dim+1), exps, marker="o")
plt.yscale('log')
plt.xticks([1,2,3,4,5],fontsize=15)
plt.xlabel('index', fontsize=20)
plt.yticks(fontsize=15)
plt.ylabel('Explained Ratio', fontsize=20)
plt.savefig('./saved_checkpoints/{}/seed_experiments/exps.png'.format(model), bbox_inches="tight")
plt.savefig('./saved_checkpoints/{}/seed_experiments/exps.pdf'.format(model), bbox_inches="tight")
