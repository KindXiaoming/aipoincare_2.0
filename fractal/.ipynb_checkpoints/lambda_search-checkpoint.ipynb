# %%
import os
import math
import numpy as np
import pandas as po
import matplotlib.pyplot as plt

import torch
from torch import nn
import torch.optim as optim
from torch.autograd import Variable

from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from tqdm import tqdm

#lambs = np.flip([0.01,0.02,0.05,0.1,0.2,0.5,1.0,2.0,5.0,10.0,20.0,50.0,100.0])
lambs = [0.01,0.02,0.05,0.1,0.2,0.5,1.0,2.0,5.0,10.0,20.0,50.0,100.0]
#lambs = [0.0]
gamma = 1

seed = 1
torch.manual_seed(seed)
np.random.seed(seed)

best_losses = []
best_regs = []

num_pts = 1000
#gamma = 10
#lamb = 0.02

data = po.DataFrame()
data['x'] = 4*np.random.rand(num_pts,)-2
data['p'] = 4*np.random.rand(num_pts,)-2


data['dx/dt'] = data['p']
data['dp/dt'] = -data['x'] - gamma*data['p']


f_z = torch.tensor(data[['dx/dt', 'dp/dt']].values, requires_grad=True).float()
z = torch.tensor(data[['x', 'p']].values, requires_grad=True).float()

class Hnet(nn.Module):
    def __init__(self, z_dim=2, w=400):
        super(Hnet, self).__init__()
        self.z_dim = z_dim
        input_dim = z_dim

        self.h_lin_1 = nn.Linear(input_dim, w) #
        self.h_lin_2 = nn.Linear(w, w) #
        self.h_lin_3 = nn.Linear(w, 1) #
        self.h_relu = nn.ReLU()
        self.h_tanh = nn.Tanh()
        self.h_silu = nn.SiLU()

    def h_z_basic(self, z):
        out = self.h_lin_1(z)
        out = self.h_silu(out)
        out = self.h_lin_2(out)
        out = self.h_silu(out)
        out = self.h_lin_3(out)
        return out

    def h_z(self, z):
        out = self.h_z_basic(z)
        return out

    def forward(self, z, verbose=False):
        bs = z.shape[0]

        h = self.h_z(z)
        dh = torch.autograd.grad(h, z, torch.ones_like(h), create_graph=True, retain_graph=True)[0]
        bs = z.shape[0]
        dh = dh.reshape(bs,-1)
        return dh


def train(nets, f_z, z,
            lr=2e-3,
            epochs = 2000, 
            bs = 100,
            es_delta = 0.000001, 
            epoch_loss = 1e9,
            max_loss_divergence = 0.1,
            weight_decay=0, 
            weight_decay_decay=False,model=None):


    num_model = len(nets)

    z_dim = z.shape[1]
    entropy_dim = np.minimum(num_model, z_dim)
    parameters = list([])
    for i in range(num_model):
        parameters = list(parameters) + list(nets[i].parameters())
    optimizer = optim.Adam(parameters, lr=lr, weight_decay=weight_decay, eps=1e-8)
    #optimizer = optim.SGD(parameters, lr=lr, weight_decay=weight_decay)

    for k in range(num_model):
        nets[k].train()
    losses = []
    losses_fit = []
    losses_reg = []
    lamb_H = 0.00
    lamb_dH = lamb
    loss_pow = 2


    for epoch in tqdm(range(epochs)):
        for i in range((len(f_z) - 1) // bs + 1):
            choices = np.random.choice(len(f_z), bs, replace=False)
            #start_i = i * bs
            #end_i = start_i + bs
            xb = z[choices, :]
            fitloss = 0.
            fitlosses = []
            yb = f_z[choices, :]
            yb = yb.reshape(bs,-1)
            yb_norm = yb/torch.linalg.norm(yb, dim=1, keepdim=True)
            #print("yb", yb_norm.shape)
            for k in range(num_model):
                pred = nets[k](xb)
                #print("pred", pred.shape)
                pred_norm = pred/torch.linalg.norm(pred, dim=1, keepdim=True)
                fit_orth = torch.matmul(yb_norm.unsqueeze(dim=1), pred_norm.unsqueeze(dim=2))
                #print(fit_orth.shape)
                fitloss_ =  torch.mean(torch.abs(fit_orth)**loss_pow)
                #fitloss_each.append(fitloss_.detach().numpy())
                fitloss = fitloss + fitloss_
                fitlosses.append(fitloss_.item())
                H_ = nets[k].h_z(xb)
                dhi = pred_norm

                if k == 0:
                    H = H_
                    dH = dhi.unsqueeze(dim=0)

                else:
                    H = torch.cat((H,H_), dim=1)
                    dH = torch.cat([dH,dhi.unsqueeze(dim=0)])

            fitloss = fitloss/num_model
            # correlation loss
            H = torch.transpose(H,0,1)
            # dH.shape = (bs, num_model, z_dim)
            dH = torch.transpose(dH,0,1)

            # SVD dH
            u, s, v = torch.svd(dH)
            exp_ratio = s**2/torch.sum(s**2, dim=1,keepdim=True)
            exp_av = torch.mean(exp_ratio,dim=0)

            # H regularization
            corr_mat = torch.corrcoef(H)
            if num_model == 1:
                reg_H = torch.tensor(0., dtype=torch.float)
            else:
                reg_H = (torch.sum(corr_mat**loss_pow)-num_model)/(num_model*(num_model-1))

            orth_mat = torch.mean(torch.abs(torch.matmul(dH, torch.transpose(dH,1,2)))**loss_pow, dim=0)
            #print(orth_mat)
            if num_model == 1:
                reg_dH = torch.tensor(0., dtype=torch.float)
            else:
                reg_dH = (torch.sum(orth_mat)-num_model)/(num_model*(num_model-1))

            loss = fitloss + lamb_H*reg_H + lamb_dH*reg_dH

            loss.backward()
            optimizer.step()   

            optimizer.zero_grad()

            losses.append(loss.item())
            losses_fit.append(fitloss.item())
            losses_reg.append(reg_dH.item())
            #print(loss.item(), fitloss.item(), reg_dH.item())

        # Best epoch loss (save best only)
        if (loss<epoch_loss):
            epoch_loss = loss
            epoch_best = epoch
            fit_loss_best = fitloss
            reg_loss_best = reg_dH
            #print("Saving model at epoch {}, current best epoch loss = {}".format(epoch, epoch_loss))
            for k in range(num_model):
                torch.save(nets[k].state_dict(), "./results/"+"{}.pt".format(k))
            np.save("./results/"+"/fit_loss.npy", fitlosses)
            np.save("./results/"+"/dH_explained.npy", exp_av.detach().numpy())

        # Early Stopping
        #if ((loss<es_delta) or abs(epoch_loss-loss)>max_loss_divergence):
        #    break

        # Print loss
        if ((epoch+1)%10==0):
            print("Epoch {}".format(epoch+1))
            print(fitloss.item())
            #print(fitlosses)
            #print(corr_mat)
            #print(reg_H.item())
            #print(orth_mat)
            print(reg_dH.item())
            #print(exp_av)

    plt.plot(losses)
    plt.plot(losses_fit)
    plt.plot(losses_reg)
    plt.yscale('log')

    print("Best epoch = {}".format(epoch_best))
    print("Best loss = {}".format(epoch_loss))
    print("Fit loss = {}".format(fit_loss_best))
    df = po.DataFrame()
    df['losses'] = losses

    return losses, fit_loss_best.detach().numpy(), reg_loss_best.detach().numpy()


num_model = 2
nets = []
for i in range(num_model):
    nets.append(Hnet(z_dim=2, w=400))

for lamb in lambs:
    print("lamb={}".format(lamb))

    loss, fit_best, reg_best = train(nets, f_z, z, lr=1e-3, epochs=100) 
    best_losses.append(fit_best)
    best_regs.append(reg_best)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
#
#   1%|          | 1/100 [00:00<00:13,  7.47it/s]
# lamb=0.01
#   2%|▏         | 2/100 [00:00<00:13,  7.07it/s]
#
#   3%|▎         | 3/100 [00:00<00:14,  6.81it/s]
#
#   4%|▍         | 4/100 [00:00<00:14,  6.52it/s]
#
#   5%|▌         | 5/100 [00:00<00:15,  6.12it/s]
#
#   6%|▌         | 6/100 [00:00<00:16,  5.87it/s]
#
#   7%|▋         | 7/100 [00:01<00:16,  5.77it/s]
#
#   8%|▊         | 8/100 [00:01<00:16,  5.62it/s]
#
#   9%|▉         | 9/100 [00:01<00:17,  5.22it/s]
#
#  10%|█         | 10/100 [00:01<00:16,  5.30it/s]
#
#  11%|█         | 11/100 [00:01<00:16,  5.31it/s]
# Epoch 10
# 0.15888598561286926
# 0.8315331935882568
#  12%|█▏        | 12/100 [00:02<00:15,  5.74it/s]
#
#  13%|█▎        | 13/100 [00:02<00:14,  5.83it/s]
#
#  14%|█▍        | 14/100 [00:02<00:14,  5.87it/s]
#
#  15%|█▌        | 15/100 [00:02<00:15,  5.41it/s]
#
#  16%|█▌        | 16/100 [00:02<00:17,  4.87it/s]
#
#  17%|█▋        | 17/100 [00:03<00:18,  4.49it/s]
#
#  18%|█▊        | 18/100 [00:03<00:19,  4.22it/s]
#
#  19%|█▉        | 19/100 [00:03<00:19,  4.09it/s]
#
#  20%|██        | 20/100 [00:03<00:19,  4.08it/s]
#
#  21%|██        | 21/100 [00:04<00:16,  4.73it/s]
# Epoch 20
# 0.09189356863498688
# 0.935333251953125
#  22%|██▏       | 22/100 [00:04<00:14,  5.35it/s]
#
#  23%|██▎       | 23/100 [00:04<00:13,  5.90it/s]
#
#  24%|██▍       | 24/100 [00:04<00:12,  6.18it/s]
#
#  25%|██▌       | 25/100 [00:04<00:11,  6.56it/s]
#
#  26%|██▌       | 26/100 [00:04<00:10,  6.73it/s]
#
#  27%|██▋       | 27/100 [00:04<00:10,  6.86it/s]
#
#  28%|██▊       | 28/100 [00:05<00:10,  6.84it/s]
#
#  29%|██▉       | 29/100 [00:05<00:10,  6.98it/s]
#
#  30%|███       | 30/100 [00:05<00:09,  7.02it/s]
#
#  31%|███       | 31/100 [00:05<00:09,  7.12it/s]
# Epoch 30
# 0.07656018435955048
# 0.9288527965545654
#  32%|███▏      | 32/100 [00:05<00:09,  7.01it/s]
#
#  33%|███▎      | 33/100 [00:05<00:09,  7.08it/s]
#
#  34%|███▍      | 34/100 [00:05<00:09,  7.17it/s]
#
#  35%|███▌      | 35/100 [00:06<00:08,  7.22it/s]
#
#  36%|███▌      | 36/100 [00:06<00:08,  7.16it/s]
#
#  37%|███▋      | 37/100 [00:06<00:08,  7.29it/s]
#
#  38%|███▊      | 38/100 [00:06<00:08,  7.40it/s]
#
#  39%|███▉      | 39/100 [00:06<00:08,  7.48it/s]
#
#  40%|████      | 40/100 [00:06<00:07,  7.51it/s]
#
#  41%|████      | 41/100 [00:06<00:07,  7.56it/s]
# Epoch 40
# 0.05440860241651535
# 0.9399272203445435
#  42%|████▏     | 42/100 [00:06<00:07,  7.55it/s]
#
#  43%|████▎     | 43/100 [00:07<00:07,  7.52it/s]
#
#  44%|████▍     | 44/100 [00:07<00:07,  7.11it/s]
#
#  45%|████▌     | 45/100 [00:07<00:08,  6.70it/s]
#
#  46%|████▌     | 46/100 [00:07<00:08,  6.38it/s]
#
#  47%|████▋     | 47/100 [00:07<00:07,  6.66it/s]
#
#  48%|████▊     | 48/100 [00:07<00:07,  6.89it/s]
#
#  49%|████▉     | 49/100 [00:07<00:07,  6.93it/s]
#
#  50%|█████     | 50/100 [00:08<00:07,  7.11it/s]
#
#  51%|█████     | 51/100 [00:08<00:06,  7.28it/s]
# Epoch 50
# 0.05161494389176369
# 0.9518716335296631
#  52%|█████▏    | 52/100 [00:08<00:06,  7.22it/s]
#
#  53%|█████▎    | 53/100 [00:08<00:06,  7.27it/s]
#
#  54%|█████▍    | 54/100 [00:08<00:06,  7.35it/s]
#
#  55%|█████▌    | 55/100 [00:08<00:06,  7.37it/s]
#
#  56%|█████▌    | 56/100 [00:08<00:06,  7.30it/s]
#
#  57%|█████▋    | 57/100 [00:09<00:05,  7.38it/s]
#
#  58%|█████▊    | 58/100 [00:09<00:06,  6.97it/s]
#
#  59%|█████▉    | 59/100 [00:09<00:06,  6.01it/s]
#
#  60%|██████    | 60/100 [00:09<00:06,  5.86it/s]
#
#  61%|██████    | 61/100 [00:09<00:06,  6.16it/s]
# Epoch 60
# 0.057371534407138824
# 0.9607319831848145
#  62%|██████▏   | 62/100 [00:09<00:06,  6.20it/s]
#
#  63%|██████▎   | 63/100 [00:10<00:05,  6.18it/s]
#
#  64%|██████▍   | 64/100 [00:10<00:05,  6.48it/s]
#
#  65%|██████▌   | 65/100 [00:10<00:05,  6.68it/s]
#
#  66%|██████▌   | 66/100 [00:10<00:04,  6.87it/s]
#
#  67%|██████▋   | 67/100 [00:10<00:04,  6.87it/s]
#
#  68%|██████▊   | 68/100 [00:10<00:04,  7.17it/s]
#
#  69%|██████▉   | 69/100 [00:10<00:04,  7.42it/s]
#
#  70%|███████   | 70/100 [00:11<00:04,  7.26it/s]
#
#  71%|███████   | 71/100 [00:11<00:03,  7.32it/s]
# Epoch 70
# 0.06325419247150421
# 0.9491297006607056
#  72%|███████▏  | 72/100 [00:11<00:03,  7.18it/s]
#
#  73%|███████▎  | 73/100 [00:11<00:03,  7.17it/s]
#
#  74%|███████▍  | 74/100 [00:11<00:03,  7.20it/s]
#
#  75%|███████▌  | 75/100 [00:11<00:03,  7.09it/s]
#
#  76%|███████▌  | 76/100 [00:11<00:03,  7.22it/s]
#
#  77%|███████▋  | 77/100 [00:12<00:03,  7.27it/s]
#
#  78%|███████▊  | 78/100 [00:12<00:02,  7.34it/s]
#
#  79%|███████▉  | 79/100 [00:12<00:02,  7.21it/s]
#
#  80%|████████  | 80/100 [00:12<00:02,  7.32it/s]
#
#  81%|████████  | 81/100 [00:12<00:02,  7.19it/s]
# Epoch 80
# 0.04577430337667465
# 0.9846401214599609
#  82%|████████▏ | 82/100 [00:12<00:02,  6.84it/s]
#
#  83%|████████▎ | 83/100 [00:12<00:02,  6.47it/s]
#
#  84%|████████▍ | 84/100 [00:13<00:02,  6.52it/s]
#
#  85%|████████▌ | 85/100 [00:13<00:02,  6.79it/s]
#
#  86%|████████▌ | 86/100 [00:13<00:02,  6.91it/s]
#
#  87%|████████▋ | 87/100 [00:13<00:01,  7.07it/s]
#
#  88%|████████▊ | 88/100 [00:13<00:01,  7.22it/s]
#
#  89%|████████▉ | 89/100 [00:13<00:01,  7.35it/s]
#
#  90%|█████████ | 90/100 [00:13<00:01,  7.50it/s]
#
#  91%|█████████ | 91/100 [00:13<00:01,  7.65it/s]
# Epoch 90
# 0.04951903223991394
# 0.9766485691070557
#  92%|█████████▏| 92/100 [00:14<00:01,  7.76it/s]
#
#  93%|█████████▎| 93/100 [00:14<00:00,  7.84it/s]
#
#  94%|█████████▍| 94/100 [00:14<00:00,  7.90it/s]
#
#  95%|█████████▌| 95/100 [00:14<00:00,  7.64it/s]
#
#  96%|█████████▌| 96/100 [00:14<00:00,  7.76it/s]
#
#  97%|█████████▋| 97/100 [00:14<00:00,  7.83it/s]
#
#  98%|█████████▊| 98/100 [00:14<00:00,  7.69it/s]
#
#  99%|█████████▉| 99/100 [00:15<00:00,  7.56it/s]
#
# 100%|██████████| 100/100 [00:15<00:00,  6.61it/s]
#
#
#   0%|          | 0/100 [00:00<?, ?it/s]
#
#   1%|          | 1/100 [00:00<00:13,  7.28it/s]
# Epoch 100
# 0.05535636469721794
# 0.9450137615203857
# Best epoch = 72
# Best loss = 0.0441201776266098
# Fit loss = 0.03438035398721695
# lamb=0.02
#   2%|▏         | 2/100 [00:00<00:13,  7.22it/s]
#
#   3%|▎         | 3/100 [00:00<00:13,  7.15it/s]
#
#   4%|▍         | 4/100 [00:00<00:13,  7.11it/s]
#
#   5%|▌         | 5/100 [00:00<00:12,  7.33it/s]
#
#   6%|▌         | 6/100 [00:00<00:12,  7.49it/s]
#
#   7%|▋         | 7/100 [00:00<00:12,  7.33it/s]
#
#   8%|▊         | 8/100 [00:01<00:12,  7.55it/s]
#
#   9%|▉         | 9/100 [00:01<00:11,  7.70it/s]
#
#  10%|█         | 10/100 [00:01<00:11,  7.77it/s]
#
#  11%|█         | 11/100 [00:01<00:12,  7.36it/s]
# Epoch 10
# 0.07744526863098145
# 0.9458391666412354
#  12%|█▏        | 12/100 [00:01<00:16,  5.44it/s]
#
#  13%|█▎        | 13/100 [00:01<00:15,  5.78it/s]
#
#  14%|█▍        | 14/100 [00:02<00:13,  6.14it/s]
#
#  15%|█▌        | 15/100 [00:02<00:13,  6.50it/s]
#
#  16%|█▌        | 16/100 [00:02<00:12,  6.47it/s]
#
#  17%|█▋        | 17/100 [00:02<00:12,  6.64it/s]
#
#  18%|█▊        | 18/100 [00:02<00:12,  6.82it/s]
#
#  19%|█▉        | 19/100 [00:02<00:11,  6.99it/s]
#
#  20%|██        | 20/100 [00:02<00:11,  6.99it/s]
#
#  21%|██        | 21/100 [00:03<00:11,  7.08it/s]
# Epoch 20
# 0.03589646890759468
# 0.9642224311828613
#  22%|██▏       | 22/100 [00:03<00:10,  7.15it/s]
#
#  23%|██▎       | 23/100 [00:03<00:11,  6.89it/s]
#
#  24%|██▍       | 24/100 [00:03<00:10,  7.05it/s]
#
#  25%|██▌       | 25/100 [00:03<00:10,  7.25it/s]
#
#  26%|██▌       | 26/100 [00:03<00:10,  6.98it/s]
#
#  27%|██▋       | 27/100 [00:03<00:10,  7.00it/s]
#
#  28%|██▊       | 28/100 [00:04<00:09,  7.30it/s]
#
#  29%|██▉       | 29/100 [00:04<00:09,  7.48it/s]
#
#  30%|███       | 30/100 [00:04<00:09,  7.65it/s]
#
#  31%|███       | 31/100 [00:04<00:08,  7.68it/s]
# Epoch 30
# 0.10983671247959137
# 0.9255743026733398
#  32%|███▏      | 32/100 [00:04<00:08,  7.75it/s]
#
#  33%|███▎      | 33/100 [00:04<00:08,  7.86it/s]
#
#  34%|███▍      | 34/100 [00:04<00:08,  7.91it/s]
#
#  35%|███▌      | 35/100 [00:04<00:08,  7.86it/s]
#
#  36%|███▌      | 36/100 [00:05<00:08,  7.93it/s]
#
#  37%|███▋      | 37/100 [00:05<00:07,  7.98it/s]
#
#  38%|███▊      | 38/100 [00:05<00:07,  8.00it/s]
#
#  39%|███▉      | 39/100 [00:05<00:07,  7.91it/s]
#
#  40%|████      | 40/100 [00:05<00:07,  7.96it/s]
#
#  41%|████      | 41/100 [00:05<00:07,  8.01it/s]
# Epoch 40
# 0.041411757469177246
# 0.9668456315994263
#  42%|████▏     | 42/100 [00:05<00:07,  8.05it/s]
#
#  43%|████▎     | 43/100 [00:05<00:07,  7.93it/s]
#
#  44%|████▍     | 44/100 [00:06<00:07,  7.94it/s]
#
#  45%|████▌     | 45/100 [00:06<00:06,  7.99it/s]
#
#  46%|████▌     | 46/100 [00:06<00:06,  8.03it/s]
#
#  47%|████▋     | 47/100 [00:06<00:07,  7.42it/s]
#
#  48%|████▊     | 48/100 [00:06<00:10,  5.07it/s]
#
#  49%|████▉     | 49/100 [00:07<00:13,  3.66it/s]
#
#  50%|█████     | 50/100 [00:07<00:14,  3.36it/s]
# Epoch 50
# 0.038684532046318054
# 0.9763844013214111
#  51%|█████     | 51/100 [00:08<00:16,  2.97it/s]
#
#  52%|█████▏    | 52/100 [00:08<00:16,  2.96it/s]
#
#  53%|█████▎    | 53/100 [00:08<00:14,  3.27it/s]
#
#  54%|█████▍    | 54/100 [00:08<00:14,  3.09it/s]
#
#  55%|█████▌    | 55/100 [00:09<00:14,  3.04it/s]
#
#  56%|█████▌    | 56/100 [00:09<00:15,  2.81it/s]
#
#  57%|█████▋    | 57/100 [00:10<00:16,  2.54it/s]
#
#  58%|█████▊    | 58/100 [00:10<00:15,  2.77it/s]
#
#  59%|█████▉    | 59/100 [00:10<00:14,  2.92it/s]
#
#  60%|██████    | 60/100 [00:11<00:13,  2.89it/s]
# Epoch 60
# 0.03685210645198822
# 0.9703307151794434
#  61%|██████    | 61/100 [00:11<00:13,  2.94it/s]
#
#  62%|██████▏   | 62/100 [00:11<00:13,  2.85it/s]
#
#  63%|██████▎   | 63/100 [00:12<00:12,  2.92it/s]
#
#  64%|██████▍   | 64/100 [00:12<00:11,  3.06it/s]
#
#  65%|██████▌   | 65/100 [00:12<00:10,  3.19it/s]
#
#  66%|██████▌   | 66/100 [00:13<00:12,  2.64it/s]
#
#  67%|██████▋   | 67/100 [00:13<00:12,  2.61it/s]
#
#  68%|██████▊   | 68/100 [00:13<00:11,  2.72it/s]
#
#  69%|██████▉   | 69/100 [00:14<00:10,  2.88it/s]
#
#  70%|███████   | 70/100 [00:14<00:09,  3.19it/s]
# Epoch 70
# 0.03866797685623169
# 0.9573959112167358
#  71%|███████   | 71/100 [00:14<00:09,  3.20it/s]
#
#  72%|███████▏  | 72/100 [00:15<00:09,  2.99it/s]
#
#  73%|███████▎  | 73/100 [00:15<00:09,  2.85it/s]
#
#  74%|███████▍  | 74/100 [00:15<00:08,  2.90it/s]
#
#  75%|███████▌  | 75/100 [00:16<00:08,  2.95it/s]
#
#  76%|███████▌  | 76/100 [00:16<00:07,  3.17it/s]
#
#  77%|███████▋  | 77/100 [00:16<00:07,  3.11it/s]
#
#  78%|███████▊  | 78/100 [00:17<00:07,  3.08it/s]
#
#  79%|███████▉  | 79/100 [00:17<00:07,  2.96it/s]
#
#  80%|████████  | 80/100 [00:17<00:06,  2.96it/s]
# Epoch 80
# 0.036850541830062866
# 0.9600450992584229
#  81%|████████  | 81/100 [00:18<00:06,  2.95it/s]
#
#  82%|████████▏ | 82/100 [00:18<00:05,  3.20it/s]
#
#  83%|████████▎ | 83/100 [00:18<00:05,  3.19it/s]
#
#  84%|████████▍ | 84/100 [00:19<00:05,  2.94it/s]
#
#  85%|████████▌ | 85/100 [00:19<00:05,  2.96it/s]
#
#  86%|████████▌ | 86/100 [00:19<00:04,  3.01it/s]
#
#  87%|████████▋ | 87/100 [00:20<00:04,  3.10it/s]
#
#  88%|████████▊ | 88/100 [00:20<00:03,  3.05it/s]
#
#  89%|████████▉ | 89/100 [00:20<00:03,  3.14it/s]
#
#  90%|█████████ | 90/100 [00:21<00:03,  2.96it/s]
# Epoch 90
# 0.026444580405950546
# 0.9556710720062256
#  91%|█████████ | 91/100 [00:21<00:02,  3.02it/s]
#
#  92%|█████████▏| 92/100 [00:21<00:02,  2.93it/s]
#
#  93%|█████████▎| 93/100 [00:22<00:02,  2.98it/s]
#
#  94%|█████████▍| 94/100 [00:22<00:02,  3.00it/s]
#
#  95%|█████████▌| 95/100 [00:22<00:01,  3.04it/s]
#
#  96%|█████████▌| 96/100 [00:23<00:01,  2.98it/s]
#
#  97%|█████████▋| 97/100 [00:23<00:01,  2.94it/s]
#
#  98%|█████████▊| 98/100 [00:23<00:00,  2.85it/s]
#
#  99%|█████████▉| 99/100 [00:24<00:00,  2.93it/s]
#
# 100%|██████████| 100/100 [00:24<00:00,  4.08it/s]
#
#
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 100
# 0.07729090750217438
# 0.969399094581604
# Best epoch = 85
# Best loss = 0.030742555856704712
# Fit loss = 0.01104066800326109
# lamb=0.05
#   1%|          | 1/100 [00:00<00:35,  2.75it/s]
#
#   2%|▏         | 2/100 [00:00<00:35,  2.79it/s]
#
#   3%|▎         | 3/100 [00:01<00:36,  2.69it/s]
#
#   4%|▍         | 4/100 [00:01<00:34,  2.77it/s]
#
#   5%|▌         | 5/100 [00:01<00:34,  2.78it/s]
#
#   6%|▌         | 6/100 [00:02<00:29,  3.17it/s]
#
#   7%|▋         | 7/100 [00:02<00:31,  3.00it/s]
#
#   8%|▊         | 8/100 [00:02<00:30,  2.98it/s]
#
#   9%|▉         | 9/100 [00:03<00:29,  3.08it/s]
#
#  10%|█         | 10/100 [00:03<00:28,  3.19it/s]
# Epoch 10
# 0.0249994695186615
# 0.9537912607192993
#  11%|█         | 11/100 [00:03<00:27,  3.19it/s]
#
#  12%|█▏        | 12/100 [00:03<00:26,  3.33it/s]
#
#  13%|█▎        | 13/100 [00:04<00:24,  3.50it/s]
#
#  14%|█▍        | 14/100 [00:04<00:25,  3.42it/s]
#
#  15%|█▌        | 15/100 [00:04<00:24,  3.46it/s]
#
#  16%|█▌        | 16/100 [00:05<00:24,  3.39it/s]
#
#  17%|█▋        | 17/100 [00:05<00:24,  3.43it/s]
#
#  18%|█▊        | 18/100 [00:05<00:23,  3.47it/s]
#
#  19%|█▉        | 19/100 [00:05<00:22,  3.58it/s]
#
#  20%|██        | 20/100 [00:06<00:21,  3.76it/s]
# Epoch 20
# 0.030126668512821198
# 0.9678463935852051
#  21%|██        | 21/100 [00:06<00:21,  3.64it/s]
#
#  22%|██▏       | 22/100 [00:06<00:21,  3.58it/s]
#
#  23%|██▎       | 23/100 [00:07<00:22,  3.42it/s]
#
#  24%|██▍       | 24/100 [00:07<00:22,  3.39it/s]
#
#  25%|██▌       | 25/100 [00:07<00:23,  3.15it/s]
#
#  26%|██▌       | 26/100 [00:07<00:21,  3.41it/s]
#
#  27%|██▋       | 27/100 [00:08<00:21,  3.32it/s]
#
#  28%|██▊       | 28/100 [00:08<00:23,  3.08it/s]
#
#  29%|██▉       | 29/100 [00:08<00:22,  3.14it/s]
#
#  30%|███       | 30/100 [00:09<00:22,  3.16it/s]
# Epoch 30
# 0.02940201200544834
# 0.9849392175674438
#  31%|███       | 31/100 [00:09<00:22,  3.08it/s]
#
#  32%|███▏      | 32/100 [00:09<00:21,  3.23it/s]
#
#  33%|███▎      | 33/100 [00:10<00:19,  3.43it/s]
#
#  34%|███▍      | 34/100 [00:10<00:20,  3.28it/s]
#
#  35%|███▌      | 35/100 [00:10<00:20,  3.23it/s]
#
#  36%|███▌      | 36/100 [00:11<00:19,  3.25it/s]
#
#  37%|███▋      | 37/100 [00:11<00:20,  3.10it/s]
#
#  38%|███▊      | 38/100 [00:11<00:19,  3.11it/s]
#
#  39%|███▉      | 39/100 [00:11<00:18,  3.34it/s]
#
#  40%|████      | 40/100 [00:12<00:17,  3.50it/s]
# Epoch 40
# 0.04897905886173248
# 0.951117753982544
#  41%|████      | 41/100 [00:12<00:17,  3.46it/s]
#
#  42%|████▏     | 42/100 [00:12<00:16,  3.47it/s]
#
#  43%|████▎     | 43/100 [00:13<00:16,  3.48it/s]
#
#  44%|████▍     | 44/100 [00:13<00:16,  3.33it/s]
#
#  45%|████▌     | 45/100 [00:13<00:17,  3.20it/s]
#
#  46%|████▌     | 46/100 [00:14<00:15,  3.42it/s]
#
#  47%|████▋     | 47/100 [00:14<00:16,  3.18it/s]
#
#  48%|████▊     | 48/100 [00:14<00:17,  2.99it/s]
#
#  49%|████▉     | 49/100 [00:15<00:17,  2.85it/s]
#
#  50%|█████     | 50/100 [00:15<00:17,  2.79it/s]
# Epoch 50
# 0.025658056139945984
# 0.9697657823562622
#  51%|█████     | 51/100 [00:15<00:17,  2.85it/s]
#
#  52%|█████▏    | 52/100 [00:16<00:15,  3.12it/s]
#
#  53%|█████▎    | 53/100 [00:16<00:15,  2.95it/s]
#
#  54%|█████▍    | 54/100 [00:16<00:16,  2.87it/s]
#
#  55%|█████▌    | 55/100 [00:17<00:16,  2.81it/s]
#
#  56%|█████▌    | 56/100 [00:17<00:16,  2.73it/s]
#
#  57%|█████▋    | 57/100 [00:17<00:15,  2.81it/s]
#
#  58%|█████▊    | 58/100 [00:18<00:14,  2.86it/s]
#
#  59%|█████▉    | 59/100 [00:18<00:15,  2.67it/s]
#
#  60%|██████    | 60/100 [00:19<00:16,  2.49it/s]
# Epoch 60
# 0.02348906546831131
# 0.9789257049560547
#  61%|██████    | 61/100 [00:19<00:15,  2.46it/s]
#
#  62%|██████▏   | 62/100 [00:19<00:13,  2.73it/s]
#
#  63%|██████▎   | 63/100 [00:20<00:13,  2.80it/s]
#
#  64%|██████▍   | 64/100 [00:20<00:13,  2.72it/s]
#
#  65%|██████▌   | 65/100 [00:21<00:13,  2.62it/s]
#
#  66%|██████▌   | 66/100 [00:21<00:12,  2.73it/s]
#
#  67%|██████▋   | 67/100 [00:21<00:12,  2.72it/s]
#
#  68%|██████▊   | 68/100 [00:21<00:10,  3.03it/s]
#
#  69%|██████▉   | 69/100 [00:22<00:10,  2.96it/s]
#
#  70%|███████   | 70/100 [00:22<00:11,  2.69it/s]
# Epoch 70
# 0.014830108731985092
# 0.9768071174621582
#  71%|███████   | 71/100 [00:23<00:10,  2.66it/s]
#
#  72%|███████▏  | 72/100 [00:23<00:10,  2.63it/s]
#
#  73%|███████▎  | 73/100 [00:23<00:09,  2.71it/s]
#
#  74%|███████▍  | 74/100 [00:24<00:08,  2.92it/s]
#
#  75%|███████▌  | 75/100 [00:24<00:08,  2.82it/s]
#
#  76%|███████▌  | 76/100 [00:24<00:08,  2.68it/s]
#
#  77%|███████▋  | 77/100 [00:25<00:08,  2.71it/s]
#
#  78%|███████▊  | 78/100 [00:25<00:08,  2.69it/s]
#
#  79%|███████▉  | 79/100 [00:25<00:07,  2.99it/s]
#
#  80%|████████  | 80/100 [00:26<00:06,  3.05it/s]
# Epoch 80
# 0.019413184374570847
# 0.9719928503036499
#  81%|████████  | 81/100 [00:26<00:06,  2.94it/s]
#
#  82%|████████▏ | 82/100 [00:27<00:06,  2.77it/s]
#
#  83%|████████▎ | 83/100 [00:27<00:06,  2.82it/s]
#
#  84%|████████▍ | 84/100 [00:27<00:05,  2.86it/s]
#
#  85%|████████▌ | 85/100 [00:27<00:04,  3.10it/s]
#
#  86%|████████▌ | 86/100 [00:28<00:04,  3.17it/s]
#
#  87%|████████▋ | 87/100 [00:28<00:04,  3.16it/s]
#
#  88%|████████▊ | 88/100 [00:28<00:03,  3.27it/s]
#
#  89%|████████▉ | 89/100 [00:29<00:03,  3.34it/s]
#
#  90%|█████████ | 90/100 [00:29<00:03,  3.30it/s]
# Epoch 90
# 0.04100498557090759
# 0.9766604900360107
#  91%|█████████ | 91/100 [00:29<00:02,  3.33it/s]
#
#  92%|█████████▏| 92/100 [00:30<00:02,  3.51it/s]
#
#  93%|█████████▎| 93/100 [00:30<00:02,  3.38it/s]
#
#  94%|█████████▍| 94/100 [00:30<00:01,  3.10it/s]
#
#  95%|█████████▌| 95/100 [00:31<00:01,  3.04it/s]
#
#  96%|█████████▌| 96/100 [00:31<00:01,  3.09it/s]
#
#  97%|█████████▋| 97/100 [00:31<00:00,  3.25it/s]
#
#  98%|█████████▊| 98/100 [00:31<00:00,  3.38it/s]
#
#  99%|█████████▉| 99/100 [00:32<00:00,  3.57it/s]
#
# 100%|██████████| 100/100 [00:32<00:00,  3.08it/s]
#
#
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 100
# 0.03190508484840393
# 0.9711806774139404
# Best epoch = 58
# Best loss = 0.05956083536148071
# Fit loss = 0.010414947755634785
# lamb=0.1
#   1%|          | 1/100 [00:00<00:37,  2.61it/s]
#
#   2%|▏         | 2/100 [00:00<00:37,  2.63it/s]
#
#   3%|▎         | 3/100 [00:01<00:36,  2.65it/s]
#
#   4%|▍         | 4/100 [00:01<00:33,  2.91it/s]
#
#   5%|▌         | 5/100 [00:01<00:30,  3.12it/s]
#
#   6%|▌         | 6/100 [00:02<00:31,  2.94it/s]
#
#   7%|▋         | 7/100 [00:02<00:34,  2.71it/s]
#
#   8%|▊         | 8/100 [00:02<00:34,  2.69it/s]
#
#   9%|▉         | 9/100 [00:03<00:33,  2.68it/s]
#
#  10%|█         | 10/100 [00:03<00:29,  3.02it/s]
# Epoch 10
# 0.019330911338329315
# 0.9723818302154541
#  11%|█         | 11/100 [00:03<00:31,  2.85it/s]
#
#  12%|█▏        | 12/100 [00:04<00:31,  2.79it/s]
#
#  13%|█▎        | 13/100 [00:04<00:30,  2.90it/s]
#
#  14%|█▍        | 14/100 [00:04<00:28,  2.99it/s]
#
#  15%|█▌        | 15/100 [00:05<00:28,  3.04it/s]
#
#  16%|█▌        | 16/100 [00:05<00:25,  3.31it/s]
#
#  17%|█▋        | 17/100 [00:05<00:24,  3.37it/s]
#
#  18%|█▊        | 18/100 [00:06<00:26,  3.10it/s]
#
#  19%|█▉        | 19/100 [00:06<00:27,  2.93it/s]
#
#  20%|██        | 20/100 [00:06<00:27,  2.91it/s]
# Epoch 20
# 0.024548370391130447
# 0.9598325490951538
#  21%|██        | 21/100 [00:07<00:26,  2.94it/s]
#
#  22%|██▏       | 22/100 [00:07<00:24,  3.21it/s]
#
#  23%|██▎       | 23/100 [00:07<00:23,  3.31it/s]
#
#  24%|██▍       | 24/100 [00:08<00:25,  2.97it/s]
#
#  25%|██▌       | 25/100 [00:08<00:26,  2.86it/s]
#
#  26%|██▌       | 26/100 [00:08<00:26,  2.74it/s]
#
#  27%|██▋       | 27/100 [00:09<00:26,  2.72it/s]
#
#  28%|██▊       | 28/100 [00:09<00:23,  3.05it/s]
#
#  29%|██▉       | 29/100 [00:09<00:23,  3.01it/s]
#
#  30%|███       | 30/100 [00:10<00:24,  2.82it/s]
# Epoch 30
# 0.030106164515018463
# 0.9577405452728271
#  31%|███       | 31/100 [00:10<00:24,  2.77it/s]
#
#  32%|███▏      | 32/100 [00:10<00:24,  2.74it/s]
#
#  33%|███▎      | 33/100 [00:11<00:23,  2.84it/s]
#
#  34%|███▍      | 34/100 [00:11<00:20,  3.20it/s]
#
#  35%|███▌      | 35/100 [00:11<00:22,  2.94it/s]
#
#  36%|███▌      | 36/100 [00:12<00:22,  2.83it/s]
#
#  37%|███▋      | 37/100 [00:12<00:22,  2.78it/s]
#
#  38%|███▊      | 38/100 [00:13<00:22,  2.74it/s]
#
#  39%|███▉      | 39/100 [00:13<00:20,  2.91it/s]
#
#  40%|████      | 40/100 [00:13<00:18,  3.16it/s]
# Epoch 40
# 0.015148594975471497
# 0.9791791439056396
#  41%|████      | 41/100 [00:14<00:20,  2.92it/s]
#
#  42%|████▏     | 42/100 [00:14<00:20,  2.85it/s]
#
#  43%|████▎     | 43/100 [00:14<00:20,  2.82it/s]
#
#  44%|████▍     | 44/100 [00:15<00:19,  2.82it/s]
#
#  45%|████▌     | 45/100 [00:15<00:18,  2.99it/s]
#
#  46%|████▌     | 46/100 [00:15<00:17,  3.15it/s]
#
#  47%|████▋     | 47/100 [00:16<00:17,  2.99it/s]
#
#  48%|████▊     | 48/100 [00:16<00:19,  2.69it/s]
#
#  49%|████▉     | 49/100 [00:16<00:19,  2.65it/s]
#
#  50%|█████     | 50/100 [00:17<00:20,  2.46it/s]
# Epoch 50
# 0.023397505283355713
# 0.9708786010742188
#  51%|█████     | 51/100 [00:17<00:20,  2.38it/s]
#
#  52%|█████▏    | 52/100 [00:18<00:20,  2.33it/s]
#
#  53%|█████▎    | 53/100 [00:18<00:18,  2.58it/s]
#
#  54%|█████▍    | 54/100 [00:18<00:16,  2.83it/s]
#
#  55%|█████▌    | 55/100 [00:19<00:15,  2.86it/s]
#
#  56%|█████▌    | 56/100 [00:19<00:14,  3.14it/s]
#
#  57%|█████▋    | 57/100 [00:19<00:13,  3.16it/s]
#
#  58%|█████▊    | 58/100 [00:20<00:14,  2.88it/s]
#
#  59%|█████▉    | 59/100 [00:20<00:15,  2.73it/s]
#
#  60%|██████    | 60/100 [00:21<00:15,  2.54it/s]
# Epoch 60
# 0.04641231894493103
# 0.9330095052719116
#  61%|██████    | 61/100 [00:21<00:14,  2.66it/s]
#
#  62%|██████▏   | 62/100 [00:21<00:12,  2.99it/s]
#
#  63%|██████▎   | 63/100 [00:21<00:12,  2.86it/s]
#
#  64%|██████▍   | 64/100 [00:22<00:12,  2.90it/s]
#
#  65%|██████▌   | 65/100 [00:22<00:13,  2.62it/s]
#
#  66%|██████▌   | 66/100 [00:23<00:12,  2.69it/s]
#
#  67%|██████▋   | 67/100 [00:23<00:11,  2.93it/s]
#
#  68%|██████▊   | 68/100 [00:23<00:10,  3.09it/s]
#
#  69%|██████▉   | 69/100 [00:24<00:10,  2.84it/s]
#
#  70%|███████   | 70/100 [00:24<00:10,  2.81it/s]
# Epoch 70
# 0.0584433376789093
# 0.9654699563980103
#  71%|███████   | 71/100 [00:24<00:10,  2.88it/s]
#
#  72%|███████▏  | 72/100 [00:25<00:09,  2.97it/s]
#
#  73%|███████▎  | 73/100 [00:25<00:08,  3.16it/s]
#
#  74%|███████▍  | 74/100 [00:25<00:08,  3.15it/s]
#
#  75%|███████▌  | 75/100 [00:26<00:08,  2.92it/s]
#
#  76%|███████▌  | 76/100 [00:26<00:08,  2.74it/s]
#
#  77%|███████▋  | 77/100 [00:26<00:08,  2.74it/s]
#
#  78%|███████▊  | 78/100 [00:27<00:08,  2.68it/s]
#
#  79%|███████▉  | 79/100 [00:27<00:07,  2.72it/s]
#
#  80%|████████  | 80/100 [00:28<00:08,  2.45it/s]
# Epoch 80
# 0.04533185809850693
# 0.9484026432037354
#  81%|████████  | 81/100 [00:28<00:07,  2.51it/s]
#
#  82%|████████▏ | 82/100 [00:28<00:06,  2.61it/s]
#
#  83%|████████▎ | 83/100 [00:29<00:06,  2.75it/s]
#
#  84%|████████▍ | 84/100 [00:29<00:05,  3.04it/s]
#
#  85%|████████▌ | 85/100 [00:29<00:04,  3.05it/s]
#
#  86%|████████▌ | 86/100 [00:30<00:04,  3.04it/s]
#
#  87%|████████▋ | 87/100 [00:30<00:04,  2.89it/s]
#
#  88%|████████▊ | 88/100 [00:30<00:04,  2.86it/s]
#
#  89%|████████▉ | 89/100 [00:31<00:04,  2.40it/s]
#
#  90%|█████████ | 90/100 [00:31<00:04,  2.49it/s]
# Epoch 90
# 0.025460783392190933
# 0.9735110998153687
#  91%|█████████ | 91/100 [00:32<00:03,  2.63it/s]
#
#  92%|█████████▏| 92/100 [00:32<00:03,  2.57it/s]
#
#  93%|█████████▎| 93/100 [00:32<00:02,  2.72it/s]
#
#  94%|█████████▍| 94/100 [00:33<00:02,  2.79it/s]
#
#  95%|█████████▌| 95/100 [00:33<00:01,  3.00it/s]
#
#  96%|█████████▌| 96/100 [00:33<00:01,  2.77it/s]
#
#  97%|█████████▋| 97/100 [00:34<00:01,  2.58it/s]
#
#  98%|█████████▊| 98/100 [00:34<00:00,  2.61it/s]
#
#  99%|█████████▉| 99/100 [00:34<00:00,  2.74it/s]
#
# 100%|██████████| 100/100 [00:35<00:00,  2.83it/s]
#
#
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 100
# 0.018019607290625572
# 0.968172550201416
# Best epoch = 57
# Best loss = 0.10622552782297134
# Fit loss = 0.007180436514317989
# lamb=0.2
#   1%|          | 1/100 [00:00<00:40,  2.43it/s]
#
#   2%|▏         | 2/100 [00:00<00:40,  2.43it/s]
#
#   3%|▎         | 3/100 [00:01<00:36,  2.62it/s]
#
#   4%|▍         | 4/100 [00:01<00:36,  2.61it/s]
#
#   5%|▌         | 5/100 [00:01<00:33,  2.82it/s]
#
#   6%|▌         | 6/100 [00:02<00:34,  2.72it/s]
#
#   7%|▋         | 7/100 [00:02<00:31,  2.96it/s]
#
#   8%|▊         | 8/100 [00:02<00:34,  2.66it/s]
#
#   9%|▉         | 9/100 [00:03<00:36,  2.51it/s]
#
#  10%|█         | 10/100 [00:03<00:35,  2.55it/s]
# Epoch 10
# 0.04474286735057831
# 0.9235758781433105
#  11%|█         | 11/100 [00:04<00:33,  2.64it/s]
#
#  12%|█▏        | 12/100 [00:04<00:30,  2.85it/s]
#
#  13%|█▎        | 13/100 [00:04<00:29,  2.98it/s]
#
#  14%|█▍        | 14/100 [00:05<00:27,  3.08it/s]
#
#  15%|█▌        | 15/100 [00:05<00:25,  3.27it/s]
#
#  16%|█▌        | 16/100 [00:05<00:26,  3.23it/s]
#
#  17%|█▋        | 17/100 [00:05<00:25,  3.30it/s]
#
#  18%|█▊        | 18/100 [00:06<00:27,  2.97it/s]
#
#  19%|█▉        | 19/100 [00:06<00:28,  2.80it/s]
#
#  20%|██        | 20/100 [00:07<00:28,  2.80it/s]
# Epoch 20
# 0.03154514729976654
# 0.9333367347717285
#  21%|██        | 21/100 [00:07<00:28,  2.81it/s]
#
#  22%|██▏       | 22/100 [00:07<00:27,  2.88it/s]
#
#  23%|██▎       | 23/100 [00:08<00:26,  2.87it/s]
#
#  24%|██▍       | 24/100 [00:08<00:23,  3.19it/s]
#
#  25%|██▌       | 25/100 [00:08<00:23,  3.20it/s]
#
#  26%|██▌       | 26/100 [00:08<00:23,  3.12it/s]
#
#  27%|██▋       | 27/100 [00:09<00:23,  3.07it/s]
#
#  28%|██▊       | 28/100 [00:09<00:22,  3.15it/s]
#
#  29%|██▉       | 29/100 [00:09<00:22,  3.18it/s]
#
#  30%|███       | 30/100 [00:10<00:19,  3.50it/s]
# Epoch 30
# 0.044098641723394394
# 0.9453233480453491
#  31%|███       | 31/100 [00:10<00:23,  2.99it/s]
#
#  32%|███▏      | 32/100 [00:10<00:24,  2.76it/s]
#
#  33%|███▎      | 33/100 [00:11<00:24,  2.73it/s]
#
#  34%|███▍      | 34/100 [00:11<00:24,  2.74it/s]
#
#  35%|███▌      | 35/100 [00:12<00:24,  2.70it/s]
#
#  36%|███▌      | 36/100 [00:12<00:24,  2.66it/s]
#
#  37%|███▋      | 37/100 [00:12<00:22,  2.78it/s]
#
#  38%|███▊      | 38/100 [00:13<00:22,  2.81it/s]
#
#  39%|███▉      | 39/100 [00:13<00:21,  2.80it/s]
#
#  40%|████      | 40/100 [00:13<00:21,  2.81it/s]
# Epoch 40
# 0.04337184131145477
# 0.9352657794952393
#  41%|████      | 41/100 [00:14<00:20,  2.91it/s]
#
#  42%|████▏     | 42/100 [00:14<00:21,  2.75it/s]
#
#  43%|████▎     | 43/100 [00:14<00:20,  2.73it/s]
#
#  44%|████▍     | 44/100 [00:15<00:19,  2.80it/s]
#
#  45%|████▌     | 45/100 [00:15<00:19,  2.80it/s]
#
#  46%|████▌     | 46/100 [00:15<00:18,  2.92it/s]
#
#  47%|████▋     | 47/100 [00:16<00:17,  3.12it/s]
#
#  48%|████▊     | 48/100 [00:16<00:19,  2.70it/s]
#
#  49%|████▉     | 49/100 [00:17<00:21,  2.41it/s]
#
#  50%|█████     | 50/100 [00:17<00:20,  2.44it/s]
# Epoch 50
# 0.02484835684299469
# 0.9568963050842285
#  51%|█████     | 51/100 [00:18<00:19,  2.52it/s]
#
#  52%|█████▏    | 52/100 [00:18<00:17,  2.75it/s]
#
#  53%|█████▎    | 53/100 [00:18<00:16,  2.90it/s]
#
#  54%|█████▍    | 54/100 [00:18<00:15,  2.90it/s]
#
#  55%|█████▌    | 55/100 [00:19<00:14,  3.04it/s]
#
#  56%|█████▌    | 56/100 [00:19<00:14,  3.10it/s]
#
#  57%|█████▋    | 57/100 [00:19<00:14,  3.00it/s]
#
#  58%|█████▊    | 58/100 [00:20<00:12,  3.32it/s]
#
#  59%|█████▉    | 59/100 [00:20<00:12,  3.23it/s]
#
#  60%|██████    | 60/100 [00:20<00:13,  2.92it/s]
# Epoch 60
# 0.03608560562133789
# 0.9472404718399048
#  61%|██████    | 61/100 [00:21<00:13,  2.98it/s]
#
#  62%|██████▏   | 62/100 [00:21<00:12,  3.12it/s]
#
#  63%|██████▎   | 63/100 [00:21<00:11,  3.17it/s]
#
#  64%|██████▍   | 64/100 [00:22<00:11,  3.15it/s]
#
#  65%|██████▌   | 65/100 [00:22<00:10,  3.19it/s]
#
#  66%|██████▌   | 66/100 [00:22<00:10,  3.09it/s]
#
#  67%|██████▋   | 67/100 [00:23<00:10,  3.11it/s]
#
#  68%|██████▊   | 68/100 [00:23<00:10,  3.18it/s]
#
#  69%|██████▉   | 69/100 [00:23<00:09,  3.27it/s]
#
#  70%|███████   | 70/100 [00:24<00:09,  3.19it/s]
# Epoch 70
# 0.04256506636738777
# 0.9185630083084106
#  71%|███████   | 71/100 [00:24<00:09,  3.06it/s]
#
#  72%|███████▏  | 72/100 [00:24<00:09,  2.97it/s]
#
#  73%|███████▎  | 73/100 [00:25<00:09,  2.94it/s]
#
#  74%|███████▍  | 74/100 [00:25<00:08,  3.00it/s]
#
#  75%|███████▌  | 75/100 [00:25<00:08,  3.07it/s]
#
#  76%|███████▌  | 76/100 [00:26<00:08,  2.77it/s]
#
#  77%|███████▋  | 77/100 [00:26<00:09,  2.40it/s]
#
#  78%|███████▊  | 78/100 [00:27<00:09,  2.44it/s]
#
#  79%|███████▉  | 79/100 [00:27<00:08,  2.51it/s]
#
#  80%|████████  | 80/100 [00:27<00:07,  2.78it/s]
# Epoch 80
# 0.021235445514321327
# 0.9546613693237305
#  81%|████████  | 81/100 [00:28<00:06,  2.97it/s]
#
#  82%|████████▏ | 82/100 [00:28<00:05,  3.15it/s]
#
#  83%|████████▎ | 83/100 [00:28<00:04,  3.46it/s]
#
#  84%|████████▍ | 84/100 [00:28<00:04,  3.58it/s]
#
#  85%|████████▌ | 85/100 [00:29<00:04,  3.40it/s]
#
#  86%|████████▌ | 86/100 [00:29<00:04,  3.39it/s]
#
#  87%|████████▋ | 87/100 [00:29<00:03,  3.50it/s]
#
#  88%|████████▊ | 88/100 [00:29<00:03,  3.53it/s]
#
#  89%|████████▉ | 89/100 [00:30<00:03,  3.54it/s]
#
#  90%|█████████ | 90/100 [00:30<00:02,  3.71it/s]
# Epoch 90
# 0.025114882737398148
# 0.9744434356689453
#  91%|█████████ | 91/100 [00:30<00:02,  3.73it/s]
#
#  92%|█████████▏| 92/100 [00:30<00:02,  3.70it/s]
#
#  93%|█████████▎| 93/100 [00:31<00:01,  3.61it/s]
#
#  94%|█████████▍| 94/100 [00:31<00:01,  3.62it/s]
#
#  95%|█████████▌| 95/100 [00:31<00:01,  3.58it/s]
#
#  96%|█████████▌| 96/100 [00:32<00:01,  3.44it/s]
#
#  97%|█████████▋| 97/100 [00:32<00:00,  3.51it/s]
#
#  98%|█████████▊| 98/100 [00:32<00:00,  3.67it/s]
#
#  99%|█████████▉| 99/100 [00:32<00:00,  3.55it/s]
#
# 100%|██████████| 100/100 [00:33<00:00,  2.97it/s]
#
#
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 100
# 0.022238994017243385
# 0.9516713619232178
# Best epoch = 52
# Best loss = 0.20353586971759796
# Fit loss = 0.00811226200312376
# lamb=0.5
#   1%|          | 1/100 [00:00<01:07,  1.47it/s]
#
#   2%|▏         | 2/100 [00:01<01:01,  1.60it/s]
#
#   3%|▎         | 3/100 [00:01<00:59,  1.64it/s]
#
#   4%|▍         | 4/100 [00:02<00:58,  1.65it/s]
#
#   5%|▌         | 5/100 [00:03<00:58,  1.61it/s]
#
#   6%|▌         | 6/100 [00:03<00:55,  1.69it/s]
#
#   7%|▋         | 7/100 [00:03<00:49,  1.87it/s]
#
#   8%|▊         | 8/100 [00:04<00:43,  2.10it/s]
#
#   9%|▉         | 9/100 [00:04<00:40,  2.22it/s]
#
#  10%|█         | 10/100 [00:04<00:34,  2.60it/s]
# Epoch 10
# 0.23747536540031433
# 0.3044804334640503
#  11%|█         | 11/100 [00:05<00:33,  2.67it/s]
#
#  12%|█▏        | 12/100 [00:05<00:32,  2.73it/s]
#
#  13%|█▎        | 13/100 [00:05<00:31,  2.73it/s]
#
#  14%|█▍        | 14/100 [00:06<00:31,  2.75it/s]
#
#  15%|█▌        | 15/100 [00:06<00:30,  2.79it/s]
#
#  16%|█▌        | 16/100 [00:06<00:26,  3.17it/s]
#
#  17%|█▋        | 17/100 [00:07<00:26,  3.13it/s]
#
#  18%|█▊        | 18/100 [00:07<00:27,  3.02it/s]
#
#  19%|█▉        | 19/100 [00:07<00:26,  3.07it/s]
#
#  20%|██        | 20/100 [00:08<00:25,  3.08it/s]
# Epoch 20
# 0.2590671181678772
# 0.2887359857559204
#  21%|██        | 21/100 [00:08<00:27,  2.88it/s]
#
#  22%|██▏       | 22/100 [00:08<00:24,  3.13it/s]
#
#  23%|██▎       | 23/100 [00:09<00:24,  3.18it/s]
#
#  24%|██▍       | 24/100 [00:09<00:25,  2.96it/s]
#
#  25%|██▌       | 25/100 [00:09<00:25,  2.91it/s]
#
#  26%|██▌       | 26/100 [00:10<00:25,  2.88it/s]
#
#  27%|██▋       | 27/100 [00:10<00:25,  2.87it/s]
#
#  28%|██▊       | 28/100 [00:10<00:22,  3.16it/s]
#
#  29%|██▉       | 29/100 [00:11<00:22,  3.21it/s]
#
#  30%|███       | 30/100 [00:11<00:23,  2.96it/s]
# Epoch 30
# 0.2650884985923767
# 0.25146782398223877
#  31%|███       | 31/100 [00:11<00:24,  2.87it/s]
#
#  32%|███▏      | 32/100 [00:12<00:23,  2.95it/s]
#
#  33%|███▎      | 33/100 [00:12<00:21,  3.06it/s]
#
#  34%|███▍      | 34/100 [00:12<00:20,  3.26it/s]
#
#  35%|███▌      | 35/100 [00:13<00:18,  3.46it/s]
#
#  36%|███▌      | 36/100 [00:13<00:18,  3.38it/s]
#
#  37%|███▋      | 37/100 [00:13<00:18,  3.39it/s]
#
#  38%|███▊      | 38/100 [00:13<00:18,  3.38it/s]
#
#  39%|███▉      | 39/100 [00:14<00:17,  3.40it/s]
#
#  40%|████      | 40/100 [00:14<00:17,  3.38it/s]
# Epoch 40
# 0.24567480385303497
# 0.27618587017059326
#  41%|████      | 41/100 [00:14<00:16,  3.53it/s]
#
#  42%|████▏     | 42/100 [00:15<00:16,  3.55it/s]
#
#  43%|████▎     | 43/100 [00:15<00:16,  3.49it/s]
#
#  44%|████▍     | 44/100 [00:15<00:16,  3.39it/s]
#
#  45%|████▌     | 45/100 [00:16<00:16,  3.32it/s]
#
#  46%|████▌     | 46/100 [00:16<00:16,  3.26it/s]
#
#  47%|████▋     | 47/100 [00:16<00:16,  3.17it/s]
#
#  48%|████▊     | 48/100 [00:16<00:14,  3.49it/s]
#
#  49%|████▉     | 49/100 [00:17<00:14,  3.42it/s]
#
#  50%|█████     | 50/100 [00:17<00:15,  3.19it/s]
# Epoch 50
# 0.2445073425769806
# 0.2758145332336426
#  51%|█████     | 51/100 [00:17<00:15,  3.10it/s]
#
#  52%|█████▏    | 52/100 [00:18<00:15,  3.07it/s]
#
#  53%|█████▎    | 53/100 [00:18<00:14,  3.14it/s]
#
#  54%|█████▍    | 54/100 [00:18<00:13,  3.38it/s]
#
#  55%|█████▌    | 55/100 [00:18<00:12,  3.62it/s]
#
#  56%|█████▌    | 56/100 [00:19<00:13,  3.35it/s]
#
#  57%|█████▋    | 57/100 [00:19<00:13,  3.29it/s]
#
#  58%|█████▊    | 58/100 [00:19<00:12,  3.40it/s]
#
#  59%|█████▉    | 59/100 [00:20<00:11,  3.50it/s]
#
#  60%|██████    | 60/100 [00:20<00:11,  3.56it/s]
# Epoch 60
# 0.25191548466682434
# 0.26224851608276367
#  61%|██████    | 61/100 [00:20<00:10,  3.63it/s]
#
#  62%|██████▏   | 62/100 [00:20<00:09,  3.88it/s]
#
#  63%|██████▎   | 63/100 [00:21<00:10,  3.68it/s]
#
#  64%|██████▍   | 64/100 [00:21<00:10,  3.53it/s]
#
#  65%|██████▌   | 65/100 [00:21<00:10,  3.39it/s]
#
#  66%|██████▌   | 66/100 [00:22<00:10,  3.32it/s]
#
#  67%|██████▋   | 67/100 [00:22<00:09,  3.34it/s]
#
#  68%|██████▊   | 68/100 [00:22<00:09,  3.49it/s]
#
#  69%|██████▉   | 69/100 [00:23<00:08,  3.56it/s]
#
#  70%|███████   | 70/100 [00:23<00:08,  3.49it/s]
# Epoch 70
# 0.2532618045806885
# 0.2805330753326416
#  71%|███████   | 71/100 [00:23<00:08,  3.41it/s]
#
#  72%|███████▏  | 72/100 [00:23<00:08,  3.46it/s]
#
#  73%|███████▎  | 73/100 [00:24<00:07,  3.58it/s]
#
#  74%|███████▍  | 74/100 [00:24<00:07,  3.59it/s]
#
#  75%|███████▌  | 75/100 [00:24<00:06,  3.71it/s]
#
#  76%|███████▌  | 76/100 [00:24<00:06,  3.95it/s]
#
#  77%|███████▋  | 77/100 [00:25<00:05,  3.85it/s]
#
#  78%|███████▊  | 78/100 [00:25<00:05,  3.81it/s]
#
#  79%|███████▉  | 79/100 [00:25<00:05,  3.69it/s]
#
#  80%|████████  | 80/100 [00:26<00:05,  3.69it/s]
# Epoch 80
# 0.23941969871520996
# 0.3114931583404541
#  81%|████████  | 81/100 [00:26<00:05,  3.78it/s]
#
#  82%|████████▏ | 82/100 [00:26<00:04,  3.80it/s]
#
#  83%|████████▎ | 83/100 [00:26<00:04,  3.95it/s]
#
#  84%|████████▍ | 84/100 [00:26<00:03,  4.11it/s]
#
#  85%|████████▌ | 85/100 [00:27<00:03,  3.94it/s]
#
#  86%|████████▌ | 86/100 [00:27<00:03,  3.92it/s]
#
#  87%|████████▋ | 87/100 [00:27<00:03,  3.90it/s]
#
#  88%|████████▊ | 88/100 [00:28<00:03,  3.91it/s]
#
#  89%|████████▉ | 89/100 [00:28<00:02,  3.78it/s]
#
#  90%|█████████ | 90/100 [00:28<00:02,  3.74it/s]
# Epoch 90
# 0.25899502635002136
# 0.2599184513092041
#  91%|█████████ | 91/100 [00:28<00:02,  3.94it/s]
#
#  92%|█████████▏| 92/100 [00:29<00:01,  4.09it/s]
#
#  93%|█████████▎| 93/100 [00:29<00:01,  3.91it/s]
#
#  94%|█████████▍| 94/100 [00:29<00:01,  3.89it/s]
#
#  95%|█████████▌| 95/100 [00:29<00:01,  3.86it/s]
#
#  96%|█████████▌| 96/100 [00:30<00:01,  3.86it/s]
#
#  97%|█████████▋| 97/100 [00:30<00:00,  3.86it/s]
#
#  98%|█████████▊| 98/100 [00:30<00:00,  3.89it/s]
#
#  99%|█████████▉| 99/100 [00:30<00:00,  4.08it/s]
#
# 100%|██████████| 100/100 [00:31<00:00,  3.22it/s]
#
#
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 100
# 0.2565087080001831
# 0.29409801959991455
# Best epoch = 94
# Best loss = 0.3788273334503174
# Fit loss = 0.24595607817173004
# lamb=1.0
#   1%|          | 1/100 [00:00<00:25,  3.83it/s]
#
#   2%|▏         | 2/100 [00:00<00:25,  3.83it/s]
#
#   3%|▎         | 3/100 [00:00<00:25,  3.84it/s]
#
#   4%|▍         | 4/100 [00:01<00:25,  3.80it/s]
#
#   5%|▌         | 5/100 [00:01<00:25,  3.70it/s]
#
#   6%|▌         | 6/100 [00:01<00:25,  3.71it/s]
#
#   7%|▋         | 7/100 [00:01<00:24,  3.84it/s]
#
#   8%|▊         | 8/100 [00:02<00:24,  3.76it/s]
#
#   9%|▉         | 9/100 [00:02<00:23,  3.79it/s]
#
#  10%|█         | 10/100 [00:02<00:23,  3.81it/s]
# Epoch 10
# 0.37751710414886475
# 0.07197022438049316
#  11%|█         | 11/100 [00:02<00:24,  3.65it/s]
#
#  12%|█▏        | 12/100 [00:03<00:24,  3.60it/s]
#
#  13%|█▎        | 13/100 [00:03<00:24,  3.57it/s]
#
#  14%|█▍        | 14/100 [00:03<00:22,  3.80it/s]
#
#  15%|█▌        | 15/100 [00:03<00:21,  3.88it/s]
#
#  16%|█▌        | 16/100 [00:04<00:22,  3.76it/s]
#
#  17%|█▋        | 17/100 [00:04<00:21,  3.80it/s]
#
#  18%|█▊        | 18/100 [00:04<00:21,  3.80it/s]
#
#  19%|█▉        | 19/100 [00:05<00:22,  3.61it/s]
#
#  20%|██        | 20/100 [00:05<00:23,  3.48it/s]
# Epoch 20
# 0.3811032176017761
# 0.07406389713287354
#  21%|██        | 21/100 [00:05<00:22,  3.52it/s]
#
#  22%|██▏       | 22/100 [00:05<00:21,  3.69it/s]
#
#  23%|██▎       | 23/100 [00:06<00:22,  3.41it/s]
#
#  24%|██▍       | 24/100 [00:06<00:22,  3.37it/s]
#
#  25%|██▌       | 25/100 [00:06<00:22,  3.35it/s]
#
#  26%|██▌       | 26/100 [00:07<00:22,  3.34it/s]
#
#  27%|██▋       | 27/100 [00:07<00:21,  3.35it/s]
#
#  28%|██▊       | 28/100 [00:07<00:20,  3.56it/s]
#
#  29%|██▉       | 29/100 [00:07<00:18,  3.75it/s]
#
#  30%|███       | 30/100 [00:08<00:19,  3.60it/s]
# Epoch 30
# 0.3946186900138855
# 0.058760762214660645
#  31%|███       | 31/100 [00:08<00:19,  3.58it/s]
#
#  32%|███▏      | 32/100 [00:08<00:19,  3.56it/s]
#
#  33%|███▎      | 33/100 [00:09<00:18,  3.54it/s]
#
#  34%|███▍      | 34/100 [00:09<00:18,  3.49it/s]
#
#  35%|███▌      | 35/100 [00:09<00:17,  3.62it/s]
#
#  36%|███▌      | 36/100 [00:09<00:16,  3.83it/s]
#
#  37%|███▋      | 37/100 [00:10<00:16,  3.73it/s]
#
#  38%|███▊      | 38/100 [00:10<00:16,  3.70it/s]
#
#  39%|███▉      | 39/100 [00:10<00:16,  3.65it/s]
#
#  40%|████      | 40/100 [00:11<00:16,  3.56it/s]
# Epoch 40
# 0.39044898748397827
# 0.071694016456604
#  41%|████      | 41/100 [00:11<00:16,  3.52it/s]
#
#  42%|████▏     | 42/100 [00:11<00:16,  3.53it/s]
#
#  43%|████▎     | 43/100 [00:11<00:15,  3.70it/s]
#
#  44%|████▍     | 44/100 [00:12<00:15,  3.65it/s]
#
#  45%|████▌     | 45/100 [00:12<00:15,  3.61it/s]
#
#  46%|████▌     | 46/100 [00:12<00:15,  3.56it/s]
#
#  47%|████▋     | 47/100 [00:12<00:14,  3.54it/s]
#
#  48%|████▊     | 48/100 [00:13<00:15,  3.27it/s]
#
#  49%|████▉     | 49/100 [00:13<00:14,  3.41it/s]
#
#  50%|█████     | 50/100 [00:13<00:13,  3.65it/s]
# Epoch 50
# 0.3754192888736725
# 0.06942760944366455
#  51%|█████     | 51/100 [00:14<00:13,  3.66it/s]
#
#  52%|█████▏    | 52/100 [00:14<00:13,  3.58it/s]
#
#  53%|█████▎    | 53/100 [00:14<00:13,  3.60it/s]
#
#  54%|█████▍    | 54/100 [00:14<00:12,  3.60it/s]
#
#  55%|█████▌    | 55/100 [00:15<00:13,  3.46it/s]
#
#  56%|█████▌    | 56/100 [00:15<00:12,  3.51it/s]
#
#  57%|█████▋    | 57/100 [00:15<00:11,  3.69it/s]
#
#  58%|█████▊    | 58/100 [00:16<00:11,  3.70it/s]
#
#  59%|█████▉    | 59/100 [00:16<00:11,  3.47it/s]
#
#  60%|██████    | 60/100 [00:16<00:11,  3.45it/s]
# Epoch 60
# 0.38890814781188965
# 0.06008434295654297
#  61%|██████    | 61/100 [00:16<00:11,  3.39it/s]
#
#  62%|██████▏   | 62/100 [00:17<00:11,  3.38it/s]
#
#  63%|██████▎   | 63/100 [00:17<00:12,  2.96it/s]
#
#  64%|██████▍   | 64/100 [00:17<00:11,  3.21it/s]
#
#  65%|██████▌   | 65/100 [00:18<00:10,  3.25it/s]
#
#  66%|██████▌   | 66/100 [00:18<00:10,  3.32it/s]
#
#  67%|██████▋   | 67/100 [00:18<00:09,  3.36it/s]
#
#  68%|██████▊   | 68/100 [00:19<00:09,  3.46it/s]
#
#  69%|██████▉   | 69/100 [00:19<00:08,  3.54it/s]
#
#  70%|███████   | 70/100 [00:19<00:08,  3.59it/s]
# Epoch 70
# 0.38423871994018555
# 0.06292355060577393
#  71%|███████   | 71/100 [00:19<00:07,  3.70it/s]
#
#  72%|███████▏  | 72/100 [00:20<00:07,  3.50it/s]
#
#  73%|███████▎  | 73/100 [00:20<00:07,  3.52it/s]
#
#  74%|███████▍  | 74/100 [00:20<00:07,  3.50it/s]
#
#  75%|███████▌  | 75/100 [00:21<00:07,  3.48it/s]
#
#  76%|███████▌  | 76/100 [00:21<00:06,  3.46it/s]
#
#  77%|███████▋  | 77/100 [00:21<00:06,  3.53it/s]
#
#  78%|███████▊  | 78/100 [00:21<00:05,  3.73it/s]
#
#  79%|███████▉  | 79/100 [00:22<00:06,  3.37it/s]
#
#  80%|████████  | 80/100 [00:22<00:06,  3.31it/s]
# Epoch 80
# 0.38298875093460083
# 0.0691293478012085
#  81%|████████  | 81/100 [00:22<00:05,  3.41it/s]
#
#  82%|████████▏ | 82/100 [00:23<00:05,  3.46it/s]
#
#  83%|████████▎ | 83/100 [00:23<00:04,  3.49it/s]
#
#  84%|████████▍ | 84/100 [00:23<00:04,  3.58it/s]
#
#  85%|████████▌ | 85/100 [00:23<00:03,  3.82it/s]
#
#  86%|████████▌ | 86/100 [00:24<00:03,  3.74it/s]
#
#  87%|████████▋ | 87/100 [00:24<00:03,  3.69it/s]
#
#  88%|████████▊ | 88/100 [00:24<00:03,  3.66it/s]
#
#  89%|████████▉ | 89/100 [00:24<00:03,  3.57it/s]
#
#  90%|█████████ | 90/100 [00:25<00:03,  3.22it/s]
# Epoch 90
# 0.37846076488494873
# 0.08200502395629883
#  91%|█████████ | 91/100 [00:25<00:02,  3.37it/s]
#
#  92%|█████████▏| 92/100 [00:25<00:02,  3.64it/s]
#
#  93%|█████████▎| 93/100 [00:26<00:02,  3.35it/s]
#
#  94%|█████████▍| 94/100 [00:26<00:01,  3.14it/s]
#
#  95%|█████████▌| 95/100 [00:26<00:01,  3.02it/s]
#
#  96%|█████████▌| 96/100 [00:27<00:01,  2.96it/s]
#
#  97%|█████████▋| 97/100 [00:27<00:01,  2.98it/s]
#
#  98%|█████████▊| 98/100 [00:27<00:00,  3.32it/s]
#
#  99%|█████████▉| 99/100 [00:28<00:00,  3.35it/s]
#
# 100%|██████████| 100/100 [00:28<00:00,  3.51it/s]
#
#
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 100
# 0.3852091133594513
# 0.06622469425201416
# Best epoch = 71
# Best loss = 0.44286566972732544
# Fit loss = 0.3826912045478821
# lamb=2.0
#   1%|          | 1/100 [00:00<00:26,  3.73it/s]
#
#   2%|▏         | 2/100 [00:00<00:26,  3.73it/s]
#
#   3%|▎         | 3/100 [00:00<00:27,  3.57it/s]
#
#   4%|▍         | 4/100 [00:01<00:27,  3.53it/s]
#
#   5%|▌         | 5/100 [00:01<00:25,  3.77it/s]
#
#   6%|▌         | 6/100 [00:01<00:27,  3.48it/s]
#
#   7%|▋         | 7/100 [00:01<00:26,  3.45it/s]
#
#   8%|▊         | 8/100 [00:02<00:26,  3.44it/s]
#
#   9%|▉         | 9/100 [00:02<00:26,  3.42it/s]
#
#  10%|█         | 10/100 [00:02<00:26,  3.36it/s]
# Epoch 10
# 0.451275110244751
# 0.02954387664794922
#  11%|█         | 11/100 [00:03<00:25,  3.51it/s]
#
#  12%|█▏        | 12/100 [00:03<00:23,  3.79it/s]
#
#  13%|█▎        | 13/100 [00:03<00:22,  3.81it/s]
#
#  14%|█▍        | 14/100 [00:03<00:23,  3.73it/s]
#
#  15%|█▌        | 15/100 [00:04<00:23,  3.55it/s]
#
#  16%|█▌        | 16/100 [00:04<00:24,  3.42it/s]
#
#  17%|█▋        | 17/100 [00:04<00:25,  3.27it/s]
#
#  18%|█▊        | 18/100 [00:05<00:24,  3.34it/s]
#
#  19%|█▉        | 19/100 [00:05<00:22,  3.64it/s]
#
#  20%|██        | 20/100 [00:05<00:22,  3.57it/s]
# Epoch 20
# 0.44834914803504944
# 0.01971566677093506
#  21%|██        | 21/100 [00:05<00:22,  3.45it/s]
#
#  22%|██▏       | 22/100 [00:06<00:22,  3.41it/s]
#
#  23%|██▎       | 23/100 [00:06<00:22,  3.40it/s]
#
#  24%|██▍       | 24/100 [00:06<00:22,  3.39it/s]
#
#  25%|██▌       | 25/100 [00:07<00:21,  3.42it/s]
#
#  26%|██▌       | 26/100 [00:07<00:20,  3.60it/s]
#
#  27%|██▋       | 27/100 [00:07<00:21,  3.41it/s]
#
#  28%|██▊       | 28/100 [00:08<00:22,  3.27it/s]
#
#  29%|██▉       | 29/100 [00:08<00:21,  3.27it/s]
#
#  30%|███       | 30/100 [00:08<00:21,  3.26it/s]
# Epoch 30
# 0.4573695659637451
# 0.01781761646270752
#  31%|███       | 31/100 [00:09<00:21,  3.20it/s]
#
#  32%|███▏      | 32/100 [00:09<00:19,  3.45it/s]
#
#  33%|███▎      | 33/100 [00:09<00:19,  3.50it/s]
#
#  34%|███▍      | 34/100 [00:09<00:19,  3.38it/s]
#
#  35%|███▌      | 35/100 [00:10<00:19,  3.27it/s]
#
#  36%|███▌      | 36/100 [00:10<00:19,  3.22it/s]
#
#  37%|███▋      | 37/100 [00:10<00:20,  3.07it/s]
#
#  38%|███▊      | 38/100 [00:11<00:19,  3.15it/s]
#
#  39%|███▉      | 39/100 [00:11<00:17,  3.48it/s]
#
#  40%|████      | 40/100 [00:11<00:17,  3.47it/s]
# Epoch 40
# 0.4389458894729614
# 0.05961942672729492
#  41%|████      | 41/100 [00:11<00:16,  3.58it/s]
#
#  42%|████▏     | 42/100 [00:12<00:15,  3.65it/s]
#
#  43%|████▎     | 43/100 [00:12<00:15,  3.74it/s]
#
#  44%|████▍     | 44/100 [00:12<00:14,  3.75it/s]
#
#  45%|████▌     | 45/100 [00:12<00:14,  3.72it/s]
#
#  46%|████▌     | 46/100 [00:13<00:13,  3.90it/s]
#
#  47%|████▋     | 47/100 [00:13<00:12,  4.14it/s]
#
#  48%|████▊     | 48/100 [00:13<00:12,  4.07it/s]
#
#  49%|████▉     | 49/100 [00:13<00:12,  4.04it/s]
#
#  50%|█████     | 50/100 [00:14<00:12,  4.00it/s]
# Epoch 50
# 0.4556812047958374
# 0.015359640121459961
#  51%|█████     | 51/100 [00:14<00:12,  4.01it/s]
#
#  52%|█████▏    | 52/100 [00:14<00:11,  4.01it/s]
#
#  53%|█████▎    | 53/100 [00:14<00:11,  3.99it/s]
#
#  54%|█████▍    | 54/100 [00:15<00:11,  4.05it/s]
#
#  55%|█████▌    | 55/100 [00:15<00:10,  4.16it/s]
#
#  56%|█████▌    | 56/100 [00:15<00:10,  4.01it/s]
#
#  57%|█████▋    | 57/100 [00:15<00:10,  3.96it/s]
#
#  58%|█████▊    | 58/100 [00:16<00:10,  3.83it/s]
#
#  59%|█████▉    | 59/100 [00:16<00:10,  3.82it/s]
#
#  60%|██████    | 60/100 [00:16<00:10,  3.76it/s]
# Epoch 60
# 0.4375610947608948
# 0.03166484832763672
#  61%|██████    | 61/100 [00:16<00:10,  3.78it/s]
#
#  62%|██████▏   | 62/100 [00:17<00:09,  3.93it/s]
#
#  63%|██████▎   | 63/100 [00:17<00:09,  4.00it/s]
#
#  64%|██████▍   | 64/100 [00:17<00:09,  3.84it/s]
#
#  65%|██████▌   | 65/100 [00:18<00:09,  3.82it/s]
#
#  66%|██████▌   | 66/100 [00:18<00:08,  3.79it/s]
#
#  67%|██████▋   | 67/100 [00:18<00:08,  3.79it/s]
#
#  68%|██████▊   | 68/100 [00:18<00:08,  3.78it/s]
#
#  69%|██████▉   | 69/100 [00:19<00:08,  3.81it/s]
#
#  70%|███████   | 70/100 [00:19<00:07,  4.05it/s]
# Epoch 70
# 0.4522930979728699
# 0.023368239402770996
#  71%|███████   | 71/100 [00:19<00:06,  4.14it/s]
#
#  72%|███████▏  | 72/100 [00:19<00:07,  3.78it/s]
#
#  73%|███████▎  | 73/100 [00:20<00:07,  3.76it/s]
#
#  74%|███████▍  | 74/100 [00:20<00:06,  3.79it/s]
#
#  75%|███████▌  | 75/100 [00:20<00:06,  3.66it/s]
#
#  76%|███████▌  | 76/100 [00:20<00:06,  3.64it/s]
#
#  77%|███████▋  | 77/100 [00:21<00:06,  3.68it/s]
#
#  78%|███████▊  | 78/100 [00:21<00:05,  3.87it/s]
#
#  79%|███████▉  | 79/100 [00:21<00:05,  3.55it/s]
#
#  80%|████████  | 80/100 [00:22<00:06,  3.30it/s]
# Epoch 80
# 0.4441913962364197
# 0.027007341384887695
#  81%|████████  | 81/100 [00:22<00:05,  3.17it/s]
#
#  82%|████████▏ | 82/100 [00:22<00:05,  3.14it/s]
#
#  83%|████████▎ | 83/100 [00:23<00:05,  3.16it/s]
#
#  84%|████████▍ | 84/100 [00:23<00:04,  3.40it/s]
#
#  85%|████████▌ | 85/100 [00:23<00:04,  3.39it/s]
#
#  86%|████████▌ | 86/100 [00:23<00:04,  3.26it/s]
#
#  87%|████████▋ | 87/100 [00:24<00:04,  3.21it/s]
#
#  88%|████████▊ | 88/100 [00:24<00:03,  3.12it/s]
#
#  89%|████████▉ | 89/100 [00:24<00:03,  3.04it/s]
#
#  90%|█████████ | 90/100 [00:25<00:03,  3.26it/s]
# Epoch 90
# 0.43818074464797974
# 0.023815631866455078
#  91%|█████████ | 91/100 [00:25<00:02,  3.36it/s]
#
#  92%|█████████▏| 92/100 [00:25<00:02,  3.23it/s]
#
#  93%|█████████▎| 93/100 [00:26<00:02,  3.17it/s]
#
#  94%|█████████▍| 94/100 [00:26<00:01,  3.06it/s]
#
#  95%|█████████▌| 95/100 [00:26<00:01,  3.05it/s]
#
#  96%|█████████▌| 96/100 [00:27<00:01,  3.14it/s]
#
#  97%|█████████▋| 97/100 [00:27<00:00,  3.40it/s]
#
#  98%|█████████▊| 98/100 [00:27<00:00,  3.35it/s]
#
#  99%|█████████▉| 99/100 [00:28<00:00,  3.21it/s]
#
# 100%|██████████| 100/100 [00:28<00:00,  3.52it/s]
#
#
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 100
# 0.45127159357070923
# 0.026099205017089844
# Best epoch = 93
# Best loss = 0.4768657684326172
# Fit loss = 0.44653749465942383
# lamb=5.0
#   1%|          | 1/100 [00:00<00:37,  2.61it/s]
#
#   2%|▏         | 2/100 [00:00<00:36,  2.69it/s]
#
#   3%|▎         | 3/100 [00:01<00:33,  2.93it/s]
#
#   4%|▍         | 4/100 [00:01<00:35,  2.71it/s]
#
#   5%|▌         | 5/100 [00:01<00:35,  2.66it/s]
#
#   6%|▌         | 6/100 [00:02<00:35,  2.64it/s]
#
#   7%|▋         | 7/100 [00:02<00:34,  2.67it/s]
#
#   8%|▊         | 8/100 [00:02<00:31,  2.92it/s]
#
#   9%|▉         | 9/100 [00:03<00:29,  3.12it/s]
#
#  10%|█         | 10/100 [00:03<00:29,  3.07it/s]
# Epoch 10
# 0.4690883755683899
# 0.019856572151184082
#  11%|█         | 11/100 [00:03<00:28,  3.10it/s]
#
#  12%|█▏        | 12/100 [00:04<00:27,  3.23it/s]
#
#  13%|█▎        | 13/100 [00:04<00:26,  3.25it/s]
#
#  14%|█▍        | 14/100 [00:04<00:25,  3.31it/s]
#
#  15%|█▌        | 15/100 [00:04<00:24,  3.49it/s]
#
#  16%|█▌        | 16/100 [00:05<00:23,  3.55it/s]
#
#  17%|█▋        | 17/100 [00:05<00:23,  3.49it/s]
#
#  18%|█▊        | 18/100 [00:05<00:23,  3.49it/s]
#
#  19%|█▉        | 19/100 [00:06<00:23,  3.48it/s]
#
#  20%|██        | 20/100 [00:06<00:23,  3.46it/s]
# Epoch 20
# 0.48263421654701233
# 0.006908059120178223
#  21%|██        | 21/100 [00:06<00:23,  3.39it/s]
#
#  22%|██▏       | 22/100 [00:06<00:21,  3.63it/s]
#
#  23%|██▎       | 23/100 [00:07<00:21,  3.62it/s]
#
#  24%|██▍       | 24/100 [00:07<00:21,  3.56it/s]
#
#  25%|██▌       | 25/100 [00:07<00:21,  3.55it/s]
#
#  26%|██▌       | 26/100 [00:08<00:21,  3.48it/s]
#
#  27%|██▋       | 27/100 [00:08<00:20,  3.50it/s]
#
#  28%|██▊       | 28/100 [00:08<00:20,  3.46it/s]
#
#  29%|██▉       | 29/100 [00:08<00:19,  3.64it/s]
#
#  30%|███       | 30/100 [00:09<00:18,  3.79it/s]
# Epoch 30
# 0.47056907415390015
# 0.011466741561889648
#  31%|███       | 31/100 [00:09<00:18,  3.63it/s]
#
#  32%|███▏      | 32/100 [00:09<00:19,  3.53it/s]
#
#  33%|███▎      | 33/100 [00:09<00:19,  3.52it/s]
#
#  34%|███▍      | 34/100 [00:10<00:18,  3.51it/s]
#
#  35%|███▌      | 35/100 [00:10<00:18,  3.53it/s]
#
#  36%|███▌      | 36/100 [00:10<00:17,  3.60it/s]
#
#  37%|███▋      | 37/100 [00:11<00:16,  3.77it/s]
#
#  38%|███▊      | 38/100 [00:11<00:16,  3.67it/s]
#
#  39%|███▉      | 39/100 [00:11<00:16,  3.64it/s]
#
#  40%|████      | 40/100 [00:11<00:16,  3.55it/s]
# Epoch 40
# 0.48053544759750366
# 0.00341188907623291
#  41%|████      | 41/100 [00:12<00:18,  3.22it/s]
#
#  42%|████▏     | 42/100 [00:12<00:18,  3.09it/s]
#
#  43%|████▎     | 43/100 [00:12<00:17,  3.28it/s]
#
#  44%|████▍     | 44/100 [00:13<00:17,  3.28it/s]
#
#  45%|████▌     | 45/100 [00:13<00:17,  3.21it/s]
#
#  46%|████▌     | 46/100 [00:13<00:16,  3.18it/s]
#
#  47%|████▋     | 47/100 [00:14<00:17,  3.05it/s]
#
#  48%|████▊     | 48/100 [00:14<00:18,  2.87it/s]
#
#  49%|████▉     | 49/100 [00:14<00:16,  3.15it/s]
#
#  50%|█████     | 50/100 [00:15<00:15,  3.13it/s]
# Epoch 50
# 0.4851206839084625
# 0.003945469856262207
#  51%|█████     | 51/100 [00:15<00:16,  2.93it/s]
#
#  52%|█████▏    | 52/100 [00:15<00:16,  2.90it/s]
#
#  53%|█████▎    | 53/100 [00:16<00:15,  2.97it/s]
#
#  54%|█████▍    | 54/100 [00:16<00:15,  3.02it/s]
#
#  55%|█████▌    | 55/100 [00:16<00:13,  3.23it/s]
#
#  56%|█████▌    | 56/100 [00:17<00:13,  3.36it/s]
#
#  57%|█████▋    | 57/100 [00:17<00:13,  3.24it/s]
#
#  58%|█████▊    | 58/100 [00:17<00:13,  3.15it/s]
#
# ...
#
#  16%|█▌        | 16/100 [00:04<00:24,  3.41it/s]
#
#  17%|█▋        | 17/100 [00:04<00:25,  3.25it/s]
#
#  18%|█▊        | 18/100 [00:05<00:25,  3.18it/s]
#
#  19%|█▉        | 19/100 [00:05<00:25,  3.13it/s]
#
#  20%|██        | 20/100 [00:05<00:25,  3.09it/s]
# Epoch 20
# 0.4861156642436981
# 0.0026704072952270508
#  21%|██        | 21/100 [00:06<00:23,  3.39it/s]
#
#  22%|██▏       | 22/100 [00:06<00:22,  3.43it/s]
#
#  23%|██▎       | 23/100 [00:06<00:23,  3.25it/s]
#
#  24%|██▍       | 24/100 [00:07<00:24,  3.14it/s]
#
#  25%|██▌       | 25/100 [00:07<00:24,  3.08it/s]
#
#  26%|██▌       | 26/100 [00:07<00:24,  3.05it/s]
#
#  27%|██▋       | 27/100 [00:08<00:22,  3.22it/s]
#
#  28%|██▊       | 28/100 [00:08<00:20,  3.46it/s]
#
#  29%|██▉       | 29/100 [00:08<00:21,  3.28it/s]
#
#  30%|███       | 30/100 [00:08<00:22,  3.17it/s]
# Epoch 30
# 0.49199041724205017
# 0.01785910129547119
#  31%|███       | 31/100 [00:09<00:22,  3.12it/s]
#
#  32%|███▏      | 32/100 [00:09<00:22,  3.05it/s]
#
#  33%|███▎      | 33/100 [00:09<00:21,  3.08it/s]
#
#  34%|███▍      | 34/100 [00:10<00:19,  3.44it/s]
#
#  35%|███▌      | 35/100 [00:10<00:19,  3.41it/s]
#
#  36%|███▌      | 36/100 [00:10<00:19,  3.33it/s]
#
#  37%|███▋      | 37/100 [00:11<00:18,  3.36it/s]
#
#  38%|███▊      | 38/100 [00:11<00:18,  3.29it/s]
#
#  39%|███▉      | 39/100 [00:11<00:18,  3.26it/s]
#
#  40%|████      | 40/100 [00:11<00:17,  3.34it/s]
# Epoch 40
# 0.5013854503631592
# 0.004638195037841797
#  41%|████      | 41/100 [00:12<00:16,  3.65it/s]
#
#  42%|████▏     | 42/100 [00:12<00:16,  3.45it/s]
#
#  43%|████▎     | 43/100 [00:12<00:17,  3.29it/s]
#
#  44%|████▍     | 44/100 [00:13<00:17,  3.23it/s]
#
#  45%|████▌     | 45/100 [00:13<00:16,  3.24it/s]
#
#  46%|████▌     | 46/100 [00:13<00:17,  3.17it/s]
#
#  47%|████▋     | 47/100 [00:14<00:15,  3.40it/s]
#
#  48%|████▊     | 48/100 [00:14<00:14,  3.52it/s]
#
#  49%|████▉     | 49/100 [00:14<00:14,  3.45it/s]
#
#  50%|█████     | 50/100 [00:14<00:14,  3.44it/s]
# Epoch 50
# 0.4849596321582794
# 0.008480072021484375
#  51%|█████     | 51/100 [00:15<00:14,  3.41it/s]
#
#  52%|█████▏    | 52/100 [00:15<00:13,  3.43it/s]
#
#  53%|█████▎    | 53/100 [00:15<00:13,  3.43it/s]
#
#  54%|█████▍    | 54/100 [00:16<00:12,  3.63it/s]
#
#  55%|█████▌    | 55/100 [00:16<00:11,  3.80it/s]
#
#  56%|█████▌    | 56/100 [00:16<00:12,  3.60it/s]
#
#  57%|█████▋    | 57/100 [00:16<00:11,  3.67it/s]
#
#  58%|█████▊    | 58/100 [00:17<00:11,  3.75it/s]
#
#  59%|█████▉    | 59/100 [00:17<00:11,  3.70it/s]
#
#  60%|██████    | 60/100 [00:17<00:10,  3.65it/s]
# Epoch 60
# 0.48938387632369995
# 0.0021761655807495117
#  61%|██████    | 61/100 [00:17<00:10,  3.63it/s]
#
#  62%|██████▏   | 62/100 [00:18<00:09,  3.88it/s]
#
#  63%|██████▎   | 63/100 [00:18<00:09,  3.86it/s]
#
#  64%|██████▍   | 64/100 [00:18<00:09,  3.74it/s]
#
#  65%|██████▌   | 65/100 [00:18<00:09,  3.74it/s]
#
#  66%|██████▌   | 66/100 [00:19<00:09,  3.72it/s]
#
#  67%|██████▋   | 67/100 [00:19<00:09,  3.42it/s]
#
#  68%|██████▊   | 68/100 [00:19<00:09,  3.43it/s]
#
#  69%|██████▉   | 69/100 [00:20<00:08,  3.66it/s]
#
#  70%|███████   | 70/100 [00:20<00:08,  3.73it/s]
# Epoch 70
# 0.49592965841293335
# 0.0020972490310668945
#  71%|███████   | 71/100 [00:20<00:08,  3.61it/s]
#
#  72%|███████▏  | 72/100 [00:20<00:07,  3.54it/s]
#
#  73%|███████▎  | 73/100 [00:21<00:07,  3.58it/s]
#
#  74%|███████▍  | 74/100 [00:21<00:07,  3.57it/s]
#
#  75%|███████▌  | 75/100 [00:21<00:07,  3.49it/s]
#
#  76%|███████▌  | 76/100 [00:22<00:06,  3.60it/s]
#
#  77%|███████▋  | 77/100 [00:22<00:06,  3.68it/s]
#
#  78%|███████▊  | 78/100 [00:22<00:05,  3.70it/s]
#
#  79%|███████▉  | 79/100 [00:22<00:05,  3.77it/s]
#
#  80%|████████  | 80/100 [00:23<00:05,  3.84it/s]
# Epoch 80
# 0.496501624584198
# 0.0012128353118896484
#  81%|████████  | 81/100 [00:23<00:04,  3.89it/s]
#
#  82%|████████▏ | 82/100 [00:23<00:04,  3.93it/s]
#
#  83%|████████▎ | 83/100 [00:23<00:04,  3.94it/s]
#
#  84%|████████▍ | 84/100 [00:24<00:03,  4.03it/s]
#
#  85%|████████▌ | 85/100 [00:24<00:03,  4.08it/s]
#
#  86%|████████▌ | 86/100 [00:24<00:03,  3.96it/s]
#
#  87%|████████▋ | 87/100 [00:24<00:03,  3.94it/s]
#
#  88%|████████▊ | 88/100 [00:25<00:03,  3.93it/s]
#
#  89%|████████▉ | 89/100 [00:25<00:02,  3.96it/s]
#
#  90%|█████████ | 90/100 [00:25<00:02,  3.93it/s]
# Epoch 90
# 0.4957464933395386
# 0.0007289648056030273
#  91%|█████████ | 91/100 [00:25<00:02,  3.92it/s]
#
#  92%|█████████▏| 92/100 [00:26<00:01,  4.07it/s]
#
#  93%|█████████▎| 93/100 [00:26<00:01,  4.15it/s]
#
#  94%|█████████▍| 94/100 [00:26<00:01,  3.92it/s]
#
#  95%|█████████▌| 95/100 [00:26<00:01,  3.79it/s]
#
#  96%|█████████▌| 96/100 [00:27<00:01,  3.79it/s]
#
#  97%|█████████▋| 97/100 [00:27<00:00,  3.75it/s]
#
#  98%|█████████▊| 98/100 [00:27<00:00,  3.74it/s]
#
#  99%|█████████▉| 99/100 [00:28<00:00,  3.67it/s]
#
# 100%|██████████| 100/100 [00:28<00:00,  3.54it/s]
#
#
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 100
# 0.49600231647491455
# 0.002447962760925293
# Best epoch = 98
# Best loss = 0.5073776245117188
# Fit loss = 0.4952993392944336
# lamb=50.0
#   1%|          | 1/100 [00:00<00:37,  2.65it/s]
#
#   2%|▏         | 2/100 [00:00<00:37,  2.63it/s]
#
#   3%|▎         | 3/100 [00:01<00:35,  2.71it/s]
#
#   4%|▍         | 4/100 [00:01<00:34,  2.75it/s]
#
#   5%|▌         | 5/100 [00:01<00:32,  2.92it/s]
#
#   6%|▌         | 6/100 [00:01<00:28,  3.26it/s]
#
#   7%|▋         | 7/100 [00:02<00:27,  3.34it/s]
#
#   8%|▊         | 8/100 [00:02<00:27,  3.38it/s]
#
#   9%|▉         | 9/100 [00:02<00:26,  3.37it/s]
#
#  10%|█         | 10/100 [00:03<00:26,  3.35it/s]
# Epoch 10
# 0.49746981263160706
# 0.007609724998474121
#  11%|█         | 11/100 [00:03<00:26,  3.30it/s]
#
#  12%|█▏        | 12/100 [00:03<00:26,  3.37it/s]
#
#  13%|█▎        | 13/100 [00:03<00:23,  3.66it/s]
#
#  14%|█▍        | 14/100 [00:04<00:23,  3.61it/s]
#
#  15%|█▌        | 15/100 [00:04<00:24,  3.50it/s]
#
#  16%|█▌        | 16/100 [00:04<00:24,  3.50it/s]
#
#  17%|█▋        | 17/100 [00:05<00:23,  3.50it/s]
#
#  18%|█▊        | 18/100 [00:05<00:23,  3.51it/s]
#
#  19%|█▉        | 19/100 [00:05<00:22,  3.55it/s]
#
#  20%|██        | 20/100 [00:05<00:21,  3.71it/s]
# Epoch 20
# 0.5038182735443115
# 0.003435492515563965
#  21%|██        | 21/100 [00:06<00:22,  3.49it/s]
#
#  22%|██▏       | 22/100 [00:06<00:22,  3.48it/s]
#
#  23%|██▎       | 23/100 [00:06<00:21,  3.59it/s]
#
#  24%|██▍       | 24/100 [00:07<00:20,  3.71it/s]
#
#  25%|██▌       | 25/100 [00:07<00:19,  3.76it/s]
#
#  26%|██▌       | 26/100 [00:07<00:19,  3.80it/s]
#
#  27%|██▋       | 27/100 [00:07<00:18,  3.92it/s]
#
#  28%|██▊       | 28/100 [00:08<00:17,  4.08it/s]
#
#  29%|██▉       | 29/100 [00:08<00:18,  3.93it/s]
#
#  30%|███       | 30/100 [00:08<00:18,  3.81it/s]
# Epoch 30
# 0.49561917781829834
# 0.001965761184692383
#  31%|███       | 31/100 [00:08<00:18,  3.76it/s]
#
#  32%|███▏      | 32/100 [00:09<00:18,  3.76it/s]
#
#  33%|███▎      | 33/100 [00:09<00:17,  3.79it/s]
#
#  34%|███▍      | 34/100 [00:09<00:17,  3.75it/s]
#
#  35%|███▌      | 35/100 [00:09<00:16,  3.95it/s]
#
#  36%|███▌      | 36/100 [00:10<00:16,  3.83it/s]
#
#  37%|███▋      | 37/100 [00:10<00:17,  3.53it/s]
#
#  38%|███▊      | 38/100 [00:10<00:18,  3.36it/s]
#
#  39%|███▉      | 39/100 [00:11<00:18,  3.26it/s]
#
#  40%|████      | 40/100 [00:11<00:18,  3.29it/s]
# Epoch 40
# 0.49862200021743774
# 0.003952383995056152
#  41%|████      | 41/100 [00:11<00:17,  3.32it/s]
#
#  42%|████▏     | 42/100 [00:11<00:16,  3.59it/s]
#
#  43%|████▎     | 43/100 [00:12<00:16,  3.42it/s]
#
#  44%|████▍     | 44/100 [00:12<00:16,  3.40it/s]
#
#  45%|████▌     | 45/100 [00:12<00:16,  3.34it/s]
#
#  46%|████▌     | 46/100 [00:13<00:15,  3.45it/s]
#
#  47%|████▋     | 47/100 [00:13<00:15,  3.51it/s]
#
#  48%|████▊     | 48/100 [00:13<00:14,  3.57it/s]
#
#  49%|████▉     | 49/100 [00:13<00:13,  3.83it/s]
#
#  50%|█████     | 50/100 [00:14<00:12,  3.85it/s]
# Epoch 50
# 0.5002439022064209
# 0.001573801040649414
#  51%|█████     | 51/100 [00:14<00:12,  3.81it/s]
#
#  52%|█████▏    | 52/100 [00:14<00:12,  3.77it/s]
#
#  53%|█████▎    | 53/100 [00:14<00:12,  3.78it/s]
#
#  54%|█████▍    | 54/100 [00:15<00:12,  3.80it/s]
#
#  55%|█████▌    | 55/100 [00:15<00:11,  3.82it/s]
#
#  56%|█████▌    | 56/100 [00:15<00:11,  3.90it/s]
#
#  57%|█████▋    | 57/100 [00:15<00:10,  4.10it/s]
#
#  58%|█████▊    | 58/100 [00:16<00:10,  4.04it/s]
#
#  59%|█████▉    | 59/100 [00:16<00:10,  3.95it/s]
#
#  60%|██████    | 60/100 [00:16<00:10,  3.90it/s]
# Epoch 60
# 0.499342679977417
# 0.001073002815246582
#  61%|██████    | 61/100 [00:17<00:09,  3.90it/s]
#
#  62%|██████▏   | 62/100 [00:17<00:09,  3.89it/s]
#
#  63%|██████▎   | 63/100 [00:17<00:09,  3.87it/s]
#
#  64%|██████▍   | 64/100 [00:17<00:09,  3.95it/s]
#
#  65%|██████▌   | 65/100 [00:17<00:08,  4.14it/s]
#
#  66%|██████▌   | 66/100 [00:18<00:08,  4.01it/s]
#
#  67%|██████▋   | 67/100 [00:18<00:08,  3.91it/s]
#
#  68%|██████▊   | 68/100 [00:18<00:08,  3.86it/s]
#
#  69%|██████▉   | 69/100 [00:19<00:08,  3.83it/s]
#
#  70%|███████   | 70/100 [00:19<00:07,  3.80it/s]
# Epoch 70
# 0.49562034010887146
# 0.0035495758056640625
#  71%|███████   | 71/100 [00:19<00:07,  3.82it/s]
#
#  72%|███████▏  | 72/100 [00:19<00:07,  3.95it/s]
#
#  73%|███████▎  | 73/100 [00:20<00:06,  4.11it/s]
#
#  74%|███████▍  | 74/100 [00:20<00:06,  3.94it/s]
#
#  75%|███████▌  | 75/100 [00:20<00:06,  3.88it/s]
#
#  76%|███████▌  | 76/100 [00:20<00:06,  3.85it/s]
#
#  77%|███████▋  | 77/100 [00:21<00:06,  3.83it/s]
#
#  78%|███████▊  | 78/100 [00:21<00:05,  3.79it/s]
#
#  79%|███████▉  | 79/100 [00:21<00:05,  3.70it/s]
#
#  80%|████████  | 80/100 [00:21<00:05,  3.88it/s]
# Epoch 80
# 0.4971972405910492
# 0.0008051395416259766
#  81%|████████  | 81/100 [00:22<00:04,  3.81it/s]
#
#  82%|████████▏ | 82/100 [00:22<00:04,  3.66it/s]
#
#  83%|████████▎ | 83/100 [00:22<00:04,  3.57it/s]
#
#  84%|████████▍ | 84/100 [00:23<00:04,  3.56it/s]
#
#  85%|████████▌ | 85/100 [00:23<00:04,  3.54it/s]
#
#  86%|████████▌ | 86/100 [00:23<00:04,  3.50it/s]
#
#  87%|████████▋ | 87/100 [00:23<00:03,  3.72it/s]
#
#  88%|████████▊ | 88/100 [00:24<00:03,  3.82it/s]
#
#  89%|████████▉ | 89/100 [00:24<00:03,  3.46it/s]
#
#  90%|█████████ | 90/100 [00:24<00:03,  3.10it/s]
# Epoch 90
# 0.49853307008743286
# 0.00018870830535888672
#  91%|█████████ | 91/100 [00:25<00:02,  3.18it/s]
#
#  92%|█████████▏| 92/100 [00:25<00:02,  3.25it/s]
#
#  93%|█████████▎| 93/100 [00:25<00:02,  3.34it/s]
#
#  94%|█████████▍| 94/100 [00:25<00:01,  3.65it/s]
#
#  95%|█████████▌| 95/100 [00:26<00:01,  3.44it/s]
#
#  96%|█████████▌| 96/100 [00:26<00:01,  3.24it/s]
#
#  97%|█████████▋| 97/100 [00:26<00:00,  3.13it/s]
#
#  98%|█████████▊| 98/100 [00:27<00:00,  3.10it/s]
#
#  99%|█████████▉| 99/100 [00:27<00:00,  3.06it/s]
#
# 100%|██████████| 100/100 [00:27<00:00,  3.59it/s]
#
#
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 100
# 0.4969918429851532
# 0.0005861520767211914
# Best epoch = 89
# Best loss = 0.5079684853553772
# Fit loss = 0.49853307008743286
# lamb=100.0
#   1%|          | 1/100 [00:00<00:29,  3.35it/s]
#
#   2%|▏         | 2/100 [00:00<00:31,  3.14it/s]
#
#   3%|▎         | 3/100 [00:01<00:32,  3.03it/s]
#
#   4%|▍         | 4/100 [00:01<00:32,  2.99it/s]
#
#   5%|▌         | 5/100 [00:01<00:32,  2.93it/s]
#
#   6%|▌         | 6/100 [00:01<00:29,  3.21it/s]
#
#   7%|▋         | 7/100 [00:02<00:27,  3.40it/s]
#
#   8%|▊         | 8/100 [00:02<00:28,  3.20it/s]
#
#   9%|▉         | 9/100 [00:02<00:29,  3.09it/s]
#
#  10%|█         | 10/100 [00:03<00:30,  3.00it/s]
# Epoch 10
# 0.496013343334198
# 0.0013161897659301758
#  11%|█         | 11/100 [00:03<00:30,  2.93it/s]
#
#  12%|█▏        | 12/100 [00:03<00:28,  3.10it/s]
#
#  13%|█▎        | 13/100 [00:04<00:25,  3.41it/s]
#
#  14%|█▍        | 14/100 [00:04<00:25,  3.33it/s]
#
#  15%|█▌        | 15/100 [00:04<00:25,  3.33it/s]
#
#  16%|█▌        | 16/100 [00:05<00:24,  3.37it/s]
#
#  17%|█▋        | 17/100 [00:05<00:24,  3.40it/s]
#
#  18%|█▊        | 18/100 [00:05<00:24,  3.41it/s]
#
#  19%|█▉        | 19/100 [00:05<00:23,  3.51it/s]
#
#  20%|██        | 20/100 [00:06<00:21,  3.81it/s]
# Epoch 20
# 0.5061426162719727
# 0.005500912666320801
#  21%|██        | 21/100 [00:06<00:20,  3.86it/s]
#
#  22%|██▏       | 22/100 [00:06<00:20,  3.88it/s]
#
#  23%|██▎       | 23/100 [00:06<00:19,  3.87it/s]
#
#  24%|██▍       | 24/100 [00:07<00:19,  3.86it/s]
#
#  25%|██▌       | 25/100 [00:07<00:19,  3.87it/s]
#
#  26%|██▌       | 26/100 [00:07<00:19,  3.88it/s]
#
#  27%|██▋       | 27/100 [00:07<00:18,  3.98it/s]
#
#  28%|██▊       | 28/100 [00:08<00:17,  4.20it/s]
#
#  29%|██▉       | 29/100 [00:08<00:17,  4.07it/s]
#
#  30%|███       | 30/100 [00:08<00:17,  3.97it/s]
# Epoch 30
# 0.5010226368904114
# 0.009992718696594238
#  31%|███       | 31/100 [00:08<00:17,  3.91it/s]
#
#  32%|███▏      | 32/100 [00:09<00:17,  3.92it/s]
#
#  33%|███▎      | 33/100 [00:09<00:17,  3.91it/s]
#
#  34%|███▍      | 34/100 [00:09<00:16,  3.92it/s]
#
#  35%|███▌      | 35/100 [00:09<00:16,  3.99it/s]
#
#  36%|███▌      | 36/100 [00:10<00:15,  4.21it/s]
#
#  37%|███▋      | 37/100 [00:10<00:15,  4.13it/s]
#
#  38%|███▊      | 38/100 [00:10<00:15,  4.06it/s]
#
#  39%|███▉      | 39/100 [00:10<00:15,  4.02it/s]
#
#  40%|████      | 40/100 [00:11<00:15,  4.00it/s]
# Epoch 40
# 0.4950394630432129
# 0.002396225929260254
#  41%|████      | 41/100 [00:11<00:14,  3.97it/s]
#
#  42%|████▏     | 42/100 [00:11<00:14,  3.96it/s]
#
#  43%|████▎     | 43/100 [00:11<00:14,  3.98it/s]
#
#  44%|████▍     | 44/100 [00:12<00:13,  4.23it/s]
#
#  45%|████▌     | 45/100 [00:12<00:13,  4.05it/s]
#
#  46%|████▌     | 46/100 [00:12<00:13,  3.97it/s]
#
#  47%|████▋     | 47/100 [00:12<00:13,  3.91it/s]
#
#  48%|████▊     | 48/100 [00:13<00:13,  3.90it/s]
#
#  49%|████▉     | 49/100 [00:13<00:13,  3.91it/s]
#
#  50%|█████     | 50/100 [00:13<00:12,  3.91it/s]
# Epoch 50
# 0.494007408618927
# 0.005335092544555664
#  51%|█████     | 51/100 [00:13<00:12,  3.96it/s]
#
#  52%|█████▏    | 52/100 [00:14<00:11,  4.18it/s]
#
#  53%|█████▎    | 53/100 [00:14<00:11,  4.12it/s]
#
#  54%|█████▍    | 54/100 [00:14<00:11,  4.04it/s]
#
#  55%|█████▌    | 55/100 [00:14<00:11,  3.97it/s]
#
#  56%|█████▌    | 56/100 [00:15<00:11,  3.93it/s]
#
#  57%|█████▋    | 57/100 [00:15<00:11,  3.90it/s]
#
#  58%|█████▊    | 58/100 [00:15<00:10,  3.91it/s]
#
#  59%|█████▉    | 59/100 [00:15<00:10,  3.99it/s]
#
#  60%|██████    | 60/100 [00:16<00:09,  4.20it/s]
# Epoch 60
# 0.4982408583164215
# 0.0012944936752319336
#  61%|██████    | 61/100 [00:16<00:09,  4.12it/s]
#
#  62%|██████▏   | 62/100 [00:16<00:09,  4.04it/s]
#
#  63%|██████▎   | 63/100 [00:16<00:09,  3.99it/s]
#
#  64%|██████▍   | 64/100 [00:17<00:09,  3.97it/s]
#
#  65%|██████▌   | 65/100 [00:17<00:08,  3.95it/s]
#
#  66%|██████▌   | 66/100 [00:17<00:08,  3.94it/s]
#
#  67%|██████▋   | 67/100 [00:17<00:08,  3.98it/s]
#
#  68%|██████▊   | 68/100 [00:18<00:07,  4.12it/s]
#
#  69%|██████▉   | 69/100 [00:18<00:08,  3.82it/s]
#
#  70%|███████   | 70/100 [00:18<00:08,  3.64it/s]
# Epoch 70
# 0.4997745156288147
# 0.0011900663375854492
#  71%|███████   | 71/100 [00:18<00:08,  3.58it/s]
#
#  72%|███████▏  | 72/100 [00:19<00:08,  3.47it/s]
#
#  73%|███████▎  | 73/100 [00:19<00:07,  3.43it/s]
#
#  74%|███████▍  | 74/100 [00:19<00:07,  3.48it/s]
#
#  75%|███████▌  | 75/100 [00:20<00:06,  3.82it/s]
#
#  76%|███████▌  | 76/100 [00:20<00:06,  3.82it/s]
#
#  77%|███████▋  | 77/100 [00:20<00:05,  3.83it/s]
#
#  78%|███████▊  | 78/100 [00:20<00:05,  3.84it/s]
#
#  79%|███████▉  | 79/100 [00:21<00:05,  3.87it/s]
#
#  80%|████████  | 80/100 [00:21<00:05,  3.89it/s]
# Epoch 80
# 0.5036153793334961
# 0.0011451244354248047
#  81%|████████  | 81/100 [00:21<00:04,  3.89it/s]
#
#  82%|████████▏ | 82/100 [00:21<00:04,  3.97it/s]
#
#  83%|████████▎ | 83/100 [00:22<00:04,  4.17it/s]
#
#  84%|████████▍ | 84/100 [00:22<00:03,  4.08it/s]
#
#  85%|████████▌ | 85/100 [00:22<00:03,  3.99it/s]
#
#  86%|████████▌ | 86/100 [00:22<00:03,  3.84it/s]
#
#  87%|████████▋ | 87/100 [00:23<00:03,  3.75it/s]
#
#  88%|████████▊ | 88/100 [00:23<00:03,  3.73it/s]
#
#  89%|████████▉ | 89/100 [00:23<00:02,  3.79it/s]
#
#  90%|█████████ | 90/100 [00:23<00:02,  3.94it/s]
# Epoch 90
# 0.49446558952331543
# 0.001819014549255371
#  91%|█████████ | 91/100 [00:24<00:02,  4.13it/s]
#
#  92%|█████████▏| 92/100 [00:24<00:02,  3.98it/s]
#
#  93%|█████████▎| 93/100 [00:24<00:01,  3.93it/s]
#
#  94%|█████████▍| 94/100 [00:24<00:01,  3.91it/s]
#
#  95%|█████████▌| 95/100 [00:25<00:01,  3.92it/s]
#
#  96%|█████████▌| 96/100 [00:25<00:01,  3.89it/s]
#
#  97%|█████████▋| 97/100 [00:25<00:00,  3.91it/s]
#
#  98%|█████████▊| 98/100 [00:25<00:00,  4.06it/s]
#
#  99%|█████████▉| 99/100 [00:26<00:00,  4.19it/s]
#
# 100%|██████████| 100/100 [00:26<00:00,  3.79it/s]
# Epoch 100
# 0.5005108118057251
# 0.0006165504455566406
# Best epoch = 98
# Best loss = 0.5404480695724487
# Fit loss = 0.49805721640586853

# %%
plt.plot(lambs, best_losses, marker="o")
plt.plot(lambs, best_regs, marker="o")
plt.xscale('log')
plt.yscale('log')
plt.xlabel(r'$\lambda$',fontsize=15)
plt.ylabel('MSE Loss', fontsize=15)
# Out:
# Text(0, 0.5, 'MSE Loss')

# %%
np.save('./results/lambda_search_gamma_1.npy', np.array([lambs, best_losses, best_regs]))

# %%
plt.figure(figsize=(12,4))

plt.subplot(1,2,1)

data = np.load('./results/lambda_search_gamma_0.npy')
lambs = data[0]
best_losses = data[1]
best_regs = data[2]

plt.plot(lambs, best_losses, marker="o")
plt.plot(lambs, best_regs, marker="o")
plt.xscale('log')
plt.yscale('log')
plt.xlabel(r'$\lambda$',fontsize=15)
plt.ylabel('Loss', fontsize=15)
plt.legend([r"$\ell_1$", r"$\ell_2$"], fontsize=15, loc="upper right")
plt.ylim(1e-7,2)
plt.title(r"$\gamma=0$", fontsize=15)


plt.subplot(1,2,2)

data = np.load('./results/lambda_search_gamma_1.npy')
lambs = data[0]
best_losses = data[1]
best_regs = data[2]

plt.plot(lambs, best_losses, marker="o")
plt.plot(lambs, best_regs, marker="o")
plt.xscale('log')
plt.yscale('log')
plt.xlabel(r'$\lambda$',fontsize=15)
plt.ylabel('Loss', fontsize=15)
#plt.legend([r"$\ell_1$", r"$\ell_2$"], fontsize=15, loc="upper right")
plt.ylim(1e-7,2)
plt.title(r"$\gamma=1$", fontsize=15)
plt.savefig('./1d_ho_lamb_pt.pdf', bbox_inches="tight")
