# %%
import os
import math
import numpy as np
import pandas as po
import matplotlib.pyplot as plt

import torch
from torch import nn
import torch.optim as optim
from torch.autograd import Variable

from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from tqdm import tqdm

#lambs = np.flip([0.01,0.02,0.05,0.1,0.2,0.5,1.0,2.0,5.0,10.0,20.0,50.0,100.0])
#lambs = [1e-4,2e-4,5e-4,1e-3,2e-3,5e-3,0.01,0.02,0.05,0.1,0.2,0.5,1.0,2.0,5.0,10.0,20.0,50.0,100.0,200,500,1000]
lambs = [0.1]
#lambs = np.array([0.01,0.02,0.05,0.1,0.2,0.5,1.0,2.0,5.0,10.0])
wx = 1
wy = 1
folder = "2D_{}_{}".format(wx,wy)

seed = 1
torch.manual_seed(seed)
np.random.seed(seed)

best_losses = []
best_regs = []

num_pts = 1000
#gamma = 10
#lamb = 0.02

data = po.DataFrame()
data['x'] = 4*np.random.rand(num_pts,)-2
data['px'] = 4*np.random.rand(num_pts,)-2

data['y'] = 4*np.random.rand(num_pts,)-2
data['py'] = 4*np.random.rand(num_pts,)-2


data['dx/dt'] = data['px']
data['dpx/dt'] = -wx**2*data['x']

data['dy/dt'] = data['py']
data['dpy/dt'] = -wy**2*data['y']


f_z = torch.tensor(data[['dx/dt', 'dpx/dt', 'dy/dt', 'dpy/dt']].values, requires_grad=True).float()
z = torch.tensor(data[['x', 'px', 'y', 'py']].values, requires_grad=True).float()


# initialize network
num_model = 4
nets = []

class Hnet(nn.Module):
    def __init__(self, z_dim=2, w=400):
        super(Hnet, self).__init__()
        self.z_dim = z_dim
        input_dim = z_dim

        self.h_lin_1 = nn.Linear(input_dim, w) #
        self.h_lin_2 = nn.Linear(w, w) #
        self.h_lin_3 = nn.Linear(w, 1) #
        self.h_relu = nn.ReLU()
        self.h_tanh = nn.Tanh()
        self.h_silu = nn.SiLU()

    def h_z_basic(self, z):
        out = self.h_lin_1(z)
        out = self.h_silu(out)
        out = self.h_lin_2(out)
        out = self.h_silu(out)
        out = self.h_lin_3(out)
        return out

    def h_z(self, z):
        out = self.h_z_basic(z)
        return out

    def forward(self, z, verbose=False):
        bs = z.shape[0]

        h = self.h_z(z)
        dh = torch.autograd.grad(h, z, torch.ones_like(h), create_graph=True, retain_graph=True)[0]
        bs = z.shape[0]
        dh = dh.reshape(bs,-1)
        return dh


def train(nets, f_z, z,
            lr=2e-2,
            epochs = 2000, 
            bs = 100,
            es_delta = 0.000001, 
            epoch_loss = 1e9,
            max_loss_divergence = 0.1,
            weight_decay=0, 
            weight_decay_decay=False,model=None):


    num_model = len(nets)

    z_dim = z.shape[1]
    entropy_dim = np.minimum(num_model, z_dim)
    parameters = list([])
    for i in range(num_model):
        parameters = list(parameters) + list(nets[i].parameters())
    optimizer = optim.Adam(parameters, lr=lr, weight_decay=weight_decay, eps=1e-8)
    #optimizer = optim.SGD(parameters, lr=lr, weight_decay=weight_decay)

    for k in range(num_model):
        nets[k].train()
    losses = []
    losses_fit = []
    losses_reg = []
    lamb_H = 0.00
    lamb_dH = lamb
    loss_pow = 2


    for epoch in tqdm(range(epochs)):
        for i in range((len(f_z) - 1) // bs + 1):
            choices = np.random.choice(len(f_z), bs, replace=False)
            #start_i = i * bs
            #end_i = start_i + bs
            xb = z[choices, :]
            fitloss = 0.
            fitlosses = []
            yb = f_z[choices, :]
            yb = yb.reshape(bs,-1)
            yb_norm = yb/torch.linalg.norm(yb, dim=1, keepdim=True)
            #print("yb", yb_norm.shape)
            for k in range(num_model):
                pred = nets[k](xb)
                #print("pred", pred.shape)
                pred_norm = pred/torch.linalg.norm(pred, dim=1, keepdim=True)
                fit_orth = torch.matmul(yb_norm.unsqueeze(dim=1), pred_norm.unsqueeze(dim=2))
                #print(fit_orth.shape)
                fitloss_ =  torch.mean(torch.abs(fit_orth)**loss_pow)
                #fitloss_each.append(fitloss_.detach().numpy())
                fitloss = fitloss + fitloss_
                fitlosses.append(fitloss_.item())
                H_ = nets[k].h_z(xb)
                dhi = pred_norm

                if k == 0:
                    H = H_
                    dH = dhi.unsqueeze(dim=0)

                else:
                    H = torch.cat((H,H_), dim=1)
                    dH = torch.cat([dH,dhi.unsqueeze(dim=0)])

            fitloss = fitloss/num_model
            # correlation loss
            H = torch.transpose(H,0,1)
            # dH.shape = (bs, num_model, z_dim)
            dH = torch.transpose(dH,0,1)

            # SVD dH
            u, s, v = torch.svd(dH)
            exp_ratio = s**2/torch.sum(s**2, dim=1,keepdim=True)
            exp_av = torch.mean(exp_ratio,dim=0)

            # H regularization
            corr_mat = torch.corrcoef(H)
            if num_model == 1:
                reg_H = torch.tensor(0., dtype=torch.float)
            else:
                reg_H = (torch.sum(corr_mat**loss_pow)-num_model)/(num_model*(num_model-1))

            orth_mat = torch.mean(torch.abs(torch.matmul(dH, torch.transpose(dH,1,2)))**loss_pow, dim=0)
            #print(orth_mat)
            if num_model == 1:
                reg_dH = torch.tensor(0., dtype=torch.float)
            else:
                reg_dH = (torch.sum(orth_mat)-num_model)/(num_model*(num_model-1))

            loss = fitloss + lamb_H*reg_H + lamb_dH*reg_dH

            loss.backward()
            optimizer.step()   

            optimizer.zero_grad()

            losses.append(loss.item())
            losses_fit.append(fitloss.item())
            losses_reg.append(reg_dH.item())
            #print(loss.item(), fitloss.item(), reg_dH.item())

        # Best epoch loss (save best only)
        if (loss<epoch_loss):
            epoch_loss = loss
            epoch_best = epoch
            fit_loss_best = fitloss
            fit_losses_best = fitlosses
            reg_loss_best = reg_dH
            #print("Saving model at epoch {}, current best epoch loss = {}".format(epoch, epoch_loss))
            for k in range(num_model):
                torch.save(nets[k].state_dict(), "./results/"+folder+"/{}.pt".format(k))
            np.save("./results/"+folder+"/fit_loss.npy", fitlosses)
            np.save("./results/"+folder+"/dH_explained.npy", exp_av.detach().numpy())

        # Early Stopping
        #if ((loss<es_delta) or abs(epoch_loss-loss)>max_loss_divergence):
        #    break

        # Print loss
        if ((epoch+1)%10==0):
            print("Epoch {}".format(epoch+1))
            print(fitloss.item())
            #print(fitlosses)
            #print(corr_mat)
            #print(reg_H.item())
            #print(orth_mat)
            print(reg_dH.item())
            #print(exp_av)

    plt.plot(losses)
    plt.plot(losses_fit)
    plt.plot(losses_reg)
    plt.yscale('log')

    print("Best epoch = {}".format(epoch_best))
    print("Best loss = {}".format(epoch_loss))
    print("Fit loss = {}".format(fit_loss_best))
    print("Fit losses = {}")
    print(fit_losses)
    df = po.DataFrame()
    df['losses'] = losses

    return losses, fit_loss_best.detach().numpy(), reg_loss_best.detach().numpy()


for i in range(num_model):
    nets.append(Hnet(z_dim=4, w=400))


for lamb in lambs:
    print("lamb={}".format(lamb))
    loss, fit_best, reg_best = train(nets, f_z, z, lr=1e-3, epochs=1000) 
    best_losses.append(fit_best)
    best_regs.append(reg_best)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# lamb=0.1
#   0%|          | 1/1000 [00:00<04:52,  3.42it/s]
#   0%|          | 2/1000 [00:00<05:06,  3.26it/s]
#   0%|          | 3/1000 [00:01<05:27,  3.04it/s]
#   0%|          | 4/1000 [00:01<05:33,  2.98it/s]
#   0%|          | 5/1000 [00:01<05:48,  2.86it/s]
#   1%|          | 6/1000 [00:02<05:26,  3.04it/s]
#   1%|          | 7/1000 [00:02<05:06,  3.24it/s]
#   1%|          | 8/1000 [00:02<04:46,  3.46it/s]
#   1%|          | 9/1000 [00:02<04:24,  3.74it/s]
#   1%|          | 10/1000 [00:03<04:24,  3.74it/s]
# Epoch 10
# 0.0009428251069039106
# 0.21840453147888184
#   1%|          | 11/1000 [00:03<04:26,  3.72it/s]
#   1%|          | 12/1000 [00:03<04:15,  3.87it/s]
#   1%|▏         | 13/1000 [00:03<04:19,  3.81it/s]
#   1%|▏         | 14/1000 [00:04<04:10,  3.93it/s]
#   2%|▏         | 15/1000 [00:04<03:59,  4.11it/s]
#   2%|▏         | 16/1000 [00:04<03:52,  4.23it/s]
#   2%|▏         | 17/1000 [00:04<03:48,  4.31it/s]
#   2%|▏         | 18/1000 [00:04<03:43,  4.40it/s]
#   2%|▏         | 19/1000 [00:05<03:44,  4.37it/s]
#   2%|▏         | 20/1000 [00:05<03:43,  4.38it/s]
# Epoch 20
# 0.00017596942780073732
# 0.13925480842590332
#   2%|▏         | 21/1000 [00:05<03:40,  4.43it/s]
#   2%|▏         | 22/1000 [00:05<03:40,  4.44it/s]
#   2%|▏         | 23/1000 [00:06<03:40,  4.44it/s]
#   2%|▏         | 24/1000 [00:06<03:36,  4.51it/s]
#   2%|▎         | 25/1000 [00:06<03:39,  4.44it/s]
#   3%|▎         | 26/1000 [00:06<03:37,  4.47it/s]
#   3%|▎         | 27/1000 [00:06<03:44,  4.34it/s]
#   3%|▎         | 28/1000 [00:07<03:43,  4.34it/s]
#   3%|▎         | 29/1000 [00:07<03:43,  4.34it/s]
#   3%|▎         | 30/1000 [00:07<03:37,  4.45it/s]
# Epoch 30
# 7.186949369497597e-05
# 0.1296338587999344
#   3%|▎         | 31/1000 [00:07<03:35,  4.50it/s]
#   3%|▎         | 32/1000 [00:08<03:34,  4.51it/s]
#   3%|▎         | 33/1000 [00:08<03:34,  4.51it/s]
#   3%|▎         | 34/1000 [00:08<03:33,  4.53it/s]
#   4%|▎         | 35/1000 [00:08<03:32,  4.54it/s]
#   4%|▎         | 36/1000 [00:08<03:32,  4.54it/s]
#   4%|▎         | 37/1000 [00:09<03:33,  4.50it/s]
#   4%|▍         | 38/1000 [00:09<03:56,  4.07it/s]
#   4%|▍         | 39/1000 [00:09<03:52,  4.13it/s]
#   4%|▍         | 40/1000 [00:09<03:47,  4.22it/s]
# Epoch 40
# 4.129127410124056e-05
# 0.12875501811504364
#   4%|▍         | 41/1000 [00:10<03:46,  4.23it/s]
#   4%|▍         | 42/1000 [00:10<03:43,  4.28it/s]
#   4%|▍         | 43/1000 [00:10<03:41,  4.31it/s]
#   4%|▍         | 44/1000 [00:10<03:40,  4.33it/s]
#   4%|▍         | 45/1000 [00:11<03:35,  4.42it/s]
#   5%|▍         | 46/1000 [00:11<03:32,  4.50it/s]
#   5%|▍         | 47/1000 [00:11<03:36,  4.41it/s]
#   5%|▍         | 48/1000 [00:11<03:59,  3.97it/s]
#   5%|▍         | 49/1000 [00:12<04:02,  3.92it/s]
#   5%|▌         | 50/1000 [00:12<03:52,  4.09it/s]
# Epoch 50
# 3.053733962588012e-05
# 0.12663491070270538
#   5%|▌         | 51/1000 [00:12<04:01,  3.92it/s]
#   5%|▌         | 52/1000 [00:12<04:24,  3.59it/s]
#   5%|▌         | 53/1000 [00:13<04:47,  3.29it/s]
#   5%|▌         | 54/1000 [00:13<05:12,  3.03it/s]
#   6%|▌         | 55/1000 [00:14<05:51,  2.68it/s]
#   6%|▌         | 56/1000 [00:14<06:06,  2.58it/s]
#   6%|▌         | 57/1000 [00:14<05:51,  2.68it/s]
#   6%|▌         | 58/1000 [00:15<06:01,  2.61it/s]
#   6%|▌         | 59/1000 [00:15<05:46,  2.72it/s]
#   6%|▌         | 60/1000 [00:15<05:26,  2.88it/s]
# Epoch 60
# 3.337606540299021e-05
# 0.1280660629272461
#   6%|▌         | 61/1000 [00:16<04:58,  3.15it/s]
#   6%|▌         | 62/1000 [00:16<05:02,  3.10it/s]
#   6%|▋         | 63/1000 [00:16<05:10,  3.01it/s]
#   6%|▋         | 64/1000 [00:17<05:08,  3.04it/s]
#   6%|▋         | 65/1000 [00:17<05:27,  2.85it/s]
#   7%|▋         | 66/1000 [00:18<06:08,  2.53it/s]
#   7%|▋         | 67/1000 [00:18<06:02,  2.57it/s]
#   7%|▋         | 68/1000 [00:18<05:45,  2.70it/s]
#   7%|▋         | 69/1000 [00:19<05:43,  2.71it/s]
#   7%|▋         | 70/1000 [00:19<06:21,  2.44it/s]
# Epoch 70
# 3.0561015591956675e-05
# 0.1275983601808548
#   7%|▋         | 71/1000 [00:19<05:50,  2.65it/s]
#   7%|▋         | 72/1000 [00:20<06:14,  2.48it/s]
#   7%|▋         | 73/1000 [00:20<06:32,  2.36it/s]
#   7%|▋         | 74/1000 [00:21<06:29,  2.38it/s]
#   8%|▊         | 75/1000 [00:21<06:10,  2.49it/s]
#   8%|▊         | 76/1000 [00:22<05:54,  2.61it/s]
#   8%|▊         | 77/1000 [00:22<05:21,  2.87it/s]
#   8%|▊         | 78/1000 [00:22<05:45,  2.67it/s]
#   8%|▊         | 79/1000 [00:23<05:47,  2.65it/s]
#   8%|▊         | 80/1000 [00:23<05:49,  2.63it/s]
# Epoch 80
# 3.931652463506907e-05
# 0.12635795772075653
#   8%|▊         | 81/1000 [00:23<06:00,  2.55it/s]
#   8%|▊         | 82/1000 [00:24<05:44,  2.67it/s]
#   8%|▊         | 83/1000 [00:24<05:30,  2.78it/s]
#   8%|▊         | 84/1000 [00:24<05:36,  2.72it/s]
#   8%|▊         | 85/1000 [00:25<05:32,  2.75it/s]
#   9%|▊         | 86/1000 [00:25<05:29,  2.77it/s]
#   9%|▊         | 87/1000 [00:26<05:23,  2.82it/s]
#   9%|▉         | 88/1000 [00:26<05:07,  2.97it/s]
#   9%|▉         | 89/1000 [00:26<04:49,  3.15it/s]
#   9%|▉         | 90/1000 [00:26<04:26,  3.42it/s]
# Epoch 90
# 3.9274880691664293e-05
# 0.12639351189136505
#   9%|▉         | 91/1000 [00:27<04:27,  3.40it/s]
#   9%|▉         | 92/1000 [00:27<04:05,  3.69it/s]
#   9%|▉         | 93/1000 [00:27<03:55,  3.85it/s]
#   9%|▉         | 94/1000 [00:27<03:53,  3.87it/s]
#  10%|▉         | 95/1000 [00:28<04:02,  3.74it/s]
#  10%|▉         | 96/1000 [00:28<04:01,  3.75it/s]
#  10%|▉         | 97/1000 [00:28<03:51,  3.91it/s]
#  10%|▉         | 98/1000 [00:28<03:43,  4.04it/s]
#  10%|▉         | 99/1000 [00:29<03:38,  4.13it/s]
#  10%|█         | 100/1000 [00:29<03:37,  4.13it/s]
# Epoch 100
# 4.610150426742621e-05
# 0.1270693987607956
#  10%|█         | 101/1000 [00:29<03:42,  4.05it/s]
#  10%|█         | 102/1000 [00:29<03:46,  3.97it/s]
#  10%|█         | 103/1000 [00:30<03:34,  4.17it/s]
#  10%|█         | 104/1000 [00:30<03:27,  4.31it/s]
#  10%|█         | 105/1000 [00:30<03:27,  4.31it/s]
#  11%|█         | 106/1000 [00:30<03:30,  4.25it/s]
#  11%|█         | 107/1000 [00:30<03:33,  4.18it/s]
#  11%|█         | 108/1000 [00:31<03:35,  4.14it/s]
#  11%|█         | 109/1000 [00:31<03:36,  4.11it/s]
#  11%|█         | 110/1000 [00:31<03:38,  4.08it/s]
# Epoch 110
# 4.089231515536085e-05
# 0.12527894973754883
#  11%|█         | 111/1000 [00:31<03:41,  4.02it/s]
#  11%|█         | 112/1000 [00:32<03:40,  4.02it/s]
#  11%|█▏        | 113/1000 [00:32<03:39,  4.04it/s]
#  11%|█▏        | 114/1000 [00:32<03:42,  3.98it/s]
#  12%|█▏        | 115/1000 [00:32<03:41,  4.00it/s]
#  12%|█▏        | 116/1000 [00:33<03:39,  4.02it/s]
#  12%|█▏        | 117/1000 [00:33<03:37,  4.07it/s]
#  12%|█▏        | 118/1000 [00:33<03:38,  4.04it/s]
#  12%|█▏        | 119/1000 [00:33<03:40,  4.00it/s]
#  12%|█▏        | 120/1000 [00:34<03:44,  3.93it/s]
# Epoch 120
# 7.352513785008341e-05
# 0.1253672093153
#  12%|█▏        | 121/1000 [00:34<03:44,  3.91it/s]
#  12%|█▏        | 122/1000 [00:34<03:41,  3.96it/s]
#  12%|█▏        | 123/1000 [00:34<03:39,  4.00it/s]
#  12%|█▏        | 124/1000 [00:35<03:38,  4.01it/s]
#  12%|█▎        | 125/1000 [00:35<03:36,  4.04it/s]
#  13%|█▎        | 126/1000 [00:35<03:35,  4.06it/s]
#  13%|█▎        | 127/1000 [00:35<03:38,  3.99it/s]
#  13%|█▎        | 128/1000 [00:36<03:37,  4.02it/s]
#  13%|█▎        | 129/1000 [00:36<03:37,  4.00it/s]
#  13%|█▎        | 130/1000 [00:36<03:38,  3.98it/s]
# Epoch 130
# 6.744111306034029e-05
# 0.12451541423797607
#  13%|█▎        | 131/1000 [00:36<03:37,  4.00it/s]
#  13%|█▎        | 132/1000 [00:37<03:36,  4.02it/s]
#  13%|█▎        | 133/1000 [00:37<03:38,  3.96it/s]
#  13%|█▎        | 134/1000 [00:37<03:41,  3.90it/s]
#  14%|█▎        | 135/1000 [00:37<03:41,  3.90it/s]
#  14%|█▎        | 136/1000 [00:38<03:39,  3.93it/s]
#  14%|█▎        | 137/1000 [00:38<03:40,  3.91it/s]
#  14%|█▍        | 138/1000 [00:38<03:40,  3.91it/s]
#  14%|█▍        | 139/1000 [00:39<03:39,  3.93it/s]
#  14%|█▍        | 140/1000 [00:39<03:36,  3.97it/s]
# Epoch 140
# 5.482614869833924e-05
# 0.12478383630514145
#  14%|█▍        | 141/1000 [00:39<03:37,  3.96it/s]
#  14%|█▍        | 142/1000 [00:39<04:00,  3.57it/s]
#  14%|█▍        | 143/1000 [00:40<04:08,  3.46it/s]
#  14%|█▍        | 144/1000 [00:40<04:03,  3.52it/s]
#  14%|█▍        | 145/1000 [00:40<04:15,  3.35it/s]
#  15%|█▍        | 146/1000 [00:41<04:28,  3.18it/s]
#  15%|█▍        | 147/1000 [00:41<04:28,  3.18it/s]
#  15%|█▍        | 148/1000 [00:41<04:11,  3.39it/s]
#  15%|█▍        | 149/1000 [00:41<04:00,  3.54it/s]
#  15%|█▌        | 150/1000 [00:42<03:50,  3.68it/s]
# Epoch 150
# 6.560551264556125e-05
# 0.12336794286966324
#  15%|█▌        | 151/1000 [00:42<03:43,  3.81it/s]
#  15%|█▌        | 152/1000 [00:42<03:38,  3.88it/s]
#  15%|█▌        | 153/1000 [00:42<03:36,  3.90it/s]
#  15%|█▌        | 154/1000 [00:43<03:35,  3.93it/s]
#  16%|█▌        | 155/1000 [00:43<03:33,  3.96it/s]
#  16%|█▌        | 156/1000 [00:43<03:34,  3.94it/s]
#  16%|█▌        | 157/1000 [00:43<03:33,  3.95it/s]
#  16%|█▌        | 158/1000 [00:44<03:30,  4.01it/s]
#  16%|█▌        | 159/1000 [00:44<03:26,  4.07it/s]
#  16%|█▌        | 160/1000 [00:44<03:25,  4.09it/s]
# Epoch 160
# 5.881074321223423e-05
# 0.12293501943349838
#  16%|█▌        | 161/1000 [00:44<03:24,  4.10it/s]
#  16%|█▌        | 162/1000 [00:45<03:24,  4.10it/s]
#  16%|█▋        | 163/1000 [00:45<03:25,  4.08it/s]
#  16%|█▋        | 164/1000 [00:45<03:24,  4.09it/s]
#  16%|█▋        | 165/1000 [00:45<03:27,  4.03it/s]
#  17%|█▋        | 166/1000 [00:46<03:27,  4.02it/s]
#  17%|█▋        | 167/1000 [00:46<03:25,  4.05it/s]
#  17%|█▋        | 168/1000 [00:46<03:25,  4.05it/s]
#  17%|█▋        | 169/1000 [00:46<03:24,  4.07it/s]
#  17%|█▋        | 170/1000 [00:47<03:24,  4.05it/s]
# Epoch 170
# 9.444910392630845e-05
# 0.12187615782022476
#  17%|█▋        | 171/1000 [00:47<03:25,  4.04it/s]
#  17%|█▋        | 172/1000 [00:47<03:25,  4.03it/s]
#  17%|█▋        | 173/1000 [00:47<03:28,  3.97it/s]
#  17%|█▋        | 174/1000 [00:48<03:29,  3.94it/s]
#  18%|█▊        | 175/1000 [00:48<03:27,  3.98it/s]
#  18%|█▊        | 176/1000 [00:48<03:25,  4.01it/s]
#  18%|█▊        | 177/1000 [00:48<03:23,  4.05it/s]
#  18%|█▊        | 178/1000 [00:49<03:22,  4.06it/s]
#  18%|█▊        | 179/1000 [00:49<03:42,  3.70it/s]
#  18%|█▊        | 180/1000 [00:49<04:07,  3.32it/s]
# Epoch 180
# 9.948195656761527e-05
# 0.12155226618051529
#  18%|█▊        | 181/1000 [00:50<03:58,  3.43it/s]
#  18%|█▊        | 182/1000 [00:50<03:49,  3.57it/s]
#  18%|█▊        | 183/1000 [00:50<03:40,  3.70it/s]
#  18%|█▊        | 184/1000 [00:50<03:40,  3.70it/s]
#  18%|█▊        | 185/1000 [00:51<03:49,  3.54it/s]
#  19%|█▊        | 186/1000 [00:51<03:43,  3.64it/s]
#  19%|█▊        | 187/1000 [00:51<03:36,  3.75it/s]
#  19%|█▉        | 188/1000 [00:51<03:36,  3.75it/s]
#  19%|█▉        | 189/1000 [00:52<03:33,  3.80it/s]
#  19%|█▉        | 190/1000 [00:52<03:31,  3.83it/s]
# Epoch 190
# 4.9482154281577095e-05
# 0.12170640379190445
#  19%|█▉        | 191/1000 [00:52<03:29,  3.86it/s]
#  19%|█▉        | 192/1000 [00:52<03:27,  3.89it/s]
#  19%|█▉        | 193/1000 [00:53<03:26,  3.91it/s]
#  19%|█▉        | 194/1000 [00:53<03:25,  3.92it/s]
#  20%|█▉        | 195/1000 [00:53<03:26,  3.90it/s]
#  20%|█▉        | 196/1000 [00:53<03:29,  3.83it/s]
#  20%|█▉        | 197/1000 [00:54<03:25,  3.91it/s]
#  20%|█▉        | 198/1000 [00:54<03:22,  3.97it/s]
#  20%|█▉        | 199/1000 [00:54<03:19,  4.01it/s]
#  20%|██        | 200/1000 [00:54<03:23,  3.94it/s]
# Epoch 200
# 4.891613207291812e-05
# 0.12213333696126938
#  20%|██        | 201/1000 [00:55<03:23,  3.93it/s]
#  20%|██        | 202/1000 [00:55<03:20,  3.97it/s]
#  20%|██        | 203/1000 [00:55<03:24,  3.90it/s]
#  20%|██        | 204/1000 [00:55<03:22,  3.93it/s]
#  20%|██        | 205/1000 [00:56<03:19,  3.98it/s]
#  21%|██        | 206/1000 [00:56<03:20,  3.97it/s]
#  21%|██        | 207/1000 [00:56<03:18,  3.99it/s]
#  21%|██        | 208/1000 [00:56<03:19,  3.98it/s]
#  21%|██        | 209/1000 [00:57<03:17,  4.01it/s]
#  21%|██        | 210/1000 [00:57<03:16,  4.02it/s]
# Epoch 210
# 6.0979022237006575e-05
# 0.12209924310445786
#  21%|██        | 211/1000 [00:57<03:17,  4.00it/s]
#  21%|██        | 212/1000 [00:58<03:19,  3.95it/s]
#  21%|██▏       | 213/1000 [00:58<03:17,  3.98it/s]
#  21%|██▏       | 214/1000 [00:58<03:15,  4.02it/s]
#  22%|██▏       | 215/1000 [00:58<03:14,  4.03it/s]
#  22%|██▏       | 216/1000 [00:58<03:15,  4.00it/s]
#  22%|██▏       | 217/1000 [00:59<03:23,  3.86it/s]
#  22%|██▏       | 218/1000 [00:59<03:21,  3.88it/s]
#  22%|██▏       | 219/1000 [00:59<03:20,  3.89it/s]
#  22%|██▏       | 220/1000 [01:00<03:20,  3.89it/s]
# Epoch 220
# 6.047538772691041e-05
# 0.12140806764364243
#  22%|██▏       | 221/1000 [01:00<03:19,  3.90it/s]
#  22%|██▏       | 222/1000 [01:00<03:22,  3.84it/s]
#  22%|██▏       | 223/1000 [01:00<03:18,  3.91it/s]
#  22%|██▏       | 224/1000 [01:01<03:17,  3.93it/s]
#  22%|██▎       | 225/1000 [01:01<03:16,  3.95it/s]
#  23%|██▎       | 226/1000 [01:01<03:16,  3.94it/s]
#  23%|██▎       | 227/1000 [01:01<03:17,  3.91it/s]
#  23%|██▎       | 228/1000 [01:02<03:20,  3.84it/s]
#  23%|██▎       | 229/1000 [01:02<03:52,  3.32it/s]
#  23%|██▎       | 230/1000 [01:02<04:13,  3.04it/s]
# Epoch 230
# 6.926717469468713e-05
# 0.12226184457540512
#  23%|██▎       | 231/1000 [01:03<04:34,  2.81it/s]
#  23%|██▎       | 232/1000 [01:03<04:42,  2.71it/s]
#  23%|██▎       | 233/1000 [01:04<04:35,  2.78it/s]
#  23%|██▎       | 234/1000 [01:04<04:30,  2.83it/s]
#  24%|██▎       | 235/1000 [01:04<04:25,  2.88it/s]
#  24%|██▎       | 236/1000 [01:05<04:17,  2.97it/s]
#  24%|██▎       | 237/1000 [01:05<04:16,  2.98it/s]
#  24%|██▍       | 238/1000 [01:05<04:15,  2.98it/s]
#  24%|██▍       | 239/1000 [01:06<04:16,  2.96it/s]
#  24%|██▍       | 240/1000 [01:06<04:12,  3.01it/s]
# Epoch 240
# 6.841680442448705e-05
# 0.12063384056091309
#  24%|██▍       | 241/1000 [01:06<04:07,  3.06it/s]
#  24%|██▍       | 242/1000 [01:06<04:05,  3.09it/s]
#  24%|██▍       | 243/1000 [01:07<04:02,  3.12it/s]
#  24%|██▍       | 244/1000 [01:07<04:02,  3.12it/s]
#  24%|██▍       | 245/1000 [01:07<04:03,  3.10it/s]
#  25%|██▍       | 246/1000 [01:08<04:02,  3.11it/s]
#  25%|██▍       | 247/1000 [01:08<04:01,  3.11it/s]
#  25%|██▍       | 248/1000 [01:08<04:12,  2.98it/s]
#  25%|██▍       | 249/1000 [01:09<04:20,  2.89it/s]
#  25%|██▌       | 250/1000 [01:09<04:35,  2.72it/s]
# Epoch 250
# 8.025063289096579e-05
# 0.11992645263671875
#  25%|██▌       | 251/1000 [01:10<04:46,  2.61it/s]
#  25%|██▌       | 252/1000 [01:10<05:05,  2.45it/s]
#  25%|██▌       | 253/1000 [01:11<05:03,  2.46it/s]
#  25%|██▌       | 254/1000 [01:11<04:52,  2.55it/s]
#  26%|██▌       | 255/1000 [01:11<04:48,  2.58it/s]
#  26%|██▌       | 256/1000 [01:12<04:26,  2.80it/s]
#  26%|██▌       | 257/1000 [01:12<05:08,  2.41it/s]
#  26%|██▌       | 258/1000 [01:13<05:13,  2.37it/s]
#  26%|██▌       | 259/1000 [01:13<05:23,  2.29it/s]
#  26%|██▌       | 260/1000 [01:13<05:19,  2.32it/s]
# Epoch 260
# 6.066640708013438e-05
# 0.12035910040140152
#  26%|██▌       | 261/1000 [01:14<04:56,  2.49it/s]
#  26%|██▌       | 262/1000 [01:14<05:05,  2.42it/s]
#  26%|██▋       | 263/1000 [01:15<05:03,  2.43it/s]
#  26%|██▋       | 264/1000 [01:15<04:54,  2.50it/s]
#  26%|██▋       | 265/1000 [01:15<05:15,  2.33it/s]
#  27%|██▋       | 266/1000 [01:16<05:08,  2.38it/s]
#  27%|██▋       | 267/1000 [01:16<05:26,  2.25it/s]
#  27%|██▋       | 268/1000 [01:17<05:21,  2.27it/s]
#  27%|██▋       | 269/1000 [01:17<05:09,  2.37it/s]
#  27%|██▋       | 270/1000 [01:18<05:18,  2.29it/s]
# Epoch 270
# 9.231701551470906e-05
# 0.12028726190328598
#  27%|██▋       | 271/1000 [01:18<05:14,  2.32it/s]
#  27%|██▋       | 272/1000 [01:19<05:10,  2.34it/s]
#  27%|██▋       | 273/1000 [01:19<05:03,  2.40it/s]
#  27%|██▋       | 274/1000 [01:19<04:59,  2.42it/s]
#  28%|██▊       | 275/1000 [01:20<04:33,  2.65it/s]
#  28%|██▊       | 276/1000 [01:20<04:30,  2.67it/s]
#  28%|██▊       | 277/1000 [01:20<04:34,  2.64it/s]
#  28%|██▊       | 278/1000 [01:21<04:29,  2.68it/s]
#  28%|██▊       | 279/1000 [01:21<04:25,  2.71it/s]
#  28%|██▊       | 280/1000 [01:21<04:24,  2.72it/s]
# Epoch 280
# 7.253227522596717e-05
# 0.12054213136434555
#  28%|██▊       | 281/1000 [01:22<04:39,  2.57it/s]
#  28%|██▊       | 282/1000 [01:22<04:19,  2.76it/s]
#  28%|██▊       | 283/1000 [01:23<04:12,  2.84it/s]
#  28%|██▊       | 284/1000 [01:23<03:59,  2.98it/s]
#  28%|██▊       | 285/1000 [01:23<03:49,  3.12it/s]
#  29%|██▊       | 286/1000 [01:23<03:45,  3.17it/s]
#  29%|██▊       | 287/1000 [01:24<03:34,  3.33it/s]
#  29%|██▉       | 288/1000 [01:24<03:35,  3.30it/s]
#  29%|██▉       | 289/1000 [01:24<03:38,  3.25it/s]
#  29%|██▉       | 290/1000 [01:25<03:29,  3.38it/s]
# Epoch 290
# 6.332424527499825e-05
# 0.11987566947937012
#  29%|██▉       | 291/1000 [01:25<03:24,  3.46it/s]
#  29%|██▉       | 292/1000 [01:25<03:26,  3.42it/s]
#  29%|██▉       | 293/1000 [01:25<03:21,  3.50it/s]
#  29%|██▉       | 294/1000 [01:26<03:24,  3.45it/s]
#  30%|██▉       | 295/1000 [01:26<03:35,  3.27it/s]
#  30%|██▉       | 296/1000 [01:26<03:26,  3.40it/s]
#  30%|██▉       | 297/1000 [01:27<03:30,  3.34it/s]
#  30%|██▉       | 298/1000 [01:27<03:36,  3.24it/s]
#  30%|██▉       | 299/1000 [01:27<03:25,  3.41it/s]
#  30%|███       | 300/1000 [01:27<03:22,  3.46it/s]
# Epoch 300
# 7.871630077715963e-05
# 0.1204785481095314
#  30%|███       | 301/1000 [01:28<03:27,  3.37it/s]
#  30%|███       | 302/1000 [01:28<03:30,  3.32it/s]
#  30%|███       | 303/1000 [01:28<03:22,  3.44it/s]
#  30%|███       | 304/1000 [01:29<03:14,  3.59it/s]
#  30%|███       | 305/1000 [01:29<03:16,  3.54it/s]
#  31%|███       | 306/1000 [01:29<03:11,  3.62it/s]
#  31%|███       | 307/1000 [01:29<03:14,  3.56it/s]
#  31%|███       | 308/1000 [01:30<03:16,  3.52it/s]
#  31%|███       | 309/1000 [01:30<03:11,  3.62it/s]
#  31%|███       | 310/1000 [01:30<03:13,  3.56it/s]
# Epoch 310
# 8.012430043891072e-05
# 0.11939068883657455
#  31%|███       | 311/1000 [01:31<03:09,  3.64it/s]
#  31%|███       | 312/1000 [01:31<03:09,  3.64it/s]
#  31%|███▏      | 313/1000 [01:31<03:07,  3.67it/s]
#  31%|███▏      | 314/1000 [01:31<03:04,  3.71it/s]
#  32%|███▏      | 315/1000 [01:32<03:01,  3.78it/s]
#  32%|███▏      | 316/1000 [01:32<03:02,  3.74it/s]
#  32%|███▏      | 317/1000 [01:32<03:08,  3.62it/s]
#  32%|███▏      | 318/1000 [01:32<03:10,  3.59it/s]
#  32%|███▏      | 319/1000 [01:33<03:09,  3.59it/s]
#  32%|███▏      | 320/1000 [01:33<03:06,  3.65it/s]
# Epoch 320
# 7.312661909963936e-05
# 0.11967317014932632
#  32%|███▏      | 321/1000 [01:33<03:00,  3.76it/s]
#  32%|███▏      | 322/1000 [01:34<03:28,  3.26it/s]
#  32%|███▏      | 323/1000 [01:34<03:46,  2.99it/s]
#  32%|███▏      | 324/1000 [01:34<03:34,  3.16it/s]
#  32%|███▎      | 325/1000 [01:35<03:39,  3.07it/s]
#  33%|███▎      | 326/1000 [01:35<04:05,  2.74it/s]
#  33%|███▎      | 327/1000 [01:36<04:15,  2.63it/s]
#  33%|███▎      | 328/1000 [01:36<03:58,  2.82it/s]
#  33%|███▎      | 329/1000 [01:36<03:38,  3.07it/s]
#  33%|███▎      | 330/1000 [01:36<03:30,  3.18it/s]
# Epoch 330
# 0.00010511668369872496
# 0.11996594816446304
#  33%|███▎      | 331/1000 [01:37<03:18,  3.37it/s]
#  33%|███▎      | 332/1000 [01:37<03:09,  3.53it/s]
#  33%|███▎      | 333/1000 [01:37<03:01,  3.67it/s]
#  33%|███▎      | 334/1000 [01:37<03:00,  3.70it/s]
#  34%|███▎      | 335/1000 [01:38<02:56,  3.78it/s]
#  34%|███▎      | 336/1000 [01:38<02:50,  3.89it/s]
#  34%|███▎      | 337/1000 [01:38<03:01,  3.66it/s]
#  34%|███▍      | 338/1000 [01:39<03:05,  3.57it/s]
#  34%|███▍      | 339/1000 [01:39<03:08,  3.51it/s]
#  34%|███▍      | 340/1000 [01:39<03:03,  3.59it/s]
# Epoch 340
# 8.095203520497307e-05
# 0.11952495574951172
#  34%|███▍      | 341/1000 [01:39<03:01,  3.64it/s]
#  34%|███▍      | 342/1000 [01:40<02:57,  3.71it/s]
#  34%|███▍      | 343/1000 [01:40<03:01,  3.62it/s]
#  34%|███▍      | 344/1000 [01:40<03:01,  3.62it/s]
#  34%|███▍      | 345/1000 [01:40<02:58,  3.67it/s]
#  35%|███▍      | 346/1000 [01:41<03:09,  3.46it/s]
#  35%|███▍      | 347/1000 [01:41<03:24,  3.20it/s]
#  35%|███▍      | 348/1000 [01:41<03:29,  3.11it/s]
#  35%|███▍      | 349/1000 [01:42<03:23,  3.20it/s]
#  35%|███▌      | 350/1000 [01:42<03:36,  3.00it/s]
# Epoch 350
# 9.494824917055666e-05
# 0.11921318620443344
#  35%|███▌      | 351/1000 [01:43<03:50,  2.82it/s]
#  35%|███▌      | 352/1000 [01:43<03:36,  3.00it/s]
#  35%|███▌      | 353/1000 [01:43<03:23,  3.18it/s]
#  35%|███▌      | 354/1000 [01:43<03:14,  3.31it/s]
#  36%|███▌      | 355/1000 [01:44<03:14,  3.31it/s]
#  36%|███▌      | 356/1000 [01:44<03:39,  2.93it/s]
#  36%|███▌      | 357/1000 [01:45<04:03,  2.64it/s]
#  36%|███▌      | 358/1000 [01:45<04:19,  2.47it/s]
#  36%|███▌      | 359/1000 [01:46<04:51,  2.20it/s]
#  36%|███▌      | 360/1000 [01:46<05:27,  1.95it/s]
# Epoch 360
# 0.00015771170728839934
# 0.12104082107543945
#  36%|███▌      | 361/1000 [01:47<05:27,  1.95it/s]
#  36%|███▌      | 362/1000 [01:47<04:41,  2.26it/s]
#  36%|███▋      | 363/1000 [01:47<04:08,  2.56it/s]
#  36%|███▋      | 364/1000 [01:48<03:41,  2.87it/s]
#  36%|███▋      | 365/1000 [01:48<03:24,  3.11it/s]
#  37%|███▋      | 366/1000 [01:48<03:12,  3.30it/s]
#  37%|███▋      | 367/1000 [01:48<03:01,  3.49it/s]
#  37%|███▋      | 368/1000 [01:49<02:56,  3.58it/s]
#  37%|███▋      | 369/1000 [01:49<02:51,  3.67it/s]
#  37%|███▋      | 370/1000 [01:49<02:49,  3.71it/s]
# Epoch 370
# 8.375926699955016e-05
# 0.11879976838827133
#  37%|███▋      | 371/1000 [01:49<02:48,  3.74it/s]
#  37%|███▋      | 372/1000 [01:50<02:58,  3.53it/s]
#  37%|███▋      | 373/1000 [01:50<02:53,  3.61it/s]
#  37%|███▋      | 374/1000 [01:50<02:48,  3.71it/s]
#  38%|███▊      | 375/1000 [01:50<02:45,  3.78it/s]
#  38%|███▊      | 376/1000 [01:51<02:41,  3.87it/s]
#  38%|███▊      | 377/1000 [01:51<02:42,  3.84it/s]
#  38%|███▊      | 378/1000 [01:51<02:39,  3.90it/s]
#  38%|███▊      | 379/1000 [01:52<02:55,  3.54it/s]
#  38%|███▊      | 380/1000 [01:52<02:51,  3.63it/s]
# Epoch 380
# 7.881480269134045e-05
# 0.12032294273376465
#  38%|███▊      | 381/1000 [01:52<03:05,  3.33it/s]
#  38%|███▊      | 382/1000 [01:53<03:11,  3.23it/s]
#  38%|███▊      | 383/1000 [01:53<03:17,  3.12it/s]
#  38%|███▊      | 384/1000 [01:53<03:11,  3.22it/s]
#  38%|███▊      | 385/1000 [01:53<03:14,  3.16it/s]
#  39%|███▊      | 386/1000 [01:54<03:03,  3.35it/s]
#  39%|███▊      | 387/1000 [01:54<03:02,  3.35it/s]
#  39%|███▉      | 388/1000 [01:54<02:56,  3.47it/s]
#  39%|███▉      | 389/1000 [01:55<02:53,  3.51it/s]
#  39%|███▉      | 390/1000 [01:55<02:53,  3.52it/s]
# Epoch 390
# 8.449015149381012e-05
# 0.1197170838713646
#  39%|███▉      | 391/1000 [01:55<02:47,  3.63it/s]
#  39%|███▉      | 392/1000 [01:55<02:54,  3.48it/s]
#  39%|███▉      | 393/1000 [01:56<02:51,  3.54it/s]
#  39%|███▉      | 394/1000 [01:56<02:52,  3.52it/s]
#  40%|███▉      | 395/1000 [01:56<03:02,  3.31it/s]
#  40%|███▉      | 396/1000 [01:57<02:55,  3.43it/s]
#  40%|███▉      | 397/1000 [01:57<02:52,  3.50it/s]
#  40%|███▉      | 398/1000 [01:57<02:47,  3.58it/s]
#  40%|███▉      | 399/1000 [01:57<02:46,  3.61it/s]
#  40%|████      | 400/1000 [01:58<02:44,  3.64it/s]
# Epoch 400
# 7.753715908620507e-05
# 0.11901763826608658
#  40%|████      | 401/1000 [01:58<02:42,  3.70it/s]
#  40%|████      | 402/1000 [01:58<02:46,  3.59it/s]
#  40%|████      | 403/1000 [01:59<02:48,  3.54it/s]
#  40%|████      | 404/1000 [01:59<02:44,  3.61it/s]
#  40%|████      | 405/1000 [01:59<03:05,  3.21it/s]
#  41%|████      | 406/1000 [02:00<03:14,  3.06it/s]
#  41%|████      | 407/1000 [02:00<03:12,  3.08it/s]
#  41%|████      | 408/1000 [02:00<03:06,  3.17it/s]
#  41%|████      | 409/1000 [02:01<03:44,  2.63it/s]
#  41%|████      | 410/1000 [02:01<03:24,  2.89it/s]
# Epoch 410
# 7.610365719301626e-05
# 0.11889076232910156
#  41%|████      | 411/1000 [02:01<03:16,  3.00it/s]
#  41%|████      | 412/1000 [02:02<03:07,  3.13it/s]
#  41%|████▏     | 413/1000 [02:02<02:58,  3.29it/s]
#  41%|████▏     | 414/1000 [02:02<03:16,  2.98it/s]
#  42%|████▏     | 415/1000 [02:03<03:34,  2.73it/s]
#  42%|████▏     | 416/1000 [02:03<03:53,  2.50it/s]
#  42%|████▏     | 417/1000 [02:04<04:18,  2.25it/s]
#  42%|████▏     | 418/1000 [02:04<04:33,  2.13it/s]
#  42%|████▏     | 419/1000 [02:05<04:24,  2.19it/s]
#  42%|████▏     | 420/1000 [02:05<03:54,  2.47it/s]
# Epoch 420
# 9.812697680899873e-05
# 0.11949387937784195
#  42%|████▏     | 421/1000 [02:05<03:30,  2.75it/s]
#  42%|████▏     | 422/1000 [02:05<03:18,  2.91it/s]
#  42%|████▏     | 423/1000 [02:06<03:01,  3.17it/s]
#  42%|████▏     | 424/1000 [02:06<02:53,  3.32it/s]
#  42%|████▎     | 425/1000 [02:06<02:44,  3.48it/s]
#  43%|████▎     | 426/1000 [02:07<02:40,  3.58it/s]
#  43%|████▎     | 427/1000 [02:07<02:34,  3.72it/s]
#  43%|████▎     | 428/1000 [02:07<02:30,  3.79it/s]
#  43%|████▎     | 429/1000 [02:07<02:28,  3.85it/s]
#  43%|████▎     | 430/1000 [02:08<02:26,  3.88it/s]
# Epoch 430
# 8.091620838968083e-05
# 0.1192023754119873
#  43%|████▎     | 431/1000 [02:08<02:27,  3.87it/s]
#  43%|████▎     | 432/1000 [02:08<02:26,  3.87it/s]
#  43%|████▎     | 433/1000 [02:08<02:28,  3.82it/s]
#  43%|████▎     | 434/1000 [02:09<02:35,  3.65it/s]
#  44%|████▎     | 435/1000 [02:09<02:46,  3.40it/s]
#  44%|████▎     | 436/1000 [02:09<02:39,  3.54it/s]
#  44%|████▎     | 437/1000 [02:09<02:37,  3.57it/s]
#  44%|████▍     | 438/1000 [02:10<02:50,  3.29it/s]
#  44%|████▍     | 439/1000 [02:10<03:02,  3.07it/s]
#  44%|████▍     | 440/1000 [02:11<02:58,  3.14it/s]
# Epoch 440
# 0.0001146470895037055
# 0.11929869651794434
#  44%|████▍     | 441/1000 [02:11<02:57,  3.15it/s]
#  44%|████▍     | 442/1000 [02:11<02:53,  3.22it/s]
#  44%|████▍     | 443/1000 [02:11<02:50,  3.27it/s]
#  44%|████▍     | 444/1000 [02:12<02:45,  3.35it/s]
#  44%|████▍     | 445/1000 [02:12<02:43,  3.40it/s]
#  45%|████▍     | 446/1000 [02:12<02:44,  3.37it/s]
#  45%|████▍     | 447/1000 [02:13<02:55,  3.15it/s]
#  45%|████▍     | 448/1000 [02:13<03:05,  2.98it/s]
#  45%|████▍     | 449/1000 [02:13<03:20,  2.75it/s]
#  45%|████▌     | 450/1000 [02:14<03:06,  2.95it/s]
# Epoch 450
# 0.00012830726336687803
# 0.11849065870046616
#  45%|████▌     | 451/1000 [02:14<03:09,  2.90it/s]
#  45%|████▌     | 452/1000 [02:15<03:16,  2.79it/s]
#  45%|████▌     | 453/1000 [02:15<03:02,  3.00it/s]
#  45%|████▌     | 454/1000 [02:15<03:00,  3.02it/s]
#  46%|████▌     | 455/1000 [02:15<02:47,  3.25it/s]
#  46%|████▌     | 456/1000 [02:16<02:45,  3.28it/s]
#  46%|████▌     | 457/1000 [02:16<03:08,  2.89it/s]
#  46%|████▌     | 458/1000 [02:17<03:20,  2.71it/s]
#  46%|████▌     | 459/1000 [02:17<03:35,  2.51it/s]
#  46%|████▌     | 460/1000 [02:18<04:06,  2.19it/s]
# Epoch 460
# 8.811489533400163e-05
# 0.11897126585245132
#  46%|████▌     | 461/1000 [02:18<04:17,  2.10it/s]
#  46%|████▌     | 462/1000 [02:18<03:58,  2.26it/s]
#  46%|████▋     | 463/1000 [02:19<03:30,  2.56it/s]
#  46%|████▋     | 464/1000 [02:19<03:11,  2.79it/s]
#  46%|████▋     | 465/1000 [02:19<03:04,  2.90it/s]
#  47%|████▋     | 466/1000 [02:20<02:49,  3.15it/s]
#  47%|████▋     | 467/1000 [02:20<02:39,  3.35it/s]
#  47%|████▋     | 468/1000 [02:20<02:36,  3.40it/s]
#  47%|████▋     | 469/1000 [02:20<02:28,  3.57it/s]
#  47%|████▋     | 470/1000 [02:21<02:25,  3.65it/s]
# Epoch 470
# 7.872406422393396e-05
# 0.11906973272562027
#  47%|████▋     | 471/1000 [02:21<02:19,  3.78it/s]
#  47%|████▋     | 472/1000 [02:21<02:17,  3.83it/s]
#  47%|████▋     | 473/1000 [02:21<02:16,  3.85it/s]
#  47%|████▋     | 474/1000 [02:22<02:15,  3.90it/s]
#  48%|████▊     | 475/1000 [02:22<02:20,  3.73it/s]
#  48%|████▊     | 476/1000 [02:22<02:20,  3.72it/s]
#  48%|████▊     | 477/1000 [02:22<02:17,  3.80it/s]
#  48%|████▊     | 478/1000 [02:23<02:15,  3.85it/s]
#  48%|████▊     | 479/1000 [02:23<02:12,  3.93it/s]
#  48%|████▊     | 480/1000 [02:23<02:27,  3.53it/s]
# Epoch 480
# 9.146958473138511e-05
# 0.1182420626282692
#  48%|████▊     | 481/1000 [02:24<02:23,  3.63it/s]
#  48%|████▊     | 482/1000 [02:24<02:18,  3.73it/s]
#  48%|████▊     | 483/1000 [02:24<02:14,  3.86it/s]
#  48%|████▊     | 484/1000 [02:24<02:12,  3.88it/s]
#  48%|████▊     | 485/1000 [02:25<02:11,  3.92it/s]
#  49%|████▊     | 486/1000 [02:25<02:13,  3.86it/s]
#  49%|████▊     | 487/1000 [02:25<02:22,  3.59it/s]
#  49%|████▉     | 488/1000 [02:26<02:44,  3.11it/s]
#  49%|████▉     | 489/1000 [02:26<02:46,  3.07it/s]
#  49%|████▉     | 490/1000 [02:26<02:45,  3.07it/s]
# Epoch 490
# 9.704494732432067e-05
# 0.11962556838989258
#  49%|████▉     | 491/1000 [02:26<02:36,  3.25it/s]
#  49%|████▉     | 492/1000 [02:27<02:29,  3.40it/s]
#  49%|████▉     | 493/1000 [02:27<02:24,  3.51it/s]
#  49%|████▉     | 494/1000 [02:27<02:20,  3.59it/s]
#  50%|████▉     | 495/1000 [02:28<02:19,  3.61it/s]
#  50%|████▉     | 496/1000 [02:28<02:16,  3.69it/s]
#  50%|████▉     | 497/1000 [02:28<02:21,  3.55it/s]
#  50%|████▉     | 498/1000 [02:28<02:27,  3.40it/s]
#  50%|████▉     | 499/1000 [02:29<02:23,  3.49it/s]
#  50%|█████     | 500/1000 [02:29<02:21,  3.54it/s]
# Epoch 500
# 8.862819959176704e-05
# 0.11900480836629868
#  50%|█████     | 501/1000 [02:29<02:39,  3.12it/s]
#  50%|█████     | 502/1000 [02:30<02:45,  3.00it/s]
#  50%|█████     | 503/1000 [02:30<02:46,  2.98it/s]
#  50%|█████     | 504/1000 [02:30<02:52,  2.87it/s]
#  50%|█████     | 505/1000 [02:31<02:55,  2.82it/s]
#  51%|█████     | 506/1000 [02:31<02:41,  3.05it/s]
#  51%|█████     | 507/1000 [02:31<02:36,  3.15it/s]
#  51%|█████     | 508/1000 [02:32<02:27,  3.33it/s]
#  51%|█████     | 509/1000 [02:32<02:44,  2.99it/s]
#  51%|█████     | 510/1000 [02:33<03:05,  2.64it/s]
# Epoch 510
# 9.027580381371081e-05
# 0.11982131004333496
#  51%|█████     | 511/1000 [02:33<03:26,  2.37it/s]
#  51%|█████     | 512/1000 [02:34<03:44,  2.17it/s]
#  51%|█████▏    | 513/1000 [02:34<03:57,  2.05it/s]
#  51%|█████▏    | 514/1000 [02:35<03:58,  2.04it/s]
#  52%|█████▏    | 515/1000 [02:35<03:30,  2.30it/s]
#  52%|█████▏    | 516/1000 [02:35<03:06,  2.60it/s]
#  52%|█████▏    | 517/1000 [02:36<02:51,  2.82it/s]
#  52%|█████▏    | 518/1000 [02:36<02:37,  3.07it/s]
#  52%|█████▏    | 519/1000 [02:36<02:29,  3.22it/s]
#  52%|█████▏    | 520/1000 [02:36<02:20,  3.42it/s]
# Epoch 520
# 9.240867075277492e-05
# 0.11909707635641098
#  52%|█████▏    | 521/1000 [02:37<02:16,  3.52it/s]
#  52%|█████▏    | 522/1000 [02:37<02:09,  3.68it/s]
#  52%|█████▏    | 523/1000 [02:37<02:07,  3.73it/s]
#  52%|█████▏    | 524/1000 [02:37<02:10,  3.65it/s]
#  52%|█████▎    | 525/1000 [02:38<02:07,  3.74it/s]
#  53%|█████▎    | 526/1000 [02:38<02:06,  3.74it/s]
#  53%|█████▎    | 527/1000 [02:38<02:07,  3.71it/s]
#  53%|█████▎    | 528/1000 [02:38<02:09,  3.65it/s]
#  53%|█████▎    | 529/1000 [02:39<02:07,  3.69it/s]
#  53%|█████▎    | 530/1000 [02:39<02:12,  3.54it/s]
# Epoch 530
# 9.540612518321723e-05
# 0.11750078201293945
#  53%|█████▎    | 531/1000 [02:39<02:08,  3.64it/s]
#  53%|█████▎    | 532/1000 [02:40<02:06,  3.69it/s]
#  53%|█████▎    | 533/1000 [02:40<02:04,  3.74it/s]
#  53%|█████▎    | 534/1000 [02:40<02:02,  3.81it/s]
#  54%|█████▎    | 535/1000 [02:40<02:01,  3.84it/s]
#  54%|█████▎    | 536/1000 [02:41<02:00,  3.84it/s]
#  54%|█████▎    | 537/1000 [02:41<01:58,  3.92it/s]
#  54%|█████▍    | 538/1000 [02:41<01:58,  3.91it/s]
#  54%|█████▍    | 539/1000 [02:41<02:04,  3.70it/s]
#  54%|█████▍    | 540/1000 [02:42<02:19,  3.30it/s]
# Epoch 540
# 7.365721103269607e-05
# 0.11928872019052505
#  54%|█████▍    | 541/1000 [02:42<02:24,  3.17it/s]
#  54%|█████▍    | 542/1000 [02:42<02:27,  3.10it/s]
#  54%|█████▍    | 543/1000 [02:43<02:24,  3.17it/s]
#  54%|█████▍    | 544/1000 [02:43<02:18,  3.30it/s]
#  55%|█████▍    | 545/1000 [02:43<02:10,  3.49it/s]
#  55%|█████▍    | 546/1000 [02:44<02:05,  3.63it/s]
#  55%|█████▍    | 547/1000 [02:44<02:00,  3.75it/s]
#  55%|█████▍    | 548/1000 [02:44<01:58,  3.81it/s]
#  55%|█████▍    | 549/1000 [02:44<02:01,  3.71it/s]
#  55%|█████▌    | 550/1000 [02:45<02:11,  3.42it/s]
# Epoch 550
# 7.485091191483662e-05
# 0.11945275217294693
#  55%|█████▌    | 551/1000 [02:45<02:32,  2.95it/s]
#  55%|█████▌    | 552/1000 [02:46<02:48,  2.67it/s]
#  55%|█████▌    | 553/1000 [02:46<03:01,  2.46it/s]
#  55%|█████▌    | 554/1000 [02:46<03:08,  2.37it/s]
#  56%|█████▌    | 555/1000 [02:47<03:07,  2.38it/s]
#  56%|█████▌    | 556/1000 [02:47<03:25,  2.16it/s]
#  56%|█████▌    | 557/1000 [02:48<03:35,  2.06it/s]
#  56%|█████▌    | 558/1000 [02:49<03:45,  1.96it/s]
#  56%|█████▌    | 559/1000 [02:49<03:36,  2.03it/s]
#  56%|█████▌    | 560/1000 [02:49<03:09,  2.32it/s]
# Epoch 560
# 8.437188807874918e-05
# 0.11831390857696533
#  56%|█████▌    | 561/1000 [02:50<02:45,  2.65it/s]
#  56%|█████▌    | 562/1000 [02:50<02:29,  2.94it/s]
#  56%|█████▋    | 563/1000 [02:50<02:24,  3.02it/s]
#  56%|█████▋    | 564/1000 [02:50<02:15,  3.21it/s]
#  56%|█████▋    | 565/1000 [02:51<02:20,  3.10it/s]
#  57%|█████▋    | 566/1000 [02:51<02:10,  3.32it/s]
#  57%|█████▋    | 567/1000 [02:51<02:02,  3.52it/s]
#  57%|█████▋    | 568/1000 [02:51<01:58,  3.66it/s]
#  57%|█████▋    | 569/1000 [02:52<01:54,  3.77it/s]
#  57%|█████▋    | 570/1000 [02:52<02:07,  3.39it/s]
# Epoch 570
# 8.603591413702816e-05
# 0.11862325668334961
#  57%|█████▋    | 571/1000 [02:52<02:11,  3.26it/s]
#  57%|█████▋    | 572/1000 [02:53<02:05,  3.40it/s]
#  57%|█████▋    | 573/1000 [02:53<02:09,  3.30it/s]
#  57%|█████▋    | 574/1000 [02:53<02:03,  3.46it/s]
#  57%|█████▊    | 575/1000 [02:54<01:58,  3.58it/s]
#  58%|█████▊    | 576/1000 [02:54<01:56,  3.63it/s]
#  58%|█████▊    | 577/1000 [02:54<01:56,  3.63it/s]
#  58%|█████▊    | 578/1000 [02:54<01:55,  3.64it/s]
#  58%|█████▊    | 579/1000 [02:55<01:52,  3.74it/s]
#  58%|█████▊    | 580/1000 [02:55<01:51,  3.75it/s]
# Epoch 580
# 0.00016170291928574443
# 0.11775032430887222
#  58%|█████▊    | 581/1000 [02:55<01:50,  3.80it/s]
#  58%|█████▊    | 582/1000 [02:55<01:48,  3.84it/s]
#  58%|█████▊    | 583/1000 [02:56<01:48,  3.84it/s]
#  58%|█████▊    | 584/1000 [02:56<01:54,  3.63it/s]
#  58%|█████▊    | 585/1000 [02:56<02:07,  3.25it/s]
#  59%|█████▊    | 586/1000 [02:57<02:16,  3.03it/s]
#  59%|█████▊    | 587/1000 [02:57<02:25,  2.84it/s]
#  59%|█████▉    | 588/1000 [02:57<02:21,  2.90it/s]
#  59%|█████▉    | 589/1000 [02:58<02:15,  3.04it/s]
#  59%|█████▉    | 590/1000 [02:58<02:11,  3.12it/s]
# Epoch 590
# 8.890108438208699e-05
# 0.1184830293059349
#  59%|█████▉    | 591/1000 [02:58<02:07,  3.21it/s]
#  59%|█████▉    | 592/1000 [02:59<02:02,  3.32it/s]
#  59%|█████▉    | 593/1000 [02:59<02:00,  3.39it/s]
#  59%|█████▉    | 594/1000 [02:59<01:58,  3.44it/s]
#  60%|█████▉    | 595/1000 [02:59<01:59,  3.39it/s]
#  60%|█████▉    | 596/1000 [03:00<02:00,  3.36it/s]
#  60%|█████▉    | 597/1000 [03:00<01:59,  3.39it/s]
#  60%|█████▉    | 598/1000 [03:00<01:58,  3.40it/s]
#  60%|█████▉    | 599/1000 [03:01<01:53,  3.54it/s]
#  60%|██████    | 600/1000 [03:01<01:55,  3.48it/s]
# Epoch 600
# 9.44842176977545e-05
# 0.11893057823181152
#  60%|██████    | 601/1000 [03:01<02:00,  3.31it/s]
#  60%|██████    | 602/1000 [03:02<02:02,  3.25it/s]
#  60%|██████    | 603/1000 [03:02<01:57,  3.38it/s]
#  60%|██████    | 604/1000 [03:02<01:52,  3.52it/s]
#  60%|██████    | 605/1000 [03:02<01:56,  3.40it/s]
#  61%|██████    | 606/1000 [03:03<01:57,  3.36it/s]
#  61%|██████    | 607/1000 [03:03<01:59,  3.28it/s]
#  61%|██████    | 608/1000 [03:03<02:04,  3.15it/s]
#  61%|██████    | 609/1000 [03:04<02:23,  2.73it/s]
#  61%|██████    | 610/1000 [03:04<02:30,  2.60it/s]
# Epoch 610
# 6.950506940484047e-05
# 0.11837927252054214
#  61%|██████    | 611/1000 [03:05<02:18,  2.80it/s]
#  61%|██████    | 612/1000 [03:05<02:07,  3.05it/s]
#  61%|██████▏   | 613/1000 [03:05<02:10,  2.97it/s]
#  61%|██████▏   | 614/1000 [03:05<02:05,  3.07it/s]
#  62%|██████▏   | 615/1000 [03:06<02:15,  2.83it/s]
#  62%|██████▏   | 616/1000 [03:06<02:16,  2.82it/s]
#  62%|██████▏   | 617/1000 [03:07<02:12,  2.90it/s]
#  62%|██████▏   | 618/1000 [03:07<02:07,  3.00it/s]
#  62%|██████▏   | 619/1000 [03:07<02:04,  3.07it/s]
#  62%|██████▏   | 620/1000 [03:08<02:03,  3.07it/s]
# Epoch 620
# 9.287121065426618e-05
# 0.11779308319091797
#  62%|██████▏   | 621/1000 [03:08<02:02,  3.10it/s]
#  62%|██████▏   | 622/1000 [03:08<02:07,  2.98it/s]
#  62%|██████▏   | 623/1000 [03:09<02:06,  2.97it/s]
#  62%|██████▏   | 624/1000 [03:09<02:01,  3.10it/s]
#  62%|██████▎   | 625/1000 [03:09<01:54,  3.27it/s]
#  63%|██████▎   | 626/1000 [03:09<01:53,  3.29it/s]
#  63%|██████▎   | 627/1000 [03:10<01:51,  3.34it/s]
#  63%|██████▎   | 628/1000 [03:10<01:46,  3.49it/s]
#  63%|██████▎   | 629/1000 [03:10<01:43,  3.60it/s]
#  63%|██████▎   | 630/1000 [03:10<01:41,  3.63it/s]
# Epoch 630
# 0.00014987522445153445
# 0.11777333170175552
#  63%|██████▎   | 631/1000 [03:11<01:42,  3.59it/s]
#  63%|██████▎   | 632/1000 [03:11<01:43,  3.54it/s]
#  63%|██████▎   | 633/1000 [03:11<01:47,  3.42it/s]
#  63%|██████▎   | 634/1000 [03:12<01:43,  3.55it/s]
#  64%|██████▎   | 635/1000 [03:12<01:41,  3.60it/s]
#  64%|██████▎   | 636/1000 [03:12<01:43,  3.52it/s]
#  64%|██████▎   | 637/1000 [03:13<01:51,  3.25it/s]
#  64%|██████▍   | 638/1000 [03:13<01:55,  3.13it/s]
#  64%|██████▍   | 639/1000 [03:13<01:49,  3.28it/s]
#  64%|██████▍   | 640/1000 [03:13<01:45,  3.41it/s]
# Epoch 640
# 9.907985804602504e-05
# 0.1177757978439331
#  64%|██████▍   | 641/1000 [03:14<01:40,  3.57it/s]
#  64%|██████▍   | 642/1000 [03:14<01:38,  3.65it/s]
#  64%|██████▍   | 643/1000 [03:14<01:35,  3.73it/s]
#  64%|██████▍   | 644/1000 [03:14<01:34,  3.78it/s]
#  64%|██████▍   | 645/1000 [03:15<01:31,  3.89it/s]
#  65%|██████▍   | 646/1000 [03:15<01:30,  3.90it/s]
#  65%|██████▍   | 647/1000 [03:15<01:30,  3.92it/s]
#  65%|██████▍   | 648/1000 [03:16<01:41,  3.45it/s]
#  65%|██████▍   | 649/1000 [03:16<01:46,  3.30it/s]
#  65%|██████▌   | 650/1000 [03:16<01:42,  3.43it/s]
# Epoch 650
# 0.00014518064563162625
# 0.11709252744913101
#  65%|██████▌   | 651/1000 [03:16<01:41,  3.44it/s]
#  65%|██████▌   | 652/1000 [03:17<01:42,  3.39it/s]
#  65%|██████▌   | 653/1000 [03:17<01:40,  3.44it/s]
#  65%|██████▌   | 654/1000 [03:17<01:44,  3.31it/s]
#  66%|██████▌   | 655/1000 [03:18<01:45,  3.27it/s]
#  66%|██████▌   | 656/1000 [03:18<01:45,  3.27it/s]
#  66%|██████▌   | 657/1000 [03:18<01:42,  3.35it/s]
#  66%|██████▌   | 658/1000 [03:19<01:39,  3.45it/s]
#  66%|██████▌   | 659/1000 [03:19<01:48,  3.15it/s]
#  66%|██████▌   | 660/1000 [03:20<02:24,  2.35it/s]
# Epoch 660
# 7.816586003173143e-05
# 0.11906925588846207
#  66%|██████▌   | 661/1000 [03:20<03:08,  1.80it/s]
#  66%|██████▌   | 662/1000 [03:21<02:57,  1.90it/s]
#  66%|██████▋   | 663/1000 [03:21<02:52,  1.95it/s]
#  66%|██████▋   | 664/1000 [03:22<02:53,  1.94it/s]
#  66%|██████▋   | 665/1000 [03:22<02:47,  2.00it/s]
#  67%|██████▋   | 666/1000 [03:23<03:04,  1.81it/s]
#  67%|██████▋   | 667/1000 [03:24<03:12,  1.73it/s]
#  67%|██████▋   | 668/1000 [03:24<02:59,  1.85it/s]
#  67%|██████▋   | 669/1000 [03:25<03:20,  1.65it/s]
#  67%|██████▋   | 670/1000 [03:25<03:11,  1.72it/s]
# Epoch 670
# 8.249371603596956e-05
# 0.11810564994812012
#  67%|██████▋   | 671/1000 [03:26<03:01,  1.81it/s]
#  67%|██████▋   | 672/1000 [03:26<02:52,  1.90it/s]
#  67%|██████▋   | 673/1000 [03:27<02:52,  1.90it/s]
#  67%|██████▋   | 674/1000 [03:27<02:46,  1.96it/s]
#  68%|██████▊   | 675/1000 [03:28<02:47,  1.94it/s]
#  68%|██████▊   | 676/1000 [03:28<02:53,  1.87it/s]
#  68%|██████▊   | 677/1000 [03:29<02:42,  1.98it/s]
#  68%|██████▊   | 678/1000 [03:29<02:37,  2.04it/s]
#  68%|██████▊   | 679/1000 [03:30<02:33,  2.09it/s]
#  68%|██████▊   | 680/1000 [03:30<02:28,  2.15it/s]
# Epoch 680
# 0.00014040779205970466
# 0.11774373054504395
#  68%|██████▊   | 681/1000 [03:31<02:23,  2.22it/s]
#  68%|██████▊   | 682/1000 [03:31<02:23,  2.21it/s]
#  68%|██████▊   | 683/1000 [03:32<02:27,  2.15it/s]
#  68%|██████▊   | 684/1000 [03:32<02:28,  2.12it/s]
#  68%|██████▊   | 685/1000 [03:33<02:44,  1.91it/s]
#  69%|██████▊   | 686/1000 [03:33<02:38,  1.98it/s]
#  69%|██████▊   | 687/1000 [03:34<02:33,  2.04it/s]
#  69%|██████▉   | 688/1000 [03:34<02:29,  2.08it/s]
#  69%|██████▉   | 689/1000 [03:35<02:27,  2.11it/s]
#  69%|██████▉   | 690/1000 [03:35<02:19,  2.23it/s]
# Epoch 690
# 9.31128888623789e-05
# 0.11713329702615738
#  69%|██████▉   | 691/1000 [03:36<02:35,  1.98it/s]
#  69%|██████▉   | 692/1000 [03:36<02:52,  1.79it/s]
#  69%|██████▉   | 693/1000 [03:37<02:46,  1.85it/s]
#  69%|██████▉   | 694/1000 [03:37<02:40,  1.91it/s]
#  70%|██████▉   | 695/1000 [03:38<02:53,  1.76it/s]
#  70%|██████▉   | 696/1000 [03:39<02:54,  1.74it/s]
#  70%|██████▉   | 697/1000 [03:39<02:40,  1.89it/s]
#  70%|██████▉   | 698/1000 [03:40<02:51,  1.76it/s]
#  70%|██████▉   | 699/1000 [03:40<02:54,  1.73it/s]
#  70%|███████   | 700/1000 [03:41<02:40,  1.87it/s]
# Epoch 700
# 0.00012287702702451497
# 0.11590508371591568
#  70%|███████   | 701/1000 [03:42<03:11,  1.56it/s]
#  70%|███████   | 702/1000 [03:43<04:24,  1.13it/s]
#  70%|███████   | 703/1000 [03:44<04:42,  1.05it/s]
#  70%|███████   | 704/1000 [03:45<05:16,  1.07s/it]
#  70%|███████   | 705/1000 [03:47<05:20,  1.09s/it]
#  71%|███████   | 706/1000 [03:48<05:32,  1.13s/it]
#  71%|███████   | 707/1000 [03:49<05:52,  1.20s/it]
#  71%|███████   | 708/1000 [03:50<05:52,  1.21s/it]
#  71%|███████   | 709/1000 [03:52<05:52,  1.21s/it]
#  71%|███████   | 710/1000 [03:53<05:37,  1.17s/it]
# Epoch 710
# 0.00011904051643796265
# 0.11718396097421646
#  71%|███████   | 711/1000 [03:54<05:53,  1.22s/it]
#  71%|███████   | 712/1000 [03:55<05:56,  1.24s/it]
#  71%|███████▏  | 713/1000 [03:57<06:12,  1.30s/it]
#  71%|███████▏  | 714/1000 [03:58<06:16,  1.32s/it]
#  72%|███████▏  | 715/1000 [03:59<06:04,  1.28s/it]
#  72%|███████▏  | 716/1000 [04:00<05:38,  1.19s/it]
#  72%|███████▏  | 717/1000 [04:01<05:17,  1.12s/it]
#  72%|███████▏  | 718/1000 [04:02<04:55,  1.05s/it]
#  72%|███████▏  | 719/1000 [04:03<05:00,  1.07s/it]
#  72%|███████▏  | 720/1000 [04:04<04:58,  1.06s/it]
# Epoch 720
# 8.500058902427554e-05
# 0.11817479133605957
#  72%|███████▏  | 721/1000 [04:05<04:54,  1.06s/it]
#  72%|███████▏  | 722/1000 [04:06<04:48,  1.04s/it]
#  72%|███████▏  | 723/1000 [04:08<05:06,  1.10s/it]
#  72%|███████▏  | 724/1000 [04:09<05:20,  1.16s/it]
#  72%|███████▎  | 725/1000 [04:10<05:05,  1.11s/it]
#  73%|███████▎  | 726/1000 [04:11<04:55,  1.08s/it]
#  73%|███████▎  | 727/1000 [04:12<04:45,  1.05s/it]
#  73%|███████▎  | 728/1000 [04:13<04:36,  1.01s/it]
#  73%|███████▎  | 729/1000 [04:14<04:38,  1.03s/it]
#  73%|███████▎  | 730/1000 [04:15<04:53,  1.09s/it]
# Epoch 730
# 9.77573508862406e-05
# 0.1177581176161766
#  73%|███████▎  | 731/1000 [04:16<05:08,  1.15s/it]
#  73%|███████▎  | 732/1000 [04:17<04:55,  1.10s/it]
#  73%|███████▎  | 733/1000 [04:19<05:18,  1.19s/it]
#  73%|███████▎  | 734/1000 [04:20<05:02,  1.14s/it]
#  74%|███████▎  | 735/1000 [04:21<04:51,  1.10s/it]
#  74%|███████▎  | 736/1000 [04:22<04:50,  1.10s/it]
#  74%|███████▎  | 737/1000 [04:23<05:19,  1.22s/it]
#  74%|███████▍  | 738/1000 [04:25<05:18,  1.22s/it]
#  74%|███████▍  | 739/1000 [04:25<04:44,  1.09s/it]
#  74%|███████▍  | 740/1000 [04:27<05:23,  1.24s/it]
# Epoch 740
# 9.076220885617658e-05
# 0.11813632398843765
#  74%|███████▍  | 741/1000 [04:29<05:52,  1.36s/it]
#  74%|███████▍  | 742/1000 [04:31<06:48,  1.58s/it]
#  74%|███████▍  | 743/1000 [04:32<06:25,  1.50s/it]
#  74%|███████▍  | 744/1000 [04:33<05:42,  1.34s/it]
#  74%|███████▍  | 745/1000 [04:34<05:26,  1.28s/it]
#  75%|███████▍  | 746/1000 [04:35<05:21,  1.26s/it]
#  75%|███████▍  | 747/1000 [04:37<05:08,  1.22s/it]
#  75%|███████▍  | 748/1000 [04:38<05:06,  1.22s/it]
#  75%|███████▍  | 749/1000 [04:39<05:04,  1.21s/it]
#  75%|███████▌  | 750/1000 [04:40<05:26,  1.31s/it]
# Epoch 750
# 9.265601693186909e-05
# 0.11784911155700684
#  75%|███████▌  | 751/1000 [04:42<05:39,  1.36s/it]
#  75%|███████▌  | 752/1000 [04:44<05:55,  1.43s/it]
#  75%|███████▌  | 753/1000 [04:45<05:37,  1.37s/it]
#  75%|███████▌  | 754/1000 [04:46<05:32,  1.35s/it]
#  76%|███████▌  | 755/1000 [04:47<05:33,  1.36s/it]
#  76%|███████▌  | 756/1000 [04:49<05:16,  1.30s/it]
#  76%|███████▌  | 757/1000 [04:50<05:03,  1.25s/it]
#  76%|███████▌  | 758/1000 [04:51<05:10,  1.28s/it]
#  76%|███████▌  | 759/1000 [04:52<05:05,  1.27s/it]
#  76%|███████▌  | 760/1000 [04:54<05:16,  1.32s/it]
# Epoch 760
# 8.775116293691099e-05
# 0.11693195253610611
#  76%|███████▌  | 761/1000 [04:56<06:07,  1.54s/it]
#  76%|███████▌  | 762/1000 [04:58<07:19,  1.85s/it]
#  76%|███████▋  | 763/1000 [05:01<07:39,  1.94s/it]
#  76%|███████▋  | 764/1000 [05:03<08:06,  2.06s/it]
#  76%|███████▋  | 765/1000 [05:05<08:18,  2.12s/it]
#  77%|███████▋  | 766/1000 [05:07<08:02,  2.06s/it]
#  77%|███████▋  | 767/1000 [05:09<08:07,  2.09s/it]
#  77%|███████▋  | 768/1000 [05:11<07:58,  2.06s/it]
#  77%|███████▋  | 769/1000 [05:13<07:53,  2.05s/it]
#  77%|███████▋  | 770/1000 [05:15<07:54,  2.06s/it]
# Epoch 770
# 9.318530646851286e-05
# 0.1176966056227684
#  77%|███████▋  | 771/1000 [05:17<07:41,  2.01s/it]
#  77%|███████▋  | 772/1000 [05:19<07:28,  1.97s/it]
#  77%|███████▋  | 773/1000 [05:21<07:10,  1.90s/it]
#  77%|███████▋  | 774/1000 [05:23<07:02,  1.87s/it]
#  78%|███████▊  | 775/1000 [05:25<07:08,  1.91s/it]
#  78%|███████▊  | 776/1000 [05:27<07:18,  1.96s/it]
#  78%|███████▊  | 777/1000 [05:29<07:30,  2.02s/it]
#  78%|███████▊  | 778/1000 [05:31<07:18,  1.98s/it]
#  78%|███████▊  | 779/1000 [05:33<07:19,  1.99s/it]
#  78%|███████▊  | 780/1000 [05:35<07:02,  1.92s/it]
# Epoch 780
# 8.839082147460431e-05
# 0.11790871620178223
#  78%|███████▊  | 781/1000 [05:36<06:54,  1.89s/it]
#  78%|███████▊  | 782/1000 [05:38<06:54,  1.90s/it]
#  78%|███████▊  | 783/1000 [05:40<06:52,  1.90s/it]
#  78%|███████▊  | 784/1000 [05:42<06:46,  1.88s/it]
#  78%|███████▊  | 785/1000 [05:44<06:59,  1.95s/it]
#  79%|███████▊  | 786/1000 [05:46<07:00,  1.97s/it]
#  79%|███████▊  | 787/1000 [05:48<07:03,  1.99s/it]
#  79%|███████▉  | 788/1000 [05:50<07:10,  2.03s/it]
#  79%|███████▉  | 789/1000 [05:52<07:00,  1.99s/it]
#  79%|███████▉  | 790/1000 [05:54<07:06,  2.03s/it]
# Epoch 790
# 8.754152804613113e-05
# 0.11745274066925049
#  79%|███████▉  | 791/1000 [05:56<06:55,  1.99s/it]
#  79%|███████▉  | 792/1000 [05:58<06:47,  1.96s/it]
#  79%|███████▉  | 793/1000 [06:00<06:51,  1.99s/it]
#  79%|███████▉  | 794/1000 [06:02<06:45,  1.97s/it]
#  80%|███████▉  | 795/1000 [06:04<06:56,  2.03s/it]
#  80%|███████▉  | 796/1000 [06:06<07:06,  2.09s/it]
#  80%|███████▉  | 797/1000 [06:09<07:08,  2.11s/it]
#  80%|███████▉  | 798/1000 [06:11<06:59,  2.08s/it]
#  80%|███████▉  | 799/1000 [06:13<06:55,  2.07s/it]
#  80%|████████  | 800/1000 [06:15<06:45,  2.03s/it]
# Epoch 800
# 8.677871664986014e-05
# 0.11839612573385239
#  80%|████████  | 801/1000 [06:17<06:39,  2.01s/it]
#  80%|████████  | 802/1000 [06:19<06:33,  1.99s/it]
#  80%|████████  | 803/1000 [06:20<06:25,  1.96s/it]
#  80%|████████  | 804/1000 [06:22<06:22,  1.95s/it]
#  80%|████████  | 805/1000 [06:24<06:11,  1.91s/it]
#  81%|████████  | 806/1000 [06:26<06:24,  1.98s/it]
#  81%|████████  | 807/1000 [06:28<06:29,  2.02s/it]
#  81%|████████  | 808/1000 [06:31<06:36,  2.07s/it]
#  81%|████████  | 809/1000 [06:33<06:36,  2.07s/it]
#  81%|████████  | 810/1000 [06:35<06:39,  2.10s/it]
# Epoch 810
# 8.939197869040072e-05
# 0.11640036106109619
#  81%|████████  | 811/1000 [06:37<06:34,  2.09s/it]
#  81%|████████  | 812/1000 [06:39<06:28,  2.07s/it]
#  81%|████████▏ | 813/1000 [06:41<06:11,  1.99s/it]
#  81%|████████▏ | 814/1000 [06:42<05:58,  1.93s/it]
#  82%|████████▏ | 815/1000 [06:44<05:55,  1.92s/it]
#  82%|████████▏ | 816/1000 [06:46<05:50,  1.90s/it]
#  82%|████████▏ | 817/1000 [06:48<05:43,  1.88s/it]
#  82%|████████▏ | 818/1000 [06:50<05:54,  1.95s/it]
#  82%|████████▏ | 819/1000 [06:52<06:08,  2.03s/it]
#  82%|████████▏ | 820/1000 [06:54<06:00,  2.00s/it]
# Epoch 820
# 0.00010036878666142002
# 0.11772219091653824
#  82%|████████▏ | 821/1000 [06:57<06:06,  2.05s/it]
#  82%|████████▏ | 822/1000 [06:58<05:58,  2.01s/it]
#  82%|████████▏ | 823/1000 [07:00<05:43,  1.94s/it]
#  82%|████████▏ | 824/1000 [07:02<05:48,  1.98s/it]
#  82%|████████▎ | 825/1000 [07:04<05:43,  1.96s/it]
#  83%|████████▎ | 826/1000 [07:06<05:41,  1.96s/it]
#  83%|████████▎ | 827/1000 [07:08<05:46,  2.00s/it]
#  83%|████████▎ | 828/1000 [07:10<05:55,  2.06s/it]
#  83%|████████▎ | 829/1000 [07:13<05:57,  2.09s/it]
#  83%|████████▎ | 830/1000 [07:15<06:01,  2.12s/it]
# Epoch 830
# 9.702696843305603e-05
# 0.11638804525136948
#  83%|████████▎ | 831/1000 [07:17<05:58,  2.12s/it]
#  83%|████████▎ | 832/1000 [07:19<06:05,  2.17s/it]
#  83%|████████▎ | 833/1000 [07:21<05:56,  2.13s/it]
#  83%|████████▎ | 834/1000 [07:23<05:54,  2.13s/it]
#  84%|████████▎ | 835/1000 [07:26<05:57,  2.17s/it]
#  84%|████████▎ | 836/1000 [07:28<06:02,  2.21s/it]
#  84%|████████▎ | 837/1000 [07:30<06:01,  2.22s/it]
#  84%|████████▍ | 838/1000 [07:32<05:55,  2.19s/it]
#  84%|████████▍ | 839/1000 [07:35<05:57,  2.22s/it]
#  84%|████████▍ | 840/1000 [07:37<06:06,  2.29s/it]
# Epoch 840
# 8.594982500653714e-05
# 0.11516690254211426
#  84%|████████▍ | 841/1000 [07:39<06:04,  2.29s/it]
#  84%|████████▍ | 842/1000 [07:42<06:07,  2.33s/it]
#  84%|████████▍ | 843/1000 [07:44<06:04,  2.32s/it]
#  84%|████████▍ | 844/1000 [07:46<06:05,  2.34s/it]
#  84%|████████▍ | 845/1000 [07:48<05:46,  2.23s/it]
#  85%|████████▍ | 846/1000 [07:50<05:34,  2.17s/it]
#  85%|████████▍ | 847/1000 [07:53<05:27,  2.14s/it]
#  85%|████████▍ | 848/1000 [07:55<05:33,  2.20s/it]
#  85%|████████▍ | 849/1000 [07:57<05:50,  2.32s/it]
#  85%|████████▌ | 850/1000 [08:00<05:36,  2.24s/it]
# Epoch 850
# 0.0001273166562896222
# 0.11608437448740005
#  85%|████████▌ | 851/1000 [08:02<05:35,  2.25s/it]
#  85%|████████▌ | 852/1000 [08:04<05:16,  2.14s/it]
#  85%|████████▌ | 853/1000 [08:06<05:02,  2.06s/it]
#  85%|████████▌ | 854/1000 [08:07<04:49,  1.98s/it]
#  86%|████████▌ | 855/1000 [08:09<04:47,  1.98s/it]
#  86%|████████▌ | 856/1000 [08:11<04:38,  1.93s/it]
#  86%|████████▌ | 857/1000 [08:13<04:36,  1.93s/it]
#  86%|████████▌ | 858/1000 [08:15<04:41,  1.98s/it]
#  86%|████████▌ | 859/1000 [08:17<04:37,  1.97s/it]
#  86%|████████▌ | 860/1000 [08:20<04:52,  2.09s/it]
# Epoch 860
# 6.094215495977551e-05
# 0.11683913320302963
#  86%|████████▌ | 861/1000 [08:22<04:53,  2.11s/it]
#  86%|████████▌ | 862/1000 [08:24<04:57,  2.15s/it]
#  86%|████████▋ | 863/1000 [08:26<04:54,  2.15s/it]
#  86%|████████▋ | 864/1000 [08:29<05:06,  2.25s/it]
#  86%|████████▋ | 865/1000 [08:31<05:01,  2.24s/it]
#  87%|████████▋ | 866/1000 [08:33<05:02,  2.26s/it]
#  87%|████████▋ | 867/1000 [08:36<05:16,  2.38s/it]
#  87%|████████▋ | 868/1000 [08:38<05:18,  2.41s/it]
#  87%|████████▋ | 869/1000 [08:40<05:03,  2.31s/it]
#  87%|████████▋ | 870/1000 [08:43<05:07,  2.36s/it]
# Epoch 870
# 0.0001040292190737091
# 0.11627431958913803
#  87%|████████▋ | 871/1000 [08:45<05:07,  2.39s/it]
#  87%|████████▋ | 872/1000 [08:48<05:09,  2.42s/it]
#  87%|████████▋ | 873/1000 [08:50<05:12,  2.46s/it]
#  87%|████████▋ | 874/1000 [08:53<05:08,  2.45s/it]
#  88%|████████▊ | 875/1000 [08:55<04:59,  2.39s/it]
#  88%|████████▊ | 876/1000 [08:57<04:55,  2.38s/it]
#  88%|████████▊ | 877/1000 [09:00<04:55,  2.40s/it]
#  88%|████████▊ | 878/1000 [09:02<04:35,  2.26s/it]
#  88%|████████▊ | 879/1000 [09:04<04:34,  2.27s/it]
#  88%|████████▊ | 880/1000 [09:06<04:30,  2.25s/it]
# Epoch 880
# 7.676190580241382e-05
# 0.1174071654677391
#  88%|████████▊ | 881/1000 [09:08<04:28,  2.26s/it]
#  88%|████████▊ | 882/1000 [09:11<04:24,  2.24s/it]
#  88%|████████▊ | 883/1000 [09:13<04:18,  2.21s/it]
#  88%|████████▊ | 884/1000 [09:15<04:09,  2.15s/it]
#  88%|████████▊ | 885/1000 [09:17<04:04,  2.12s/it]
#  89%|████████▊ | 886/1000 [09:19<04:03,  2.14s/it]
#  89%|████████▊ | 887/1000 [09:21<04:01,  2.14s/it]
#  89%|████████▉ | 888/1000 [09:23<03:56,  2.12s/it]
#  89%|████████▉ | 889/1000 [09:26<04:05,  2.21s/it]
#  89%|████████▉ | 890/1000 [09:28<04:10,  2.28s/it]
# Epoch 890
# 8.302609785459936e-05
# 0.11555862426757812
#  89%|████████▉ | 891/1000 [09:30<04:03,  2.23s/it]
#  89%|████████▉ | 892/1000 [09:32<03:58,  2.21s/it]
#  89%|████████▉ | 893/1000 [09:34<03:51,  2.16s/it]
#  89%|████████▉ | 894/1000 [09:37<03:45,  2.13s/it]
#  90%|████████▉ | 895/1000 [09:38<03:35,  2.05s/it]
#  90%|████████▉ | 896/1000 [09:40<03:32,  2.04s/it]
#  90%|████████▉ | 897/1000 [09:42<03:31,  2.05s/it]
#  90%|████████▉ | 898/1000 [09:45<03:38,  2.14s/it]
#  90%|████████▉ | 899/1000 [09:47<03:28,  2.06s/it]
#  90%|█████████ | 900/1000 [09:49<03:34,  2.14s/it]
# Epoch 900
# 8.960180275607854e-05
# 0.11671292781829834
#  90%|█████████ | 901/1000 [09:51<03:26,  2.09s/it]
#  90%|█████████ | 902/1000 [09:53<03:25,  2.10s/it]
#  90%|█████████ | 903/1000 [09:55<03:13,  2.00s/it]
#  90%|█████████ | 904/1000 [09:57<03:17,  2.06s/it]
#  90%|█████████ | 905/1000 [10:00<03:30,  2.22s/it]
#  91%|█████████ | 906/1000 [10:02<03:33,  2.27s/it]
#  91%|█████████ | 907/1000 [10:04<03:29,  2.25s/it]
#  91%|█████████ | 908/1000 [10:07<03:39,  2.38s/it]
#  91%|█████████ | 909/1000 [10:09<03:16,  2.16s/it]
#  91%|█████████ | 910/1000 [10:10<02:52,  1.91s/it]
# Epoch 910
# 8.598665590398014e-05
# 0.11654432862997055
#  91%|█████████ | 911/1000 [10:12<02:41,  1.81s/it]
#  91%|█████████ | 912/1000 [10:13<02:34,  1.76s/it]
#  91%|█████████▏| 913/1000 [10:15<02:29,  1.72s/it]
#  91%|█████████▏| 914/1000 [10:16<02:22,  1.66s/it]
#  92%|█████████▏| 915/1000 [10:18<02:17,  1.62s/it]
#  92%|█████████▏| 916/1000 [10:19<02:13,  1.58s/it]
#  92%|█████████▏| 917/1000 [10:21<02:10,  1.57s/it]
#  92%|█████████▏| 918/1000 [10:22<02:06,  1.54s/it]
#  92%|█████████▏| 919/1000 [10:24<02:04,  1.53s/it]
#  92%|█████████▏| 920/1000 [10:25<02:04,  1.56s/it]
# Epoch 920
# 9.26674110814929e-05
# 0.11661946773529053
#  92%|█████████▏| 921/1000 [10:27<02:01,  1.53s/it]
#  92%|█████████▏| 922/1000 [10:29<02:00,  1.55s/it]
#  92%|█████████▏| 923/1000 [10:30<01:58,  1.54s/it]
#  92%|█████████▏| 924/1000 [10:32<01:57,  1.54s/it]
#  92%|█████████▎| 925/1000 [10:33<01:54,  1.53s/it]
#  93%|█████████▎| 926/1000 [10:35<01:52,  1.52s/it]
#  93%|█████████▎| 927/1000 [10:36<01:52,  1.54s/it]
#  93%|█████████▎| 928/1000 [10:38<01:50,  1.54s/it]
#  93%|█████████▎| 929/1000 [10:39<01:48,  1.53s/it]
#  93%|█████████▎| 930/1000 [10:41<01:44,  1.50s/it]
# Epoch 930
# 8.468967280350626e-05
# 0.11571371555328369
#  93%|█████████▎| 931/1000 [10:42<01:42,  1.49s/it]
#  93%|█████████▎| 932/1000 [10:44<01:42,  1.51s/it]
#  93%|█████████▎| 933/1000 [10:45<01:39,  1.49s/it]
#  93%|█████████▎| 934/1000 [10:47<01:37,  1.47s/it]
#  94%|█████████▎| 935/1000 [10:48<01:36,  1.48s/it]
#  94%|█████████▎| 936/1000 [10:49<01:34,  1.48s/it]
#  94%|█████████▎| 937/1000 [10:51<01:32,  1.47s/it]
#  94%|█████████▍| 938/1000 [10:53<01:32,  1.50s/it]
#  94%|█████████▍| 939/1000 [10:54<01:33,  1.53s/it]
#  94%|█████████▍| 940/1000 [10:56<01:33,  1.56s/it]
# Epoch 940
# 8.669395901961252e-05
# 0.11569932848215103
#  94%|█████████▍| 941/1000 [10:57<01:30,  1.54s/it]
#  94%|█████████▍| 942/1000 [10:59<01:30,  1.56s/it]
#  94%|█████████▍| 943/1000 [11:00<01:28,  1.55s/it]
#  94%|█████████▍| 944/1000 [11:03<01:37,  1.74s/it]
#  94%|█████████▍| 945/1000 [11:04<01:36,  1.75s/it]
#  95%|█████████▍| 946/1000 [11:06<01:31,  1.69s/it]
#  95%|█████████▍| 947/1000 [11:07<01:28,  1.67s/it]
#  95%|█████████▍| 948/1000 [11:09<01:26,  1.67s/it]
#  95%|█████████▍| 949/1000 [11:11<01:22,  1.61s/it]
#  95%|█████████▌| 950/1000 [11:12<01:18,  1.57s/it]
# Epoch 950
# 8.323291694978252e-05
# 0.11601933091878891
#  95%|█████████▌| 951/1000 [11:14<01:16,  1.56s/it]
#  95%|█████████▌| 952/1000 [11:15<01:13,  1.54s/it]
#  95%|█████████▌| 953/1000 [11:17<01:11,  1.52s/it]
#  95%|█████████▌| 954/1000 [11:18<01:08,  1.50s/it]
#  96%|█████████▌| 955/1000 [11:19<01:06,  1.48s/it]
#  96%|█████████▌| 956/1000 [11:21<01:04,  1.47s/it]
#  96%|█████████▌| 957/1000 [11:22<01:03,  1.47s/it]
#  96%|█████████▌| 958/1000 [11:24<01:01,  1.47s/it]
#  96%|█████████▌| 959/1000 [11:25<01:00,  1.47s/it]
#  96%|█████████▌| 960/1000 [11:27<00:58,  1.46s/it]
# Epoch 960
# 8.179401629604399e-05
# 0.11626505851745605
#  96%|█████████▌| 961/1000 [11:28<00:56,  1.46s/it]
#  96%|█████████▌| 962/1000 [11:30<00:55,  1.46s/it]
#  96%|█████████▋| 963/1000 [11:31<00:54,  1.46s/it]
#  96%|█████████▋| 964/1000 [11:33<00:52,  1.46s/it]
#  96%|█████████▋| 965/1000 [11:34<00:51,  1.48s/it]
#  97%|█████████▋| 966/1000 [11:36<00:50,  1.49s/it]
#  97%|█████████▋| 967/1000 [11:37<00:48,  1.47s/it]
#  97%|█████████▋| 968/1000 [11:39<00:47,  1.48s/it]
#  97%|█████████▋| 969/1000 [11:40<00:45,  1.47s/it]
#  97%|█████████▋| 970/1000 [11:41<00:43,  1.46s/it]
# Epoch 970
# 7.515565084759146e-05
# 0.11612117290496826
#  97%|█████████▋| 971/1000 [11:43<00:42,  1.46s/it]
#  97%|█████████▋| 972/1000 [11:44<00:41,  1.46s/it]
#  97%|█████████▋| 973/1000 [11:46<00:39,  1.48s/it]
#  97%|█████████▋| 974/1000 [11:47<00:37,  1.46s/it]
#  98%|█████████▊| 975/1000 [11:49<00:36,  1.44s/it]
#  98%|█████████▊| 976/1000 [11:50<00:34,  1.44s/it]
#  98%|█████████▊| 977/1000 [11:52<00:32,  1.43s/it]
#  98%|█████████▊| 978/1000 [11:53<00:31,  1.44s/it]
#  98%|█████████▊| 979/1000 [11:54<00:30,  1.44s/it]
#  98%|█████████▊| 980/1000 [11:56<00:29,  1.47s/it]
# Epoch 980
# 0.00010452338756294921
# 0.11659789085388184
#  98%|█████████▊| 981/1000 [11:57<00:27,  1.45s/it]
#  98%|█████████▊| 982/1000 [11:59<00:25,  1.44s/it]
#  98%|█████████▊| 983/1000 [12:00<00:23,  1.41s/it]
#  98%|█████████▊| 984/1000 [12:02<00:22,  1.42s/it]
#  98%|█████████▊| 985/1000 [12:03<00:21,  1.43s/it]
#  99%|█████████▊| 986/1000 [12:05<00:20,  1.45s/it]
#  99%|█████████▊| 987/1000 [12:06<00:18,  1.45s/it]
#  99%|█████████▉| 988/1000 [12:08<00:17,  1.46s/it]
#  99%|█████████▉| 989/1000 [12:09<00:15,  1.45s/it]
#  99%|█████████▉| 990/1000 [12:10<00:14,  1.44s/it]
# Epoch 990
# 8.907167648430914e-05
# 0.11654356867074966
#  99%|█████████▉| 991/1000 [12:12<00:13,  1.46s/it]
#  99%|█████████▉| 992/1000 [12:13<00:11,  1.44s/it]
#  99%|█████████▉| 993/1000 [12:15<00:09,  1.43s/it]
#  99%|█████████▉| 994/1000 [12:16<00:08,  1.45s/it]
# 100%|█████████▉| 995/1000 [12:18<00:07,  1.45s/it]
# 100%|█████████▉| 996/1000 [12:19<00:05,  1.44s/it]
# 100%|█████████▉| 997/1000 [12:20<00:04,  1.45s/it]
# 100%|█████████▉| 998/1000 [12:22<00:02,  1.46s/it]
# 100%|█████████▉| 999/1000 [12:23<00:01,  1.46s/it]
# 100%|██████████| 1000/1000 [12:25<00:00,  1.34it/s]
# Epoch 1000
# 0.00011104716395493597
# 0.11642786115407944
# Best epoch = 997
# Best loss = 0.011548362672328949
# Fit loss = 7.702824950683862e-05
# Fit losses = {}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-d312d305de15> in <module>
#     243 for lamb in lambs:
#     244     print("lamb={}".format(lamb))
# --> 245     loss, fit_best, reg_best = train(nets, f_z, z, lr=1e-3, epochs=1000)
#     246     best_losses.append(fit_best)
#     247     best_regs.append(reg_best)
#
# <ipython-input-6-d312d305de15> in train(nets, f_z, z, lr, epochs, bs, es_delta, epoch_loss, max_loss_divergence, weight_decay, weight_decay_decay, model)
#     230     print("Fit loss = {}".format(fit_loss_best))
#     231     print("Fit losses = {}")
# --> 232     print(fit_losses)
#     233     df = po.DataFrame()
#     234     df['losses'] = losses
#
# NameError: name 'fit_losses' is not defined

# %%
print(np.load("./results/"+folder+"/fit_loss.npy"))
print(np.argmax(np.load("./results/"+folder+"/fit_loss.npy")))
# Out:
# [4.40283729e-05 1.12005044e-04 5.58785105e-05 9.62010599e-05]
# 1

# %%
#nets[1].h
worst_losses = []
mean_losses = []
fontsize = 20

plt.figure(figsize=(26,5))

plt.subplot(1,5,1)

folder = "2D_1_1"
fitlosses = np.load("./results/"+folder+"/fit_loss.npy")
arg = np.argmax(fitlosses)
worst_losses.append(fitlosses[arg])
mean_losses.append(np.mean(fitlosses))
model = Hnet(z_dim=4, w=400)
model.load_state_dict(torch.load("./results/"+folder+"/{}.pt".format(arg)))
R = 1.2

num = 101
phi1 = np.linspace(0,2*np.pi,num=num)
phi2 = np.linspace(0,2*np.pi,num=num)
PHI1, PHI2 = np.meshgrid(phi1,phi2)
PHI1 = PHI1.reshape(-1,)
PHI2 = PHI2.reshape(-1,)

z = torch.tensor(np.transpose(np.array([R*np.cos(PHI1), R*np.sin(PHI1), R*np.cos(PHI2), R*np.sin(PHI2)])), requires_grad=True).float()
H = model.h_z(z).detach().numpy()

plt.scatter(PHI1, PHI2, c=H[:,0])
plt.xlim(0,np.pi*2)
plt.ylim(0,np.pi*2)
plt.title(r"$(\omega_x,\omega_y)=(1,1)$", fontsize=fontsize)
plt.xlabel(r"$\varphi_1$", fontsize=fontsize)
plt.ylabel(r"$\varphi_2$", fontsize=fontsize)

plt.subplot(1,5,2)

folder = "2D_1_2"
fitlosses = np.load("./results/"+folder+"/fit_loss.npy")
arg = np.argmax(fitlosses)
worst_losses.append(fitlosses[arg])
mean_losses.append(np.mean(fitlosses))
model = Hnet(z_dim=4, w=400)
model.load_state_dict(torch.load("./results/"+folder+"/{}.pt".format(arg)))
R = 1.2

num = 101
phi1 = np.linspace(0,2*np.pi,num=num)
phi2 = np.linspace(0,2*np.pi,num=num)
PHI1, PHI2 = np.meshgrid(phi1,phi2)
PHI1 = PHI1.reshape(-1,)
PHI2 = PHI2.reshape(-1,)

z = torch.tensor(np.transpose(np.array([R*np.cos(PHI1), R*np.sin(PHI1), R*np.cos(PHI2), R*np.sin(PHI2)])), requires_grad=True).float()
H = model.h_z(z).detach().numpy()

plt.scatter(PHI2, PHI1, c=H[:,0])
plt.xlim(0,np.pi*2)
plt.ylim(0,np.pi*2)
plt.title(r"$(\omega_x,\omega_y)=(1,2)$", fontsize=fontsize)

plt.subplot(1,5,3)

folder = "2D_2_3"
fitlosses = np.load("./results/"+folder+"/fit_loss.npy")
print(fitlosses)
arg = np.argmax(fitlosses)
worst_losses.append(fitlosses[arg])
mean_losses.append(np.mean(fitlosses))
model = Hnet(z_dim=4, w=400)
model.load_state_dict(torch.load("./results/"+folder+"/{}.pt".format(arg)))
R = 1.0

num = 101
phi1 = np.linspace(0,2*np.pi,num=num)
phi2 = np.linspace(0,2*np.pi,num=num)
PHI1, PHI2 = np.meshgrid(phi1,phi2)
PHI1 = PHI1.reshape(-1,)
PHI2 = PHI2.reshape(-1,)

z = torch.tensor(np.transpose(np.array([R*np.cos(PHI1), R*np.sin(PHI1), R*np.cos(PHI2), R*np.sin(PHI2)])), requires_grad=True).float()
H = model.h_z(z).detach().numpy()

plt.scatter(PHI1, PHI2, c=H[:,0])
plt.xlim(0,np.pi*2)
plt.ylim(0,np.pi*2)
plt.title(r"$(\omega_x,\omega_y)=(2,3)$", fontsize=fontsize)


plt.subplot(1,5,4)

folder = "2D_17_23"
fitlosses = np.load("./results/"+folder+"/fit_loss.npy")
print(fitlosses)
arg = np.argmax(fitlosses)
worst_losses.append(fitlosses[arg])
mean_losses.append(np.mean(fitlosses))
model = Hnet(z_dim=4, w=400)
model.load_state_dict(torch.load("./results/"+folder+"/{}.pt".format(arg)))
R = 1.2

num = 101
phi1 = np.linspace(0,2*np.pi,num=num)
phi2 = np.linspace(0,2*np.pi,num=num)
PHI1, PHI2 = np.meshgrid(phi1,phi2)
PHI1 = PHI1.reshape(-1,)
PHI2 = PHI2.reshape(-1,)

z = torch.tensor(np.transpose(np.array([R*np.cos(PHI1), R*np.sin(PHI1), R*np.cos(PHI2), R*np.sin(PHI2)])), requires_grad=True).float()
H = model.h_z(z).detach().numpy()

plt.scatter(PHI1, PHI2, c=H[:,0])
plt.xlim(0,np.pi*2)
plt.ylim(0,np.pi*2)
plt.title(r"$(\omega_x,\omega_y)=(17,23)$", fontsize=fontsize)

plt.subplot(1,5,5)

folder = "2D_67_97"
fitlosses = np.load("./results/"+folder+"/fit_loss.npy")
print(fitlosses)
arg = np.argmax(fitlosses)
worst_losses.append(fitlosses[arg])
mean_losses.append(np.mean(fitlosses))
model = Hnet(z_dim=4, w=400)
model.load_state_dict(torch.load("./results/"+folder+"/{}.pt".format(arg)))
R = 1.2

num = 101
phi1 = np.linspace(0,2*np.pi,num=num)
phi2 = np.linspace(0,2*np.pi,num=num)
PHI1, PHI2 = np.meshgrid(phi1,phi2)
PHI1 = PHI1.reshape(-1,)
PHI2 = PHI2.reshape(-1,)

z = torch.tensor(np.transpose(np.array([R*np.cos(PHI1), R*np.sin(PHI1), R*np.cos(PHI2), R*np.sin(PHI2)])), requires_grad=True).float()
H = model.h_z(z).detach().numpy()

plt.scatter(PHI1, PHI2, c=H[:,0])
plt.xlim(0,np.pi*2)
plt.ylim(0,np.pi*2)
plt.title(r"$(\omega_x,\omega_y)=(67,97)$", fontsize=fontsize)
# Out:
# [0.00059798 0.00046907 0.00032209 0.0004991 ]
# [0.00116642 0.00105138 0.00118749 0.00070542]
# [0.00096011 0.00093559 0.0010197  0.00135176]
# Text(0.5, 1.0, '$(\\omega_x,\\omega_y)=(67,97)$')

# %%
mean_losses
# Out:
# [7.702824677835451e-05,
#  0.0004563481707009487,
#  0.0004720583019661717,
#  0.0010276783141307533,
#  0.001066790908225812]

# %%
worst_losses
# Out:
# [0.00011200504377484322,
#  0.0007130312733352184,
#  0.0005979751003906131,
#  0.0011874920455738902,
#  0.0013517579063773155]

# %%
plt.plot(lambs, best_losses, marker="o")
plt.plot(lambs, best_regs, marker="o")
plt.xscale('log')
plt.yscale('log')
plt.xlabel(r'$\lambda$',fontsize=15)
plt.ylabel('MSE Loss', fontsize=15)
plt.ylim(-0.01,1.5)
# Out:
# /home/luke/anaconda3/envs/zimingenv/lib/python3.6/site-packages/ipykernel_launcher.py:7: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   import sys
# (5.757693509720421e-08, 1.5)

# %%
np.save('./results/lambda_search_2dho_1.npy', np.array([lambs, best_losses, best_regs]))

# %%
plt.figure(figsize=(12,4))

plt.subplot(1,2,1)

data = np.load('./results/lambda_search_2dho_1.npy')
lambs = data[0]
best_losses = data[1]
best_regs = data[2]

plt.plot(lambs, best_losses, marker="o")
plt.plot(lambs, best_regs, marker="o")
plt.xscale('log')
#plt.yscale('log')
plt.xlabel(r'$\lambda$',fontsize=15)
plt.ylabel('Loss', fontsize=15)
plt.legend([r"$\ell_1$", r"$\ell_2$"], fontsize=15, loc="upper right")
plt.ylim(-0.01,0.4)
plt.title(r"$(\omega_x,\omega_y)=(1,1)$", fontsize=15)


plt.subplot(1,2,2)

data = np.load('./results/lambda_search_2dho_sqrt2.npy')
lambs = data[0]
best_losses = data[1]
best_regs = data[2]

plt.plot(lambs, best_losses, marker="o")
plt.plot(lambs, best_regs, marker="o")
plt.xscale('log')
#plt.yscale('log')
plt.xlabel(r'$\lambda$',fontsize=15)
plt.ylabel('Loss', fontsize=15)
#plt.legend([r"$\ell_1$", r"$\ell_2$"], fontsize=15, loc="upper right")
plt.ylim(-0.01,0.4)
plt.title(r"$(\omega_x,\omega_y)=(1,\sqrt{2})$", fontsize=15)
plt.savefig('./2d_ho_lamb_pt.pdf', bbox_inches="tight")
