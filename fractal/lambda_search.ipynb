# %%
import os
import math
import numpy as np
import pandas as po
import matplotlib.pyplot as plt

import torch
from torch import nn
import torch.optim as optim
from torch.autograd import Variable

from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from tqdm import tqdm

#lambs = np.flip([0.01,0.02,0.05,0.1,0.2,0.5,1.0,2.0,5.0,10.0,20.0,50.0,100.0])
lambs = [0.01,0.02,0.05,0.1,0.2,0.5,1.0,2.0,5.0,10.0,20.0,50.0,100.0]
#lambs = [0.0]
gamma = 1

seed = 1
torch.manual_seed(seed)
np.random.seed(seed)

best_losses = []
best_regs = []

num_pts = 1000
#gamma = 10
#lamb = 0.02

data = po.DataFrame()
data['x'] = 4*np.random.rand(num_pts,)-2
data['p'] = 4*np.random.rand(num_pts,)-2


data['dx/dt'] = data['p']
data['dp/dt'] = -data['x'] - gamma*data['p']


f_z = torch.tensor(data[['dx/dt', 'dp/dt']].values, requires_grad=True).float()
z = torch.tensor(data[['x', 'p']].values, requires_grad=True).float()

class Hnet(nn.Module):
    def __init__(self, z_dim=2, w=400):
        super(Hnet, self).__init__()
        self.z_dim = z_dim
        input_dim = z_dim

        self.h_lin_1 = nn.Linear(input_dim, w) #
        self.h_lin_2 = nn.Linear(w, w) #
        self.h_lin_3 = nn.Linear(w, 1) #
        self.h_relu = nn.ReLU()
        self.h_tanh = nn.Tanh()
        self.h_silu = nn.SiLU()

    def h_z_basic(self, z):
        out = self.h_lin_1(z)
        out = self.h_silu(out)
        out = self.h_lin_2(out)
        out = self.h_silu(out)
        out = self.h_lin_3(out)
        return out

    def h_z(self, z):
        out = self.h_z_basic(z)
        return out

    def forward(self, z, verbose=False):
        bs = z.shape[0]

        h = self.h_z(z)
        dh = torch.autograd.grad(h, z, torch.ones_like(h), create_graph=True, retain_graph=True)[0]
        bs = z.shape[0]
        dh = dh.reshape(bs,-1)
        return dh


def train(nets, f_z, z,
            lr=2e-3,
            epochs = 2000, 
            bs = 100,
            es_delta = 0.000001, 
            epoch_loss = 1e9,
            max_loss_divergence = 0.1,
            weight_decay=0, 
            weight_decay_decay=False,model=None):


    num_model = len(nets)

    z_dim = z.shape[1]
    entropy_dim = np.minimum(num_model, z_dim)
    parameters = list([])
    for i in range(num_model):
        parameters = list(parameters) + list(nets[i].parameters())
    optimizer = optim.Adam(parameters, lr=lr, weight_decay=weight_decay, eps=1e-8)
    #optimizer = optim.SGD(parameters, lr=lr, weight_decay=weight_decay)

    for k in range(num_model):
        nets[k].train()
    losses = []
    losses_fit = []
    losses_reg = []
    lamb_H = 0.00
    lamb_dH = lamb
    loss_pow = 2


    for epoch in tqdm(range(epochs)):
        for i in range((len(f_z) - 1) // bs + 1):
            choices = np.random.choice(len(f_z), bs, replace=False)
            #start_i = i * bs
            #end_i = start_i + bs
            xb = z[choices, :]
            fitloss = 0.
            fitlosses = []
            yb = f_z[choices, :]
            yb = yb.reshape(bs,-1)
            yb_norm = yb/torch.linalg.norm(yb, dim=1, keepdim=True)
            #print("yb", yb_norm.shape)
            for k in range(num_model):
                pred = nets[k](xb)
                #print("pred", pred.shape)
                pred_norm = pred/torch.linalg.norm(pred, dim=1, keepdim=True)
                fit_orth = torch.matmul(yb_norm.unsqueeze(dim=1), pred_norm.unsqueeze(dim=2))
                #print(fit_orth.shape)
                fitloss_ =  torch.mean(torch.abs(fit_orth)**loss_pow)
                #fitloss_each.append(fitloss_.detach().numpy())
                fitloss = fitloss + fitloss_
                fitlosses.append(fitloss_.item())
                H_ = nets[k].h_z(xb)
                dhi = pred_norm

                if k == 0:
                    H = H_
                    dH = dhi.unsqueeze(dim=0)

                else:
                    H = torch.cat((H,H_), dim=1)
                    dH = torch.cat([dH,dhi.unsqueeze(dim=0)])

            fitloss = fitloss/num_model
            # correlation loss
            H = torch.transpose(H,0,1)
            # dH.shape = (bs, num_model, z_dim)
            dH = torch.transpose(dH,0,1)

            # SVD dH
            u, s, v = torch.svd(dH)
            exp_ratio = s**2/torch.sum(s**2, dim=1,keepdim=True)
            exp_av = torch.mean(exp_ratio,dim=0)

            # H regularization
            corr_mat = torch.corrcoef(H)
            if num_model == 1:
                reg_H = torch.tensor(0., dtype=torch.float)
            else:
                reg_H = (torch.sum(corr_mat**loss_pow)-num_model)/(num_model*(num_model-1))

            orth_mat = torch.mean(torch.abs(torch.matmul(dH, torch.transpose(dH,1,2)))**loss_pow, dim=0)
            #print(orth_mat)
            if num_model == 1:
                reg_dH = torch.tensor(0., dtype=torch.float)
            else:
                reg_dH = (torch.sum(orth_mat)-num_model)/(num_model*(num_model-1))

            loss = fitloss + lamb_H*reg_H + lamb_dH*reg_dH

            loss.backward()
            optimizer.step()   

            optimizer.zero_grad()

            losses.append(loss.item())
            losses_fit.append(fitloss.item())
            losses_reg.append(reg_dH.item())
            #print(loss.item(), fitloss.item(), reg_dH.item())

        # Best epoch loss (save best only)
        if (loss<epoch_loss):
            epoch_loss = loss
            epoch_best = epoch
            fit_loss_best = fitloss
            reg_loss_best = reg_dH
            #print("Saving model at epoch {}, current best epoch loss = {}".format(epoch, epoch_loss))
            for k in range(num_model):
                torch.save(nets[k].state_dict(), "./results/"+"{}.pt".format(k))
            np.save("./results/"+"/fit_loss.npy", fitlosses)
            np.save("./results/"+"/dH_explained.npy", exp_av.detach().numpy())

        # Early Stopping
        #if ((loss<es_delta) or abs(epoch_loss-loss)>max_loss_divergence):
        #    break

        # Print loss
        if ((epoch+1)%10==0):
            print("Epoch {}".format(epoch+1))
            print(fitloss.item())
            #print(fitlosses)
            #print(corr_mat)
            #print(reg_H.item())
            #print(orth_mat)
            print(reg_dH.item())
            #print(exp_av)

    plt.plot(losses)
    plt.plot(losses_fit)
    plt.plot(losses_reg)
    plt.yscale('log')

    print("Best epoch = {}".format(epoch_best))
    print("Best loss = {}".format(epoch_loss))
    print("Fit loss = {}".format(fit_loss_best))
    df = po.DataFrame()
    df['losses'] = losses

    return losses, fit_loss_best.detach().numpy(), reg_loss_best.detach().numpy()


num_model = 2
nets = []
for i in range(num_model):
    nets.append(Hnet(z_dim=2, w=400))

for lamb in lambs:
    print("lamb={}".format(lamb))

    loss, fit_best, reg_best = train(nets, f_z, z, lr=1e-3, epochs=1000) 
    best_losses.append(fit_best)
    best_regs.append(reg_best)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
#
#   0%|          | 1/1000 [00:00<02:07,  7.86it/s]
# lamb=0.01
#   0%|          | 2/1000 [00:00<02:30,  6.64it/s]
#
#   0%|          | 3/1000 [00:00<02:37,  6.33it/s]
#
#   0%|          | 4/1000 [00:00<02:43,  6.07it/s]
#
#   0%|          | 5/1000 [00:00<02:42,  6.14it/s]
#
#   1%|          | 6/1000 [00:01<02:42,  6.13it/s]
#
#   1%|          | 7/1000 [00:01<02:46,  5.98it/s]
#
#   1%|          | 8/1000 [00:01<02:55,  5.66it/s]
#
#   1%|          | 9/1000 [00:01<03:12,  5.15it/s]
#
#   1%|          | 10/1000 [00:01<03:06,  5.32it/s]
#
#   1%|          | 11/1000 [00:01<02:55,  5.62it/s]
# Epoch 10
# 0.15888598561286926
# 0.8315331935882568
#   1%|          | 12/1000 [00:02<02:47,  5.89it/s]
#
#   1%|▏         | 13/1000 [00:02<02:54,  5.67it/s]
#
#   1%|▏         | 14/1000 [00:02<03:09,  5.19it/s]
#
#   2%|▏         | 15/1000 [00:02<03:28,  4.72it/s]
#
#   2%|▏         | 16/1000 [00:03<03:46,  4.34it/s]
#
#   2%|▏         | 17/1000 [00:03<03:52,  4.23it/s]
#
#   2%|▏         | 18/1000 [00:03<03:40,  4.45it/s]
#
#   2%|▏         | 19/1000 [00:03<03:31,  4.64it/s]
#
#   2%|▏         | 20/1000 [00:03<03:26,  4.75it/s]
#
#   2%|▏         | 21/1000 [00:04<03:17,  4.97it/s]
# Epoch 20
# 0.09189356863498688
# 0.935333251953125
#   2%|▏         | 22/1000 [00:04<03:19,  4.91it/s]
#
#   2%|▏         | 23/1000 [00:04<03:18,  4.93it/s]
#
#   2%|▏         | 24/1000 [00:04<03:17,  4.94it/s]
#
#   2%|▎         | 25/1000 [00:04<03:20,  4.87it/s]
#
#   3%|▎         | 26/1000 [00:05<03:18,  4.90it/s]
#
#   3%|▎         | 27/1000 [00:05<03:10,  5.12it/s]
#
#   3%|▎         | 28/1000 [00:05<03:06,  5.22it/s]
#
#   3%|▎         | 29/1000 [00:05<03:00,  5.39it/s]
#
#   3%|▎         | 30/1000 [00:05<02:59,  5.41it/s]
#
#   3%|▎         | 31/1000 [00:05<02:48,  5.75it/s]
# Epoch 30
# 0.07656018435955048
# 0.9288527965545654
#   3%|▎         | 32/1000 [00:06<02:44,  5.90it/s]
#
#   3%|▎         | 33/1000 [00:06<02:45,  5.85it/s]
#
#   3%|▎         | 34/1000 [00:06<02:53,  5.56it/s]
#
#   4%|▎         | 35/1000 [00:06<02:57,  5.45it/s]
#
#   4%|▎         | 36/1000 [00:06<03:06,  5.17it/s]
#
#   4%|▎         | 37/1000 [00:07<03:06,  5.16it/s]
#
#   4%|▍         | 38/1000 [00:07<03:01,  5.31it/s]
#
#   4%|▍         | 39/1000 [00:07<03:01,  5.31it/s]
#
#   4%|▍         | 40/1000 [00:07<03:03,  5.24it/s]
#
#   4%|▍         | 41/1000 [00:07<02:53,  5.51it/s]
# Epoch 40
# 0.05440860241651535
# 0.9399272203445435
#   4%|▍         | 42/1000 [00:08<03:01,  5.29it/s]
#
#   4%|▍         | 43/1000 [00:08<02:45,  5.78it/s]
#
#   4%|▍         | 44/1000 [00:08<02:35,  6.14it/s]
#
#   4%|▍         | 45/1000 [00:08<02:32,  6.27it/s]
#
#   5%|▍         | 46/1000 [00:08<02:29,  6.38it/s]
#
#   5%|▍         | 47/1000 [00:08<02:19,  6.81it/s]
#
#   5%|▍         | 48/1000 [00:08<02:13,  7.14it/s]
#
#   5%|▍         | 49/1000 [00:08<02:13,  7.12it/s]
#
#   5%|▌         | 50/1000 [00:09<02:32,  6.24it/s]
#
#   5%|▌         | 51/1000 [00:09<02:41,  5.89it/s]
# Epoch 50
# 0.05161494389176369
# 0.9518716335296631
#   5%|▌         | 52/1000 [00:09<02:54,  5.44it/s]
#
#   5%|▌         | 53/1000 [00:09<03:06,  5.08it/s]
#
#   5%|▌         | 54/1000 [00:10<03:09,  4.99it/s]
#
#   6%|▌         | 55/1000 [00:10<03:03,  5.16it/s]
#
#   6%|▌         | 56/1000 [00:10<03:06,  5.07it/s]
#
#   6%|▌         | 57/1000 [00:10<03:11,  4.92it/s]
#
#   6%|▌         | 58/1000 [00:10<03:06,  5.06it/s]
#
#   6%|▌         | 59/1000 [00:11<03:01,  5.18it/s]
#
#   6%|▌         | 60/1000 [00:11<02:53,  5.43it/s]
# Epoch 60
# 0.057371534407138824
# 0.9607319831848145
#   6%|▌         | 61/1000 [00:11<02:59,  5.22it/s]
#
#   6%|▌         | 62/1000 [00:11<03:01,  5.16it/s]
#
#   6%|▋         | 63/1000 [00:11<03:11,  4.89it/s]
#
#   6%|▋         | 64/1000 [00:11<03:04,  5.06it/s]
#
#   6%|▋         | 65/1000 [00:12<03:11,  4.87it/s]
#
#   7%|▋         | 66/1000 [00:12<03:04,  5.06it/s]
#
#   7%|▋         | 67/1000 [00:12<03:11,  4.86it/s]
#
#   7%|▋         | 68/1000 [00:12<03:46,  4.12it/s]
#
#   7%|▋         | 69/1000 [00:13<03:28,  4.46it/s]
#
#   7%|▋         | 70/1000 [00:13<03:30,  4.41it/s]
#
#   7%|▋         | 71/1000 [00:13<03:13,  4.79it/s]
# Epoch 70
# 0.06325419247150421
# 0.9491297006607056
#   7%|▋         | 72/1000 [00:13<02:58,  5.19it/s]
#
#   7%|▋         | 73/1000 [00:13<02:55,  5.27it/s]
#
#   7%|▋         | 74/1000 [00:14<02:52,  5.36it/s]
#
#   8%|▊         | 75/1000 [00:14<02:46,  5.56it/s]
#
#   8%|▊         | 76/1000 [00:14<02:40,  5.75it/s]
#
#   8%|▊         | 77/1000 [00:14<02:37,  5.86it/s]
#
#   8%|▊         | 78/1000 [00:14<02:34,  5.98it/s]
#
#   8%|▊         | 79/1000 [00:14<02:31,  6.07it/s]
#
#   8%|▊         | 80/1000 [00:15<02:29,  6.14it/s]
#
#   8%|▊         | 81/1000 [00:15<02:27,  6.24it/s]
# Epoch 80
# 0.04577430337667465
# 0.9846401214599609
#   8%|▊         | 82/1000 [00:15<02:25,  6.32it/s]
#
#   8%|▊         | 83/1000 [00:15<02:23,  6.38it/s]
#
#   8%|▊         | 84/1000 [00:15<02:22,  6.42it/s]
#
#   8%|▊         | 85/1000 [00:15<02:22,  6.40it/s]
#
#   9%|▊         | 86/1000 [00:15<02:23,  6.37it/s]
#
#   9%|▊         | 87/1000 [00:16<02:18,  6.60it/s]
#
#   9%|▉         | 88/1000 [00:16<02:13,  6.84it/s]
#
#   9%|▉         | 89/1000 [00:16<02:09,  7.06it/s]
#
#   9%|▉         | 90/1000 [00:16<02:06,  7.22it/s]
#
#   9%|▉         | 91/1000 [00:16<02:06,  7.16it/s]
# Epoch 90
# 0.04951903223991394
# 0.9766485691070557
#   9%|▉         | 92/1000 [00:16<02:11,  6.91it/s]
#
#   9%|▉         | 93/1000 [00:16<02:12,  6.86it/s]
#
#   9%|▉         | 94/1000 [00:17<02:06,  7.19it/s]
#
#  10%|▉         | 95/1000 [00:17<02:01,  7.45it/s]
#
#  10%|▉         | 96/1000 [00:17<01:58,  7.65it/s]
#
#  10%|▉         | 97/1000 [00:17<01:56,  7.77it/s]
#
#  10%|▉         | 98/1000 [00:17<01:54,  7.87it/s]
#
#  10%|▉         | 99/1000 [00:17<01:53,  7.93it/s]
#
#  10%|█         | 100/1000 [00:17<01:53,  7.96it/s]
#
#  10%|█         | 101/1000 [00:17<01:52,  8.00it/s]
# Epoch 100
# 0.05535636469721794
# 0.9450137615203857
#  10%|█         | 102/1000 [00:18<01:52,  7.96it/s]
#
#  10%|█         | 103/1000 [00:18<01:52,  8.00it/s]
#
#  10%|█         | 104/1000 [00:18<01:51,  8.04it/s]
#
#  10%|█         | 105/1000 [00:18<01:50,  8.07it/s]
#
#  11%|█         | 106/1000 [00:18<01:50,  8.07it/s]
#
#  11%|█         | 107/1000 [00:18<01:50,  8.09it/s]
#
#  11%|█         | 108/1000 [00:18<01:51,  8.03it/s]
#
#  11%|█         | 109/1000 [00:18<01:51,  8.02it/s]
#
#  11%|█         | 110/1000 [00:19<01:50,  8.04it/s]
#
#  11%|█         | 111/1000 [00:19<01:50,  8.06it/s]
# Epoch 110
# 0.07486477494239807
# 0.9643182754516602
#  11%|█         | 112/1000 [00:19<01:50,  8.04it/s]
#
#  11%|█▏        | 113/1000 [00:19<01:50,  8.06it/s]
#
#  11%|█▏        | 114/1000 [00:19<01:49,  8.07it/s]
#
#  12%|█▏        | 115/1000 [00:19<01:49,  8.08it/s]
#
#  12%|█▏        | 116/1000 [00:19<01:49,  8.09it/s]
#
#  12%|█▏        | 117/1000 [00:19<01:49,  8.08it/s]
#
#  12%|█▏        | 118/1000 [00:20<01:52,  7.82it/s]
#
#  12%|█▏        | 119/1000 [00:20<01:55,  7.65it/s]
#
#  12%|█▏        | 120/1000 [00:20<01:56,  7.52it/s]
#
#  12%|█▏        | 121/1000 [00:20<01:55,  7.60it/s]
# Epoch 120
# 0.04112040624022484
# 0.9697649478912354
#  12%|█▏        | 122/1000 [00:20<01:54,  7.64it/s]
#
#  12%|█▏        | 123/1000 [00:20<01:52,  7.77it/s]
#
#  12%|█▏        | 124/1000 [00:20<01:51,  7.86it/s]
#
#  12%|█▎        | 125/1000 [00:20<01:50,  7.92it/s]
#
#  13%|█▎        | 126/1000 [00:21<01:50,  7.91it/s]
#
#  13%|█▎        | 127/1000 [00:21<01:49,  7.95it/s]
#
#  13%|█▎        | 128/1000 [00:21<01:48,  8.00it/s]
#
#  13%|█▎        | 129/1000 [00:21<01:52,  7.77it/s]
#
#  13%|█▎        | 130/1000 [00:21<01:51,  7.79it/s]
#
#  13%|█▎        | 131/1000 [00:21<01:50,  7.89it/s]
# Epoch 130
# 0.07544717192649841
# 0.9342801570892334
#  13%|█▎        | 132/1000 [00:21<01:49,  7.94it/s]
#
#  13%|█▎        | 133/1000 [00:21<01:48,  7.99it/s]
#
#  13%|█▎        | 134/1000 [00:22<01:47,  8.02it/s]
#
#  14%|█▎        | 135/1000 [00:22<01:47,  8.06it/s]
#
#  14%|█▎        | 136/1000 [00:22<01:46,  8.08it/s]
#
#  14%|█▎        | 137/1000 [00:22<01:46,  8.09it/s]
#
#  14%|█▍        | 138/1000 [00:22<01:46,  8.11it/s]
#
#  14%|█▍        | 139/1000 [00:22<01:46,  8.10it/s]
#
#  14%|█▍        | 140/1000 [00:22<01:46,  8.10it/s]
#
#  14%|█▍        | 141/1000 [00:22<01:46,  8.10it/s]
# Epoch 140
# 0.05547415465116501
# 0.9285930395126343
#  14%|█▍        | 142/1000 [00:23<01:46,  8.09it/s]
#
#  14%|█▍        | 143/1000 [00:23<01:45,  8.10it/s]
#
#  14%|█▍        | 144/1000 [00:23<01:45,  8.08it/s]
#
#  14%|█▍        | 145/1000 [00:23<01:45,  8.09it/s]
#
#  15%|█▍        | 146/1000 [00:23<01:45,  8.08it/s]
#
#  15%|█▍        | 147/1000 [00:23<01:49,  7.82it/s]
#
#  15%|█▍        | 148/1000 [00:23<01:47,  7.91it/s]
#
#  15%|█▍        | 149/1000 [00:23<01:47,  7.95it/s]
#
#  15%|█▌        | 150/1000 [00:24<01:46,  7.98it/s]
#
#  15%|█▌        | 151/1000 [00:24<01:45,  8.02it/s]
# Epoch 150
# 0.03915673494338989
# 0.9645676612854004
#  15%|█▌        | 152/1000 [00:24<01:45,  8.02it/s]
#
#  15%|█▌        | 153/1000 [00:24<01:45,  7.99it/s]
#
#  15%|█▌        | 154/1000 [00:24<01:45,  8.03it/s]
#
#  16%|█▌        | 155/1000 [00:24<01:44,  8.05it/s]
#
#  16%|█▌        | 156/1000 [00:24<01:44,  8.07it/s]
#
#  16%|█▌        | 157/1000 [00:24<01:44,  8.09it/s]
#
#  16%|█▌        | 158/1000 [00:25<01:44,  8.08it/s]
#
#  16%|█▌        | 159/1000 [00:25<01:43,  8.10it/s]
#
#  16%|█▌        | 160/1000 [00:25<01:43,  8.10it/s]
#
#  16%|█▌        | 161/1000 [00:25<01:43,  8.10it/s]
# Epoch 160
# 0.053744904696941376
# 0.9299501180648804
#  16%|█▌        | 162/1000 [00:25<01:43,  8.08it/s]
#
#  16%|█▋        | 163/1000 [00:25<01:43,  8.09it/s]
#
#  16%|█▋        | 164/1000 [00:25<01:43,  8.10it/s]
#
#  16%|█▋        | 165/1000 [00:25<01:43,  8.11it/s]
#
#  17%|█▋        | 166/1000 [00:26<01:42,  8.11it/s]
#
#  17%|█▋        | 167/1000 [00:26<01:42,  8.11it/s]
#
#  17%|█▋        | 168/1000 [00:26<01:42,  8.11it/s]
#
#  17%|█▋        | 169/1000 [00:26<01:42,  8.09it/s]
#
#  17%|█▋        | 170/1000 [00:26<01:42,  8.09it/s]
#
#  17%|█▋        | 171/1000 [00:26<01:42,  8.10it/s]
# Epoch 170
# 0.032658472657203674
# 0.9780181646347046
#  17%|█▋        | 172/1000 [00:26<01:42,  8.09it/s]
#
#  17%|█▋        | 173/1000 [00:26<01:42,  8.09it/s]
#
#  17%|█▋        | 174/1000 [00:27<01:43,  7.98it/s]
#
#  18%|█▊        | 175/1000 [00:27<01:51,  7.39it/s]
#
#  18%|█▊        | 176/1000 [00:27<01:48,  7.56it/s]
#
#  18%|█▊        | 177/1000 [00:27<01:56,  7.07it/s]
#
#  18%|█▊        | 178/1000 [00:27<01:57,  6.97it/s]
#
#  18%|█▊        | 179/1000 [00:27<01:54,  7.17it/s]
#
#  18%|█▊        | 180/1000 [00:27<01:52,  7.29it/s]
#
#  18%|█▊        | 181/1000 [00:28<02:05,  6.52it/s]
# Epoch 180
# 0.05004969239234924
# 0.9620797634124756
#  18%|█▊        | 182/1000 [00:28<02:15,  6.03it/s]
#
#  18%|█▊        | 183/1000 [00:28<02:07,  6.41it/s]
#
#  18%|█▊        | 184/1000 [00:28<02:00,  6.76it/s]
#
#  18%|█▊        | 185/1000 [00:28<01:56,  7.00it/s]
#
#  19%|█▊        | 186/1000 [00:28<01:53,  7.17it/s]
#
#  19%|█▊        | 187/1000 [00:28<01:50,  7.34it/s]
#
#  19%|█▉        | 188/1000 [00:29<01:50,  7.32it/s]
#
#  19%|█▉        | 189/1000 [00:29<01:47,  7.52it/s]
#
#  19%|█▉        | 190/1000 [00:29<01:55,  7.02it/s]
#
#  19%|█▉        | 191/1000 [00:29<02:05,  6.43it/s]
# Epoch 190
# 0.025032246485352516
# 0.9737043380737305
#  19%|█▉        | 192/1000 [00:29<01:59,  6.75it/s]
#
#  19%|█▉        | 193/1000 [00:29<01:54,  7.02it/s]
#
#  19%|█▉        | 194/1000 [00:29<01:51,  7.24it/s]
#
#  20%|█▉        | 195/1000 [00:30<01:49,  7.32it/s]
#
#  20%|█▉        | 196/1000 [00:30<01:46,  7.55it/s]
#
#  20%|█▉        | 197/1000 [00:30<01:44,  7.69it/s]
#
#  20%|█▉        | 198/1000 [00:30<01:43,  7.78it/s]
#
#  20%|█▉        | 199/1000 [00:30<01:41,  7.87it/s]
#
#  20%|██        | 200/1000 [00:30<01:40,  7.94it/s]
#
#  20%|██        | 201/1000 [00:30<01:39,  8.00it/s]
# Epoch 200
# 0.0725436732172966
# 0.9841736555099487
#  20%|██        | 202/1000 [00:30<01:39,  8.02it/s]
#
#  20%|██        | 203/1000 [00:31<01:39,  8.04it/s]
#
#  20%|██        | 204/1000 [00:31<01:38,  8.05it/s]
#
#  20%|██        | 205/1000 [00:31<01:38,  8.07it/s]
#
#  21%|██        | 206/1000 [00:31<01:38,  8.08it/s]
#
#  21%|██        | 207/1000 [00:31<01:37,  8.09it/s]
#
#  21%|██        | 208/1000 [00:31<01:37,  8.10it/s]
#
#  21%|██        | 209/1000 [00:31<01:37,  8.11it/s]
#
#  21%|██        | 210/1000 [00:31<01:37,  8.10it/s]
#
#  21%|██        | 211/1000 [00:32<01:37,  8.11it/s]
# Epoch 210
# 0.027897045016288757
# 0.9834914207458496
#  21%|██        | 212/1000 [00:32<01:37,  8.10it/s]
#
#  21%|██▏       | 213/1000 [00:32<01:36,  8.12it/s]
#
#  21%|██▏       | 214/1000 [00:32<01:36,  8.12it/s]
#
#  22%|██▏       | 215/1000 [00:32<01:37,  8.08it/s]
#
#  22%|██▏       | 216/1000 [00:32<01:53,  6.91it/s]
#
#  22%|██▏       | 217/1000 [00:32<02:13,  5.84it/s]
#
#  22%|██▏       | 218/1000 [00:33<02:06,  6.19it/s]
#
#  22%|██▏       | 219/1000 [00:33<01:59,  6.55it/s]
#
#  22%|██▏       | 220/1000 [00:33<01:55,  6.76it/s]
#
#  22%|██▏       | 221/1000 [00:33<01:52,  6.90it/s]
# Epoch 220
# 0.02718430571258068
# 0.972874641418457
#  22%|██▏       | 222/1000 [00:33<01:50,  7.04it/s]
#
#  22%|██▏       | 223/1000 [00:33<01:47,  7.20it/s]
#
#  22%|██▏       | 224/1000 [00:33<01:47,  7.20it/s]
#
#  22%|██▎       | 225/1000 [00:34<02:12,  5.87it/s]
#
#  23%|██▎       | 226/1000 [00:34<02:17,  5.62it/s]
#
#  23%|██▎       | 227/1000 [00:34<02:14,  5.76it/s]
#
#  23%|██▎       | 228/1000 [00:34<02:16,  5.64it/s]
#
#  23%|██▎       | 229/1000 [00:34<02:14,  5.73it/s]
#
#  23%|██▎       | 230/1000 [00:35<02:10,  5.89it/s]
#
#  23%|██▎       | 231/1000 [00:35<02:09,  5.96it/s]
# Epoch 230
# 0.03901151567697525
# 0.9793422222137451
#  23%|██▎       | 232/1000 [00:35<02:00,  6.37it/s]
#
#  23%|██▎       | 233/1000 [00:35<01:56,  6.56it/s]
#
#  23%|██▎       | 234/1000 [00:35<02:05,  6.10it/s]
#
#  24%|██▎       | 235/1000 [00:35<02:04,  6.13it/s]
#
#  24%|██▎       | 236/1000 [00:35<02:08,  5.93it/s]
#
#  24%|██▎       | 237/1000 [00:36<02:00,  6.32it/s]
#
#  24%|██▍       | 238/1000 [00:36<01:52,  6.77it/s]
#
#  24%|██▍       | 239/1000 [00:36<01:46,  7.13it/s]
#
#  24%|██▍       | 240/1000 [00:36<01:44,  7.28it/s]
#
#  24%|██▍       | 241/1000 [00:36<01:52,  6.72it/s]
# Epoch 240
# 0.046792276203632355
# 0.9592969417572021
#  24%|██▍       | 242/1000 [00:36<01:58,  6.40it/s]
#
#  24%|██▍       | 243/1000 [00:37<02:09,  5.86it/s]
#
#  24%|██▍       | 244/1000 [00:37<02:10,  5.79it/s]
#
#  24%|██▍       | 245/1000 [00:37<02:13,  5.65it/s]
#
#  25%|██▍       | 246/1000 [00:37<02:15,  5.58it/s]
#
#  25%|██▍       | 247/1000 [00:37<02:15,  5.57it/s]
#
#  25%|██▍       | 248/1000 [00:37<02:03,  6.08it/s]
#
#  25%|██▍       | 249/1000 [00:38<01:59,  6.29it/s]
#
#  25%|██▌       | 250/1000 [00:38<02:04,  6.01it/s]
#
#  25%|██▌       | 251/1000 [00:38<02:00,  6.21it/s]
# Epoch 250
# 0.0259394571185112
# 0.9817836284637451
#  25%|██▌       | 252/1000 [00:38<01:53,  6.57it/s]
#
#  25%|██▌       | 253/1000 [00:38<01:48,  6.86it/s]
#
#  25%|██▌       | 254/1000 [00:38<01:47,  6.97it/s]
#
#  26%|██▌       | 255/1000 [00:38<01:43,  7.18it/s]
#
#  26%|██▌       | 256/1000 [00:39<01:41,  7.33it/s]
#
#  26%|██▌       | 257/1000 [00:39<01:40,  7.41it/s]
#
#  26%|██▌       | 258/1000 [00:39<01:38,  7.50it/s]
#
#  26%|██▌       | 259/1000 [00:39<01:37,  7.57it/s]
#
#  26%|██▌       | 260/1000 [00:39<01:38,  7.54it/s]
#
#  26%|██▌       | 261/1000 [00:39<01:38,  7.51it/s]
# Epoch 260
# 0.022800952196121216
# 0.983088493347168
#  26%|██▌       | 262/1000 [00:39<01:41,  7.25it/s]
#
#  26%|██▋       | 263/1000 [00:40<01:41,  7.28it/s]
#
#  26%|██▋       | 264/1000 [00:40<01:41,  7.26it/s]
#
#  26%|██▋       | 265/1000 [00:40<01:39,  7.38it/s]
#
#  27%|██▋       | 266/1000 [00:40<01:38,  7.46it/s]
#
#  27%|██▋       | 267/1000 [00:40<01:37,  7.54it/s]
#
#  27%|██▋       | 268/1000 [00:40<01:36,  7.57it/s]
#
#  27%|██▋       | 269/1000 [00:40<01:35,  7.62it/s]
#
#  27%|██▋       | 270/1000 [00:40<01:35,  7.63it/s]
#
#  27%|██▋       | 271/1000 [00:41<01:33,  7.77it/s]
# Epoch 270
# 0.028346415609121323
# 0.9667843580245972
#  27%|██▋       | 272/1000 [00:41<01:32,  7.84it/s]
#
#  27%|██▋       | 273/1000 [00:41<01:31,  7.92it/s]
#
#  27%|██▋       | 274/1000 [00:41<01:31,  7.97it/s]
#
#  28%|██▊       | 275/1000 [00:41<01:30,  8.02it/s]
#
#  28%|██▊       | 276/1000 [00:41<01:30,  8.03it/s]
#
#  28%|██▊       | 277/1000 [00:41<01:29,  8.05it/s]
#
#  28%|██▊       | 278/1000 [00:41<01:29,  8.07it/s]
#
#  28%|██▊       | 279/1000 [00:42<01:29,  8.07it/s]
#
#  28%|██▊       | 280/1000 [00:42<01:29,  8.07it/s]
#
#  28%|██▊       | 281/1000 [00:42<01:28,  8.08it/s]
# Epoch 280
# 0.025903884321451187
# 0.974936842918396
#  28%|██▊       | 282/1000 [00:42<01:29,  8.03it/s]
#
#  28%|██▊       | 283/1000 [00:42<01:32,  7.72it/s]
#
#  28%|██▊       | 284/1000 [00:42<01:37,  7.37it/s]
#
#  28%|██▊       | 285/1000 [00:42<01:50,  6.45it/s]
#
#  29%|██▊       | 286/1000 [00:43<01:54,  6.26it/s]
#
#  29%|██▊       | 287/1000 [00:43<01:55,  6.18it/s]
#
#  29%|██▉       | 288/1000 [00:43<02:00,  5.93it/s]
#
#  29%|██▉       | 289/1000 [00:43<01:57,  6.03it/s]
#
#  29%|██▉       | 290/1000 [00:43<01:50,  6.43it/s]
#
#  29%|██▉       | 291/1000 [00:43<01:44,  6.78it/s]
# Epoch 290
# 0.03984206169843674
# 0.9850716590881348
#  29%|██▉       | 292/1000 [00:43<01:39,  7.10it/s]
#
#  29%|██▉       | 293/1000 [00:44<01:36,  7.35it/s]
#
#  29%|██▉       | 294/1000 [00:44<01:33,  7.53it/s]
#
#  30%|██▉       | 295/1000 [00:44<01:31,  7.70it/s]
#
#  30%|██▉       | 296/1000 [00:44<01:30,  7.81it/s]
#
#  30%|██▉       | 297/1000 [00:44<01:29,  7.89it/s]
#
#  30%|██▉       | 298/1000 [00:44<01:39,  7.08it/s]
#
#  30%|██▉       | 299/1000 [00:44<01:42,  6.87it/s]
#
#  30%|███       | 300/1000 [00:45<01:37,  7.18it/s]
#
#  30%|███       | 301/1000 [00:45<01:33,  7.44it/s]
# Epoch 300
# 0.04964091628789902
# 0.9422874450683594
#  30%|███       | 302/1000 [00:45<01:31,  7.60it/s]
#
#  30%|███       | 303/1000 [00:45<01:29,  7.75it/s]
#
#  30%|███       | 304/1000 [00:45<01:28,  7.84it/s]
#
#  30%|███       | 305/1000 [00:45<01:27,  7.92it/s]
#
#  31%|███       | 306/1000 [00:45<01:28,  7.81it/s]
#
#  31%|███       | 307/1000 [00:45<01:43,  6.72it/s]
#
#  31%|███       | 308/1000 [00:46<01:52,  6.14it/s]
#
#  31%|███       | 309/1000 [00:46<02:17,  5.01it/s]
#
#  31%|███       | 310/1000 [00:46<02:02,  5.64it/s]
#
#  31%|███       | 311/1000 [00:46<01:59,  5.75it/s]
# Epoch 310
# 0.016098685562610626
# 0.9786760807037354
#  31%|███       | 312/1000 [00:47<02:27,  4.67it/s]
#
#  31%|███▏      | 313/1000 [00:47<02:26,  4.68it/s]
#
#  31%|███▏      | 314/1000 [00:47<02:08,  5.36it/s]
#
#  32%|███▏      | 315/1000 [00:47<01:55,  5.94it/s]
#
#  32%|███▏      | 316/1000 [00:47<02:08,  5.32it/s]
#
#  32%|███▏      | 317/1000 [00:48<02:24,  4.74it/s]
#
#  32%|███▏      | 318/1000 [00:48<02:37,  4.34it/s]
#
#  32%|███▏      | 319/1000 [00:48<02:41,  4.22it/s]
#
#  32%|███▏      | 320/1000 [00:48<02:36,  4.33it/s]
# Epoch 320
# 0.02720477432012558
# 0.9656546115875244
#  32%|███▏      | 321/1000 [00:49<02:39,  4.25it/s]
#
#  32%|███▏      | 322/1000 [00:49<02:20,  4.83it/s]
#
#  32%|███▏      | 323/1000 [00:49<02:03,  5.47it/s]
#
#  32%|███▏      | 324/1000 [00:49<01:53,  5.96it/s]
#
#  32%|███▎      | 325/1000 [00:49<01:46,  6.34it/s]
#
#  33%|███▎      | 326/1000 [00:49<01:40,  6.68it/s]
#
#  33%|███▎      | 327/1000 [00:49<01:40,  6.70it/s]
#
#  33%|███▎      | 328/1000 [00:49<01:37,  6.91it/s]
#
#  33%|███▎      | 329/1000 [00:50<01:33,  7.15it/s]
#
#  33%|███▎      | 330/1000 [00:50<01:32,  7.24it/s]
#
#  33%|███▎      | 331/1000 [00:50<01:32,  7.26it/s]
# Epoch 330
# 0.030515989288687706
# 0.975672721862793
#  33%|███▎      | 332/1000 [00:50<01:31,  7.32it/s]
#
#  33%|███▎      | 333/1000 [00:50<01:32,  7.23it/s]
#
#  33%|███▎      | 334/1000 [00:50<01:30,  7.39it/s]
#
#  34%|███▎      | 335/1000 [00:50<01:30,  7.38it/s]
#
#  34%|███▎      | 336/1000 [00:51<01:28,  7.52it/s]
#
#  34%|███▎      | 337/1000 [00:51<01:27,  7.54it/s]
#
#  34%|███▍      | 338/1000 [00:51<01:35,  6.91it/s]
#
#  34%|███▍      | 339/1000 [00:51<01:41,  6.51it/s]
#
#  34%|███▍      | 340/1000 [00:51<01:35,  6.91it/s]
#
#  34%|███▍      | 341/1000 [00:51<01:31,  7.24it/s]
# Epoch 340
# 0.0197627954185009
# 0.9791910648345947
#  34%|███▍      | 342/1000 [00:51<01:28,  7.44it/s]
#
#  34%|███▍      | 343/1000 [00:52<01:29,  7.33it/s]
#
#  34%|███▍      | 344/1000 [00:52<01:29,  7.37it/s]
#
#  34%|███▍      | 345/1000 [00:52<01:28,  7.43it/s]
#
#  35%|███▍      | 346/1000 [00:52<01:27,  7.46it/s]
#
#  35%|███▍      | 347/1000 [00:52<01:29,  7.27it/s]
#
#  35%|███▍      | 348/1000 [00:52<01:29,  7.31it/s]
#
#  35%|███▍      | 349/1000 [00:52<01:28,  7.33it/s]
#
#  35%|███▌      | 350/1000 [00:52<01:28,  7.34it/s]
#
#  35%|███▌      | 351/1000 [00:53<01:28,  7.36it/s]
# Epoch 350
# 0.03543130308389664
# 0.9583389759063721
#  35%|███▌      | 352/1000 [00:53<01:30,  7.16it/s]
#
#  35%|███▌      | 353/1000 [00:53<01:29,  7.26it/s]
#
#  35%|███▌      | 354/1000 [00:53<01:27,  7.40it/s]
#
#  36%|███▌      | 355/1000 [00:53<01:27,  7.37it/s]
#
#  36%|███▌      | 356/1000 [00:53<01:29,  7.18it/s]
#
#  36%|███▌      | 357/1000 [00:53<01:28,  7.23it/s]
#
#  36%|███▌      | 358/1000 [00:54<01:28,  7.27it/s]
#
#  36%|███▌      | 359/1000 [00:54<01:28,  7.25it/s]
#
#  36%|███▌      | 360/1000 [00:54<01:30,  7.11it/s]
#
#  36%|███▌      | 361/1000 [00:54<01:28,  7.21it/s]
# Epoch 360
# 0.04981635510921478
# 0.9568808078765869
#  36%|███▌      | 362/1000 [00:54<01:27,  7.25it/s]
#
#  36%|███▋      | 363/1000 [00:54<01:27,  7.31it/s]
#
#  36%|███▋      | 364/1000 [00:54<01:27,  7.30it/s]
#
#  36%|███▋      | 365/1000 [00:55<01:25,  7.45it/s]
#
#  37%|███▋      | 366/1000 [00:55<01:23,  7.58it/s]
#
#  37%|███▋      | 367/1000 [00:55<01:22,  7.66it/s]
#
#  37%|███▋      | 368/1000 [00:55<01:23,  7.58it/s]
#
#  37%|███▋      | 369/1000 [00:55<01:22,  7.68it/s]
#
#  37%|███▋      | 370/1000 [00:55<01:20,  7.78it/s]
#
#  37%|███▋      | 371/1000 [00:55<01:19,  7.89it/s]
# Epoch 370
# 0.06538449972867966
# 0.9611821174621582
#  37%|███▋      | 372/1000 [00:55<01:20,  7.80it/s]
#
#  37%|███▋      | 373/1000 [00:56<01:19,  7.91it/s]
#
#  37%|███▋      | 374/1000 [00:56<01:22,  7.60it/s]
#
#  38%|███▊      | 375/1000 [00:56<01:21,  7.71it/s]
#
#  38%|███▊      | 376/1000 [00:56<01:19,  7.84it/s]
#
#  38%|███▊      | 377/1000 [00:56<01:21,  7.62it/s]
#
#  38%|███▊      | 378/1000 [00:56<01:24,  7.38it/s]
#
#  38%|███▊      | 379/1000 [00:56<01:25,  7.25it/s]
#
#  38%|███▊      | 380/1000 [00:57<01:23,  7.38it/s]
#
#  38%|███▊      | 381/1000 [00:57<01:24,  7.33it/s]
# Epoch 380
# 0.04672149941325188
# 0.9613778591156006
#  38%|███▊      | 382/1000 [00:57<01:28,  6.97it/s]
#
#  38%|███▊      | 383/1000 [00:57<01:27,  7.04it/s]
#
#  38%|███▊      | 384/1000 [00:57<01:25,  7.18it/s]
#
#  38%|███▊      | 385/1000 [00:57<01:24,  7.31it/s]
#
#  39%|███▊      | 386/1000 [00:57<01:25,  7.21it/s]
#
#  39%|███▊      | 387/1000 [00:57<01:23,  7.32it/s]
#
#  39%|███▉      | 388/1000 [00:58<01:29,  6.81it/s]
#
#  39%|███▉      | 389/1000 [00:58<01:28,  6.87it/s]
#
#  39%|███▉      | 390/1000 [00:58<01:25,  7.12it/s]
#
#  39%|███▉      | 391/1000 [00:58<01:23,  7.27it/s]
# Epoch 390
# 0.03508133441209793
# 0.9573959112167358
#  39%|███▉      | 392/1000 [00:58<01:29,  6.83it/s]
#
#  39%|███▉      | 393/1000 [00:58<01:39,  6.08it/s]
#
#  39%|███▉      | 394/1000 [00:59<01:45,  5.73it/s]
#
#  40%|███▉      | 395/1000 [00:59<01:49,  5.52it/s]
#
#  40%|███▉      | 396/1000 [00:59<01:40,  6.02it/s]
#
#  40%|███▉      | 397/1000 [00:59<01:35,  6.35it/s]
#
#  40%|███▉      | 398/1000 [00:59<01:29,  6.74it/s]
#
#  40%|███▉      | 399/1000 [00:59<01:27,  6.90it/s]
#
#  40%|████      | 400/1000 [00:59<01:23,  7.21it/s]
#
#  40%|████      | 401/1000 [01:00<01:20,  7.47it/s]
# Epoch 400
# 0.017671409994363785
# 0.970388650894165
#  40%|████      | 402/1000 [01:00<01:18,  7.58it/s]
#
#  40%|████      | 403/1000 [01:00<01:19,  7.55it/s]
#
#  40%|████      | 404/1000 [01:00<01:19,  7.54it/s]
#
#  40%|████      | 405/1000 [01:00<01:18,  7.54it/s]
#
#  41%|████      | 406/1000 [01:00<01:19,  7.52it/s]
#
#  41%|████      | 407/1000 [01:00<01:21,  7.24it/s]
#
#  41%|████      | 408/1000 [01:01<01:20,  7.39it/s]
#
#  41%|████      | 409/1000 [01:01<01:27,  6.77it/s]
#
#  41%|████      | 410/1000 [01:01<01:24,  7.00it/s]
#
#  41%|████      | 411/1000 [01:01<01:22,  7.11it/s]
# Epoch 410
# 0.03822328895330429
# 0.9760676622390747
#  41%|████      | 412/1000 [01:01<01:21,  7.24it/s]
#
#  41%|████▏     | 413/1000 [01:01<01:19,  7.36it/s]
#
#  41%|████▏     | 414/1000 [01:01<01:18,  7.43it/s]
#
#  42%|████▏     | 415/1000 [01:02<01:18,  7.43it/s]
#
#  42%|████▏     | 416/1000 [01:02<01:16,  7.64it/s]
#
#  42%|████▏     | 417/1000 [01:02<01:14,  7.78it/s]
#
#  42%|████▏     | 418/1000 [01:02<01:13,  7.89it/s]
#
#  42%|████▏     | 419/1000 [01:02<01:14,  7.82it/s]
#
#  42%|████▏     | 420/1000 [01:02<01:13,  7.91it/s]
#
#  42%|████▏     | 421/1000 [01:02<01:12,  7.97it/s]
# Epoch 420
# 0.022498253732919693
# 0.9675335884094238
#  42%|████▏     | 422/1000 [01:02<01:12,  8.01it/s]
#
#  42%|████▏     | 423/1000 [01:03<01:12,  7.95it/s]
#
#  42%|████▏     | 424/1000 [01:03<01:12,  7.91it/s]
#
#  42%|████▎     | 425/1000 [01:03<01:14,  7.68it/s]
#
#  43%|████▎     | 426/1000 [01:03<01:18,  7.34it/s]
#
#  43%|████▎     | 427/1000 [01:03<01:23,  6.86it/s]
#
#  43%|████▎     | 428/1000 [01:03<01:23,  6.89it/s]
#
#  43%|████▎     | 429/1000 [01:03<01:21,  7.00it/s]
#
#  43%|████▎     | 430/1000 [01:04<01:21,  7.03it/s]
#
#  43%|████▎     | 431/1000 [01:04<01:20,  7.11it/s]
# Epoch 430
# 0.0322720892727375
# 0.9672842025756836
#  43%|████▎     | 432/1000 [01:04<01:18,  7.23it/s]
#
#  43%|████▎     | 433/1000 [01:04<01:19,  7.17it/s]
#
#  43%|████▎     | 434/1000 [01:04<01:21,  6.96it/s]
#
#  44%|████▎     | 435/1000 [01:04<01:17,  7.26it/s]
#
#  44%|████▎     | 436/1000 [01:04<01:15,  7.49it/s]
#
#  44%|████▎     | 437/1000 [01:04<01:15,  7.43it/s]
#
#  44%|████▍     | 438/1000 [01:05<01:13,  7.61it/s]
#
#  44%|████▍     | 439/1000 [01:05<01:12,  7.75it/s]
#
#  44%|████▍     | 440/1000 [01:05<01:11,  7.79it/s]
#
#  44%|████▍     | 441/1000 [01:05<01:12,  7.74it/s]
# Epoch 440
# 0.04470508545637131
# 0.9484090805053711
#  44%|████▍     | 442/1000 [01:05<01:12,  7.69it/s]
#
#  44%|████▍     | 443/1000 [01:05<01:12,  7.68it/s]
#
#  44%|████▍     | 444/1000 [01:05<01:11,  7.80it/s]
#
#  44%|████▍     | 445/1000 [01:05<01:11,  7.79it/s]
#
#  45%|████▍     | 446/1000 [01:06<01:12,  7.68it/s]
#
#  45%|████▍     | 447/1000 [01:06<01:16,  7.22it/s]
#
#  45%|████▍     | 448/1000 [01:06<01:18,  7.07it/s]
#
#  45%|████▍     | 449/1000 [01:06<01:17,  7.12it/s]
#
#  45%|████▌     | 450/1000 [01:06<01:17,  7.09it/s]
#
#  45%|████▌     | 451/1000 [01:06<01:16,  7.17it/s]
# Epoch 450
# 0.021245155483484268
# 0.9751144647598267
#  45%|████▌     | 452/1000 [01:06<01:15,  7.28it/s]
#
#  45%|████▌     | 453/1000 [01:07<01:13,  7.46it/s]
#
#  45%|████▌     | 454/1000 [01:07<01:14,  7.32it/s]
#
#  46%|████▌     | 455/1000 [01:07<01:20,  6.79it/s]
#
#  46%|████▌     | 456/1000 [01:07<01:29,  6.10it/s]
#
#  46%|████▌     | 457/1000 [01:07<01:34,  5.72it/s]
#
#  46%|████▌     | 458/1000 [01:07<01:28,  6.15it/s]
#
#  46%|████▌     | 459/1000 [01:08<01:26,  6.22it/s]
#
#  46%|████▌     | 460/1000 [01:08<01:21,  6.63it/s]
#
#  46%|████▌     | 461/1000 [01:08<01:17,  6.97it/s]
# Epoch 460
# 0.030317433178424835
# 0.977104663848877
#  46%|████▌     | 462/1000 [01:08<01:14,  7.21it/s]
#
#  46%|████▋     | 463/1000 [01:08<01:12,  7.37it/s]
#
#  46%|████▋     | 464/1000 [01:08<01:13,  7.33it/s]
#
#  46%|████▋     | 465/1000 [01:08<01:13,  7.28it/s]
#
#  47%|████▋     | 466/1000 [01:09<01:12,  7.41it/s]
#
#  47%|████▋     | 467/1000 [01:09<01:10,  7.55it/s]
#
#  47%|████▋     | 468/1000 [01:09<01:10,  7.58it/s]
#
#  47%|████▋     | 469/1000 [01:09<01:12,  7.32it/s]
#
#  47%|████▋     | 470/1000 [01:09<01:11,  7.38it/s]
#
#  47%|████▋     | 471/1000 [01:09<01:11,  7.38it/s]
# Epoch 470
# 0.03354795277118683
# 0.9673612117767334
#  47%|████▋     | 472/1000 [01:09<01:13,  7.23it/s]
#
#  47%|████▋     | 473/1000 [01:09<01:10,  7.47it/s]
#
#  47%|████▋     | 474/1000 [01:10<01:08,  7.66it/s]
#
#  48%|████▊     | 475/1000 [01:10<01:09,  7.52it/s]
#
#  48%|████▊     | 476/1000 [01:10<01:08,  7.70it/s]
#
#  48%|████▊     | 477/1000 [01:10<01:06,  7.83it/s]
#
#  48%|████▊     | 478/1000 [01:10<01:06,  7.89it/s]
#
#  48%|████▊     | 479/1000 [01:10<01:06,  7.81it/s]
#
#  48%|████▊     | 480/1000 [01:10<01:05,  7.90it/s]
#
#  48%|████▊     | 481/1000 [01:10<01:05,  7.87it/s]
# Epoch 480
# 0.01955327019095421
# 0.9676785469055176
#  48%|████▊     | 482/1000 [01:11<01:06,  7.73it/s]
#
#  48%|████▊     | 483/1000 [01:11<01:10,  7.37it/s]
#
#  48%|████▊     | 484/1000 [01:11<01:09,  7.41it/s]
#
#  48%|████▊     | 485/1000 [01:11<01:08,  7.57it/s]
#
#  49%|████▊     | 486/1000 [01:11<01:07,  7.66it/s]
#
#  49%|████▊     | 487/1000 [01:11<01:08,  7.51it/s]
#
#  49%|████▉     | 488/1000 [01:11<01:07,  7.55it/s]
#
#  49%|████▉     | 489/1000 [01:12<01:07,  7.58it/s]
#
#  49%|████▉     | 490/1000 [01:12<01:08,  7.44it/s]
#
#  49%|████▉     | 491/1000 [01:12<01:10,  7.19it/s]
# Epoch 490
# 0.03073873557150364
# 0.9624137878417969
#  49%|████▉     | 492/1000 [01:12<01:08,  7.41it/s]
#
#  49%|████▉     | 493/1000 [01:12<01:07,  7.52it/s]
#
#  49%|████▉     | 494/1000 [01:12<01:06,  7.58it/s]
#
#  50%|████▉     | 495/1000 [01:12<01:07,  7.50it/s]
#
#  50%|████▉     | 496/1000 [01:13<01:23,  6.07it/s]
#
#  50%|████▉     | 497/1000 [01:13<01:30,  5.55it/s]
#
#  50%|████▉     | 498/1000 [01:13<01:31,  5.49it/s]
#
#  50%|████▉     | 499/1000 [01:13<01:28,  5.69it/s]
#
#  50%|█████     | 500/1000 [01:13<01:26,  5.76it/s]
# Epoch 500
# 0.013147193938493729
# 0.9770141839981079
#  50%|█████     | 501/1000 [01:14<01:40,  4.99it/s]
#
#  50%|█████     | 502/1000 [01:14<01:50,  4.52it/s]
#
#  50%|█████     | 503/1000 [01:14<01:54,  4.35it/s]
#
#  50%|█████     | 504/1000 [01:14<01:58,  4.18it/s]
#
#  50%|█████     | 505/1000 [01:15<02:02,  4.04it/s]
#
#  51%|█████     | 506/1000 [01:15<01:50,  4.49it/s]
#
#  51%|█████     | 507/1000 [01:15<01:35,  5.16it/s]
#
#  51%|█████     | 508/1000 [01:15<01:33,  5.24it/s]
#
#  51%|█████     | 509/1000 [01:15<01:26,  5.66it/s]
#
#  51%|█████     | 510/1000 [01:15<01:35,  5.15it/s]
#
#  51%|█████     | 511/1000 [01:16<01:28,  5.50it/s]
# Epoch 510
# 0.024695083498954773
# 0.977452278137207
#  51%|█████     | 512/1000 [01:16<01:22,  5.94it/s]
#
#  51%|█████▏    | 513/1000 [01:16<01:16,  6.38it/s]
#
#  51%|█████▏    | 514/1000 [01:16<01:13,  6.63it/s]
#
#  52%|█████▏    | 515/1000 [01:16<01:10,  6.87it/s]
#
#  52%|█████▏    | 516/1000 [01:16<01:14,  6.49it/s]
#
#  52%|█████▏    | 517/1000 [01:17<01:22,  5.86it/s]
#
#  52%|█████▏    | 518/1000 [01:17<01:16,  6.31it/s]
#
#  52%|█████▏    | 519/1000 [01:17<01:27,  5.52it/s]
#
#  52%|█████▏    | 520/1000 [01:17<01:36,  4.97it/s]
#
#  52%|█████▏    | 521/1000 [01:17<01:26,  5.55it/s]
# Epoch 520
# 0.03651232272386551
# 0.9683630466461182
#  52%|█████▏    | 522/1000 [01:17<01:18,  6.12it/s]
#
#  52%|█████▏    | 523/1000 [01:18<01:27,  5.44it/s]
#
#  52%|█████▏    | 524/1000 [01:18<01:21,  5.85it/s]
#
#  52%|█████▎    | 525/1000 [01:18<01:26,  5.49it/s]
#
#  53%|█████▎    | 526/1000 [01:18<01:19,  5.95it/s]
#
#  53%|█████▎    | 527/1000 [01:18<01:27,  5.38it/s]
#
#  53%|█████▎    | 528/1000 [01:19<01:19,  5.94it/s]
#
#  53%|█████▎    | 529/1000 [01:19<01:23,  5.62it/s]
#
#  53%|█████▎    | 530/1000 [01:19<01:17,  6.10it/s]
# Epoch 530
# 0.032452292740345
# 0.9581247568130493
#  53%|█████▎    | 531/1000 [01:19<01:22,  5.66it/s]
#
#  53%|█████▎    | 532/1000 [01:19<01:18,  5.95it/s]
#
#  53%|█████▎    | 533/1000 [01:19<01:22,  5.65it/s]
#
#  53%|█████▎    | 534/1000 [01:20<01:19,  5.88it/s]
#
#  54%|█████▎    | 535/1000 [01:20<01:18,  5.91it/s]
#
#  54%|█████▎    | 536/1000 [01:20<01:20,  5.76it/s]
#
#  54%|█████▎    | 537/1000 [01:20<01:17,  5.99it/s]
#
#  54%|█████▍    | 538/1000 [01:20<01:11,  6.51it/s]
#
#  54%|█████▍    | 539/1000 [01:20<01:06,  6.91it/s]
#
#  54%|█████▍    | 540/1000 [01:20<01:13,  6.24it/s]
#
#  54%|█████▍    | 541/1000 [01:21<01:10,  6.50it/s]
# Epoch 540
# 0.017941007390618324
# 0.9623066186904907
#  54%|█████▍    | 542/1000 [01:21<01:06,  6.90it/s]
#
#  54%|█████▍    | 543/1000 [01:21<01:03,  7.15it/s]
#
#  54%|█████▍    | 544/1000 [01:21<01:02,  7.30it/s]
#
#  55%|█████▍    | 545/1000 [01:21<01:01,  7.43it/s]
#
#  55%|█████▍    | 546/1000 [01:21<01:00,  7.50it/s]
#
#  55%|█████▍    | 547/1000 [01:21<01:07,  6.69it/s]
#
#  55%|█████▍    | 548/1000 [01:22<01:17,  5.86it/s]
#
#  55%|█████▍    | 549/1000 [01:22<01:12,  6.23it/s]
#
#  55%|█████▌    | 550/1000 [01:22<01:09,  6.49it/s]
#
#  55%|█████▌    | 551/1000 [01:22<01:05,  6.83it/s]
# Epoch 550
# 0.019841162487864494
# 0.976152777671814
#  55%|█████▌    | 552/1000 [01:22<01:15,  5.94it/s]
#
#  55%|█████▌    | 553/1000 [01:23<01:20,  5.52it/s]
#
#  55%|█████▌    | 554/1000 [01:23<01:36,  4.60it/s]
#
#  56%|█████▌    | 555/1000 [01:23<01:44,  4.27it/s]
#
#  56%|█████▌    | 556/1000 [01:23<01:32,  4.82it/s]
#
#  56%|█████▌    | 557/1000 [01:23<01:26,  5.14it/s]
#
#  56%|█████▌    | 558/1000 [01:24<01:35,  4.63it/s]
#
#  56%|█████▌    | 559/1000 [01:24<01:48,  4.05it/s]
#
#  56%|█████▌    | 560/1000 [01:24<01:52,  3.93it/s]
#
#  56%|█████▌    | 561/1000 [01:24<01:36,  4.57it/s]
# Epoch 560
# 0.02314673736691475
# 0.9612550735473633
#  56%|█████▌    | 562/1000 [01:25<01:34,  4.65it/s]
#
#  56%|█████▋    | 563/1000 [01:25<01:31,  4.79it/s]
#
#  56%|█████▋    | 564/1000 [01:25<01:21,  5.34it/s]
#
#  56%|█████▋    | 565/1000 [01:25<01:14,  5.81it/s]
#
#  57%|█████▋    | 566/1000 [01:25<01:09,  6.26it/s]
#
#  57%|█████▋    | 567/1000 [01:25<01:05,  6.58it/s]
#
#  57%|█████▋    | 568/1000 [01:25<01:03,  6.79it/s]
#
#  57%|█████▋    | 569/1000 [01:26<01:01,  6.96it/s]
#
#  57%|█████▋    | 570/1000 [01:26<01:00,  7.07it/s]
#
#  57%|█████▋    | 571/1000 [01:26<01:00,  7.15it/s]
# Epoch 570
# 0.02640526555478573
# 0.9786273241043091
#  57%|█████▋    | 572/1000 [01:26<01:00,  7.11it/s]
#
#  57%|█████▋    | 573/1000 [01:26<00:59,  7.19it/s]
#
#  57%|█████▋    | 574/1000 [01:26<00:59,  7.18it/s]
#
#  57%|█████▊    | 575/1000 [01:26<00:58,  7.27it/s]
#
#  58%|█████▊    | 576/1000 [01:27<00:56,  7.46it/s]
#
#  58%|█████▊    | 577/1000 [01:27<00:55,  7.63it/s]
#
#  58%|█████▊    | 578/1000 [01:27<00:55,  7.63it/s]
#
#  58%|█████▊    | 579/1000 [01:27<00:55,  7.54it/s]
#
#  58%|█████▊    | 580/1000 [01:27<00:55,  7.52it/s]
#
#  58%|█████▊    | 581/1000 [01:27<00:55,  7.54it/s]
# Epoch 580
# 0.021924573928117752
# 0.97080397605896
#  58%|█████▊    | 582/1000 [01:27<00:54,  7.65it/s]
#
#  58%|█████▊    | 583/1000 [01:27<00:56,  7.43it/s]
#
#  58%|█████▊    | 584/1000 [01:28<00:55,  7.52it/s]
#
#  58%|█████▊    | 585/1000 [01:28<00:55,  7.51it/s]
#
#  59%|█████▊    | 586/1000 [01:28<00:55,  7.52it/s]
#
#  59%|█████▊    | 587/1000 [01:28<00:54,  7.53it/s]
#
#  59%|█████▉    | 588/1000 [01:28<00:55,  7.48it/s]
#
#  59%|█████▉    | 589/1000 [01:28<00:56,  7.24it/s]
#
#  59%|█████▉    | 590/1000 [01:28<00:56,  7.20it/s]
#
#  59%|█████▉    | 591/1000 [01:29<00:58,  7.05it/s]
# Epoch 590
# 0.043144240975379944
# 0.9351663589477539
#  59%|█████▉    | 592/1000 [01:29<00:56,  7.21it/s]
#
#  59%|█████▉    | 593/1000 [01:29<00:54,  7.41it/s]
#
#  59%|█████▉    | 594/1000 [01:29<00:56,  7.24it/s]
#
#  60%|█████▉    | 595/1000 [01:29<01:03,  6.42it/s]
#
#  60%|█████▉    | 596/1000 [01:29<01:04,  6.22it/s]
#
#  60%|█████▉    | 597/1000 [01:30<01:04,  6.26it/s]
#
#  60%|█████▉    | 598/1000 [01:30<01:04,  6.28it/s]
#
#  60%|█████▉    | 599/1000 [01:30<01:03,  6.33it/s]
#
#  60%|██████    | 600/1000 [01:30<01:02,  6.42it/s]
#
#  60%|██████    | 601/1000 [01:30<00:59,  6.72it/s]
# Epoch 600
# 0.028850480914115906
# 0.9581636190414429
#  60%|██████    | 602/1000 [01:30<01:16,  5.18it/s]
#
#  60%|██████    | 603/1000 [01:31<01:25,  4.63it/s]
#
#  60%|██████    | 604/1000 [01:31<01:35,  4.15it/s]
#
#  60%|██████    | 605/1000 [01:31<01:26,  4.56it/s]
#
#  61%|██████    | 606/1000 [01:31<01:15,  5.21it/s]
#
#  61%|██████    | 607/1000 [01:31<01:08,  5.73it/s]
#
#  61%|██████    | 608/1000 [01:32<01:03,  6.16it/s]
#
#  61%|██████    | 609/1000 [01:32<00:59,  6.61it/s]
#
#  61%|██████    | 610/1000 [01:32<00:56,  6.91it/s]
#
#  61%|██████    | 611/1000 [01:32<00:54,  7.09it/s]
# Epoch 610
# 0.018797628581523895
# 0.9669749736785889
#  61%|██████    | 612/1000 [01:32<00:54,  7.11it/s]
#
#  61%|██████▏   | 613/1000 [01:32<00:55,  6.95it/s]
#
#  61%|██████▏   | 614/1000 [01:32<00:55,  6.90it/s]
#
#  62%|██████▏   | 615/1000 [01:33<00:55,  6.97it/s]
#
#  62%|██████▏   | 616/1000 [01:33<00:53,  7.13it/s]
#
#  62%|██████▏   | 617/1000 [01:33<00:52,  7.35it/s]
#
#  62%|██████▏   | 618/1000 [01:33<00:50,  7.52it/s]
#
#  62%|██████▏   | 619/1000 [01:33<00:49,  7.63it/s]
#
#  62%|██████▏   | 620/1000 [01:33<00:51,  7.32it/s]
#
#  62%|██████▏   | 621/1000 [01:33<00:53,  7.12it/s]
# Epoch 620
# 0.030621476471424103
# 0.954343318939209
#  62%|██████▏   | 622/1000 [01:33<00:53,  7.04it/s]
#
#  62%|██████▏   | 623/1000 [01:34<00:52,  7.15it/s]
#
#  62%|██████▏   | 624/1000 [01:34<00:52,  7.14it/s]
#
#  62%|██████▎   | 625/1000 [01:34<00:51,  7.25it/s]
#
#  63%|██████▎   | 626/1000 [01:34<00:50,  7.45it/s]
#
#  63%|██████▎   | 627/1000 [01:34<00:48,  7.63it/s]
#
#  63%|██████▎   | 628/1000 [01:34<00:48,  7.62it/s]
#
#  63%|██████▎   | 629/1000 [01:34<00:47,  7.74it/s]
#
#  63%|██████▎   | 630/1000 [01:34<00:47,  7.83it/s]
#
#  63%|██████▎   | 631/1000 [01:35<00:46,  7.89it/s]
# Epoch 630
# 0.02424435317516327
# 0.9747998714447021
#  63%|██████▎   | 632/1000 [01:35<00:47,  7.80it/s]
#
#  63%|██████▎   | 633/1000 [01:35<00:46,  7.88it/s]
#
#  63%|██████▎   | 634/1000 [01:35<00:46,  7.94it/s]
#
#  64%|██████▎   | 635/1000 [01:35<00:46,  7.87it/s]
#
#  64%|██████▎   | 636/1000 [01:35<00:47,  7.66it/s]
#
#  64%|██████▎   | 637/1000 [01:35<00:47,  7.59it/s]
#
#  64%|██████▍   | 638/1000 [01:36<00:48,  7.53it/s]
#
#  64%|██████▍   | 639/1000 [01:36<00:48,  7.49it/s]
#
#  64%|██████▍   | 640/1000 [01:36<00:48,  7.36it/s]
#
#  64%|██████▍   | 641/1000 [01:36<00:48,  7.40it/s]
# Epoch 640
# 0.030759692192077637
# 0.9541935920715332
#  64%|██████▍   | 642/1000 [01:36<00:48,  7.45it/s]
#
#  64%|██████▍   | 643/1000 [01:36<00:47,  7.46it/s]
#
#  64%|██████▍   | 644/1000 [01:36<00:48,  7.37it/s]
#
#  64%|██████▍   | 645/1000 [01:36<00:48,  7.36it/s]
#
#  65%|██████▍   | 646/1000 [01:37<00:48,  7.37it/s]
#
#  65%|██████▍   | 647/1000 [01:37<00:48,  7.35it/s]
#
#  65%|██████▍   | 648/1000 [01:37<00:48,  7.33it/s]
#
#  65%|██████▍   | 649/1000 [01:37<00:47,  7.44it/s]
#
#  65%|██████▌   | 650/1000 [01:37<00:46,  7.61it/s]
#
#  65%|██████▌   | 651/1000 [01:37<00:46,  7.46it/s]
# Epoch 650
# 0.03738395869731903
# 0.9554286003112793
#  65%|██████▌   | 652/1000 [01:37<00:51,  6.74it/s]
#
#  65%|██████▌   | 653/1000 [01:38<00:59,  5.87it/s]
#
#  65%|██████▌   | 654/1000 [01:38<00:55,  6.29it/s]
#
#  66%|██████▌   | 655/1000 [01:38<00:52,  6.55it/s]
#
#  66%|██████▌   | 656/1000 [01:38<00:51,  6.70it/s]
#
#  66%|██████▌   | 657/1000 [01:38<00:49,  6.90it/s]
#
#  66%|██████▌   | 658/1000 [01:38<00:50,  6.72it/s]
#
#  66%|██████▌   | 659/1000 [01:39<00:49,  6.84it/s]
#
#  66%|██████▌   | 660/1000 [01:39<00:48,  7.06it/s]
#
#  66%|██████▌   | 661/1000 [01:39<00:48,  7.02it/s]
# Epoch 660
# 0.024872248992323875
# 0.9627453088760376
#  66%|██████▌   | 662/1000 [01:39<00:52,  6.43it/s]
#
#  66%|██████▋   | 663/1000 [01:39<00:49,  6.84it/s]
#
#  66%|██████▋   | 664/1000 [01:39<00:46,  7.17it/s]
#
#  66%|██████▋   | 665/1000 [01:39<00:46,  7.28it/s]
#
#  67%|██████▋   | 666/1000 [01:40<00:44,  7.45it/s]
#
#  67%|██████▋   | 667/1000 [01:40<00:43,  7.63it/s]
#
#  67%|██████▋   | 668/1000 [01:40<00:42,  7.77it/s]
#
#  67%|██████▋   | 669/1000 [01:40<00:42,  7.73it/s]
#
#  67%|██████▋   | 670/1000 [01:40<00:42,  7.78it/s]
#
#  67%|██████▋   | 671/1000 [01:40<00:43,  7.50it/s]
# Epoch 670
# 0.012929287739098072
# 0.981250524520874
#  67%|██████▋   | 672/1000 [01:40<00:43,  7.59it/s]
#
#  67%|██████▋   | 673/1000 [01:40<00:42,  7.66it/s]
#
#  67%|██████▋   | 674/1000 [01:41<00:42,  7.72it/s]
#
#  68%|██████▊   | 675/1000 [01:41<00:42,  7.62it/s]
#
#  68%|██████▊   | 676/1000 [01:41<00:43,  7.46it/s]
#
#  68%|██████▊   | 677/1000 [01:41<00:43,  7.45it/s]
#
#  68%|██████▊   | 678/1000 [01:41<00:42,  7.63it/s]
#
#  68%|██████▊   | 679/1000 [01:41<00:41,  7.76it/s]
#
#  68%|██████▊   | 680/1000 [01:41<00:41,  7.76it/s]
#
#  68%|██████▊   | 681/1000 [01:41<00:40,  7.82it/s]
# Epoch 680
# 0.024245677515864372
# 0.9580135345458984
#  68%|██████▊   | 682/1000 [01:42<00:42,  7.54it/s]
#
#  68%|██████▊   | 683/1000 [01:42<00:41,  7.68it/s]
#
#  68%|██████▊   | 684/1000 [01:42<00:41,  7.60it/s]
#
#  68%|██████▊   | 685/1000 [01:42<00:41,  7.53it/s]
#
#  69%|██████▊   | 686/1000 [01:42<00:41,  7.53it/s]
#
#  69%|██████▊   | 687/1000 [01:42<00:42,  7.44it/s]
#
#  69%|██████▉   | 688/1000 [01:42<00:42,  7.39it/s]
#
#  69%|██████▉   | 689/1000 [01:43<00:41,  7.44it/s]
#
#  69%|██████▉   | 690/1000 [01:43<00:42,  7.37it/s]
#
#  69%|██████▉   | 691/1000 [01:43<00:41,  7.51it/s]
# Epoch 690
# 0.044019393622875214
# 0.963701605796814
#  69%|██████▉   | 692/1000 [01:43<00:40,  7.65it/s]
#
#  69%|██████▉   | 693/1000 [01:43<00:40,  7.55it/s]
#
#  69%|██████▉   | 694/1000 [01:43<00:39,  7.68it/s]
#
#  70%|██████▉   | 695/1000 [01:43<00:40,  7.55it/s]
#
#  70%|██████▉   | 696/1000 [01:43<00:41,  7.29it/s]
#
#  70%|██████▉   | 697/1000 [01:44<00:44,  6.89it/s]
#
#  70%|██████▉   | 698/1000 [01:44<00:42,  7.17it/s]
#
#  70%|██████▉   | 699/1000 [01:44<00:40,  7.44it/s]
#
#  70%|███████   | 700/1000 [01:44<00:39,  7.63it/s]
#
#  70%|███████   | 701/1000 [01:44<00:39,  7.65it/s]
# Epoch 700
# 0.033691950142383575
# 0.9399082660675049
#  70%|███████   | 702/1000 [01:44<00:38,  7.72it/s]
#
#  70%|███████   | 703/1000 [01:44<00:38,  7.68it/s]
#
#  70%|███████   | 704/1000 [01:45<00:38,  7.64it/s]
#
#  70%|███████   | 705/1000 [01:45<00:39,  7.50it/s]
#
#  71%|███████   | 706/1000 [01:45<00:38,  7.54it/s]
#
#  71%|███████   | 707/1000 [01:45<00:38,  7.54it/s]
#
#  71%|███████   | 708/1000 [01:45<00:38,  7.50it/s]
#
#  71%|███████   | 709/1000 [01:45<00:39,  7.31it/s]
#
#  71%|███████   | 710/1000 [01:45<00:40,  7.12it/s]
# Epoch 710
# 0.059205155819654465
# 0.9303073883056641
#  71%|███████   | 711/1000 [01:46<00:47,  6.02it/s]
#
#  71%|███████   | 712/1000 [01:46<00:46,  6.21it/s]
#
#  71%|███████▏  | 713/1000 [01:46<00:43,  6.56it/s]
#
#  71%|███████▏  | 714/1000 [01:46<00:43,  6.64it/s]
#
#  72%|███████▏  | 715/1000 [01:46<00:42,  6.67it/s]
#
#  72%|███████▏  | 716/1000 [01:46<00:41,  6.82it/s]
#
#  72%|███████▏  | 717/1000 [01:46<00:41,  6.87it/s]
#
#  72%|███████▏  | 718/1000 [01:47<00:39,  7.08it/s]
#
#  72%|███████▏  | 719/1000 [01:47<00:38,  7.27it/s]
#
#  72%|███████▏  | 720/1000 [01:47<00:39,  7.11it/s]
#
#  72%|███████▏  | 721/1000 [01:47<00:39,  7.01it/s]
# Epoch 720
# 0.032811038196086884
# 0.9617116451263428
#  72%|███████▏  | 722/1000 [01:47<00:38,  7.27it/s]
#
#  72%|███████▏  | 723/1000 [01:47<00:37,  7.48it/s]
#
#  72%|███████▏  | 724/1000 [01:47<00:37,  7.38it/s]
#
#  72%|███████▎  | 725/1000 [01:48<00:36,  7.50it/s]
#
#  73%|███████▎  | 726/1000 [01:48<00:36,  7.49it/s]
#
#  73%|███████▎  | 727/1000 [01:48<00:36,  7.50it/s]
#
#  73%|███████▎  | 728/1000 [01:48<00:36,  7.51it/s]
#
#  73%|███████▎  | 729/1000 [01:48<00:35,  7.62it/s]
#
#  73%|███████▎  | 730/1000 [01:48<00:37,  7.17it/s]
#
#  73%|███████▎  | 731/1000 [01:48<00:38,  6.94it/s]
# Epoch 730
# 0.017212029546499252
# 0.9828485250473022
#  73%|███████▎  | 732/1000 [01:49<00:38,  6.89it/s]
#
#  73%|███████▎  | 733/1000 [01:49<00:38,  6.96it/s]
#
#  73%|███████▎  | 734/1000 [01:49<00:38,  6.95it/s]
#
#  74%|███████▎  | 735/1000 [01:49<00:38,  6.95it/s]
#
#  74%|███████▎  | 736/1000 [01:49<00:37,  7.10it/s]
#
#  74%|███████▎  | 737/1000 [01:49<00:36,  7.17it/s]
#
#  74%|███████▍  | 738/1000 [01:49<00:36,  7.25it/s]
#
#  74%|███████▍  | 739/1000 [01:49<00:35,  7.40it/s]
#
#  74%|███████▍  | 740/1000 [01:50<00:34,  7.56it/s]
#
#  74%|███████▍  | 741/1000 [01:50<00:33,  7.70it/s]
# Epoch 740
# 0.012827316299080849
# 0.9731855392456055
#  74%|███████▍  | 742/1000 [01:50<00:33,  7.65it/s]
#
#  74%|███████▍  | 743/1000 [01:50<00:33,  7.78it/s]
#
#  74%|███████▍  | 744/1000 [01:50<00:32,  7.87it/s]
#
#  74%|███████▍  | 745/1000 [01:50<00:32,  7.89it/s]
#
#  75%|███████▍  | 746/1000 [01:50<00:38,  6.58it/s]
#
#  75%|███████▍  | 747/1000 [01:51<00:38,  6.64it/s]
#
#  75%|███████▍  | 748/1000 [01:51<00:36,  6.96it/s]
#
#  75%|███████▍  | 749/1000 [01:51<00:36,  6.97it/s]
#
#  75%|███████▌  | 750/1000 [01:51<00:35,  6.97it/s]
#
#  75%|███████▌  | 751/1000 [01:51<00:35,  6.99it/s]
# Epoch 750
# 0.02954651601612568
# 0.9687540531158447
#  75%|███████▌  | 752/1000 [01:51<00:36,  6.83it/s]
#
#  75%|███████▌  | 753/1000 [01:51<00:36,  6.84it/s]
#
#  75%|███████▌  | 754/1000 [01:52<00:34,  7.10it/s]
#
#  76%|███████▌  | 755/1000 [01:52<00:33,  7.24it/s]
#
#  76%|███████▌  | 756/1000 [01:52<00:33,  7.20it/s]
#
#  76%|███████▌  | 757/1000 [01:52<00:33,  7.22it/s]
#
#  76%|███████▌  | 758/1000 [01:52<00:32,  7.44it/s]
#
#  76%|███████▌  | 759/1000 [01:52<00:31,  7.62it/s]
#
#  76%|███████▌  | 760/1000 [01:52<00:31,  7.74it/s]
#
#  76%|███████▌  | 761/1000 [01:52<00:31,  7.55it/s]
# Epoch 760
# 0.01408749632537365
# 0.9856345653533936
#  76%|███████▌  | 762/1000 [01:53<00:39,  6.08it/s]
#
#  76%|███████▋  | 763/1000 [01:53<00:53,  4.46it/s]
#
#  76%|███████▋  | 764/1000 [01:54<01:06,  3.57it/s]
#
#  76%|███████▋  | 765/1000 [01:54<01:13,  3.19it/s]
#
#  77%|███████▋  | 766/1000 [01:54<01:26,  2.71it/s]
#
#  77%|███████▋  | 767/1000 [01:55<01:27,  2.67it/s]
#
#  77%|███████▋  | 768/1000 [01:55<01:25,  2.70it/s]
#
#  77%|███████▋  | 769/1000 [01:56<01:25,  2.72it/s]
#
#  77%|███████▋  | 770/1000 [01:56<01:32,  2.49it/s]
# Epoch 770
# 0.030397586524486542
# 0.9684435129165649
#  77%|███████▋  | 771/1000 [01:56<01:38,  2.33it/s]
#
#  77%|███████▋  | 772/1000 [01:57<01:56,  1.96it/s]
#
#  77%|███████▋  | 773/1000 [01:58<02:01,  1.87it/s]
#
#  77%|███████▋  | 774/1000 [01:58<01:53,  1.99it/s]
#
#  78%|███████▊  | 775/1000 [01:59<01:44,  2.16it/s]
#
#  78%|███████▊  | 776/1000 [01:59<01:40,  2.22it/s]
#
#  78%|███████▊  | 777/1000 [01:59<01:41,  2.20it/s]
#
#  78%|███████▊  | 778/1000 [02:00<01:35,  2.33it/s]
#
#  78%|███████▊  | 779/1000 [02:00<01:31,  2.41it/s]
#
#  78%|███████▊  | 780/1000 [02:01<01:29,  2.46it/s]
# Epoch 780
# 0.012801804579794407
# 0.9791519641876221
#  78%|███████▊  | 781/1000 [02:01<01:23,  2.63it/s]
#
#  78%|███████▊  | 782/1000 [02:01<01:20,  2.71it/s]
#
#  78%|███████▊  | 783/1000 [02:02<01:13,  2.93it/s]
#
#  78%|███████▊  | 784/1000 [02:02<01:10,  3.05it/s]
#
#  78%|███████▊  | 785/1000 [02:02<01:11,  2.99it/s]
#
#  79%|███████▊  | 786/1000 [02:03<01:14,  2.88it/s]
#
#  79%|███████▊  | 787/1000 [02:03<01:16,  2.78it/s]
#
#  79%|███████▉  | 788/1000 [02:03<01:20,  2.63it/s]
#
#  79%|███████▉  | 789/1000 [02:04<01:16,  2.74it/s]
#
#  79%|███████▉  | 790/1000 [02:04<01:16,  2.75it/s]
# Epoch 790
# 0.01930277980864048
# 0.9845383167266846
#  79%|███████▉  | 791/1000 [02:04<01:09,  2.99it/s]
#
#  79%|███████▉  | 792/1000 [02:05<01:06,  3.14it/s]
#
#  79%|███████▉  | 793/1000 [02:05<01:02,  3.31it/s]
#
#  79%|███████▉  | 794/1000 [02:05<00:59,  3.49it/s]
#
#  80%|███████▉  | 795/1000 [02:05<00:57,  3.59it/s]
#
#  80%|███████▉  | 796/1000 [02:06<00:55,  3.69it/s]
#
#  80%|███████▉  | 797/1000 [02:06<00:53,  3.79it/s]
#
#  80%|███████▉  | 798/1000 [02:06<00:51,  3.89it/s]
#
#  80%|███████▉  | 799/1000 [02:06<00:50,  4.02it/s]
#
#  80%|████████  | 800/1000 [02:07<00:48,  4.09it/s]
# Epoch 800
# 0.020422793924808502
# 0.9761669635772705
#  80%|████████  | 801/1000 [02:07<00:49,  4.00it/s]
#
#  80%|████████  | 802/1000 [02:07<00:50,  3.94it/s]
#
#  80%|████████  | 803/1000 [02:07<00:50,  3.88it/s]
#
#  80%|████████  | 804/1000 [02:08<00:49,  3.94it/s]
#
#  80%|████████  | 805/1000 [02:08<00:49,  3.91it/s]
#
#  81%|████████  | 806/1000 [02:08<00:55,  3.49it/s]
#
#  81%|████████  | 807/1000 [02:09<00:56,  3.39it/s]
#
#  81%|████████  | 808/1000 [02:09<00:55,  3.45it/s]
#
#  81%|████████  | 809/1000 [02:09<00:56,  3.36it/s]
#
#  81%|████████  | 810/1000 [02:10<01:14,  2.57it/s]
# Epoch 810
# 0.004574545193463564
# 0.995816707611084
#  81%|████████  | 811/1000 [02:10<01:06,  2.86it/s]
#
#  81%|████████  | 812/1000 [02:10<00:59,  3.17it/s]
#
#  81%|████████▏ | 813/1000 [02:10<00:54,  3.42it/s]
#
#  81%|████████▏ | 814/1000 [02:11<00:59,  3.12it/s]
#
#  82%|████████▏ | 815/1000 [02:11<01:13,  2.50it/s]
#
#  82%|████████▏ | 816/1000 [02:12<01:18,  2.34it/s]
#
#  82%|████████▏ | 817/1000 [02:12<01:15,  2.41it/s]
#
#  82%|████████▏ | 818/1000 [02:13<01:20,  2.25it/s]
#
#  82%|████████▏ | 819/1000 [02:13<01:24,  2.15it/s]
#
#  82%|████████▏ | 820/1000 [02:14<01:29,  2.02it/s]
# Epoch 820
# 0.02828468382358551
# 0.9459102153778076
#  82%|████████▏ | 821/1000 [02:14<01:13,  2.42it/s]
#
#  82%|████████▏ | 822/1000 [02:14<01:02,  2.83it/s]
#
#  82%|████████▏ | 823/1000 [02:15<00:54,  3.24it/s]
#
#  82%|████████▏ | 824/1000 [02:15<00:48,  3.61it/s]
#
#  82%|████████▎ | 825/1000 [02:15<00:44,  3.92it/s]
#
#  83%|████████▎ | 826/1000 [02:15<00:44,  3.95it/s]
#
#  83%|████████▎ | 827/1000 [02:15<00:41,  4.14it/s]
#
#  83%|████████▎ | 828/1000 [02:16<00:56,  3.02it/s]
#
#  83%|████████▎ | 829/1000 [02:16<00:52,  3.26it/s]
#
#  83%|████████▎ | 830/1000 [02:17<00:51,  3.29it/s]
# Epoch 830
# 0.02429351583123207
# 0.9768149852752686
#  83%|████████▎ | 831/1000 [02:17<00:48,  3.47it/s]
#
#  83%|████████▎ | 832/1000 [02:17<00:44,  3.81it/s]
#
#  83%|████████▎ | 833/1000 [02:17<00:41,  3.99it/s]
#
#  83%|████████▎ | 834/1000 [02:18<00:45,  3.62it/s]
#
#  84%|████████▎ | 835/1000 [02:18<00:46,  3.51it/s]
#
#  84%|████████▎ | 836/1000 [02:18<00:44,  3.70it/s]
#
#  84%|████████▎ | 837/1000 [02:18<00:40,  4.01it/s]
#
#  84%|████████▍ | 838/1000 [02:19<00:39,  4.09it/s]
#
#  84%|████████▍ | 839/1000 [02:19<00:38,  4.16it/s]
#
#  84%|████████▍ | 840/1000 [02:19<00:36,  4.36it/s]
# Epoch 840
# 0.02615271881222725
# 0.9490315914154053
#  84%|████████▍ | 841/1000 [02:19<00:36,  4.30it/s]
#
#  84%|████████▍ | 842/1000 [02:19<00:36,  4.38it/s]
#
#  84%|████████▍ | 843/1000 [02:20<00:34,  4.56it/s]
#
#  84%|████████▍ | 844/1000 [02:20<00:33,  4.68it/s]
#
#  84%|████████▍ | 845/1000 [02:20<00:32,  4.79it/s]
#
#  85%|████████▍ | 846/1000 [02:20<00:31,  4.87it/s]
#
# ...
#
#  72%|███████▏  | 722/1000 [02:48<01:02,  4.43it/s]
#
#  72%|███████▏  | 723/1000 [02:48<01:02,  4.45it/s]
#
#  72%|███████▏  | 724/1000 [02:48<01:02,  4.41it/s]
#
#  72%|███████▎  | 725/1000 [02:49<01:02,  4.40it/s]
#
#  73%|███████▎  | 726/1000 [02:49<01:02,  4.37it/s]
#
#  73%|███████▎  | 727/1000 [02:49<01:02,  4.37it/s]
#
#  73%|███████▎  | 728/1000 [02:49<01:02,  4.35it/s]
#
#  73%|███████▎  | 729/1000 [02:50<01:07,  3.99it/s]
#
#  73%|███████▎  | 730/1000 [02:50<01:23,  3.23it/s]
# Epoch 730
# 0.5008958578109741
# 0.0003097057342529297
#  73%|███████▎  | 731/1000 [02:50<01:30,  2.96it/s]
#
#  73%|███████▎  | 732/1000 [02:51<01:24,  3.15it/s]
#
#  73%|███████▎  | 733/1000 [02:51<01:24,  3.17it/s]
#
#  73%|███████▎  | 734/1000 [02:51<01:23,  3.20it/s]
#
#  74%|███████▎  | 735/1000 [02:52<01:39,  2.67it/s]
#
#  74%|███████▎  | 736/1000 [02:52<01:26,  3.04it/s]
#
#  74%|███████▎  | 737/1000 [02:52<01:18,  3.34it/s]
#
#  74%|███████▍  | 738/1000 [02:52<01:12,  3.61it/s]
#
#  74%|███████▍  | 739/1000 [02:53<01:08,  3.83it/s]
#
#  74%|███████▍  | 740/1000 [02:53<01:05,  3.98it/s]
# Epoch 740
# 0.4945487082004547
# 0.030666708946228027
#  74%|███████▍  | 741/1000 [02:53<01:03,  4.11it/s]
#
#  74%|███████▍  | 742/1000 [02:53<01:01,  4.21it/s]
#
#  74%|███████▍  | 743/1000 [02:54<00:59,  4.29it/s]
#
#  74%|███████▍  | 744/1000 [02:54<00:59,  4.34it/s]
#
#  74%|███████▍  | 745/1000 [02:54<00:58,  4.37it/s]
#
#  75%|███████▍  | 746/1000 [02:54<00:57,  4.41it/s]
#
#  75%|███████▍  | 747/1000 [02:55<00:57,  4.41it/s]
#
#  75%|███████▍  | 748/1000 [02:55<00:56,  4.43it/s]
#
#  75%|███████▍  | 749/1000 [02:55<00:56,  4.44it/s]
#
#  75%|███████▌  | 750/1000 [02:55<00:56,  4.46it/s]
# Epoch 750
# 0.4954437017440796
# 0.0180966854095459
#  75%|███████▌  | 751/1000 [02:55<00:55,  4.45it/s]
#
#  75%|███████▌  | 752/1000 [02:56<00:55,  4.45it/s]
#
#  75%|███████▌  | 753/1000 [02:56<00:55,  4.44it/s]
#
#  75%|███████▌  | 754/1000 [02:56<00:55,  4.47it/s]
#
#  76%|███████▌  | 755/1000 [02:56<00:55,  4.45it/s]
#
#  76%|███████▌  | 756/1000 [02:57<00:55,  4.42it/s]
#
#  76%|███████▌  | 757/1000 [02:57<00:54,  4.44it/s]
#
#  76%|███████▌  | 758/1000 [02:57<00:54,  4.45it/s]
#
#  76%|███████▌  | 759/1000 [02:57<00:53,  4.47it/s]
#
#  76%|███████▌  | 760/1000 [02:57<00:53,  4.46it/s]
# Epoch 760
# 0.5039000511169434
# 0.010874509811401367
#  76%|███████▌  | 761/1000 [02:58<00:53,  4.43it/s]
#
#  76%|███████▌  | 762/1000 [02:58<00:53,  4.44it/s]
#
#  76%|███████▋  | 763/1000 [02:58<00:53,  4.43it/s]
#
#  76%|███████▋  | 764/1000 [02:58<00:53,  4.44it/s]
#
#  76%|███████▋  | 765/1000 [02:59<00:53,  4.43it/s]
#
#  77%|███████▋  | 766/1000 [02:59<00:52,  4.42it/s]
#
#  77%|███████▋  | 767/1000 [02:59<00:52,  4.44it/s]
#
#  77%|███████▋  | 768/1000 [02:59<00:52,  4.46it/s]
#
#  77%|███████▋  | 769/1000 [02:59<00:52,  4.43it/s]
#
#  77%|███████▋  | 770/1000 [03:00<00:51,  4.43it/s]
# Epoch 770
# 0.497251033782959
# 0.005591750144958496
#  77%|███████▋  | 771/1000 [03:00<00:52,  4.40it/s]
#
#  77%|███████▋  | 772/1000 [03:00<00:51,  4.43it/s]
#
#  77%|███████▋  | 773/1000 [03:00<00:51,  4.40it/s]
#
#  77%|███████▋  | 774/1000 [03:01<00:51,  4.40it/s]
#
#  78%|███████▊  | 775/1000 [03:01<00:51,  4.39it/s]
#
#  78%|███████▊  | 776/1000 [03:01<00:50,  4.41it/s]
#
#  78%|███████▊  | 777/1000 [03:01<00:50,  4.40it/s]
#
#  78%|███████▊  | 778/1000 [03:02<00:50,  4.41it/s]
#
#  78%|███████▊  | 779/1000 [03:02<00:49,  4.43it/s]
#
#  78%|███████▊  | 780/1000 [03:02<00:49,  4.42it/s]
# Epoch 780
# 0.4970131814479828
# 0.002086043357849121
#  78%|███████▊  | 781/1000 [03:02<00:49,  4.45it/s]
#
#  78%|███████▊  | 782/1000 [03:02<00:49,  4.43it/s]
#
#  78%|███████▊  | 783/1000 [03:03<00:48,  4.45it/s]
#
#  78%|███████▊  | 784/1000 [03:03<00:48,  4.44it/s]
#
#  78%|███████▊  | 785/1000 [03:03<00:48,  4.46it/s]
#
#  79%|███████▊  | 786/1000 [03:03<00:48,  4.45it/s]
#
#  79%|███████▊  | 787/1000 [03:04<00:48,  4.43it/s]
#
#  79%|███████▉  | 788/1000 [03:04<00:48,  4.39it/s]
#
#  79%|███████▉  | 789/1000 [03:04<00:47,  4.42it/s]
#
#  79%|███████▉  | 790/1000 [03:04<00:47,  4.44it/s]
# Epoch 790
# 0.5028884410858154
# 0.0011397600173950195
#  79%|███████▉  | 791/1000 [03:04<00:47,  4.40it/s]
#
#  79%|███████▉  | 792/1000 [03:05<00:46,  4.46it/s]
#
#  79%|███████▉  | 793/1000 [03:05<00:46,  4.42it/s]
#
#  79%|███████▉  | 794/1000 [03:05<00:46,  4.42it/s]
#
#  80%|███████▉  | 795/1000 [03:05<00:46,  4.42it/s]
#
#  80%|███████▉  | 796/1000 [03:06<00:46,  4.42it/s]
#
#  80%|███████▉  | 797/1000 [03:06<00:46,  4.41it/s]
#
#  80%|███████▉  | 798/1000 [03:06<00:45,  4.43it/s]
#
#  80%|███████▉  | 799/1000 [03:06<00:45,  4.45it/s]
#
#  80%|████████  | 800/1000 [03:06<00:45,  4.42it/s]
# Epoch 800
# 0.49832063913345337
# 0.0006629228591918945
#  80%|████████  | 801/1000 [03:07<00:44,  4.43it/s]
#
#  80%|████████  | 802/1000 [03:07<00:44,  4.41it/s]
#
#  80%|████████  | 803/1000 [03:07<00:44,  4.41it/s]
#
#  80%|████████  | 804/1000 [03:07<00:44,  4.40it/s]
#
#  80%|████████  | 805/1000 [03:08<00:44,  4.38it/s]
#
#  81%|████████  | 806/1000 [03:08<00:44,  4.36it/s]
#
#  81%|████████  | 807/1000 [03:08<00:44,  4.39it/s]
#
#  81%|████████  | 808/1000 [03:08<00:43,  4.39it/s]
#
#  81%|████████  | 809/1000 [03:09<00:43,  4.38it/s]
#
#  81%|████████  | 810/1000 [03:09<00:43,  4.35it/s]
# Epoch 810
# 0.4986567497253418
# 0.001322627067565918
#  81%|████████  | 811/1000 [03:09<00:43,  4.37it/s]
#
#  81%|████████  | 812/1000 [03:09<00:42,  4.45it/s]
#
#  81%|████████▏ | 813/1000 [03:09<00:42,  4.43it/s]
#
#  81%|████████▏ | 814/1000 [03:10<00:41,  4.46it/s]
#
#  82%|████████▏ | 815/1000 [03:10<00:41,  4.45it/s]
#
#  82%|████████▏ | 816/1000 [03:10<00:41,  4.48it/s]
#
#  82%|████████▏ | 817/1000 [03:10<00:40,  4.48it/s]
#
#  82%|████████▏ | 818/1000 [03:11<00:40,  4.47it/s]
#
#  82%|████████▏ | 819/1000 [03:11<00:40,  4.49it/s]
#
#  82%|████████▏ | 820/1000 [03:11<00:40,  4.49it/s]
# Epoch 820
# 0.4978012144565582
# 0.0004906654357910156
#  82%|████████▏ | 821/1000 [03:11<00:40,  4.46it/s]
#
#  82%|████████▏ | 822/1000 [03:11<00:40,  4.39it/s]
#
#  82%|████████▏ | 823/1000 [03:12<00:40,  4.42it/s]
#
#  82%|████████▏ | 824/1000 [03:12<00:40,  4.40it/s]
#
#  82%|████████▎ | 825/1000 [03:12<00:39,  4.41it/s]
#
#  83%|████████▎ | 826/1000 [03:12<00:39,  4.38it/s]
#
#  83%|████████▎ | 827/1000 [03:13<00:41,  4.21it/s]
#
#  83%|████████▎ | 828/1000 [03:13<00:40,  4.22it/s]
#
#  83%|████████▎ | 829/1000 [03:13<00:39,  4.30it/s]
#
#  83%|████████▎ | 830/1000 [03:13<00:39,  4.29it/s]
# Epoch 830
# 0.49811190366744995
# 0.00036013126373291016
#  83%|████████▎ | 831/1000 [03:14<00:39,  4.33it/s]
#
#  83%|████████▎ | 832/1000 [03:14<00:38,  4.37it/s]
#
#  83%|████████▎ | 833/1000 [03:14<00:38,  4.36it/s]
#
#  83%|████████▎ | 834/1000 [03:14<00:37,  4.40it/s]
#
#  84%|████████▎ | 835/1000 [03:14<00:37,  4.37it/s]
#
#  84%|████████▎ | 836/1000 [03:15<00:37,  4.41it/s]
#
#  84%|████████▎ | 837/1000 [03:15<00:37,  4.37it/s]
#
#  84%|████████▍ | 838/1000 [03:15<00:36,  4.39it/s]
#
#  84%|████████▍ | 839/1000 [03:15<00:36,  4.38it/s]
#
#  84%|████████▍ | 840/1000 [03:16<00:36,  4.37it/s]
# Epoch 840
# 0.49868592619895935
# 0.0003324747085571289
#  84%|████████▍ | 841/1000 [03:16<00:36,  4.35it/s]
#
#  84%|████████▍ | 842/1000 [03:16<00:36,  4.38it/s]
#
#  84%|████████▍ | 843/1000 [03:16<00:35,  4.39it/s]
#
#  84%|████████▍ | 844/1000 [03:16<00:35,  4.36it/s]
#
#  84%|████████▍ | 845/1000 [03:17<00:35,  4.38it/s]
#
#  85%|████████▍ | 846/1000 [03:17<00:35,  4.37it/s]
#
#  85%|████████▍ | 847/1000 [03:17<00:34,  4.43it/s]
#
#  85%|████████▍ | 848/1000 [03:17<00:34,  4.40it/s]
#
#  85%|████████▍ | 849/1000 [03:18<00:34,  4.39it/s]
#
#  85%|████████▌ | 850/1000 [03:18<00:34,  4.35it/s]
# Epoch 850
# 0.49676674604415894
# 0.001556992530822754
#  85%|████████▌ | 851/1000 [03:18<00:33,  4.38it/s]
#
#  85%|████████▌ | 852/1000 [03:18<00:33,  4.40it/s]
#
#  85%|████████▌ | 853/1000 [03:19<00:33,  4.41it/s]
#
#  85%|████████▌ | 854/1000 [03:19<00:32,  4.44it/s]
#
#  86%|████████▌ | 855/1000 [03:19<00:32,  4.43it/s]
#
#  86%|████████▌ | 856/1000 [03:19<00:32,  4.43it/s]
#
#  86%|████████▌ | 857/1000 [03:19<00:32,  4.40it/s]
#
#  86%|████████▌ | 858/1000 [03:20<00:32,  4.42it/s]
#
#  86%|████████▌ | 859/1000 [03:20<00:32,  4.40it/s]
#
#  86%|████████▌ | 860/1000 [03:20<00:31,  4.42it/s]
# Epoch 860
# 0.5003560781478882
# 0.0005348920822143555
#  86%|████████▌ | 861/1000 [03:20<00:31,  4.39it/s]
#
#  86%|████████▌ | 862/1000 [03:21<00:31,  4.36it/s]
#
#  86%|████████▋ | 863/1000 [03:21<00:31,  4.33it/s]
#
#  86%|████████▋ | 864/1000 [03:21<00:31,  4.33it/s]
#
#  86%|████████▋ | 865/1000 [03:21<00:31,  4.30it/s]
#
#  87%|████████▋ | 866/1000 [03:22<00:31,  4.29it/s]
#
#  87%|████████▋ | 867/1000 [03:22<00:30,  4.30it/s]
#
#  87%|████████▋ | 868/1000 [03:22<00:30,  4.27it/s]
#
#  87%|████████▋ | 869/1000 [03:22<00:31,  4.12it/s]
#
#  87%|████████▋ | 870/1000 [03:22<00:31,  4.13it/s]
# Epoch 870
# 0.4988827705383301
# 0.0003657341003417969
#  87%|████████▋ | 871/1000 [03:23<00:31,  4.16it/s]
#
#  87%|████████▋ | 872/1000 [03:23<00:30,  4.18it/s]
#
#  87%|████████▋ | 873/1000 [03:23<00:29,  4.24it/s]
#
#  87%|████████▋ | 874/1000 [03:23<00:29,  4.21it/s]
#
#  88%|████████▊ | 875/1000 [03:24<00:29,  4.23it/s]
#
#  88%|████████▊ | 876/1000 [03:24<00:29,  4.24it/s]
#
#  88%|████████▊ | 877/1000 [03:24<00:28,  4.26it/s]
#
#  88%|████████▊ | 878/1000 [03:24<00:28,  4.25it/s]
#
#  88%|████████▊ | 879/1000 [03:25<00:28,  4.25it/s]
#
#  88%|████████▊ | 880/1000 [03:25<00:28,  4.25it/s]
# Epoch 880
# 0.49909529089927673
# 0.00018203258514404297
#  88%|████████▊ | 881/1000 [03:25<00:27,  4.30it/s]
#
#  88%|████████▊ | 882/1000 [03:25<00:28,  4.15it/s]
#
#  88%|████████▊ | 883/1000 [03:26<00:27,  4.20it/s]
#
#  88%|████████▊ | 884/1000 [03:26<00:27,  4.24it/s]
#
#  88%|████████▊ | 885/1000 [03:26<00:26,  4.31it/s]
#
#  89%|████████▊ | 886/1000 [03:26<00:26,  4.34it/s]
#
#  89%|████████▊ | 887/1000 [03:26<00:26,  4.31it/s]
#
#  89%|████████▉ | 888/1000 [03:27<00:26,  4.30it/s]
#
#  89%|████████▉ | 889/1000 [03:27<00:26,  4.25it/s]
#
#  89%|████████▉ | 890/1000 [03:27<00:25,  4.25it/s]
# Epoch 890
# 0.49919092655181885
# 0.00020754337310791016
#  89%|████████▉ | 891/1000 [03:27<00:25,  4.20it/s]
#
#  89%|████████▉ | 892/1000 [03:28<00:25,  4.23it/s]
#
#  89%|████████▉ | 893/1000 [03:28<00:25,  4.22it/s]
#
#  89%|████████▉ | 894/1000 [03:28<00:24,  4.26it/s]
#
#  90%|████████▉ | 895/1000 [03:28<00:24,  4.23it/s]
#
#  90%|████████▉ | 896/1000 [03:29<00:24,  4.23it/s]
#
#  90%|████████▉ | 897/1000 [03:29<00:24,  4.23it/s]
#
#  90%|████████▉ | 898/1000 [03:29<00:24,  4.24it/s]
#
#  90%|████████▉ | 899/1000 [03:29<00:23,  4.24it/s]
#
#  90%|█████████ | 900/1000 [03:30<00:23,  4.24it/s]
# Epoch 900
# 0.5004783272743225
# 0.0001951456069946289
#  90%|█████████ | 901/1000 [03:30<00:23,  4.20it/s]
#
#  90%|█████████ | 902/1000 [03:30<00:23,  4.25it/s]
#
#  90%|█████████ | 903/1000 [03:30<00:22,  4.26it/s]
#
#  90%|█████████ | 904/1000 [03:31<00:22,  4.21it/s]
#
#  90%|█████████ | 905/1000 [03:31<00:22,  4.24it/s]
#
#  91%|█████████ | 906/1000 [03:31<00:22,  4.24it/s]
#
#  91%|█████████ | 907/1000 [03:31<00:21,  4.28it/s]
#
#  91%|█████████ | 908/1000 [03:31<00:21,  4.21it/s]
#
#  91%|█████████ | 909/1000 [03:32<00:21,  4.14it/s]
#
#  91%|█████████ | 910/1000 [03:32<00:21,  4.16it/s]
# Epoch 910
# 0.4984356760978699
# 0.0005429983139038086
#  91%|█████████ | 911/1000 [03:32<00:21,  4.23it/s]
#
#  91%|█████████ | 912/1000 [03:32<00:20,  4.26it/s]
#
#  91%|█████████▏| 913/1000 [03:33<00:20,  4.29it/s]
#
#  91%|█████████▏| 914/1000 [03:33<00:20,  4.30it/s]
#
#  92%|█████████▏| 915/1000 [03:33<00:19,  4.28it/s]
#
#  92%|█████████▏| 916/1000 [03:33<00:19,  4.28it/s]
#
#  92%|█████████▏| 917/1000 [03:34<00:19,  4.28it/s]
#
#  92%|█████████▏| 918/1000 [03:34<00:18,  4.34it/s]
#
#  92%|█████████▏| 919/1000 [03:34<00:18,  4.35it/s]
#
#  92%|█████████▏| 920/1000 [03:34<00:18,  4.38it/s]
# Epoch 920
# 0.4983609914779663
# 0.00036454200744628906
#  92%|█████████▏| 921/1000 [03:35<00:19,  4.05it/s]
#
#  92%|█████████▏| 922/1000 [03:35<00:20,  3.83it/s]
#
#  92%|█████████▏| 923/1000 [03:35<00:19,  3.89it/s]
#
#  92%|█████████▏| 924/1000 [03:35<00:19,  3.92it/s]
#
#  92%|█████████▎| 925/1000 [03:36<00:19,  3.94it/s]
#
#  93%|█████████▎| 926/1000 [03:36<00:18,  3.92it/s]
#
#  93%|█████████▎| 927/1000 [03:36<00:18,  3.93it/s]
#
#  93%|█████████▎| 928/1000 [03:36<00:18,  3.96it/s]
#
#  93%|█████████▎| 929/1000 [03:37<00:17,  3.96it/s]
#
#  93%|█████████▎| 930/1000 [03:37<00:17,  3.97it/s]
# Epoch 930
# 0.49960529804229736
# 0.00010406970977783203
#  93%|█████████▎| 931/1000 [03:37<00:17,  3.96it/s]
#
#  93%|█████████▎| 932/1000 [03:37<00:17,  3.97it/s]
#
#  93%|█████████▎| 933/1000 [03:38<00:16,  3.97it/s]
#
#  93%|█████████▎| 934/1000 [03:38<00:16,  3.98it/s]
#
#  94%|█████████▎| 935/1000 [03:38<00:16,  3.96it/s]
#
#  94%|█████████▎| 936/1000 [03:38<00:16,  3.96it/s]
#
#  94%|█████████▎| 937/1000 [03:39<00:15,  3.96it/s]
#
#  94%|█████████▍| 938/1000 [03:39<00:15,  3.97it/s]
#
#  94%|█████████▍| 939/1000 [03:39<00:15,  3.99it/s]
#
#  94%|█████████▍| 940/1000 [03:39<00:15,  3.98it/s]
# Epoch 940
# 0.4983815550804138
# 0.00014030933380126953
#  94%|█████████▍| 941/1000 [03:40<00:14,  3.97it/s]
#
#  94%|█████████▍| 942/1000 [03:40<00:14,  3.99it/s]
#
#  94%|█████████▍| 943/1000 [03:40<00:14,  3.99it/s]
#
#  94%|█████████▍| 944/1000 [03:40<00:14,  3.97it/s]
#
#  94%|█████████▍| 945/1000 [03:41<00:13,  3.97it/s]
#
#  95%|█████████▍| 946/1000 [03:41<00:13,  3.96it/s]
#
#  95%|█████████▍| 947/1000 [03:41<00:13,  3.98it/s]
#
#  95%|█████████▍| 948/1000 [03:41<00:13,  3.98it/s]
#
#  95%|█████████▍| 949/1000 [03:42<00:12,  4.02it/s]
#
#  95%|█████████▌| 950/1000 [03:42<00:12,  4.03it/s]
# Epoch 950
# 0.49756699800491333
# 0.0011017322540283203
#  95%|█████████▌| 951/1000 [03:42<00:12,  4.02it/s]
#
#  95%|█████████▌| 952/1000 [03:42<00:11,  4.03it/s]
#
#  95%|█████████▌| 953/1000 [03:43<00:11,  4.06it/s]
#
#  95%|█████████▌| 954/1000 [03:43<00:11,  4.06it/s]
#
#  96%|█████████▌| 955/1000 [03:43<00:11,  4.08it/s]
#
#  96%|█████████▌| 956/1000 [03:43<00:10,  4.08it/s]
#
#  96%|█████████▌| 957/1000 [03:44<00:10,  4.09it/s]
#
#  96%|█████████▌| 958/1000 [03:44<00:10,  4.11it/s]
#
#  96%|█████████▌| 959/1000 [03:44<00:09,  4.11it/s]
#
#  96%|█████████▌| 960/1000 [03:44<00:09,  4.09it/s]
# Epoch 960
# 0.49851909279823303
# 0.0003628730773925781
#  96%|█████████▌| 961/1000 [03:45<00:09,  4.07it/s]
#
#  96%|█████████▌| 962/1000 [03:45<00:09,  4.08it/s]
#
#  96%|█████████▋| 963/1000 [03:45<00:09,  4.05it/s]
#
#  96%|█████████▋| 964/1000 [03:45<00:08,  4.07it/s]
#
#  96%|█████████▋| 965/1000 [03:46<00:08,  4.03it/s]
#
#  97%|█████████▋| 966/1000 [03:46<00:08,  4.06it/s]
#
#  97%|█████████▋| 967/1000 [03:46<00:08,  4.05it/s]
#
#  97%|█████████▋| 968/1000 [03:46<00:07,  4.07it/s]
#
#  97%|█████████▋| 969/1000 [03:47<00:07,  4.05it/s]
#
#  97%|█████████▋| 970/1000 [03:47<00:07,  4.06it/s]
# Epoch 970
# 0.4986555576324463
# 0.00034940242767333984
#  97%|█████████▋| 971/1000 [03:47<00:07,  4.04it/s]
#
#  97%|█████████▋| 972/1000 [03:47<00:06,  4.07it/s]
#
#  97%|█████████▋| 973/1000 [03:48<00:06,  4.05it/s]
#
#  97%|█████████▋| 974/1000 [03:48<00:06,  4.07it/s]
#
#  98%|█████████▊| 975/1000 [03:48<00:06,  4.04it/s]
#
#  98%|█████████▊| 976/1000 [03:48<00:05,  4.03it/s]
#
#  98%|█████████▊| 977/1000 [03:49<00:05,  4.02it/s]
#
#  98%|█████████▊| 978/1000 [03:49<00:05,  4.04it/s]
#
#  98%|█████████▊| 979/1000 [03:49<00:05,  4.05it/s]
#
#  98%|█████████▊| 980/1000 [03:49<00:04,  4.08it/s]
# Epoch 980
# 0.49953532218933105
# 0.0001596212387084961
#  98%|█████████▊| 981/1000 [03:49<00:04,  4.08it/s]
#
#  98%|█████████▊| 982/1000 [03:50<00:04,  4.12it/s]
#
#  98%|█████████▊| 983/1000 [03:50<00:04,  4.19it/s]
#
#  98%|█████████▊| 984/1000 [03:50<00:03,  4.23it/s]
#
#  98%|█████████▊| 985/1000 [03:50<00:03,  4.25it/s]
#
#  99%|█████████▊| 986/1000 [03:51<00:03,  4.27it/s]
#
#  99%|█████████▊| 987/1000 [03:51<00:03,  4.28it/s]
#
#  99%|█████████▉| 988/1000 [03:51<00:02,  4.30it/s]
#
#  99%|█████████▉| 989/1000 [03:51<00:02,  4.31it/s]
#
#  99%|█████████▉| 990/1000 [03:52<00:02,  4.30it/s]
# Epoch 990
# 0.48562556505203247
# 0.02294325828552246
#  99%|█████████▉| 991/1000 [03:52<00:02,  4.32it/s]
#
#  99%|█████████▉| 992/1000 [03:52<00:01,  4.31it/s]
#
#  99%|█████████▉| 993/1000 [03:52<00:01,  4.29it/s]
#
#  99%|█████████▉| 994/1000 [03:53<00:01,  4.27it/s]
#
# 100%|█████████▉| 995/1000 [03:53<00:01,  4.24it/s]
#
# 100%|█████████▉| 996/1000 [03:53<00:00,  4.21it/s]
#
# 100%|█████████▉| 997/1000 [03:53<00:00,  4.20it/s]
#
# 100%|█████████▉| 998/1000 [03:53<00:00,  4.19it/s]
#
# 100%|█████████▉| 999/1000 [03:54<00:00,  4.18it/s]
#
# 100%|██████████| 1000/1000 [03:54<00:00,  4.27it/s]
# Epoch 1000
# 0.502583384513855
# 0.004036307334899902
# Best epoch = 147
# Best loss = 0.5025202631950378
# Fit loss = 0.4998142123222351

# %%
plt.plot(lambs, best_losses, marker="o")
plt.plot(lambs, best_regs, marker="o")
plt.xscale('log')
plt.yscale('log')
plt.xlabel(r'$\lambda$',fontsize=15)
plt.ylabel('MSE Loss', fontsize=15)
# Out:
# Text(0, 0.5, 'MSE Loss')

# %%
np.save('./results/lambda_search_gamma_1.npy', np.array([lambs, best_losses, best_regs]))

# %%
plt.figure(figsize=(12,4))

plt.subplot(1,2,1)

data = np.load('./results/lambda_search_gamma_0.npy')
lambs = data[0]
best_losses = data[1]
best_regs = data[2]

plt.plot(lambs, best_losses, marker="o")
plt.plot(lambs, best_regs, marker="o")
plt.xscale('log')
plt.yscale('log')
plt.xlabel(r'$\lambda$',fontsize=15)
plt.ylabel('Loss', fontsize=15)
plt.legend([r"$\ell_1$", r"$\ell_2$"], fontsize=15, loc="upper right")
plt.ylim(1e-7,2)
plt.title(r"$\gamma=0$", fontsize=15)


plt.subplot(1,2,2)

data = np.load('./results/lambda_search_gamma_1.npy')
lambs = data[0]
best_losses = data[1]
best_regs = data[2]

plt.plot(lambs, best_losses, marker="o")
plt.plot(lambs, best_regs, marker="o")
plt.xscale('log')
plt.yscale('log')
plt.xlabel(r'$\lambda$',fontsize=15)
plt.ylabel('Loss', fontsize=15)
#plt.legend([r"$\ell_1$", r"$\ell_2$"], fontsize=15, loc="upper right")
plt.ylim(1e-7,2)
plt.title(r"$\gamma=1$", fontsize=15)
plt.savefig('./1d_ho_lamb_pt.pdf', bbox_inches="tight")
