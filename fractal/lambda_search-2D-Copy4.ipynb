# %%
import os
import math
import numpy as np
import pandas as po
import matplotlib.pyplot as plt

import torch
from torch import nn
import torch.optim as optim
from torch.autograd import Variable

from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from tqdm import tqdm

#lambs = np.flip([0.01,0.02,0.05,0.1,0.2,0.5,1.0,2.0,5.0,10.0,20.0,50.0,100.0])
#lambs = [1e-4,2e-4,5e-4,1e-3,2e-3,5e-3,0.01,0.02,0.05,0.1,0.2,0.5,1.0,2.0,5.0,10.0,20.0,50.0,100.0,200,500,1000]
lambs = [0.5]
#lambs = np.array([0.01,0.02,0.05,0.1,0.2,0.5,1.0,2.0,5.0,10.0])
wx = 67
wy = 97
folder = "2D_{}_{}".format(wx,wy)

wy = wy/wx
wx = 1

seed = 3
torch.manual_seed(seed)
np.random.seed(seed)

best_losses = []
best_regs = []

num_pts = 1000
#gamma = 10
#lamb = 0.02

data = po.DataFrame()
data['x'] = 4*np.random.rand(num_pts,)-2
data['px'] = 4*np.random.rand(num_pts,)-2

data['y'] = 4*np.random.rand(num_pts,)-2
data['py'] = 4*np.random.rand(num_pts,)-2


data['dx/dt'] = data['px']
data['dpx/dt'] = -wx**2*data['x']

data['dy/dt'] = data['py']
data['dpy/dt'] = -wy**2*data['y']


f_z = torch.tensor(data[['dx/dt', 'dpx/dt', 'dy/dt', 'dpy/dt']].values, requires_grad=True).float()
z = torch.tensor(data[['x', 'px', 'y', 'py']].values, requires_grad=True).float()


# initialize network
num_model = 4
nets = []

class Hnet(nn.Module):
    def __init__(self, z_dim=2, w=400):
        super(Hnet, self).__init__()
        self.z_dim = z_dim
        input_dim = z_dim

        self.h_lin_1 = nn.Linear(input_dim, w) #
        self.h_lin_2 = nn.Linear(w, w) #
        self.h_lin_3 = nn.Linear(w, 1) #
        self.h_relu = nn.ReLU()
        self.h_tanh = nn.Tanh()
        self.h_silu = nn.SiLU()

    def h_z_basic(self, z):
        out = self.h_lin_1(z)
        out = self.h_silu(out)
        out = self.h_lin_2(out)
        out = self.h_silu(out)
        out = self.h_lin_3(out)
        return out

    def h_z(self, z):
        out = self.h_z_basic(z)
        return out

    def forward(self, z, verbose=False):
        bs = z.shape[0]

        h = self.h_z(z)
        dh = torch.autograd.grad(h, z, torch.ones_like(h), create_graph=True, retain_graph=True)[0]
        bs = z.shape[0]
        dh = dh.reshape(bs,-1)
        return dh


def train(nets, f_z, z,
            lr=2e-2,
            epochs = 2000, 
            bs = 100,
            es_delta = 0.000001, 
            epoch_loss = 1e9,
            max_loss_divergence = 0.1,
            weight_decay=0, 
            weight_decay_decay=False,model=None):


    num_model = len(nets)

    z_dim = z.shape[1]
    entropy_dim = np.minimum(num_model, z_dim)
    parameters = list([])
    for i in range(num_model):
        parameters = list(parameters) + list(nets[i].parameters())
    optimizer = optim.Adam(parameters, lr=lr, weight_decay=weight_decay, eps=1e-8)
    #optimizer = optim.SGD(parameters, lr=lr, weight_decay=weight_decay)

    for k in range(num_model):
        nets[k].train()
    losses = []
    losses_fit = []
    losses_reg = []
    lamb_H = 0.00
    lamb_dH = lamb
    loss_pow = 2


    for epoch in tqdm(range(epochs)):
        for i in range((len(f_z) - 1) // bs + 1):
            choices = np.random.choice(len(f_z), bs, replace=False)
            #start_i = i * bs
            #end_i = start_i + bs
            xb = z[choices, :]
            fitloss = 0.
            fitlosses = []
            yb = f_z[choices, :]
            yb = yb.reshape(bs,-1)
            yb_norm = yb/torch.linalg.norm(yb, dim=1, keepdim=True)
            #print("yb", yb_norm.shape)
            for k in range(num_model):
                pred = nets[k](xb)
                #print("pred", pred.shape)
                pred_norm = pred/torch.linalg.norm(pred, dim=1, keepdim=True)
                fit_orth = torch.matmul(yb_norm.unsqueeze(dim=1), pred_norm.unsqueeze(dim=2))
                #print(fit_orth.shape)
                fitloss_ =  torch.mean(torch.abs(fit_orth)**loss_pow)
                #fitloss_each.append(fitloss_.detach().numpy())
                fitloss = fitloss + fitloss_
                fitlosses.append(fitloss_.item())
                H_ = nets[k].h_z(xb)
                dhi = pred_norm

                if k == 0:
                    H = H_
                    dH = dhi.unsqueeze(dim=0)

                else:
                    H = torch.cat((H,H_), dim=1)
                    dH = torch.cat([dH,dhi.unsqueeze(dim=0)])

            fitloss = fitloss/num_model
            # correlation loss
            H = torch.transpose(H,0,1)
            # dH.shape = (bs, num_model, z_dim)
            dH = torch.transpose(dH,0,1)

            # SVD dH
            u, s, v = torch.svd(dH)
            exp_ratio = s**2/torch.sum(s**2, dim=1,keepdim=True)
            exp_av = torch.mean(exp_ratio,dim=0)

            # H regularization
            corr_mat = torch.corrcoef(H)
            if num_model == 1:
                reg_H = torch.tensor(0., dtype=torch.float)
            else:
                reg_H = (torch.sum(corr_mat**loss_pow)-num_model)/(num_model*(num_model-1))

            orth_mat = torch.mean(torch.abs(torch.matmul(dH, torch.transpose(dH,1,2)))**loss_pow, dim=0)
            #print(orth_mat)
            if num_model == 1:
                reg_dH = torch.tensor(0., dtype=torch.float)
            else:
                reg_dH = (torch.sum(orth_mat)-num_model)/(num_model*(num_model-1))

            loss = fitloss + lamb_H*reg_H + lamb_dH*reg_dH

            loss.backward()
            optimizer.step()   

            optimizer.zero_grad()

            losses.append(loss.item())
            losses_fit.append(fitloss.item())
            losses_reg.append(reg_dH.item())
            #print(loss.item(), fitloss.item(), reg_dH.item())

        # Best epoch loss (save best only)
        if (loss<epoch_loss):
            epoch_loss = loss
            epoch_best = epoch
            fit_loss_best = fitloss
            fit_losses_best = fitlosses
            reg_loss_best = reg_dH
            #print("Saving model at epoch {}, current best epoch loss = {}".format(epoch, epoch_loss))
            for k in range(num_model):
                torch.save(nets[k].state_dict(), "./results/"+folder+"/{}.pt".format(k))
            np.save("./results/"+folder+"/fit_loss.npy", fitlosses)
            np.save("./results/"+folder+"/dH_explained.npy", exp_av.detach().numpy())

        # Early Stopping
        #if ((loss<es_delta) or abs(epoch_loss-loss)>max_loss_divergence):
        #    break

        # Print loss
        if ((epoch+1)%10==0):
            print("Epoch {}".format(epoch+1))
            print(fitloss.item())
            #print(fitlosses)
            #print(corr_mat)
            #print(reg_H.item())
            #print(orth_mat)
            print(reg_dH.item())
            #print(exp_av)

    plt.plot(losses)
    plt.plot(losses_fit)
    plt.plot(losses_reg)
    plt.yscale('log')

    print("Best epoch = {}".format(epoch_best))
    print("Best loss = {}".format(epoch_loss))
    print("Fit loss = {}".format(fit_loss_best))
    print("Fit losses = {}")
    print(fit_losses)
    df = po.DataFrame()
    df['losses'] = losses

    return losses, fit_loss_best.detach().numpy(), reg_loss_best.detach().numpy()


for i in range(num_model):
    nets.append(Hnet(z_dim=4, w=400))


for lamb in lambs:
    print("lamb={}".format(lamb))
    loss, fit_best, reg_best = train(nets, f_z, z, lr=1e-3, epochs=1000) 
    best_losses.append(fit_best)
    best_regs.append(reg_best)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# lamb=0.5
#   0%|          | 1/1000 [00:00<04:37,  3.60it/s]
#   0%|          | 2/1000 [00:00<04:52,  3.42it/s]
#   0%|          | 3/1000 [00:00<05:09,  3.23it/s]
#   0%|          | 4/1000 [00:01<05:30,  3.01it/s]
#   0%|          | 5/1000 [00:01<05:31,  3.00it/s]
#   1%|          | 6/1000 [00:01<05:23,  3.08it/s]
#   1%|          | 7/1000 [00:02<05:02,  3.29it/s]
#   1%|          | 8/1000 [00:02<05:15,  3.15it/s]
#   1%|          | 9/1000 [00:02<05:23,  3.06it/s]
#   1%|          | 10/1000 [00:03<05:23,  3.06it/s]
# Epoch 10
# 0.13629083335399628
# 0.09243234246969223
#   1%|          | 11/1000 [00:03<05:27,  3.02it/s]
#   1%|          | 12/1000 [00:03<05:17,  3.11it/s]
#   1%|▏         | 13/1000 [00:04<05:12,  3.16it/s]
#   1%|▏         | 14/1000 [00:04<05:10,  3.18it/s]
#   2%|▏         | 15/1000 [00:04<05:13,  3.14it/s]
#   2%|▏         | 16/1000 [00:05<05:32,  2.96it/s]
#   2%|▏         | 17/1000 [00:05<05:37,  2.91it/s]
#   2%|▏         | 18/1000 [00:05<05:31,  2.96it/s]
#   2%|▏         | 19/1000 [00:06<05:22,  3.04it/s]
#   2%|▏         | 20/1000 [00:06<04:58,  3.29it/s]
# Epoch 20
# 0.0709305927157402
# 0.11609920114278793
#   2%|▏         | 21/1000 [00:06<04:30,  3.63it/s]
#   2%|▏         | 22/1000 [00:06<04:13,  3.85it/s]
#   2%|▏         | 23/1000 [00:07<04:21,  3.74it/s]
#   2%|▏         | 24/1000 [00:07<04:56,  3.29it/s]
#   2%|▎         | 25/1000 [00:07<05:16,  3.08it/s]
#   3%|▎         | 26/1000 [00:08<04:41,  3.46it/s]
#   3%|▎         | 27/1000 [00:08<04:18,  3.77it/s]
#   3%|▎         | 28/1000 [00:08<04:00,  4.04it/s]
#   3%|▎         | 29/1000 [00:08<03:46,  4.29it/s]
#   3%|▎         | 30/1000 [00:08<03:39,  4.43it/s]
# Epoch 30
# 0.0131145678460598
# 0.13911263644695282
#   3%|▎         | 31/1000 [00:09<03:32,  4.57it/s]
#   3%|▎         | 32/1000 [00:09<03:26,  4.68it/s]
#   3%|▎         | 33/1000 [00:09<03:23,  4.76it/s]
#   3%|▎         | 34/1000 [00:09<03:23,  4.75it/s]
#   4%|▎         | 35/1000 [00:09<03:20,  4.81it/s]
#   4%|▎         | 36/1000 [00:10<03:19,  4.82it/s]
#   4%|▎         | 37/1000 [00:10<03:17,  4.87it/s]
#   4%|▍         | 38/1000 [00:10<03:17,  4.86it/s]
#   4%|▍         | 39/1000 [00:10<03:16,  4.90it/s]
#   4%|▍         | 40/1000 [00:11<03:15,  4.92it/s]
# Epoch 40
# 0.014624416828155518
# 0.13494150340557098
#   4%|▍         | 41/1000 [00:11<03:15,  4.90it/s]
#   4%|▍         | 42/1000 [00:11<03:14,  4.93it/s]
#   4%|▍         | 43/1000 [00:11<03:14,  4.91it/s]
#   4%|▍         | 44/1000 [00:11<03:17,  4.85it/s]
#   4%|▍         | 45/1000 [00:12<03:15,  4.89it/s]
#   5%|▍         | 46/1000 [00:12<03:15,  4.88it/s]
#   5%|▍         | 47/1000 [00:12<03:13,  4.92it/s]
#   5%|▍         | 48/1000 [00:12<03:12,  4.94it/s]
#   5%|▍         | 49/1000 [00:12<03:13,  4.92it/s]
#   5%|▌         | 50/1000 [00:13<03:13,  4.90it/s]
# Epoch 50
# 0.00881225150078535
# 0.12382566928863525
#   5%|▌         | 51/1000 [00:13<03:12,  4.93it/s]
#   5%|▌         | 52/1000 [00:13<03:11,  4.94it/s]
#   5%|▌         | 53/1000 [00:13<03:11,  4.95it/s]
#   5%|▌         | 54/1000 [00:13<03:15,  4.84it/s]
#   6%|▌         | 55/1000 [00:14<03:13,  4.88it/s]
#   6%|▌         | 56/1000 [00:14<03:13,  4.89it/s]
#   6%|▌         | 57/1000 [00:14<03:11,  4.91it/s]
#   6%|▌         | 58/1000 [00:14<03:11,  4.92it/s]
#   6%|▌         | 59/1000 [00:14<03:15,  4.82it/s]
#   6%|▌         | 60/1000 [00:15<03:13,  4.87it/s]
# Epoch 60
# 0.009030529297888279
# 0.12097255140542984
#   6%|▌         | 61/1000 [00:15<03:13,  4.86it/s]
#   6%|▌         | 62/1000 [00:15<03:11,  4.89it/s]
#   6%|▋         | 63/1000 [00:15<03:10,  4.91it/s]
#   6%|▋         | 64/1000 [00:15<03:12,  4.87it/s]
#   6%|▋         | 65/1000 [00:16<03:10,  4.90it/s]
#   7%|▋         | 66/1000 [00:16<03:09,  4.93it/s]
#   7%|▋         | 67/1000 [00:16<03:08,  4.94it/s]
#   7%|▋         | 68/1000 [00:16<03:08,  4.95it/s]
#   7%|▋         | 69/1000 [00:16<03:07,  4.96it/s]
#   7%|▋         | 70/1000 [00:17<03:07,  4.97it/s]
# Epoch 70
# 0.007803105283528566
# 0.1222224235534668
#   7%|▋         | 71/1000 [00:17<03:07,  4.97it/s]
#   7%|▋         | 72/1000 [00:17<03:09,  4.90it/s]
#   7%|▋         | 73/1000 [00:17<03:14,  4.77it/s]
#   7%|▋         | 74/1000 [00:17<03:13,  4.78it/s]
#   8%|▊         | 75/1000 [00:18<03:10,  4.84it/s]
#   8%|▊         | 76/1000 [00:18<03:08,  4.89it/s]
#   8%|▊         | 77/1000 [00:18<03:07,  4.92it/s]
#   8%|▊         | 78/1000 [00:18<03:06,  4.94it/s]
#   8%|▊         | 79/1000 [00:18<03:07,  4.91it/s]
#   8%|▊         | 80/1000 [00:19<03:06,  4.92it/s]
# Epoch 80
# 0.007136843632906675
# 0.12097728252410889
#   8%|▊         | 81/1000 [00:19<03:06,  4.93it/s]
#   8%|▊         | 82/1000 [00:19<03:05,  4.94it/s]
#   8%|▊         | 83/1000 [00:19<03:06,  4.91it/s]
#   8%|▊         | 84/1000 [00:19<03:06,  4.92it/s]
#   8%|▊         | 85/1000 [00:20<03:06,  4.90it/s]
#   9%|▊         | 86/1000 [00:20<03:05,  4.92it/s]
#   9%|▊         | 87/1000 [00:20<03:05,  4.93it/s]
#   9%|▉         | 88/1000 [00:20<03:04,  4.94it/s]
#   9%|▉         | 89/1000 [00:20<03:04,  4.95it/s]
#   9%|▉         | 90/1000 [00:21<03:04,  4.92it/s]
# Epoch 90
# 0.007130431476980448
# 0.11810767650604248
#   9%|▉         | 91/1000 [00:21<03:05,  4.90it/s]
#   9%|▉         | 92/1000 [00:21<03:04,  4.93it/s]
#   9%|▉         | 93/1000 [00:21<03:05,  4.90it/s]
#   9%|▉         | 94/1000 [00:22<03:03,  4.93it/s]
#  10%|▉         | 95/1000 [00:22<03:02,  4.95it/s]
#  10%|▉         | 96/1000 [00:22<03:02,  4.96it/s]
#  10%|▉         | 97/1000 [00:22<03:02,  4.96it/s]
#  10%|▉         | 98/1000 [00:22<03:01,  4.97it/s]
#  10%|▉         | 99/1000 [00:23<03:01,  4.97it/s]
#  10%|█         | 100/1000 [00:23<03:02,  4.93it/s]
# Epoch 100
# 0.006776893977075815
# 0.11793991178274155
#  10%|█         | 101/1000 [00:23<03:01,  4.95it/s]
#  10%|█         | 102/1000 [00:23<03:05,  4.84it/s]
#  10%|█         | 103/1000 [00:23<03:09,  4.73it/s]
#  10%|█         | 104/1000 [00:24<03:07,  4.77it/s]
#  10%|█         | 105/1000 [00:24<03:05,  4.83it/s]
#  11%|█         | 106/1000 [00:24<03:03,  4.88it/s]
#  11%|█         | 107/1000 [00:24<03:02,  4.90it/s]
#  11%|█         | 108/1000 [00:24<03:01,  4.92it/s]
#  11%|█         | 109/1000 [00:25<03:02,  4.88it/s]
#  11%|█         | 110/1000 [00:25<03:01,  4.90it/s]
# Epoch 110
# 0.007409147918224335
# 0.11662427335977554
#  11%|█         | 111/1000 [00:25<03:00,  4.93it/s]
#  11%|█         | 112/1000 [00:25<03:01,  4.89it/s]
#  11%|█▏        | 113/1000 [00:25<03:08,  4.72it/s]
#  11%|█▏        | 114/1000 [00:26<03:12,  4.60it/s]
#  12%|█▏        | 115/1000 [00:26<03:20,  4.41it/s]
#  12%|█▏        | 116/1000 [00:26<03:21,  4.38it/s]
#  12%|█▏        | 117/1000 [00:26<03:22,  4.36it/s]
#  12%|█▏        | 118/1000 [00:27<03:22,  4.35it/s]
#  12%|█▏        | 119/1000 [00:27<03:23,  4.32it/s]
#  12%|█▏        | 120/1000 [00:27<03:23,  4.32it/s]
# Epoch 120
# 0.0063224732875823975
# 0.11746084690093994
#  12%|█▏        | 121/1000 [00:27<03:26,  4.25it/s]
#  12%|█▏        | 122/1000 [00:28<03:25,  4.26it/s]
#  12%|█▏        | 123/1000 [00:28<03:25,  4.26it/s]
#  12%|█▏        | 124/1000 [00:28<03:24,  4.28it/s]
#  12%|█▎        | 125/1000 [00:28<03:24,  4.27it/s]
#  13%|█▎        | 126/1000 [00:28<03:23,  4.29it/s]
#  13%|█▎        | 127/1000 [00:29<03:23,  4.28it/s]
#  13%|█▎        | 128/1000 [00:29<03:23,  4.29it/s]
#  13%|█▎        | 129/1000 [00:29<03:23,  4.28it/s]
#  13%|█▎        | 130/1000 [00:29<03:25,  4.23it/s]
# Epoch 130
# 0.006315151229500771
# 0.11625190824270248
#  13%|█▎        | 131/1000 [00:30<03:24,  4.25it/s]
#  13%|█▎        | 132/1000 [00:30<03:24,  4.25it/s]
#  13%|█▎        | 133/1000 [00:30<03:23,  4.27it/s]
#  13%|█▎        | 134/1000 [00:30<03:23,  4.26it/s]
#  14%|█▎        | 135/1000 [00:31<03:21,  4.28it/s]
#  14%|█▎        | 136/1000 [00:31<03:22,  4.27it/s]
#  14%|█▎        | 137/1000 [00:31<03:21,  4.29it/s]
#  14%|█▍        | 138/1000 [00:31<03:23,  4.24it/s]
#  14%|█▍        | 139/1000 [00:32<03:22,  4.26it/s]
#  14%|█▍        | 140/1000 [00:32<03:21,  4.28it/s]
# Epoch 140
# 0.006491539068520069
# 0.11724233627319336
#  14%|█▍        | 141/1000 [00:32<03:21,  4.27it/s]
#  14%|█▍        | 142/1000 [00:32<03:20,  4.29it/s]
#  14%|█▍        | 143/1000 [00:32<03:20,  4.28it/s]
#  14%|█▍        | 144/1000 [00:33<03:19,  4.28it/s]
#  14%|█▍        | 145/1000 [00:33<03:19,  4.28it/s]
#  15%|█▍        | 146/1000 [00:33<03:20,  4.26it/s]
#  15%|█▍        | 147/1000 [00:33<03:22,  4.22it/s]
#  15%|█▍        | 148/1000 [00:34<03:20,  4.25it/s]
#  15%|█▍        | 149/1000 [00:34<03:19,  4.28it/s]
#  15%|█▌        | 150/1000 [00:34<03:19,  4.27it/s]
# Epoch 150
# 0.00593913346529007
# 0.11563555151224136
#  15%|█▌        | 151/1000 [00:34<03:21,  4.22it/s]
#  15%|█▌        | 152/1000 [00:35<03:19,  4.25it/s]
#  15%|█▌        | 153/1000 [00:35<03:18,  4.27it/s]
#  15%|█▌        | 154/1000 [00:35<03:18,  4.27it/s]
#  16%|█▌        | 155/1000 [00:35<03:18,  4.25it/s]
#  16%|█▌        | 156/1000 [00:36<03:28,  4.06it/s]
#  16%|█▌        | 157/1000 [00:36<03:46,  3.73it/s]
#  16%|█▌        | 158/1000 [00:36<03:45,  3.74it/s]
#  16%|█▌        | 159/1000 [00:36<03:37,  3.86it/s]
#  16%|█▌        | 160/1000 [00:37<03:33,  3.93it/s]
# Epoch 160
# 0.004837511572986841
# 0.11559764295816422
#  16%|█▌        | 161/1000 [00:37<03:28,  4.02it/s]
#  16%|█▌        | 162/1000 [00:37<03:24,  4.10it/s]
#  16%|█▋        | 163/1000 [00:37<03:23,  4.11it/s]
#  16%|█▋        | 164/1000 [00:38<03:21,  4.16it/s]
#  16%|█▋        | 165/1000 [00:38<03:30,  3.96it/s]
#  17%|█▋        | 166/1000 [00:38<03:26,  4.05it/s]
#  17%|█▋        | 167/1000 [00:38<03:22,  4.12it/s]
#  17%|█▋        | 168/1000 [00:39<03:20,  4.16it/s]
#  17%|█▋        | 169/1000 [00:39<03:18,  4.18it/s]
#  17%|█▋        | 170/1000 [00:39<03:19,  4.16it/s]
# Epoch 170
# 0.006231558974832296
# 0.11620660871267319
#  17%|█▋        | 171/1000 [00:39<03:19,  4.16it/s]
#  17%|█▋        | 172/1000 [00:39<03:17,  4.19it/s]
#  17%|█▋        | 173/1000 [00:40<03:15,  4.22it/s]
#  17%|█▋        | 174/1000 [00:40<03:14,  4.24it/s]
#  18%|█▊        | 175/1000 [00:40<03:13,  4.27it/s]
#  18%|█▊        | 176/1000 [00:40<03:13,  4.27it/s]
#  18%|█▊        | 177/1000 [00:41<03:11,  4.29it/s]
#  18%|█▊        | 178/1000 [00:41<03:11,  4.30it/s]
#  18%|█▊        | 179/1000 [00:41<03:18,  4.15it/s]
#  18%|█▊        | 180/1000 [00:41<03:19,  4.11it/s]
# Epoch 180
# 0.005982769653201103
# 0.11586081981658936
#  18%|█▊        | 181/1000 [00:42<03:17,  4.16it/s]
#  18%|█▊        | 182/1000 [00:42<03:16,  4.16it/s]
#  18%|█▊        | 183/1000 [00:42<03:22,  4.03it/s]
#  18%|█▊        | 184/1000 [00:42<03:19,  4.08it/s]
#  18%|█▊        | 185/1000 [00:43<03:16,  4.15it/s]
#  19%|█▊        | 186/1000 [00:43<03:13,  4.20it/s]
#  19%|█▊        | 187/1000 [00:43<03:13,  4.21it/s]
#  19%|█▉        | 188/1000 [00:43<03:13,  4.20it/s]
#  19%|█▉        | 189/1000 [00:44<03:11,  4.23it/s]
#  19%|█▉        | 190/1000 [00:44<03:12,  4.21it/s]
# Epoch 190
# 0.005910204723477364
# 0.11642304807901382
#  19%|█▉        | 191/1000 [00:44<03:11,  4.23it/s]
#  19%|█▉        | 192/1000 [00:44<03:10,  4.24it/s]
#  19%|█▉        | 193/1000 [00:44<03:09,  4.27it/s]
#  19%|█▉        | 194/1000 [00:45<03:08,  4.28it/s]
#  20%|█▉        | 195/1000 [00:45<03:08,  4.27it/s]
#  20%|█▉        | 196/1000 [00:45<03:10,  4.21it/s]
#  20%|█▉        | 197/1000 [00:45<03:17,  4.06it/s]
#  20%|█▉        | 198/1000 [00:46<03:14,  4.13it/s]
#  20%|█▉        | 199/1000 [00:46<03:11,  4.19it/s]
#  20%|██        | 200/1000 [00:46<03:10,  4.19it/s]
# Epoch 200
# 0.00511016882956028
# 0.11495891958475113
#  20%|██        | 201/1000 [00:46<03:09,  4.22it/s]
#  20%|██        | 202/1000 [00:47<03:09,  4.22it/s]
#  20%|██        | 203/1000 [00:47<03:08,  4.23it/s]
#  20%|██        | 204/1000 [00:47<03:08,  4.21it/s]
#  20%|██        | 205/1000 [00:47<03:09,  4.20it/s]
#  21%|██        | 206/1000 [00:48<03:07,  4.24it/s]
#  21%|██        | 207/1000 [00:48<03:06,  4.24it/s]
#  21%|██        | 208/1000 [00:48<03:05,  4.27it/s]
#  21%|██        | 209/1000 [00:48<03:05,  4.26it/s]
#  21%|██        | 210/1000 [00:49<03:04,  4.27it/s]
# Epoch 210
# 0.004883955232799053
# 0.11493968963623047
#  21%|██        | 211/1000 [00:49<03:04,  4.28it/s]
#  21%|██        | 212/1000 [00:49<03:03,  4.29it/s]
#  21%|██▏       | 213/1000 [00:49<03:05,  4.25it/s]
#  21%|██▏       | 214/1000 [00:49<03:06,  4.21it/s]
#  22%|██▏       | 215/1000 [00:50<03:06,  4.20it/s]
#  22%|██▏       | 216/1000 [00:50<03:04,  4.24it/s]
#  22%|██▏       | 217/1000 [00:50<03:03,  4.26it/s]
#  22%|██▏       | 218/1000 [00:50<03:02,  4.28it/s]
#  22%|██▏       | 219/1000 [00:51<03:02,  4.27it/s]
#  22%|██▏       | 220/1000 [00:51<03:02,  4.28it/s]
# Epoch 220
# 0.00586576946079731
# 0.11454018205404282
#  22%|██▏       | 221/1000 [00:51<03:01,  4.28it/s]
#  22%|██▏       | 222/1000 [00:51<03:04,  4.22it/s]
#  22%|██▏       | 223/1000 [00:52<03:03,  4.24it/s]
#  22%|██▏       | 224/1000 [00:52<03:02,  4.26it/s]
#  22%|██▎       | 225/1000 [00:52<03:00,  4.28it/s]
#  23%|██▎       | 226/1000 [00:52<03:00,  4.29it/s]
#  23%|██▎       | 227/1000 [00:53<03:00,  4.28it/s]
#  23%|██▎       | 228/1000 [00:53<03:01,  4.26it/s]
#  23%|██▎       | 229/1000 [00:53<03:01,  4.26it/s]
#  23%|██▎       | 230/1000 [00:53<03:01,  4.23it/s]
# Epoch 230
# 0.0050287144258618355
# 0.11493968963623047
#  23%|██▎       | 231/1000 [00:53<03:02,  4.22it/s]
#  23%|██▎       | 232/1000 [00:54<03:01,  4.22it/s]
#  23%|██▎       | 233/1000 [00:54<03:01,  4.23it/s]
#  23%|██▎       | 234/1000 [00:54<03:02,  4.20it/s]
#  24%|██▎       | 235/1000 [00:54<03:00,  4.24it/s]
#  24%|██▎       | 236/1000 [00:55<02:59,  4.26it/s]
#  24%|██▎       | 237/1000 [00:55<02:59,  4.26it/s]
#  24%|██▍       | 238/1000 [00:55<02:58,  4.28it/s]
#  24%|██▍       | 239/1000 [00:55<03:00,  4.21it/s]
#  24%|██▍       | 240/1000 [00:56<02:59,  4.24it/s]
# Epoch 240
# 0.0052308812737464905
# 0.11420353502035141
#  24%|██▍       | 241/1000 [00:56<02:58,  4.24it/s]
#  24%|██▍       | 242/1000 [00:56<02:57,  4.27it/s]
#  24%|██▍       | 243/1000 [00:56<02:58,  4.25it/s]
#  24%|██▍       | 244/1000 [00:57<02:57,  4.25it/s]
#  24%|██▍       | 245/1000 [00:57<02:57,  4.24it/s]
#  25%|██▍       | 246/1000 [00:57<03:02,  4.14it/s]
#  25%|██▍       | 247/1000 [00:57<03:00,  4.18it/s]
#  25%|██▍       | 248/1000 [00:57<02:59,  4.18it/s]
#  25%|██▍       | 249/1000 [00:58<02:58,  4.21it/s]
#  25%|██▌       | 250/1000 [00:58<02:56,  4.25it/s]
# Epoch 250
# 0.0058334288187325
# 0.1143849715590477
#  25%|██▌       | 251/1000 [00:58<02:56,  4.25it/s]
#  25%|██▌       | 252/1000 [00:58<02:55,  4.27it/s]
#  25%|██▌       | 253/1000 [00:59<02:54,  4.28it/s]
#  25%|██▌       | 254/1000 [00:59<02:53,  4.30it/s]
#  26%|██▌       | 255/1000 [00:59<02:54,  4.27it/s]
#  26%|██▌       | 256/1000 [00:59<02:59,  4.15it/s]
#  26%|██▌       | 257/1000 [01:00<03:00,  4.12it/s]
#  26%|██▌       | 258/1000 [01:00<02:59,  4.13it/s]
#  26%|██▌       | 259/1000 [01:00<02:57,  4.19it/s]
#  26%|██▌       | 260/1000 [01:00<02:55,  4.22it/s]
# Epoch 260
# 0.004980449099093676
# 0.1144707202911377
#  26%|██▌       | 261/1000 [01:01<02:55,  4.20it/s]
#  26%|██▌       | 262/1000 [01:01<02:54,  4.24it/s]
#  26%|██▋       | 263/1000 [01:01<02:55,  4.20it/s]
#  26%|██▋       | 264/1000 [01:01<02:58,  4.13it/s]
#  26%|██▋       | 265/1000 [01:02<02:55,  4.18it/s]
#  27%|██▋       | 266/1000 [01:02<02:53,  4.22it/s]
#  27%|██▋       | 267/1000 [01:02<02:52,  4.25it/s]
#  27%|██▋       | 268/1000 [01:02<02:51,  4.27it/s]
#  27%|██▋       | 269/1000 [01:02<02:50,  4.29it/s]
#  27%|██▋       | 270/1000 [01:03<02:50,  4.29it/s]
# Epoch 270
# 0.007159789092838764
# 0.1138148307800293
#  27%|██▋       | 271/1000 [01:03<02:50,  4.28it/s]
#  27%|██▋       | 272/1000 [01:03<02:49,  4.29it/s]
#  27%|██▋       | 273/1000 [01:03<02:51,  4.24it/s]
#  27%|██▋       | 274/1000 [01:04<02:50,  4.26it/s]
#  28%|██▊       | 275/1000 [01:04<02:49,  4.28it/s]
#  28%|██▊       | 276/1000 [01:04<02:48,  4.29it/s]
#  28%|██▊       | 277/1000 [01:04<02:48,  4.28it/s]
#  28%|██▊       | 278/1000 [01:05<02:48,  4.30it/s]
#  28%|██▊       | 279/1000 [01:05<02:47,  4.30it/s]
#  28%|██▊       | 280/1000 [01:05<02:47,  4.30it/s]
# Epoch 280
# 0.005257715471088886
# 0.11458754539489746
#  28%|██▊       | 281/1000 [01:05<02:48,  4.27it/s]
#  28%|██▊       | 282/1000 [01:05<02:49,  4.24it/s]
#  28%|██▊       | 283/1000 [01:06<02:49,  4.23it/s]
#  28%|██▊       | 284/1000 [01:06<02:48,  4.26it/s]
#  28%|██▊       | 285/1000 [01:06<02:47,  4.27it/s]
#  29%|██▊       | 286/1000 [01:06<02:48,  4.24it/s]
#  29%|██▊       | 287/1000 [01:07<02:47,  4.26it/s]
#  29%|██▉       | 288/1000 [01:07<02:46,  4.28it/s]
#  29%|██▉       | 289/1000 [01:07<02:46,  4.27it/s]
#  29%|██▉       | 290/1000 [01:07<02:47,  4.24it/s]
# Epoch 290
# 0.004841755144298077
# 0.11346379667520523
#  29%|██▉       | 291/1000 [01:08<02:47,  4.24it/s]
#  29%|██▉       | 292/1000 [01:08<02:45,  4.27it/s]
#  29%|██▉       | 293/1000 [01:08<02:45,  4.28it/s]
#  29%|██▉       | 294/1000 [01:08<02:45,  4.28it/s]
#  30%|██▉       | 295/1000 [01:09<02:44,  4.29it/s]
#  30%|██▉       | 296/1000 [01:09<02:43,  4.30it/s]
#  30%|██▉       | 297/1000 [01:09<02:43,  4.29it/s]
#  30%|██▉       | 298/1000 [01:09<02:43,  4.30it/s]
#  30%|██▉       | 299/1000 [01:09<02:46,  4.21it/s]
#  30%|███       | 300/1000 [01:10<02:46,  4.20it/s]
# Epoch 300
# 0.004815845750272274
# 0.11431225389242172
#  30%|███       | 301/1000 [01:10<02:47,  4.18it/s]
#  30%|███       | 302/1000 [01:10<02:47,  4.18it/s]
#  30%|███       | 303/1000 [01:10<02:45,  4.22it/s]
#  30%|███       | 304/1000 [01:11<02:43,  4.25it/s]
#  30%|███       | 305/1000 [01:11<02:42,  4.27it/s]
#  31%|███       | 306/1000 [01:11<02:42,  4.28it/s]
#  31%|███       | 307/1000 [01:11<02:44,  4.22it/s]
#  31%|███       | 308/1000 [01:12<02:42,  4.25it/s]
#  31%|███       | 309/1000 [01:12<02:41,  4.27it/s]
#  31%|███       | 310/1000 [01:12<02:41,  4.28it/s]
# Epoch 310
# 0.004191885702311993
# 0.11482783406972885
#  31%|███       | 311/1000 [01:12<02:41,  4.28it/s]
#  31%|███       | 312/1000 [01:13<02:40,  4.29it/s]
#  31%|███▏      | 313/1000 [01:13<02:39,  4.30it/s]
#  31%|███▏      | 314/1000 [01:13<02:39,  4.30it/s]
#  32%|███▏      | 315/1000 [01:13<02:39,  4.29it/s]
#  32%|███▏      | 316/1000 [01:13<02:40,  4.27it/s]
#  32%|███▏      | 317/1000 [01:14<02:41,  4.24it/s]
#  32%|███▏      | 318/1000 [01:14<02:40,  4.26it/s]
#  32%|███▏      | 319/1000 [01:14<02:39,  4.27it/s]
#  32%|███▏      | 320/1000 [01:14<02:39,  4.27it/s]
# Epoch 320
# 0.005207432899624109
# 0.11378920078277588
#  32%|███▏      | 321/1000 [01:15<02:38,  4.28it/s]
#  32%|███▏      | 322/1000 [01:15<02:40,  4.23it/s]
#  32%|███▏      | 323/1000 [01:15<02:39,  4.23it/s]
#  32%|███▏      | 324/1000 [01:15<02:39,  4.23it/s]
#  32%|███▎      | 325/1000 [01:16<02:38,  4.26it/s]
#  33%|███▎      | 326/1000 [01:16<02:40,  4.19it/s]
#  33%|███▎      | 327/1000 [01:16<02:39,  4.23it/s]
#  33%|███▎      | 328/1000 [01:16<02:39,  4.20it/s]
#  33%|███▎      | 329/1000 [01:17<02:38,  4.24it/s]
#  33%|███▎      | 330/1000 [01:17<02:37,  4.25it/s]
# Epoch 330
# 0.004356995224952698
# 0.11415954679250717
#  33%|███▎      | 331/1000 [01:17<02:37,  4.26it/s]
#  33%|███▎      | 332/1000 [01:17<02:36,  4.28it/s]
#  33%|███▎      | 333/1000 [01:17<02:37,  4.24it/s]
#  33%|███▎      | 334/1000 [01:18<02:36,  4.26it/s]
#  34%|███▎      | 335/1000 [01:18<02:35,  4.29it/s]
#  34%|███▎      | 336/1000 [01:18<02:34,  4.30it/s]
#  34%|███▎      | 337/1000 [01:18<02:34,  4.30it/s]
#  34%|███▍      | 338/1000 [01:19<02:33,  4.30it/s]
#  34%|███▍      | 339/1000 [01:19<02:34,  4.27it/s]
#  34%|███▍      | 340/1000 [01:19<02:34,  4.27it/s]
# Epoch 340
# 0.005173893179744482
# 0.11385679244995117
#  34%|███▍      | 341/1000 [01:19<02:35,  4.23it/s]
#  34%|███▍      | 342/1000 [01:20<02:34,  4.25it/s]
#  34%|███▍      | 343/1000 [01:20<02:33,  4.27it/s]
#  34%|███▍      | 344/1000 [01:20<02:32,  4.29it/s]
#  34%|███▍      | 345/1000 [01:20<02:32,  4.29it/s]
#  35%|███▍      | 346/1000 [01:21<02:32,  4.30it/s]
#  35%|███▍      | 347/1000 [01:21<02:31,  4.31it/s]
#  35%|███▍      | 348/1000 [01:21<02:31,  4.30it/s]
#  35%|███▍      | 349/1000 [01:21<02:31,  4.29it/s]
#  35%|███▌      | 350/1000 [01:21<02:32,  4.25it/s]
# Epoch 350
# 0.004325727932155132
# 0.11395648866891861
#  35%|███▌      | 351/1000 [01:22<02:32,  4.26it/s]
#  35%|███▌      | 352/1000 [01:22<02:31,  4.26it/s]
#  35%|███▌      | 353/1000 [01:22<02:31,  4.28it/s]
#  35%|███▌      | 354/1000 [01:22<02:30,  4.30it/s]
#  36%|███▌      | 355/1000 [01:23<02:29,  4.31it/s]
#  36%|███▌      | 356/1000 [01:23<02:29,  4.29it/s]
#  36%|███▌      | 357/1000 [01:23<02:29,  4.30it/s]
#  36%|███▌      | 358/1000 [01:23<02:29,  4.28it/s]
#  36%|███▌      | 359/1000 [01:24<02:30,  4.27it/s]
#  36%|███▌      | 360/1000 [01:24<02:29,  4.29it/s]
# Epoch 360
# 0.003927015699446201
# 0.113372802734375
#  36%|███▌      | 361/1000 [01:24<02:28,  4.29it/s]
#  36%|███▌      | 362/1000 [01:24<02:28,  4.28it/s]
#  36%|███▋      | 363/1000 [01:24<02:28,  4.29it/s]
#  36%|███▋      | 364/1000 [01:25<02:28,  4.29it/s]
#  36%|███▋      | 365/1000 [01:25<02:27,  4.30it/s]
#  37%|███▋      | 366/1000 [01:25<02:27,  4.31it/s]
#  37%|███▋      | 367/1000 [01:25<02:28,  4.26it/s]
#  37%|███▋      | 368/1000 [01:26<02:27,  4.28it/s]
#  37%|███▋      | 369/1000 [01:26<02:26,  4.30it/s]
#  37%|███▋      | 370/1000 [01:26<02:26,  4.29it/s]
# Epoch 370
# 0.004765402525663376
# 0.1136423721909523
#  37%|███▋      | 371/1000 [01:26<02:26,  4.28it/s]
#  37%|███▋      | 372/1000 [01:27<02:26,  4.30it/s]
#  37%|███▋      | 373/1000 [01:27<02:25,  4.31it/s]
#  37%|███▋      | 374/1000 [01:27<02:25,  4.31it/s]
#  38%|███▊      | 375/1000 [01:27<02:26,  4.27it/s]
#  38%|███▊      | 376/1000 [01:28<02:25,  4.28it/s]
#  38%|███▊      | 377/1000 [01:28<02:25,  4.29it/s]
#  38%|███▊      | 378/1000 [01:28<02:24,  4.29it/s]
#  38%|███▊      | 379/1000 [01:28<02:24,  4.30it/s]
#  38%|███▊      | 380/1000 [01:28<02:23,  4.31it/s]
# Epoch 380
# 0.004479406867176294
# 0.11415934562683105
#  38%|███▊      | 381/1000 [01:29<02:24,  4.29it/s]
#  38%|███▊      | 382/1000 [01:29<02:23,  4.31it/s]
#  38%|███▊      | 383/1000 [01:29<02:23,  4.31it/s]
#  38%|███▊      | 384/1000 [01:29<02:24,  4.26it/s]
#  38%|███▊      | 385/1000 [01:30<02:23,  4.28it/s]
#  39%|███▊      | 386/1000 [01:30<02:22,  4.30it/s]
#  39%|███▊      | 387/1000 [01:30<02:25,  4.22it/s]
#  39%|███▉      | 388/1000 [01:30<02:23,  4.26it/s]
#  39%|███▉      | 389/1000 [01:31<02:22,  4.27it/s]
#  39%|███▉      | 390/1000 [01:31<02:22,  4.28it/s]
# Epoch 390
# 0.0035933356266468763
# 0.11361674219369888
#  39%|███▉      | 391/1000 [01:31<02:21,  4.30it/s]
#  39%|███▉      | 392/1000 [01:31<02:22,  4.27it/s]
#  39%|███▉      | 393/1000 [01:31<02:22,  4.25it/s]
#  39%|███▉      | 394/1000 [01:32<02:21,  4.28it/s]
#  40%|███▉      | 395/1000 [01:32<02:21,  4.28it/s]
#  40%|███▉      | 396/1000 [01:32<02:21,  4.28it/s]
#  40%|███▉      | 397/1000 [01:32<02:20,  4.29it/s]
#  40%|███▉      | 398/1000 [01:33<02:19,  4.30it/s]
#  40%|███▉      | 399/1000 [01:33<02:20,  4.27it/s]
#  40%|████      | 400/1000 [01:33<02:20,  4.26it/s]
# Epoch 400
# 0.003937367349863052
# 0.11365195363759995
#  40%|████      | 401/1000 [01:33<02:21,  4.24it/s]
#  40%|████      | 402/1000 [01:34<02:20,  4.27it/s]
#  40%|████      | 403/1000 [01:34<02:19,  4.27it/s]
#  40%|████      | 404/1000 [01:34<02:18,  4.29it/s]
#  40%|████      | 405/1000 [01:34<02:18,  4.30it/s]
#  41%|████      | 406/1000 [01:35<02:17,  4.32it/s]
#  41%|████      | 407/1000 [01:35<02:17,  4.30it/s]
#  41%|████      | 408/1000 [01:35<02:17,  4.31it/s]
#  41%|████      | 409/1000 [01:35<02:17,  4.31it/s]
#  41%|████      | 410/1000 [01:35<02:18,  4.27it/s]
# Epoch 410
# 0.004323688335716724
# 0.1139671802520752
#  41%|████      | 411/1000 [01:36<02:17,  4.28it/s]
#  41%|████      | 412/1000 [01:36<02:16,  4.30it/s]
#  41%|████▏     | 413/1000 [01:36<02:17,  4.28it/s]
#  41%|████▏     | 414/1000 [01:36<02:16,  4.28it/s]
#  42%|████▏     | 415/1000 [01:37<02:16,  4.29it/s]
#  42%|████▏     | 416/1000 [01:37<02:15,  4.30it/s]
#  42%|████▏     | 417/1000 [01:37<02:15,  4.31it/s]
#  42%|████▏     | 418/1000 [01:37<02:16,  4.26it/s]
#  42%|████▏     | 419/1000 [01:38<02:16,  4.25it/s]
#  42%|████▏     | 420/1000 [01:38<02:16,  4.26it/s]
# Epoch 420
# 0.0036278816405683756
# 0.11379166692495346
#  42%|████▏     | 421/1000 [01:38<02:15,  4.27it/s]
#  42%|████▏     | 422/1000 [01:38<02:14,  4.29it/s]
#  42%|████▏     | 423/1000 [01:38<02:14,  4.29it/s]
#  42%|████▏     | 424/1000 [01:39<02:13,  4.30it/s]
#  42%|████▎     | 425/1000 [01:39<02:13,  4.31it/s]
#  43%|████▎     | 426/1000 [01:39<02:13,  4.32it/s]
#  43%|████▎     | 427/1000 [01:39<02:14,  4.26it/s]
#  43%|████▎     | 428/1000 [01:40<02:13,  4.28it/s]
#  43%|████▎     | 429/1000 [01:40<02:12,  4.30it/s]
#  43%|████▎     | 430/1000 [01:40<02:12,  4.30it/s]
# Epoch 430
# 0.0038411677815020084
# 0.11353492736816406
#  43%|████▎     | 431/1000 [01:40<02:12,  4.29it/s]
#  43%|████▎     | 432/1000 [01:41<02:11,  4.31it/s]
#  43%|████▎     | 433/1000 [01:41<02:11,  4.32it/s]
#  43%|████▎     | 434/1000 [01:41<02:11,  4.32it/s]
#  44%|████▎     | 435/1000 [01:41<02:11,  4.30it/s]
#  44%|████▎     | 436/1000 [01:42<02:11,  4.28it/s]
#  44%|████▎     | 437/1000 [01:42<02:11,  4.28it/s]
#  44%|████▍     | 438/1000 [01:42<02:10,  4.30it/s]
#  44%|████▍     | 439/1000 [01:42<02:10,  4.30it/s]
#  44%|████▍     | 440/1000 [01:42<02:10,  4.30it/s]
# Epoch 440
# 0.003920822869986296
# 0.11414790153503418
#  44%|████▍     | 441/1000 [01:43<02:10,  4.28it/s]
#  44%|████▍     | 442/1000 [01:43<02:10,  4.29it/s]
#  44%|████▍     | 443/1000 [01:43<02:09,  4.29it/s]
#  44%|████▍     | 444/1000 [01:43<02:11,  4.24it/s]
#  44%|████▍     | 445/1000 [01:44<02:10,  4.26it/s]
#  45%|████▍     | 446/1000 [01:44<02:09,  4.27it/s]
#  45%|████▍     | 447/1000 [01:44<02:09,  4.28it/s]
#  45%|████▍     | 448/1000 [01:44<02:08,  4.29it/s]
#  45%|████▍     | 449/1000 [01:45<02:08,  4.29it/s]
#  45%|████▌     | 450/1000 [01:45<02:08,  4.29it/s]
# Epoch 450
# 0.0037652908358722925
# 0.11396118253469467
#  45%|████▌     | 451/1000 [01:45<02:07,  4.30it/s]
#  45%|████▌     | 452/1000 [01:45<02:07,  4.30it/s]
#  45%|████▌     | 453/1000 [01:45<02:08,  4.25it/s]
#  45%|████▌     | 454/1000 [01:46<02:07,  4.27it/s]
#  46%|████▌     | 455/1000 [01:46<02:07,  4.28it/s]
#  46%|████▌     | 456/1000 [01:46<02:07,  4.27it/s]
#  46%|████▌     | 457/1000 [01:46<02:06,  4.29it/s]
#  46%|████▌     | 458/1000 [01:47<02:07,  4.25it/s]
#  46%|████▌     | 459/1000 [01:47<02:06,  4.27it/s]
#  46%|████▌     | 460/1000 [01:47<02:09,  4.18it/s]
# Epoch 460
# 0.003972308710217476
# 0.11378240585327148
#  46%|████▌     | 461/1000 [01:47<02:12,  4.08it/s]
#  46%|████▌     | 462/1000 [01:48<02:11,  4.09it/s]
#  46%|████▋     | 463/1000 [01:48<02:08,  4.16it/s]
#  46%|████▋     | 464/1000 [01:48<02:07,  4.21it/s]
#  46%|████▋     | 465/1000 [01:48<02:06,  4.25it/s]
#  47%|████▋     | 466/1000 [01:49<02:05,  4.25it/s]
#  47%|████▋     | 467/1000 [01:49<02:04,  4.28it/s]
#  47%|████▋     | 468/1000 [01:49<02:03,  4.30it/s]
#  47%|████▋     | 469/1000 [01:49<02:03,  4.29it/s]
#  47%|████▋     | 470/1000 [01:49<02:04,  4.25it/s]
# Epoch 470
# 0.004280830733478069
# 0.11369773000478745
#  47%|████▋     | 471/1000 [01:50<02:04,  4.27it/s]
#  47%|████▋     | 472/1000 [01:50<02:03,  4.28it/s]
#  47%|████▋     | 473/1000 [01:50<02:03,  4.28it/s]
#  47%|████▋     | 474/1000 [01:50<02:02,  4.29it/s]
#  48%|████▊     | 475/1000 [01:51<02:02,  4.30it/s]
#  48%|████▊     | 476/1000 [01:51<02:01,  4.31it/s]
#  48%|████▊     | 477/1000 [01:51<02:01,  4.31it/s]
#  48%|████▊     | 478/1000 [01:51<02:03,  4.23it/s]
#  48%|████▊     | 479/1000 [01:52<02:02,  4.26it/s]
#  48%|████▊     | 480/1000 [01:52<02:01,  4.28it/s]
# Epoch 480
# 0.004382224753499031
# 0.11404311656951904
#  48%|████▊     | 481/1000 [01:52<02:01,  4.29it/s]
#  48%|████▊     | 482/1000 [01:52<02:02,  4.21it/s]
#  48%|████▊     | 483/1000 [01:53<02:01,  4.25it/s]
#  48%|████▊     | 484/1000 [01:53<02:00,  4.27it/s]
#  48%|████▊     | 485/1000 [01:53<02:00,  4.27it/s]
#  49%|████▊     | 486/1000 [01:53<01:59,  4.29it/s]
#  49%|████▊     | 487/1000 [01:53<02:00,  4.27it/s]
#  49%|████▉     | 488/1000 [01:54<01:59,  4.28it/s]
#  49%|████▉     | 489/1000 [01:54<01:59,  4.29it/s]
#  49%|████▉     | 490/1000 [01:54<01:58,  4.30it/s]
# Epoch 490
# 0.003931260202080011
# 0.11367210000753403
#  49%|████▉     | 491/1000 [01:54<01:58,  4.31it/s]
#  49%|████▉     | 492/1000 [01:55<01:58,  4.30it/s]
#  49%|████▉     | 493/1000 [01:55<01:57,  4.31it/s]
#  49%|████▉     | 494/1000 [01:55<01:57,  4.32it/s]
#  50%|████▉     | 495/1000 [01:55<01:58,  4.28it/s]
#  50%|████▉     | 496/1000 [01:56<01:57,  4.28it/s]
#  50%|████▉     | 497/1000 [01:56<01:57,  4.29it/s]
#  50%|████▉     | 498/1000 [01:56<01:57,  4.28it/s]
#  50%|████▉     | 499/1000 [01:56<01:57,  4.27it/s]
#  50%|█████     | 500/1000 [01:56<01:56,  4.28it/s]
# Epoch 500
# 0.0030918398406356573
# 0.11374350637197495
#  50%|█████     | 501/1000 [01:57<01:57,  4.24it/s]
#  50%|█████     | 502/1000 [01:57<01:57,  4.25it/s]
#  50%|█████     | 503/1000 [01:57<01:56,  4.27it/s]
#  50%|█████     | 504/1000 [01:57<01:58,  4.20it/s]
#  50%|█████     | 505/1000 [01:58<01:57,  4.22it/s]
#  51%|█████     | 506/1000 [01:58<01:56,  4.22it/s]
#  51%|█████     | 507/1000 [01:58<01:55,  4.25it/s]
#  51%|█████     | 508/1000 [01:58<01:55,  4.28it/s]
#  51%|█████     | 509/1000 [01:59<01:54,  4.29it/s]
#  51%|█████     | 510/1000 [01:59<01:54,  4.28it/s]
# Epoch 510
# 0.003246748587116599
# 0.11313843727111816
#  51%|█████     | 511/1000 [01:59<01:54,  4.29it/s]
#  51%|█████     | 512/1000 [01:59<01:54,  4.26it/s]
#  51%|█████▏    | 513/1000 [02:00<01:54,  4.26it/s]
#  51%|█████▏    | 514/1000 [02:00<01:53,  4.28it/s]
#  52%|█████▏    | 515/1000 [02:00<01:52,  4.30it/s]
#  52%|█████▏    | 516/1000 [02:00<01:52,  4.30it/s]
#  52%|█████▏    | 517/1000 [02:00<01:52,  4.28it/s]
#  52%|█████▏    | 518/1000 [02:01<01:52,  4.30it/s]
#  52%|█████▏    | 519/1000 [02:01<01:51,  4.30it/s]
#  52%|█████▏    | 520/1000 [02:01<01:51,  4.30it/s]
# Epoch 520
# 0.003441435284912586
# 0.11299518495798111
#  52%|█████▏    | 521/1000 [02:01<01:52,  4.27it/s]
#  52%|█████▏    | 522/1000 [02:02<01:51,  4.28it/s]
#  52%|█████▏    | 523/1000 [02:02<01:51,  4.29it/s]
#  52%|█████▏    | 524/1000 [02:02<01:51,  4.28it/s]
#  52%|█████▎    | 525/1000 [02:02<01:50,  4.30it/s]
#  53%|█████▎    | 526/1000 [02:03<01:49,  4.31it/s]
#  53%|█████▎    | 527/1000 [02:03<01:49,  4.30it/s]
#  53%|█████▎    | 528/1000 [02:03<01:49,  4.31it/s]
#  53%|█████▎    | 529/1000 [02:03<01:49,  4.28it/s]
#  53%|█████▎    | 530/1000 [02:04<01:49,  4.28it/s]
# Epoch 530
# 0.003461339045315981
# 0.11366844177246094
#  53%|█████▎    | 531/1000 [02:04<01:49,  4.29it/s]
#  53%|█████▎    | 532/1000 [02:04<01:48,  4.31it/s]
#  53%|█████▎    | 533/1000 [02:04<01:48,  4.30it/s]
#  53%|█████▎    | 534/1000 [02:04<01:48,  4.31it/s]
#  54%|█████▎    | 535/1000 [02:05<01:47,  4.32it/s]
#  54%|█████▎    | 536/1000 [02:05<01:47,  4.32it/s]
#  54%|█████▎    | 537/1000 [02:05<01:47,  4.31it/s]
#  54%|█████▍    | 538/1000 [02:05<01:48,  4.24it/s]
#  54%|█████▍    | 539/1000 [02:06<01:47,  4.27it/s]
#  54%|█████▍    | 540/1000 [02:06<01:47,  4.29it/s]
# Epoch 540
# 0.0033270178828388453
# 0.11384367942810059
#  54%|█████▍    | 541/1000 [02:06<01:47,  4.28it/s]
#  54%|█████▍    | 542/1000 [02:06<01:47,  4.26it/s]
#  54%|█████▍    | 543/1000 [02:07<01:48,  4.22it/s]
#  54%|█████▍    | 544/1000 [02:07<01:52,  4.05it/s]
#  55%|█████▍    | 545/1000 [02:07<01:50,  4.10it/s]
#  55%|█████▍    | 546/1000 [02:07<01:50,  4.11it/s]
#  55%|█████▍    | 547/1000 [02:08<01:49,  4.13it/s]
#  55%|█████▍    | 548/1000 [02:08<01:47,  4.19it/s]
#  55%|█████▍    | 549/1000 [02:08<01:46,  4.23it/s]
#  55%|█████▌    | 550/1000 [02:08<01:48,  4.16it/s]
# Epoch 550
# 0.00274096243083477
# 0.11321274191141129
#  55%|█████▌    | 551/1000 [02:08<01:47,  4.19it/s]
#  55%|█████▌    | 552/1000 [02:09<01:45,  4.23it/s]
#  55%|█████▌    | 553/1000 [02:09<01:44,  4.26it/s]
#  55%|█████▌    | 554/1000 [02:09<01:44,  4.27it/s]
#  56%|█████▌    | 555/1000 [02:09<01:45,  4.24it/s]
#  56%|█████▌    | 556/1000 [02:10<01:44,  4.26it/s]
#  56%|█████▌    | 557/1000 [02:10<01:43,  4.28it/s]
#  56%|█████▌    | 558/1000 [02:10<01:43,  4.29it/s]
#  56%|█████▌    | 559/1000 [02:10<01:42,  4.28it/s]
#  56%|█████▌    | 560/1000 [02:11<01:42,  4.30it/s]
# Epoch 560
# 0.00386267458088696
# 0.11384478956460953
#  56%|█████▌    | 561/1000 [02:11<01:42,  4.30it/s]
#  56%|█████▌    | 562/1000 [02:11<01:41,  4.30it/s]
#  56%|█████▋    | 563/1000 [02:11<01:42,  4.27it/s]
#  56%|█████▋    | 564/1000 [02:12<01:41,  4.28it/s]
#  56%|█████▋    | 565/1000 [02:12<01:42,  4.25it/s]
#  57%|█████▋    | 566/1000 [02:12<01:42,  4.23it/s]
#  57%|█████▋    | 567/1000 [02:12<01:42,  4.23it/s]
#  57%|█████▋    | 568/1000 [02:12<01:42,  4.23it/s]
#  57%|█████▋    | 569/1000 [02:13<01:41,  4.26it/s]
#  57%|█████▋    | 570/1000 [02:13<01:40,  4.28it/s]
# Epoch 570
# 0.003421216271817684
# 0.11349475383758545
#  57%|█████▋    | 571/1000 [02:13<01:40,  4.27it/s]
#  57%|█████▋    | 572/1000 [02:13<01:40,  4.25it/s]
#  57%|█████▋    | 573/1000 [02:14<01:40,  4.27it/s]
#  57%|█████▋    | 574/1000 [02:14<01:39,  4.27it/s]
#  57%|█████▊    | 575/1000 [02:14<01:39,  4.28it/s]
#  58%|█████▊    | 576/1000 [02:14<01:40,  4.22it/s]
#  58%|█████▊    | 577/1000 [02:15<01:39,  4.25it/s]
#  58%|█████▊    | 578/1000 [02:15<01:38,  4.27it/s]
#  58%|█████▊    | 579/1000 [02:15<01:38,  4.28it/s]
#  58%|█████▊    | 580/1000 [02:15<01:38,  4.26it/s]
# Epoch 580
# 0.0032041186932474375
# 0.1132553443312645
#  58%|█████▊    | 581/1000 [02:16<01:38,  4.26it/s]
#  58%|█████▊    | 582/1000 [02:16<01:37,  4.27it/s]
#  58%|█████▊    | 583/1000 [02:16<01:37,  4.28it/s]
#  58%|█████▊    | 584/1000 [02:16<01:36,  4.29it/s]
#  58%|█████▊    | 585/1000 [02:16<01:36,  4.30it/s]
#  59%|█████▊    | 586/1000 [02:17<01:36,  4.31it/s]
#  59%|█████▊    | 587/1000 [02:17<01:36,  4.30it/s]
#  59%|█████▉    | 588/1000 [02:17<01:35,  4.30it/s]
#  59%|█████▉    | 589/1000 [02:17<01:36,  4.24it/s]
#  59%|█████▉    | 590/1000 [02:18<01:36,  4.23it/s]
# Epoch 590
# 0.00264452351257205
# 0.11319192498922348
#  59%|█████▉    | 591/1000 [02:18<01:36,  4.25it/s]
#  59%|█████▉    | 592/1000 [02:18<01:35,  4.27it/s]
#  59%|█████▉    | 593/1000 [02:18<01:35,  4.26it/s]
#  59%|█████▉    | 594/1000 [02:19<01:34,  4.28it/s]
#  60%|█████▉    | 595/1000 [02:19<01:34,  4.29it/s]
#  60%|█████▉    | 596/1000 [02:19<01:34,  4.30it/s]
#  60%|█████▉    | 597/1000 [02:19<01:34,  4.29it/s]
#  60%|█████▉    | 598/1000 [02:19<01:34,  4.24it/s]
#  60%|█████▉    | 599/1000 [02:20<01:34,  4.27it/s]
#  60%|██████    | 600/1000 [02:20<01:33,  4.28it/s]
# Epoch 600
# 0.00331437261775136
# 0.11301199346780777
#  60%|██████    | 601/1000 [02:20<01:33,  4.27it/s]
#  60%|██████    | 602/1000 [02:20<01:32,  4.28it/s]
#  60%|██████    | 603/1000 [02:21<01:32,  4.29it/s]
#  60%|██████    | 604/1000 [02:21<01:33,  4.25it/s]
#  60%|██████    | 605/1000 [02:21<01:32,  4.27it/s]
#  61%|██████    | 606/1000 [02:21<01:33,  4.22it/s]
#  61%|██████    | 607/1000 [02:22<01:32,  4.25it/s]
#  61%|██████    | 608/1000 [02:22<01:31,  4.27it/s]
#  61%|██████    | 609/1000 [02:22<01:31,  4.27it/s]
#  61%|██████    | 610/1000 [02:22<01:31,  4.27it/s]
# Epoch 610
# 0.0034305579029023647
# 0.11397325992584229
#  61%|██████    | 611/1000 [02:23<01:30,  4.28it/s]
#  61%|██████    | 612/1000 [02:23<01:30,  4.29it/s]
#  61%|██████▏   | 613/1000 [02:23<01:30,  4.29it/s]
#  61%|██████▏   | 614/1000 [02:23<01:30,  4.28it/s]
#  62%|██████▏   | 615/1000 [02:23<01:30,  4.26it/s]
#  62%|██████▏   | 616/1000 [02:24<01:30,  4.26it/s]
#  62%|██████▏   | 617/1000 [02:24<01:29,  4.28it/s]
#  62%|██████▏   | 618/1000 [02:24<01:28,  4.29it/s]
#  62%|██████▏   | 619/1000 [02:24<01:30,  4.22it/s]
#  62%|██████▏   | 620/1000 [02:25<01:29,  4.25it/s]
# Epoch 620
# 0.0027764607220888138
# 0.11304792016744614
#  62%|██████▏   | 621/1000 [02:25<01:28,  4.26it/s]
#  62%|██████▏   | 622/1000 [02:25<01:29,  4.23it/s]
#  62%|██████▏   | 623/1000 [02:25<01:29,  4.22it/s]
#  62%|██████▏   | 624/1000 [02:26<01:28,  4.24it/s]
#  62%|██████▎   | 625/1000 [02:26<01:28,  4.26it/s]
#  63%|██████▎   | 626/1000 [02:26<01:27,  4.26it/s]
#  63%|██████▎   | 627/1000 [02:26<01:27,  4.27it/s]
#  63%|██████▎   | 628/1000 [02:27<01:26,  4.29it/s]
#  63%|██████▎   | 629/1000 [02:27<01:26,  4.29it/s]
#  63%|██████▎   | 630/1000 [02:27<01:26,  4.29it/s]
# Epoch 630
# 0.0035147955641150475
# 0.11351100355386734
#  63%|██████▎   | 631/1000 [02:27<01:26,  4.29it/s]
#  63%|██████▎   | 632/1000 [02:27<01:26,  4.24it/s]
#  63%|██████▎   | 633/1000 [02:28<01:26,  4.25it/s]
#  63%|██████▎   | 634/1000 [02:28<01:25,  4.27it/s]
#  64%|██████▎   | 635/1000 [02:28<01:25,  4.28it/s]
#  64%|██████▎   | 636/1000 [02:28<01:24,  4.28it/s]
#  64%|██████▎   | 637/1000 [02:29<01:24,  4.30it/s]
#  64%|██████▍   | 638/1000 [02:29<01:24,  4.29it/s]
#  64%|██████▍   | 639/1000 [02:29<01:24,  4.29it/s]
#  64%|██████▍   | 640/1000 [02:29<01:24,  4.25it/s]
# Epoch 640
# 0.0030279699712991714
# 0.1135927066206932
#  64%|██████▍   | 641/1000 [02:30<01:24,  4.26it/s]
#  64%|██████▍   | 642/1000 [02:30<01:23,  4.28it/s]
#  64%|██████▍   | 643/1000 [02:30<01:23,  4.29it/s]
#  64%|██████▍   | 644/1000 [02:30<01:23,  4.28it/s]
#  64%|██████▍   | 645/1000 [02:30<01:22,  4.30it/s]
#  65%|██████▍   | 646/1000 [02:31<01:22,  4.31it/s]
#  65%|██████▍   | 647/1000 [02:31<01:22,  4.30it/s]
#  65%|██████▍   | 648/1000 [02:31<01:23,  4.22it/s]
#  65%|██████▍   | 649/1000 [02:31<01:23,  4.20it/s]
#  65%|██████▌   | 650/1000 [02:32<01:23,  4.21it/s]
# Epoch 650
# 0.0032865614630281925
# 0.11323690414428711
#  65%|██████▌   | 651/1000 [02:32<01:22,  4.24it/s]
#  65%|██████▌   | 652/1000 [02:32<01:21,  4.26it/s]
#  65%|██████▌   | 653/1000 [02:32<01:21,  4.28it/s]
#  65%|██████▌   | 654/1000 [02:33<01:20,  4.29it/s]
#  66%|██████▌   | 655/1000 [02:33<01:20,  4.28it/s]
#  66%|██████▌   | 656/1000 [02:33<01:20,  4.29it/s]
#  66%|██████▌   | 657/1000 [02:33<01:20,  4.27it/s]
#  66%|██████▌   | 658/1000 [02:34<01:20,  4.27it/s]
#  66%|██████▌   | 659/1000 [02:34<01:19,  4.29it/s]
#  66%|██████▌   | 660/1000 [02:34<01:19,  4.30it/s]
# Epoch 660
# 0.0028141336515545845
# 0.1133977547287941
#  66%|██████▌   | 661/1000 [02:34<01:19,  4.28it/s]
#  66%|██████▌   | 662/1000 [02:34<01:18,  4.29it/s]
#  66%|██████▋   | 663/1000 [02:35<01:18,  4.30it/s]
#  66%|██████▋   | 664/1000 [02:35<01:18,  4.27it/s]
#  66%|██████▋   | 665/1000 [02:35<01:18,  4.28it/s]
#  67%|██████▋   | 666/1000 [02:35<01:18,  4.24it/s]
#  67%|██████▋   | 667/1000 [02:36<01:18,  4.26it/s]
#  67%|██████▋   | 668/1000 [02:36<01:17,  4.28it/s]
#  67%|██████▋   | 669/1000 [02:36<01:17,  4.29it/s]
#  67%|██████▋   | 670/1000 [02:36<01:17,  4.28it/s]
# Epoch 670
# 0.0035483227111399174
# 0.11307135969400406
#  67%|██████▋   | 671/1000 [02:37<01:16,  4.29it/s]
#  67%|██████▋   | 672/1000 [02:37<01:18,  4.19it/s]
#  67%|██████▋   | 673/1000 [02:37<01:17,  4.22it/s]
#  67%|██████▋   | 674/1000 [02:37<01:17,  4.22it/s]
#  68%|██████▊   | 675/1000 [02:38<01:16,  4.25it/s]
#  68%|██████▊   | 676/1000 [02:38<01:15,  4.27it/s]
#  68%|██████▊   | 677/1000 [02:38<01:15,  4.28it/s]
#  68%|██████▊   | 678/1000 [02:38<01:15,  4.28it/s]
#  68%|██████▊   | 679/1000 [02:38<01:14,  4.29it/s]
#  68%|██████▊   | 680/1000 [02:39<01:14,  4.29it/s]
# Epoch 680
# 0.0026436022017151117
# 0.11347520351409912
#  68%|██████▊   | 681/1000 [02:39<01:14,  4.30it/s]
#  68%|██████▊   | 682/1000 [02:39<01:13,  4.30it/s]
#  68%|██████▊   | 683/1000 [02:39<01:14,  4.25it/s]
#  68%|██████▊   | 684/1000 [02:40<01:13,  4.28it/s]
#  68%|██████▊   | 685/1000 [02:40<01:13,  4.29it/s]
#  69%|██████▊   | 686/1000 [02:40<01:12,  4.30it/s]
#  69%|██████▊   | 687/1000 [02:40<01:12,  4.29it/s]
#  69%|██████▉   | 688/1000 [02:41<01:12,  4.31it/s]
#  69%|██████▉   | 689/1000 [02:41<01:12,  4.32it/s]
#  69%|██████▉   | 690/1000 [02:41<01:11,  4.31it/s]
# Epoch 690
# 0.0028242708649486303
# 0.11315377801656723
#  69%|██████▉   | 691/1000 [02:41<01:11,  4.31it/s]
#  69%|██████▉   | 692/1000 [02:41<01:12,  4.27it/s]
#  69%|██████▉   | 693/1000 [02:42<01:11,  4.29it/s]
#  69%|██████▉   | 694/1000 [02:42<01:11,  4.30it/s]
#  70%|██████▉   | 695/1000 [02:42<01:12,  4.19it/s]
#  70%|██████▉   | 696/1000 [02:42<01:11,  4.22it/s]
#  70%|██████▉   | 697/1000 [02:43<01:11,  4.25it/s]
#  70%|██████▉   | 698/1000 [02:43<01:10,  4.28it/s]
#  70%|██████▉   | 699/1000 [02:43<01:10,  4.27it/s]
#  70%|███████   | 700/1000 [02:43<01:10,  4.26it/s]
# Epoch 700
# 0.0022000684402883053
# 0.11318850517272949
#  70%|███████   | 701/1000 [02:44<01:10,  4.27it/s]
#  70%|███████   | 702/1000 [02:44<01:09,  4.27it/s]
#  70%|███████   | 703/1000 [02:44<01:09,  4.28it/s]
#  70%|███████   | 704/1000 [02:44<01:09,  4.29it/s]
#  70%|███████   | 705/1000 [02:45<01:09,  4.22it/s]
#  71%|███████   | 706/1000 [02:45<01:09,  4.25it/s]
#  71%|███████   | 707/1000 [02:45<01:08,  4.28it/s]
#  71%|███████   | 708/1000 [02:45<01:08,  4.29it/s]
#  71%|███████   | 709/1000 [02:45<01:08,  4.25it/s]
#  71%|███████   | 710/1000 [02:46<01:07,  4.27it/s]
# Epoch 710
# 0.0028305272571742535
# 0.11295787245035172
#  71%|███████   | 711/1000 [02:46<01:07,  4.28it/s]
#  71%|███████   | 712/1000 [02:46<01:07,  4.28it/s]
#  71%|███████▏  | 713/1000 [02:46<01:06,  4.29it/s]
#  71%|███████▏  | 714/1000 [02:47<01:06,  4.30it/s]
#  72%|███████▏  | 715/1000 [02:47<01:06,  4.31it/s]
#  72%|███████▏  | 716/1000 [02:47<01:08,  4.16it/s]
#  72%|███████▏  | 717/1000 [02:47<01:08,  4.12it/s]
#  72%|███████▏  | 718/1000 [02:48<01:08,  4.14it/s]
#  72%|███████▏  | 719/1000 [02:48<01:07,  4.19it/s]
#  72%|███████▏  | 720/1000 [02:48<01:06,  4.23it/s]
# Epoch 720
# 0.0026617099065333605
# 0.11299093812704086
#  72%|███████▏  | 721/1000 [02:48<01:05,  4.24it/s]
#  72%|███████▏  | 722/1000 [02:49<01:05,  4.26it/s]
#  72%|███████▏  | 723/1000 [02:49<01:04,  4.28it/s]
#  72%|███████▏  | 724/1000 [02:49<01:04,  4.29it/s]
#  72%|███████▎  | 725/1000 [02:49<01:03,  4.30it/s]
#  73%|███████▎  | 726/1000 [02:49<01:04,  4.25it/s]
#  73%|███████▎  | 727/1000 [02:50<01:03,  4.28it/s]
#  73%|███████▎  | 728/1000 [02:50<01:03,  4.29it/s]
#  73%|███████▎  | 729/1000 [02:50<01:03,  4.29it/s]
#  73%|███████▎  | 730/1000 [02:50<01:03,  4.28it/s]
# Epoch 730
# 0.002185001503676176
# 0.11275664716959
#  73%|███████▎  | 731/1000 [02:51<01:02,  4.28it/s]
#  73%|███████▎  | 732/1000 [02:51<01:02,  4.30it/s]
#  73%|███████▎  | 733/1000 [02:51<01:02,  4.28it/s]
#  73%|███████▎  | 734/1000 [02:51<01:03,  4.21it/s]
#  74%|███████▎  | 735/1000 [02:52<01:02,  4.24it/s]
#  74%|███████▎  | 736/1000 [02:52<01:02,  4.25it/s]
#  74%|███████▎  | 737/1000 [02:52<01:01,  4.27it/s]
#  74%|███████▍  | 738/1000 [02:52<01:01,  4.27it/s]
#  74%|███████▍  | 739/1000 [02:53<01:01,  4.27it/s]
#  74%|███████▍  | 740/1000 [02:53<01:00,  4.28it/s]
# Epoch 740
# 0.002627316163852811
# 0.11316672712564468
#  74%|███████▍  | 741/1000 [02:53<01:00,  4.29it/s]
#  74%|███████▍  | 742/1000 [02:53<01:00,  4.29it/s]
#  74%|███████▍  | 743/1000 [02:53<01:00,  4.25it/s]
#  74%|███████▍  | 744/1000 [02:54<00:59,  4.27it/s]
#  74%|███████▍  | 745/1000 [02:54<00:59,  4.29it/s]
#  75%|███████▍  | 746/1000 [02:54<00:59,  4.27it/s]
#  75%|███████▍  | 747/1000 [02:54<00:59,  4.28it/s]
#  75%|███████▍  | 748/1000 [02:55<00:58,  4.29it/s]
#  75%|███████▍  | 749/1000 [02:55<00:58,  4.30it/s]
#  75%|███████▌  | 750/1000 [02:55<00:58,  4.28it/s]
# Epoch 750
# 0.003182444255799055
# 0.11288746446371078
#  75%|███████▌  | 751/1000 [02:55<00:59,  4.20it/s]
#  75%|███████▌  | 752/1000 [02:56<00:58,  4.23it/s]
#  75%|███████▌  | 753/1000 [02:56<00:58,  4.26it/s]
#  75%|███████▌  | 754/1000 [02:56<00:57,  4.27it/s]
#  76%|███████▌  | 755/1000 [02:56<00:57,  4.27it/s]
#  76%|███████▌  | 756/1000 [02:57<00:57,  4.28it/s]
#  76%|███████▌  | 757/1000 [02:57<00:57,  4.22it/s]
#  76%|███████▌  | 758/1000 [02:57<00:56,  4.25it/s]
#  76%|███████▌  | 759/1000 [02:57<00:56,  4.27it/s]
#  76%|███████▌  | 760/1000 [02:57<00:56,  4.23it/s]
# Epoch 760
# 0.002614842727780342
# 0.11263561248779297
#  76%|███████▌  | 761/1000 [02:58<00:56,  4.25it/s]
#  76%|███████▌  | 762/1000 [02:58<00:55,  4.27it/s]
#  76%|███████▋  | 763/1000 [02:58<00:55,  4.28it/s]
#  76%|███████▋  | 764/1000 [02:58<00:55,  4.24it/s]
#  76%|███████▋  | 765/1000 [02:59<00:55,  4.26it/s]
#  77%|███████▋  | 766/1000 [02:59<00:54,  4.27it/s]
#  77%|███████▋  | 767/1000 [02:59<00:54,  4.26it/s]
#  77%|███████▋  | 768/1000 [02:59<00:54,  4.24it/s]
#  77%|███████▋  | 769/1000 [03:00<00:54,  4.24it/s]
#  77%|███████▋  | 770/1000 [03:00<00:54,  4.26it/s]
# Epoch 770
# 0.0024004268925637007
# 0.11339680105447769
#  77%|███████▋  | 771/1000 [03:00<00:53,  4.27it/s]
#  77%|███████▋  | 772/1000 [03:00<00:53,  4.28it/s]
#  77%|███████▋  | 773/1000 [03:01<00:53,  4.26it/s]
#  77%|███████▋  | 774/1000 [03:01<00:54,  4.18it/s]
#  78%|███████▊  | 775/1000 [03:01<00:53,  4.20it/s]
#  78%|███████▊  | 776/1000 [03:01<00:53,  4.20it/s]
#  78%|███████▊  | 777/1000 [03:01<00:53,  4.19it/s]
#  78%|███████▊  | 778/1000 [03:02<00:52,  4.20it/s]
#  78%|███████▊  | 779/1000 [03:02<00:52,  4.24it/s]
#  78%|███████▊  | 780/1000 [03:02<00:51,  4.23it/s]
# Epoch 780
# 0.002003233414143324
# 0.1128888949751854
#  78%|███████▊  | 781/1000 [03:02<00:51,  4.25it/s]
#  78%|███████▊  | 782/1000 [03:03<00:50,  4.28it/s]
#  78%|███████▊  | 783/1000 [03:03<00:50,  4.30it/s]
#  78%|███████▊  | 784/1000 [03:03<00:50,  4.29it/s]
#  78%|███████▊  | 785/1000 [03:03<00:50,  4.26it/s]
#  79%|███████▊  | 786/1000 [03:04<00:50,  4.27it/s]
#  79%|███████▊  | 787/1000 [03:04<00:49,  4.29it/s]
#  79%|███████▉  | 788/1000 [03:04<00:49,  4.31it/s]
#  79%|███████▉  | 789/1000 [03:04<00:48,  4.31it/s]
#  79%|███████▉  | 790/1000 [03:05<00:48,  4.30it/s]
# Epoch 790
# 0.0024073831737041473
# 0.1129930391907692
#  79%|███████▉  | 791/1000 [03:05<00:48,  4.30it/s]
#  79%|███████▉  | 792/1000 [03:05<00:48,  4.31it/s]
#  79%|███████▉  | 793/1000 [03:05<00:47,  4.31it/s]
#  79%|███████▉  | 794/1000 [03:05<00:48,  4.25it/s]
#  80%|███████▉  | 795/1000 [03:06<00:47,  4.27it/s]
#  80%|███████▉  | 796/1000 [03:06<00:47,  4.29it/s]
#  80%|███████▉  | 797/1000 [03:06<00:47,  4.30it/s]
#  80%|███████▉  | 798/1000 [03:06<00:48,  4.19it/s]
#  80%|███████▉  | 799/1000 [03:07<00:47,  4.23it/s]
#  80%|████████  | 800/1000 [03:07<00:46,  4.26it/s]
# Epoch 800
# 0.002601224696263671
# 0.11302026361227036
#  80%|████████  | 801/1000 [03:07<00:46,  4.24it/s]
#  80%|████████  | 802/1000 [03:07<00:46,  4.22it/s]
#  80%|████████  | 803/1000 [03:08<00:46,  4.25it/s]
#  80%|████████  | 804/1000 [03:08<00:45,  4.27it/s]
#  80%|████████  | 805/1000 [03:08<00:45,  4.26it/s]
#  81%|████████  | 806/1000 [03:08<00:45,  4.25it/s]
#  81%|████████  | 807/1000 [03:08<00:45,  4.28it/s]
#  81%|████████  | 808/1000 [03:09<00:44,  4.29it/s]
#  81%|████████  | 809/1000 [03:09<00:44,  4.29it/s]
#  81%|████████  | 810/1000 [03:09<00:44,  4.29it/s]
# Epoch 810
# 0.001954777631908655
# 0.11296931654214859
#  81%|████████  | 811/1000 [03:09<00:44,  4.27it/s]
#  81%|████████  | 812/1000 [03:10<00:43,  4.29it/s]
#  81%|████████▏ | 813/1000 [03:10<00:43,  4.29it/s]
#  81%|████████▏ | 814/1000 [03:10<00:43,  4.30it/s]
#  82%|████████▏ | 815/1000 [03:10<00:42,  4.31it/s]
#  82%|████████▏ | 816/1000 [03:11<00:42,  4.30it/s]
#  82%|████████▏ | 817/1000 [03:11<00:42,  4.31it/s]
#  82%|████████▏ | 818/1000 [03:11<00:42,  4.28it/s]
#  82%|████████▏ | 819/1000 [03:11<00:42,  4.26it/s]
#  82%|████████▏ | 820/1000 [03:12<00:42,  4.27it/s]
# Epoch 820
# 0.0019309492781758308
# 0.11295203119516373
#  82%|████████▏ | 821/1000 [03:12<00:41,  4.28it/s]
#  82%|████████▏ | 822/1000 [03:12<00:41,  4.28it/s]
#  82%|████████▏ | 823/1000 [03:12<00:41,  4.27it/s]
#  82%|████████▏ | 824/1000 [03:12<00:41,  4.28it/s]
#  82%|████████▎ | 825/1000 [03:13<00:40,  4.28it/s]
#  83%|████████▎ | 826/1000 [03:13<00:40,  4.29it/s]
#  83%|████████▎ | 827/1000 [03:13<00:40,  4.28it/s]
#  83%|████████▎ | 828/1000 [03:13<00:40,  4.25it/s]
#  83%|████████▎ | 829/1000 [03:14<00:40,  4.27it/s]
#  83%|████████▎ | 830/1000 [03:14<00:39,  4.26it/s]
# Epoch 830
# 0.00204392964951694
# 0.11310871690511703
#  83%|████████▎ | 831/1000 [03:14<00:39,  4.26it/s]
#  83%|████████▎ | 832/1000 [03:14<00:40,  4.19it/s]
#  83%|████████▎ | 833/1000 [03:15<00:39,  4.22it/s]
#  83%|████████▎ | 834/1000 [03:15<00:39,  4.25it/s]
#  84%|████████▎ | 835/1000 [03:15<00:38,  4.27it/s]
#  84%|████████▎ | 836/1000 [03:15<00:38,  4.23it/s]
#  84%|████████▎ | 837/1000 [03:16<00:38,  4.26it/s]
#  84%|████████▍ | 838/1000 [03:16<00:37,  4.28it/s]
#  84%|████████▍ | 839/1000 [03:16<00:37,  4.25it/s]
#  84%|████████▍ | 840/1000 [03:16<00:37,  4.22it/s]
# Epoch 840
# 0.002007489325478673
# 0.11282694339752197
#  84%|████████▍ | 841/1000 [03:16<00:37,  4.25it/s]
#  84%|████████▍ | 842/1000 [03:17<00:36,  4.27it/s]
#  84%|████████▍ | 843/1000 [03:17<00:36,  4.28it/s]
#  84%|████████▍ | 844/1000 [03:17<00:36,  4.29it/s]
#  84%|████████▍ | 845/1000 [03:17<00:36,  4.25it/s]
#  85%|████████▍ | 846/1000 [03:18<00:36,  4.26it/s]
#  85%|████████▍ | 847/1000 [03:18<00:35,  4.28it/s]
#  85%|████████▍ | 848/1000 [03:18<00:35,  4.29it/s]
#  85%|████████▍ | 849/1000 [03:18<00:35,  4.25it/s]
#  85%|████████▌ | 850/1000 [03:19<00:35,  4.23it/s]
# Epoch 850
# 0.0023131552152335644
# 0.11305391788482666
#  85%|████████▌ | 851/1000 [03:19<00:35,  4.25it/s]
#  85%|████████▌ | 852/1000 [03:19<00:34,  4.28it/s]
#  85%|████████▌ | 853/1000 [03:19<00:34,  4.26it/s]
#  85%|████████▌ | 854/1000 [03:20<00:34,  4.25it/s]
#  86%|████████▌ | 855/1000 [03:20<00:33,  4.28it/s]
#  86%|████████▌ | 856/1000 [03:20<00:33,  4.29it/s]
#  86%|████████▌ | 857/1000 [03:20<00:33,  4.29it/s]
#  86%|████████▌ | 858/1000 [03:20<00:33,  4.30it/s]
#  86%|████████▌ | 859/1000 [03:21<00:32,  4.31it/s]
#  86%|████████▌ | 860/1000 [03:21<00:32,  4.31it/s]
# Epoch 860
# 0.00204093917272985
# 0.11303266137838364
#  86%|████████▌ | 861/1000 [03:21<00:32,  4.29it/s]
#  86%|████████▌ | 862/1000 [03:21<00:32,  4.27it/s]
#  86%|████████▋ | 863/1000 [03:22<00:31,  4.29it/s]
#  86%|████████▋ | 864/1000 [03:22<00:31,  4.27it/s]
#  86%|████████▋ | 865/1000 [03:22<00:31,  4.29it/s]
#  87%|████████▋ | 866/1000 [03:22<00:32,  4.07it/s]
#  87%|████████▋ | 867/1000 [03:23<00:32,  4.15it/s]
#  87%|████████▋ | 868/1000 [03:23<00:31,  4.20it/s]
#  87%|████████▋ | 869/1000 [03:23<00:30,  4.24it/s]
#  87%|████████▋ | 870/1000 [03:23<00:31,  4.15it/s]
# Epoch 870
# 0.0018314255867153406
# 0.11264284700155258
#  87%|████████▋ | 871/1000 [03:24<00:31,  4.16it/s]
#  87%|████████▋ | 872/1000 [03:24<00:30,  4.21it/s]
#  87%|████████▋ | 873/1000 [03:24<00:30,  4.20it/s]
#  87%|████████▋ | 874/1000 [03:24<00:29,  4.22it/s]
#  88%|████████▊ | 875/1000 [03:24<00:29,  4.25it/s]
#  88%|████████▊ | 876/1000 [03:25<00:29,  4.27it/s]
#  88%|████████▊ | 877/1000 [03:25<00:28,  4.27it/s]
#  88%|████████▊ | 878/1000 [03:25<00:28,  4.28it/s]
#  88%|████████▊ | 879/1000 [03:25<00:28,  4.18it/s]
#  88%|████████▊ | 880/1000 [03:26<00:28,  4.18it/s]
# Epoch 880
# 0.0018931450322270393
# 0.11264554411172867
#  88%|████████▊ | 881/1000 [03:26<00:28,  4.21it/s]
#  88%|████████▊ | 882/1000 [03:26<00:28,  4.21it/s]
#  88%|████████▊ | 883/1000 [03:26<00:27,  4.21it/s]
#  88%|████████▊ | 884/1000 [03:27<00:27,  4.23it/s]
#  88%|████████▊ | 885/1000 [03:27<00:27,  4.26it/s]
#  89%|████████▊ | 886/1000 [03:27<00:26,  4.28it/s]
#  89%|████████▊ | 887/1000 [03:27<00:26,  4.26it/s]
#  89%|████████▉ | 888/1000 [03:28<00:27,  4.14it/s]
#  89%|████████▉ | 889/1000 [03:28<00:26,  4.20it/s]
#  89%|████████▉ | 890/1000 [03:28<00:25,  4.23it/s]
# Epoch 890
# 0.0020004184916615486
# 0.11277774721384048
#  89%|████████▉ | 891/1000 [03:28<00:25,  4.25it/s]
#  89%|████████▉ | 892/1000 [03:28<00:25,  4.24it/s]
#  89%|████████▉ | 893/1000 [03:29<00:25,  4.27it/s]
#  89%|████████▉ | 894/1000 [03:29<00:24,  4.29it/s]
#  90%|████████▉ | 895/1000 [03:29<00:24,  4.27it/s]
#  90%|████████▉ | 896/1000 [03:29<00:24,  4.25it/s]
#  90%|████████▉ | 897/1000 [03:30<00:24,  4.27it/s]
#  90%|████████▉ | 898/1000 [03:30<00:23,  4.27it/s]
#  90%|████████▉ | 899/1000 [03:30<00:23,  4.24it/s]
#  90%|█████████ | 900/1000 [03:30<00:23,  4.24it/s]
# Epoch 900
# 0.001821181969717145
# 0.11280425637960434
#  90%|█████████ | 901/1000 [03:31<00:23,  4.26it/s]
#  90%|█████████ | 902/1000 [03:31<00:22,  4.28it/s]
#  90%|█████████ | 903/1000 [03:31<00:23,  4.19it/s]
#  90%|█████████ | 904/1000 [03:31<00:22,  4.20it/s]
#  90%|█████████ | 905/1000 [03:32<00:22,  4.24it/s]
#  91%|█████████ | 906/1000 [03:32<00:22,  4.26it/s]
#  91%|█████████ | 907/1000 [03:32<00:21,  4.29it/s]
#  91%|█████████ | 908/1000 [03:32<00:21,  4.28it/s]
#  91%|█████████ | 909/1000 [03:32<00:21,  4.27it/s]
#  91%|█████████ | 910/1000 [03:33<00:21,  4.28it/s]
# Epoch 910
# 0.0016023269854485989
# 0.11300543695688248
#  91%|█████████ | 911/1000 [03:33<00:20,  4.29it/s]
#  91%|█████████ | 912/1000 [03:33<00:20,  4.27it/s]
#  91%|█████████▏| 913/1000 [03:33<00:20,  4.25it/s]
#  91%|█████████▏| 914/1000 [03:34<00:20,  4.22it/s]
#  92%|█████████▏| 915/1000 [03:34<00:19,  4.26it/s]
#  92%|█████████▏| 916/1000 [03:34<00:19,  4.28it/s]
#  92%|█████████▏| 917/1000 [03:34<00:19,  4.28it/s]
#  92%|█████████▏| 918/1000 [03:35<00:19,  4.30it/s]
#  92%|█████████▏| 919/1000 [03:35<00:18,  4.31it/s]
#  92%|█████████▏| 920/1000 [03:35<00:18,  4.26it/s]
# Epoch 920
# 0.001372483093291521
# 0.11261896044015884
#  92%|█████████▏| 921/1000 [03:35<00:18,  4.23it/s]
#  92%|█████████▏| 922/1000 [03:36<00:18,  4.25it/s]
#  92%|█████████▏| 923/1000 [03:36<00:18,  4.20it/s]
#  92%|█████████▏| 924/1000 [03:36<00:18,  4.22it/s]
#  92%|█████████▎| 925/1000 [03:36<00:17,  4.25it/s]
#  93%|█████████▎| 926/1000 [03:36<00:17,  4.26it/s]
#  93%|█████████▎| 927/1000 [03:37<00:17,  4.28it/s]
#  93%|█████████▎| 928/1000 [03:37<00:16,  4.29it/s]
#  93%|█████████▎| 929/1000 [03:37<00:16,  4.28it/s]
#  93%|█████████▎| 930/1000 [03:37<00:16,  4.25it/s]
# Epoch 930
# 0.001856592483818531
# 0.11282352358102798
#  93%|█████████▎| 931/1000 [03:38<00:16,  4.25it/s]
#  93%|█████████▎| 932/1000 [03:38<00:15,  4.26it/s]
#  93%|█████████▎| 933/1000 [03:38<00:15,  4.28it/s]
#  93%|█████████▎| 934/1000 [03:38<00:15,  4.29it/s]
#  94%|█████████▎| 935/1000 [03:39<00:15,  4.28it/s]
#  94%|█████████▎| 936/1000 [03:39<00:14,  4.29it/s]
#  94%|█████████▎| 937/1000 [03:39<00:14,  4.30it/s]
#  94%|█████████▍| 938/1000 [03:39<00:14,  4.29it/s]
#  94%|█████████▍| 939/1000 [03:40<00:14,  4.26it/s]
#  94%|█████████▍| 940/1000 [03:40<00:14,  4.28it/s]
# Epoch 940
# 0.0014723963104188442
# 0.11270749568939209
#  94%|█████████▍| 941/1000 [03:40<00:13,  4.29it/s]
#  94%|█████████▍| 942/1000 [03:40<00:13,  4.25it/s]
#  94%|█████████▍| 943/1000 [03:40<00:13,  4.27it/s]
#  94%|█████████▍| 944/1000 [03:41<00:13,  4.28it/s]
#  94%|█████████▍| 945/1000 [03:41<00:12,  4.29it/s]
#  95%|█████████▍| 946/1000 [03:41<00:12,  4.28it/s]
#  95%|█████████▍| 947/1000 [03:41<00:12,  4.26it/s]
#  95%|█████████▍| 948/1000 [03:42<00:12,  4.26it/s]
#  95%|█████████▍| 949/1000 [03:42<00:11,  4.28it/s]
#  95%|█████████▌| 950/1000 [03:42<00:11,  4.29it/s]
# Epoch 950
# 0.002167454920709133
# 0.1127767562866211
#  95%|█████████▌| 951/1000 [03:42<00:11,  4.29it/s]
#  95%|█████████▌| 952/1000 [03:43<00:11,  4.24it/s]
#  95%|█████████▌| 953/1000 [03:43<00:11,  4.27it/s]
#  95%|█████████▌| 954/1000 [03:43<00:10,  4.29it/s]
#  96%|█████████▌| 955/1000 [03:43<00:10,  4.28it/s]
#  96%|█████████▌| 956/1000 [03:43<00:10,  4.24it/s]
#  96%|█████████▌| 957/1000 [03:44<00:10,  4.23it/s]
#  96%|█████████▌| 958/1000 [03:44<00:09,  4.24it/s]
#  96%|█████████▌| 959/1000 [03:44<00:09,  4.25it/s]
#  96%|█████████▌| 960/1000 [03:44<00:09,  4.27it/s]
# Epoch 960
# 0.0014333534054458141
# 0.11265464872121811
#  96%|█████████▌| 961/1000 [03:45<00:09,  4.28it/s]
#  96%|█████████▌| 962/1000 [03:45<00:08,  4.26it/s]
#  96%|█████████▋| 963/1000 [03:45<00:08,  4.28it/s]
#  96%|█████████▋| 964/1000 [03:45<00:08,  4.25it/s]
#  96%|█████████▋| 965/1000 [03:46<00:08,  4.26it/s]
#  97%|█████████▋| 966/1000 [03:46<00:07,  4.28it/s]
#  97%|█████████▋| 967/1000 [03:46<00:07,  4.29it/s]
#  97%|█████████▋| 968/1000 [03:46<00:07,  4.30it/s]
#  97%|█████████▋| 969/1000 [03:47<00:07,  4.29it/s]
#  97%|█████████▋| 970/1000 [03:47<00:06,  4.30it/s]
# Epoch 970
# 0.0015277336351573467
# 0.11295577138662338
#  97%|█████████▋| 971/1000 [03:47<00:06,  4.30it/s]
#  97%|█████████▋| 972/1000 [03:47<00:06,  4.02it/s]
#  97%|█████████▋| 973/1000 [03:48<00:06,  4.02it/s]
#  97%|█████████▋| 974/1000 [03:48<00:06,  4.06it/s]
#  98%|█████████▊| 975/1000 [03:48<00:06,  4.12it/s]
#  98%|█████████▊| 976/1000 [03:48<00:05,  4.18it/s]
#  98%|█████████▊| 977/1000 [03:48<00:05,  4.18it/s]
#  98%|█████████▊| 978/1000 [03:49<00:05,  4.19it/s]
#  98%|█████████▊| 979/1000 [03:49<00:04,  4.20it/s]
#  98%|█████████▊| 980/1000 [03:49<00:04,  4.15it/s]
# Epoch 980
# 0.0016366331838071346
# 0.11269032955169678
#  98%|█████████▊| 981/1000 [03:49<00:04,  4.17it/s]
#  98%|█████████▊| 982/1000 [03:50<00:04,  4.22it/s]
#  98%|█████████▊| 983/1000 [03:50<00:04,  4.22it/s]
#  98%|█████████▊| 984/1000 [03:50<00:03,  4.24it/s]
#  98%|█████████▊| 985/1000 [03:50<00:03,  4.26it/s]
#  99%|█████████▊| 986/1000 [03:51<00:03,  4.27it/s]
#  99%|█████████▊| 987/1000 [03:51<00:03,  4.29it/s]
#  99%|█████████▉| 988/1000 [03:51<00:02,  4.30it/s]
#  99%|█████████▉| 989/1000 [03:51<00:02,  4.23it/s]
#  99%|█████████▉| 990/1000 [03:52<00:02,  4.17it/s]
# Epoch 990
# 0.0013606364373117685
# 0.11238595098257065
#  99%|█████████▉| 991/1000 [03:52<00:02,  4.21it/s]
#  99%|█████████▉| 992/1000 [03:52<00:01,  4.24it/s]
#  99%|█████████▉| 993/1000 [03:52<00:01,  4.26it/s]
#  99%|█████████▉| 994/1000 [03:52<00:01,  4.27it/s]
# 100%|█████████▉| 995/1000 [03:53<00:01,  4.27it/s]
# 100%|█████████▉| 996/1000 [03:53<00:00,  4.28it/s]
# 100%|█████████▉| 997/1000 [03:53<00:00,  4.28it/s]
# 100%|█████████▉| 998/1000 [03:53<00:00,  4.23it/s]
# 100%|█████████▉| 999/1000 [03:54<00:00,  4.20it/s]
# 100%|██████████| 1000/1000 [03:54<00:00,  4.27it/s]
# Epoch 1000
# 0.0012381593696773052
# 0.11292680352926254
# Best epoch = 976
# Best loss = 0.05730448663234711
# Fit loss = 0.0010667908936738968
# Fit losses = {}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-30d8563f320e> in <module>
#     246 for lamb in lambs:
#     247     print("lamb={}".format(lamb))
# --> 248     loss, fit_best, reg_best = train(nets, f_z, z, lr=1e-3, epochs=1000)
#     249     best_losses.append(fit_best)
#     250     best_regs.append(reg_best)
#
# <ipython-input-7-30d8563f320e> in train(nets, f_z, z, lr, epochs, bs, es_delta, epoch_loss, max_loss_divergence, weight_decay, weight_decay_decay, model)
#     233     print("Fit loss = {}".format(fit_loss_best))
#     234     print("Fit losses = {}")
# --> 235     print(fit_losses)
#     236     df = po.DataFrame()
#     237     df['losses'] = losses
#
# NameError: name 'fit_losses' is not defined

# %%
plt.plot(lambs, best_losses, marker="o")
plt.plot(lambs, best_regs, marker="o")
plt.xscale('log')
plt.yscale('log')
plt.xlabel(r'$\lambda$',fontsize=15)
plt.ylabel('MSE Loss', fontsize=15)
plt.ylim(-0.01,1.5)
# Out:
# /home/luke/anaconda3/envs/zimingenv/lib/python3.6/site-packages/ipykernel_launcher.py:7: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   import sys
# (5.757693509720421e-08, 1.5)

# %%
np.save('./results/lambda_search_2dho_1.npy', np.array([lambs, best_losses, best_regs]))

# %%
plt.figure(figsize=(12,4))

plt.subplot(1,2,1)

data = np.load('./results/lambda_search_2dho_1.npy')
lambs = data[0]
best_losses = data[1]
best_regs = data[2]

plt.plot(lambs, best_losses, marker="o")
plt.plot(lambs, best_regs, marker="o")
plt.xscale('log')
#plt.yscale('log')
plt.xlabel(r'$\lambda$',fontsize=15)
plt.ylabel('Loss', fontsize=15)
plt.legend([r"$\ell_1$", r"$\ell_2$"], fontsize=15, loc="upper right")
plt.ylim(-0.01,0.4)
plt.title(r"$(\omega_x,\omega_y)=(1,1)$", fontsize=15)


plt.subplot(1,2,2)

data = np.load('./results/lambda_search_2dho_sqrt2.npy')
lambs = data[0]
best_losses = data[1]
best_regs = data[2]

plt.plot(lambs, best_losses, marker="o")
plt.plot(lambs, best_regs, marker="o")
plt.xscale('log')
#plt.yscale('log')
plt.xlabel(r'$\lambda$',fontsize=15)
plt.ylabel('Loss', fontsize=15)
#plt.legend([r"$\ell_1$", r"$\ell_2$"], fontsize=15, loc="upper right")
plt.ylim(-0.01,0.4)
plt.title(r"$(\omega_x,\omega_y)=(1,\sqrt{2})$", fontsize=15)
plt.savefig('./2d_ho_lamb_pt.pdf', bbox_inches="tight")
